# %% [markdown]
# ___

# %%
# Import libraries to be used

# Warning messages display
# import warnings
# warnings.filterwarnings(action='once') # https://docs.python.org/3/library/warnings.html#the-warnings-filter

# Directories/Files management
import os.path
## from zipfile import ZipFile # De momento no ha hecho falta 

# Timing
import time

# Data analysis and wrangling
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) # Show all columns in DataFrames
pd.set_option('display.max_rows', 100) # If too high, it greatly slows down the output display and freezes the kernel


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot') # choose a style: 'plt.style.available'
sns.set_theme(context='notebook',
              style="darkgrid") # {darkgrid, whitegrid, dark, white, ticks}
palette = sns.color_palette("flare", as_cmap=True);
import altair as alt

# Machine Learning
## from sklearn.[...] import ...

# %%
# %load_ext memory_profiler

# %%
t0 = time.perf_counter()

# %%
# Detect Operating System running and manage paths accordingly

if os.name == 'nt': # Windows
    root = r"C:\Users\turge\CompartidoVM\0.TFM"
    print("Running on Windows.")
elif os.name == 'posix': # Ubuntu
    root = "/home/dsc/shared/0.TFM"
    print("Running on Ubuntu.")
print("root path\t", root)
# Out:
# Running on Windows.
# root path	 C:\Users\turge\CompartidoVM\0.TFM

# %% [markdown]
# ___

# %% [markdown]
# ## 1. Load the dataset

# %%
cols = [
     'MONTH',
     'DAY_OF_MONTH',
     'DAY_OF_WEEK',
     'OP_UNIQUE_CARRIER',
# For the time being, 'TAIL_NUM' will be disregarded due to its high cardinality  (~ 4500) and low expected added value    
#      'TAIL_NUM',
#      'ORIGIN', # Let's skip this feature to prevent high cardinality and check if it's relevant or not
#      'DEST', # Let's skip this feature to prevent high cardinality and check if it's relevant or not
#      'CRS_DEP_TIME', # Redundant having the 'DEP_ARR_hour' feature
     'DEP_TIME_hour',
#      'DEP_TIME',
#      'DEP_DELAY',
#      'DEP_DEL15',
#      'TAXI_OUT',
     'TAXI_OUT_median',
#      'TAXI_IN',
     'TAXI_IN_median',
#      'CRS_ARR_TIME', # Redundant having the 'ARR_ARR_hour' feature
     'ARR_TIME_hour', 
#      'ARR_TIME',   
#      'ARR_DELAY',
     'ARR_DEL15', # → Target !!
#      'CANCELLED',
     'CRS_ELAPSED_TIME',
     'DISTANCE',
     'DISTANCE_GROUP',
#      'CARRIER_DELAY',
#      'WEATHER_DELAY',
#      'NAS_DELAY',
#      'SECURITY_DELAY',
#      'LATE_AIRCRAFT_DELAY',
]

# %%
preprocessed_input_csv_path = os.path.join(root,
                                           "Output_Data",
                                           "US_DoT",
                                           "AL_OTP_MVP_Preprocessed_19_v2_clean.csv")
preprocessed_input_csv_path
# Out:
# 'C:\\Users\\turge\\CompartidoVM\\0.TFM\\Output_Data\\US_DoT\\AL_OTP_MVP_Preprocessed_19_v2_clean.csv'

# %%
cols_dtypes = {
               'MONTH' : 'category',
               'DAY_OF_MONTH' : 'category',
               'DAY_OF_WEEK' : 'category',
               'OP_UNIQUE_CARRIER' : 'category',
#                'ORIGIN' : 'category',
#                'DEST' : 'category',
               'DEP_TIME_hour' : 'category',
               'TAXI_OUT_median' : 'int64',
               'TAXI_IN_median' : 'int64',
               'ARR_TIME_hour' : 'category', 
               'ARR_DEL15' : 'int32', # → Target !!
               'CRS_ELAPSED_TIME' : 'int64',
               'DISTANCE' : 'int64',
               'DISTANCE_GROUP' : 'category'
               }

# %%
# %%time

df_all = pd.read_csv(preprocessed_input_csv_path,
                     encoding='latin1',
                     usecols=cols,
                     low_memory = False)
# Out:
# Wall time: 24.9 s

# %%
# Cast types in accordance to previously defined dictionary:
df_all = df_all.astype(cols_dtypes)
# Display DF columns according to 'cols' order:
df_all = df_all[cols]
df_all
# Out:
#         MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER DEP_TIME_hour  \
# 0           1            3           4                9E            11
# 1           1            4           5                9E            11
# 2           1            5           6                9E             9
# 3           1            6           7                9E             9
# 4           1            7           1                9E             9
# ...       ...          ...         ...               ...           ...
# 7268227    12           31           2                B6            13
# 7268228    12           31           2                B6            14
# 7268229    12           31           2                B6             7
# 7268230    12           31           2                B6             8
# 7268231    12           31           2                B6             0
#
#          TAXI_OUT_median  TAXI_IN_median ARR_TIME_hour  ARR_DEL15  \
# 0                     15               8            12          1
# 1                     15               8            12          1
# 2                     17               5            10          0
# 3                     17               5            10          0
# 4                     17               5            10          0
# ...                  ...             ...           ...        ...
# 7268227               15               6            16          1
# 7268228               15               6            15          0
# 7268229               17               6             8          0
# 7268230               16               5            13          0
# 7268231               11               6             7          0
#
#          CRS_ELAPSED_TIME  DISTANCE DISTANCE_GROUP
# 0                      70       152              1
# 1                      70       152              1
# 2                     121       563              3
# 3                     123       563              3
# 4                     123       563              3
# ...                   ...       ...            ...
# 7268227               163       989              4
# 7268228                90       399              2
# 7268229                85       280              2
# 7268230               242      1674              7
# 7268231               249      1674              7
#
# [7268232 rows x 12 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7268232 entries, 0 to 7268231
# Data columns (total 12 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   MONTH              category
#  1   DAY_OF_MONTH       category
#  2   DAY_OF_WEEK        category
#  3   OP_UNIQUE_CARRIER  category
#  4   DEP_TIME_hour      category
#  5   TAXI_OUT_median    int64
#  6   TAXI_IN_median     int64
#  7   ARR_TIME_hour      category
#  8   ARR_DEL15          int32
#  9   CRS_ELAPSED_TIME   int64
#  10  DISTANCE           int64
#  11  DISTANCE_GROUP     category
# dtypes: category(7), int32(1), int64(4)
# memory usage: 298.1 MB

# %%
# from pandas_profiling import ProfileReport

# # # Complete report:
# # prof = ProfileReport(df_all)
# # prof.to_file('informe.html')

# # Sample report (more computationally efficient)
# prof = ProfileReport(df_all.sample(10000)) 
# prof.to_file('sample_report.html')

# %%
# from pandas_profiling import ProfileReport

# # Complete report:
# prof = ProfileReport(df_all, minimal=True)
# prof.to_file('complete_report.html')

# # # Sample report (more computationally efficient)
# # prof = ProfileReport(df_all.sample(10000)) 
# # prof.to_file('sample_report.html')

# %% [markdown]
# ## 2. Dataset overview

# %%
# For the initial runs, define a reasonably-sized sample:
sample_length = int(1e6)

# The dataset is somehow imbalanced (80% on-time / 20% delayed), so let's perform some quick undersampling:
delayed = df_all[df_all['ARR_DEL15'] == 1].sample(sample_length // 2)
ontime = df_all[df_all['ARR_DEL15'] == 0].sample(sample_length // 2)
df = delayed.append(ontime)

# Get dummies for the categorical features:
df = pd.get_dummies(df)

print("On-time flights: {:7d} ({:5.2f}%)".format(len(ontime), 100*len(ontime)/len(df)))
print("Delayed flights: {:7d} ({:5.2f}%)".format(len(delayed), 100*len(delayed)/len(df)))
# Out:
# On-time flights:  500000 (50.00%)
# Delayed flights:  500000 (50.00%)

# %% [markdown]
# ### Train / Test / Validation split
# Break the dataset into three blocks:
# 1. Training (70%)
# 2. Test (15%)
# 3. Validation (15%)

# %%
# Divide the data:
train = df.sample(frac=0.7)
test_valid = df.drop(train.index)
test = test_valid.sample(frac=0.5)
valid = test_valid.drop(test.index)

print("Total dataset:      {:7d} ({:6.2f}%)".format(len(df), 100*len(df)/len(df)))
print("Training dataset:   {:7d} ( {:5.2f}%)".format(len(train), 100*len(train)/len(df)))
print("Test dataset:       {:7d} ( {:5.2f}%)".format(len(test), 100*len(test)/len(df)))
print("Validation dataset: {:7d} ( {:5.2f}%)".format(len(valid), 100*len(valid)/len(df)))
# Out:
# Total dataset:      1000000 (100.00%)
# Training dataset:    700000 ( 70.00%)
# Test dataset:        150000 ( 15.00%)
# Validation dataset:  150000 ( 15.00%)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
# Train / Test partition:
X_train, y_train = train.drop("ARR_DEL15", axis=1), train["ARR_DEL15"]
X_test, y_test = test.drop("ARR_DEL15", axis=1), test["ARR_DEL15"]

# Validation:
X_valid, y_valid = valid.drop("ARR_DEL15", axis=1), valid["ARR_DEL15"]

# %%
# Basic model definition:
xgb_model = XGBClassifier(use_label_encoder=False, verbosity=1, random_state=0,
                          n_estimators=300,
                          max_depth= 4,
                          learning_rate=0.0001,
                          objective= 'binary:logistic',
                          booster='gbtree',
                          tree_method='auto')

# %% [markdown]
# ## Training

# %%
xgb_model.fit(X_train, y_train,
              eval_set=[(X_train, y_train), (X_test, y_test), (X_valid, y_valid)],
              eval_metric='auc',
              verbose=True)
# Out:
# [0]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [1]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [2]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [3]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [4]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [5]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [6]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [7]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [8]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [9]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [10]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [11]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [12]	validation_0-auc:0.56116	validation_1-auc:0.56021	validation_2-auc:0.56232
# [13]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [14]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [15]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [16]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [17]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [18]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [19]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [20]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [21]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [22]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [23]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [24]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [25]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [26]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [27]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [28]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [29]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [30]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [31]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [32]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [33]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [34]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [35]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [36]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [37]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [38]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [39]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [40]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [41]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [42]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [43]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [44]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [45]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [46]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [47]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [48]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [49]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [50]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [51]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [52]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [53]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [54]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [55]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [56]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [57]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [58]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [59]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [60]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [61]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [62]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [63]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [64]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [65]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [66]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [67]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [68]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [69]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [70]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [71]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [72]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [73]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [74]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [75]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [76]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [77]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [78]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [79]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [80]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [81]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [82]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [83]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [84]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [85]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [86]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [87]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [88]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [89]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [90]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [91]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [92]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [93]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [94]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [95]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [96]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [97]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [98]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [99]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [100]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [101]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [102]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [103]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [104]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [105]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [106]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [107]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [108]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [109]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [110]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [111]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [112]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [113]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [114]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [115]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [116]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [117]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [118]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [119]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [120]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [121]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [122]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [123]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [124]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [125]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [126]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [127]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [128]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [129]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [130]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [131]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [132]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [133]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [134]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [135]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [136]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [137]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [138]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [139]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [140]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [141]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [142]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [143]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [144]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [145]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [146]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [147]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [148]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [149]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [150]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [151]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [152]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [153]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [154]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [155]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [156]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [157]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [158]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [159]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [160]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [161]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [162]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [163]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [164]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [165]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [166]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [167]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [168]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [169]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [170]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [171]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [172]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [173]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [174]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [175]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [176]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [177]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [178]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [179]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [180]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [181]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [182]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [183]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [184]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [185]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [186]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [187]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [188]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [189]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [190]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [191]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [192]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [193]	validation_0-auc:0.56117	validation_1-auc:0.56021	validation_2-auc:0.56232
# [194]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [195]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [196]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [197]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [198]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [199]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [200]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [201]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [202]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [203]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [204]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [205]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [206]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [207]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [208]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [209]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [210]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [211]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [212]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [213]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [214]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [215]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [216]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [217]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [218]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [219]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [220]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [221]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [222]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [223]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [224]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [225]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [226]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [227]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [228]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [229]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [230]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [231]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [232]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [233]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [234]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [235]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [236]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [237]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [238]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [239]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [240]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [241]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [242]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [243]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [244]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [245]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [246]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [247]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [248]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [249]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [250]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [251]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [252]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [253]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [254]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [255]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [256]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [257]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [258]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [259]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [260]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [261]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [262]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [263]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [264]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [265]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [266]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [267]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [268]	validation_0-auc:0.56118	validation_1-auc:0.56022	validation_2-auc:0.56233
# [269]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [270]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [271]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [272]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [273]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [274]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [275]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [276]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [277]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [278]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [279]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [280]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [281]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [282]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [283]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [284]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [285]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [286]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [287]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [288]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [289]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [290]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [291]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [292]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [293]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [294]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [295]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [296]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [297]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [298]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# [299]	validation_0-auc:0.56120	validation_1-auc:0.56025	validation_2-auc:0.56234
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.0001, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='auto', use_label_encoder=False,
#               validate_parameters=1, verbosity=1)

# %% [markdown]
# <em>
# Probar con:
#
# - `logloss`: negative log-likelihood
# - `auc`: Area under the curve. Available for binary classification and learning-to-rank tasks.
# - `aucpr`: Area under the PR curve. Available for binary classification and learning-to-rank tasks.
#
# Source: https://xgboost.readthedocs.io/en/latest/parameter.html
# </em>

# %%
# Get parameters:
xgb_model.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': False,
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'gpu_id': -1,
#  'importance_type': 'gain',
#  'interaction_constraints': '',
#  'learning_rate': 0.0001,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 1,
#  'missing': nan,
#  'monotone_constraints': '()',
#  'n_estimators': 300,
#  'n_jobs': 4,
#  'num_parallel_tree': 1,
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': 'auto',
#  'validate_parameters': 1,
#  'verbosity': 1}

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Evaluation metric results (here, `auc`)

# %%
# Evaluation results for all passed eval_sets.
# Validation metrics will help us track the performance of the model:
evals_result = xgb_model.evals_result()
evals_result
# Out:
# {'validation_0': OrderedDict([('auc',
#                [0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561162,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561167,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.561181,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612,
#                 0.5612])]),
#  'validation_1': OrderedDict([('auc',
#                [0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560207,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560212,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560225,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248,
#                 0.560248])]),
#  'validation_2': OrderedDict([('auc',
#                [0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562315,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562319,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562327,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344,
#                 0.562344])])}

# %% [markdown]
# ### Additional metrics results

# %%
# Evaluate the model's metrics:

from sklearn.metrics import fbeta_score, f1_score, recall_score, precision_score, accuracy_score, \
                            confusion_matrix, roc_curve, roc_auc_score, plot_roc_curve

def clf_metrics(classifier, y_test, y_pred):
    print(confusion_matrix(y_test, y_pred))
    print("F-beta (ß=2) = {:6.3f}".format(fbeta_score(y_test, y_pred, beta=2)))   
    print("F1 =           {:6.3f}".format(f1_score(y_test, y_pred)))   
    print("Recall =       {:6.3f}".format(recall_score(y_test, y_pred)))   
    print("Precision =    {:6.3f}".format(precision_score(y_test, y_pred)))   
    print("Accuracy =     {:6.3f}".format(accuracy_score(y_test, y_pred)))

# %% [markdown]
# ### Test

# %%
y_train_pred = xgb_model.predict(X_train)
y_test_pred = xgb_model.predict(X_test)
y_valid_pred = xgb_model.predict(X_valid)
y_test_pred
# Out:
# array([1, 1, 1, ..., 0, 1, 0])

# %%
print("   TRAINING dataset:")
clf_metrics(xgb_model, y_train, y_train_pred)
print("--------------------------------------------------")
print("   TEST dataset:")
clf_metrics(xgb_model, y_test, y_test_pred)
print("--------------------------------------------------")
print("   VALIDATION dataset:")
clf_metrics(xgb_model, y_valid, y_valid_pred)
# Out:
#    TRAINING dataset:
# [[ 90209 259645]
#  [ 49330 300816]]
# F-beta (ß=2) =  0.767
# F1 =            0.661
# Recall =        0.859
# Precision =     0.537
# Accuracy =      0.559
# --------------------------------------------------
#    TEST dataset:
# [[19344 55885]
#  [10635 64136]]
# F-beta (ß=2) =  0.765
# F1 =            0.659
# Recall =        0.858
# Precision =     0.534
# Accuracy =      0.557
# --------------------------------------------------
#    VALIDATION dataset:
# [[19286 55631]
#  [10369 64714]]
# F-beta (ß=2) =  0.769
# F1 =            0.662
# Recall =        0.862
# Precision =     0.538
# Accuracy =      0.560

# %% [markdown]
# ### ROC curve

# %%
y_train_probabilities = xgb_model.predict_proba(X_train)[:,1]
y_test_probabilities = xgb_model.predict_proba(X_test)[:,1]
y_valid_probabilities = xgb_model.predict_proba(X_valid)[:,1]
y_test_probabilities[:10]
# Out:
# array([0.5010855 , 0.5010855 , 0.5010855 , 0.5010855 , 0.5010855 ,
#        0.49714488, 0.5010855 , 0.5010855 , 0.5010855 , 0.5010855 ],
#       dtype=float32)

# %%
fpr_train, tpr_train, _ = roc_curve(y_train,  y_train_probabilities)
fpr_test, tpr_test, _ = roc_curve(y_test,  y_test_probabilities)
fpr_valid, tpr_valid, _ = roc_curve(y_valid,  y_valid_probabilities)

auc_train = roc_auc_score(y_train, y_train_probabilities)
auc_test = roc_auc_score(y_test, y_test_probabilities)
auc_valid = roc_auc_score(y_valid, y_valid_probabilities)

# %%
# Plot the figure:
fig, ax = plt.subplots(figsize=(6,6))

plot_roc_curve(xgb_model, X_train, y_train, color='red', ax=ax, name='XGBoost_train')
plot_roc_curve(xgb_model, X_test, y_test, color='blue', ax=ax, name='XGBoost_test')
plot_roc_curve(xgb_model, X_valid, y_valid, color='green', ax=ax, name='XGBoost_valid')
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("fpr", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("tpr", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### Feature importance (data)

# %%
# Let's build a dictionary to better see each feature with its corresponding importance:
feature_importance_dict = dict(zip(X_train.columns, xgb_model.feature_importances_))
feature_importance_dict
# Out:
# {'TAXI_OUT_median': 0.0,
#  'TAXI_IN_median': 0.0022174784,
#  'CRS_ELAPSED_TIME': 0.0016158106,
#  'DISTANCE': 0.0016129964,
#  'MONTH_1': 0.0,
#  'MONTH_2': 0.0015658864,
#  'MONTH_3': 0.0,
#  'MONTH_4': 0.0,
#  'MONTH_5': 0.0,
#  'MONTH_6': 0.0,
#  'MONTH_7': 0.0,
#  'MONTH_8': 0.0,
#  'MONTH_9': 0.0,
#  'MONTH_10': 0.0,
#  'MONTH_11': 0.0,
#  'MONTH_12': 0.0,
#  'DAY_OF_MONTH_1': 0.0,
#  'DAY_OF_MONTH_2': 0.0,
#  'DAY_OF_MONTH_3': 0.0,
#  'DAY_OF_MONTH_4': 0.0,
#  'DAY_OF_MONTH_5': 0.0,
#  'DAY_OF_MONTH_6': 0.0,
#  'DAY_OF_MONTH_7': 0.0,
#  'DAY_OF_MONTH_8': 0.0,
#  'DAY_OF_MONTH_9': 0.0,
#  'DAY_OF_MONTH_10': 0.0,
#  'DAY_OF_MONTH_11': 0.0,
#  'DAY_OF_MONTH_12': 0.0,
#  'DAY_OF_MONTH_13': 0.0,
#  'DAY_OF_MONTH_14': 0.0,
#  'DAY_OF_MONTH_15': 0.0,
#  'DAY_OF_MONTH_16': 0.0,
#  'DAY_OF_MONTH_17': 0.0,
#  'DAY_OF_MONTH_18': 0.0,
#  'DAY_OF_MONTH_19': 0.0,
#  'DAY_OF_MONTH_20': 0.0,
#  'DAY_OF_MONTH_21': 0.0,
#  'DAY_OF_MONTH_22': 0.0,
#  'DAY_OF_MONTH_23': 0.0,
#  'DAY_OF_MONTH_24': 0.0,
#  'DAY_OF_MONTH_25': 0.0,
#  'DAY_OF_MONTH_26': 0.0,
#  'DAY_OF_MONTH_27': 0.0,
#  'DAY_OF_MONTH_28': 0.0,
#  'DAY_OF_MONTH_29': 0.0,
#  'DAY_OF_MONTH_30': 0.0,
#  'DAY_OF_MONTH_31': 0.0,
#  'DAY_OF_WEEK_1': 0.0,
#  'DAY_OF_WEEK_2': 0.0,
#  'DAY_OF_WEEK_3': 0.0,
#  'DAY_OF_WEEK_4': 0.0,
#  'DAY_OF_WEEK_5': 0.0,
#  'DAY_OF_WEEK_6': 0.0,
#  'DAY_OF_WEEK_7': 0.0,
#  'OP_UNIQUE_CARRIER_9E': 0.0,
#  'OP_UNIQUE_CARRIER_AA': 0.0,
#  'OP_UNIQUE_CARRIER_AS': 0.0,
#  'OP_UNIQUE_CARRIER_B6': 0.0,
#  'OP_UNIQUE_CARRIER_DL': 0.009238347,
#  'OP_UNIQUE_CARRIER_EV': 0.0,
#  'OP_UNIQUE_CARRIER_F9': 0.0035818757,
#  'OP_UNIQUE_CARRIER_G4': 0.0,
#  'OP_UNIQUE_CARRIER_HA': 0.0036486587,
#  'OP_UNIQUE_CARRIER_MQ': 0.0,
#  'OP_UNIQUE_CARRIER_NK': 0.0,
#  'OP_UNIQUE_CARRIER_OH': 0.0,
#  'OP_UNIQUE_CARRIER_OO': 0.0,
#  'OP_UNIQUE_CARRIER_UA': 0.0,
#  'OP_UNIQUE_CARRIER_WN': 0.020057283,
#  'OP_UNIQUE_CARRIER_YV': 0.0,
#  'OP_UNIQUE_CARRIER_YX': 0.0,
#  'DEP_TIME_hour_0': 0.17497009,
#  'DEP_TIME_hour_6': 0.3938774,
#  'DEP_TIME_hour_7': 0.21663396,
#  'DEP_TIME_hour_8': 0.16986842,
#  'DEP_TIME_hour_9': 0.0,
#  'DEP_TIME_hour_10': 0.0,
#  'DEP_TIME_hour_11': 0.0,
#  'DEP_TIME_hour_12': 0.0,
#  'DEP_TIME_hour_13': 0.0,
#  'DEP_TIME_hour_14': 0.0,
#  'DEP_TIME_hour_15': 0.0,
#  'DEP_TIME_hour_16': 0.0,
#  'DEP_TIME_hour_17': 0.0,
#  'DEP_TIME_hour_18': 0.0,
#  'DEP_TIME_hour_19': 0.0,
#  'DEP_TIME_hour_20': 0.0,
#  'DEP_TIME_hour_21': 0.0,
#  'DEP_TIME_hour_22': 0.0,
#  'DEP_TIME_hour_23': 0.0,
#  'ARR_TIME_hour_0': 0.0,
#  'ARR_TIME_hour_6': 0.0,
#  'ARR_TIME_hour_7': 0.0011118343,
#  'ARR_TIME_hour_8': 0.0,
#  'ARR_TIME_hour_9': 0.0,
#  'ARR_TIME_hour_10': 0.0,
#  'ARR_TIME_hour_11': 0.0,
#  'ARR_TIME_hour_12': 0.0,
#  'ARR_TIME_hour_13': 0.0,
#  'ARR_TIME_hour_14': 0.0,
#  'ARR_TIME_hour_15': 0.0,
#  'ARR_TIME_hour_16': 0.0,
#  'ARR_TIME_hour_17': 0.0,
#  'ARR_TIME_hour_18': 0.0,
#  'ARR_TIME_hour_19': 0.0,
#  'ARR_TIME_hour_20': 0.0,
#  'ARR_TIME_hour_21': 0.0,
#  'ARR_TIME_hour_22': 0.0,
#  'ARR_TIME_hour_23': 0.0,
#  'DISTANCE_GROUP_1': 0.0,
#  'DISTANCE_GROUP_2': 0.0,
#  'DISTANCE_GROUP_3': 0.0,
#  'DISTANCE_GROUP_4': 0.0,
#  'DISTANCE_GROUP_5': 0.0,
#  'DISTANCE_GROUP_6': 0.0,
#  'DISTANCE_GROUP_7': 0.0,
#  'DISTANCE_GROUP_8': 0.0,
#  'DISTANCE_GROUP_9': 0.0,
#  'DISTANCE_GROUP_10': 0.0,
#  'DISTANCE_GROUP_11': 0.0}

# %% [markdown]
# ### Feature importance (plot)

# %% [markdown]
# #### Weight-based

# %%
from xgboost import plot_importance

fig,ax = plt.subplots(figsize=(5,5))

plot_importance(booster=xgb_model,
                ax=ax,
                grid=True,
                importance_type='weight', # ”weight” is the number of times a feature appears in a tree
                max_num_features=None, 
                height=0.5,
                xlim=None,
                ylim=None, 
                title='Feature importance (WEIGHT-based)',
                xlabel='F score',
                ylabel='Features',
                show_values=True);

# %% [markdown]
# #### Gain-based

# %%
from xgboost import plot_importance

fig,ax = plt.subplots(figsize=(5,5))

plot_importance(booster=xgb_model,
                ax=ax,
                grid=True,
                importance_type='gain', # ”weight” is the number of times a feature appears in a tree
                max_num_features=None, 
                height=0.5,
                xlim=None,
                ylim=None, 
                title='Feature importance (GAIN-based)',
                xlabel='F score',
                ylabel='Features',
                show_values=True);

# %% [markdown]
# ### Tree

# %%
from xgboost import plot_tree

fig,ax = plt.subplots(figsize=(80,50))

plot_tree(booster=xgb_model,
          num_trees=0,
          ax=ax)

plt.savefig('plot_tree_11.png')

# %% [markdown]
# ### Graphviz (tree)

# %% [markdown]
# *Convert specified tree to graphviz instance. IPython can automatically plot the returned graphiz instance. Otherwise, you should call `.render()` method of the returned graphiz instance.*

# %%
from xgboost import to_graphviz

tree_graphviz = to_graphviz(booster=xgb_model,
                            yes_color='#0000FF',
                            no_color='#FF0000',
                            condition_node_params={'shape': 'box',
                                                   'style': 'filled,rounded',
                                                   'fillcolor': '#78bceb'},
                            leaf_node_params={'shape': 'box',
                                              'style': 'filled',
                                              'fillcolor': '#e48038'})

format = 'png'
tree_graphviz = to_graphviz(xgb_model)
tree_graphviz.graph_attr = {'dpi':'400'}
tree_graphviz.render('tree_graphviz_11', format = format)
# Out:
# 'tree_graphviz_11.png'

# %% [markdown]
# ___

# %%
t1 = time.perf_counter() - t0
print("Time elapsed: {:2.0f}h {:2.0f}min {:2.0f}s".format(t1//3600, (t1%3600)//60, (t1%3600)%60))
# Out:
# Time elapsed:  0h  9min 36s

# %% [raw]
# Time elapsed:  0h  9min 36s

# %% [markdown]
# ## Save the model

# %%
from joblib import dump, load

# Save model to file:
dump(xgb_model, "XGBoost_11.joblib.dat")
print("Saved model to: XGBoost_11.joblib.dat")
# Out:
# Saved model to: XGBoost_11.joblib.dat

# %%
# Load model from file:
loaded_model = load("XGBoost_11.joblib.dat")
print("Loaded model from: XGBoost_11.joblib.dat")
# Out:
# Loaded model from: XGBoost_11.joblib.dat

# %%
# Make predictions for test data
predictions = loaded_model.predict(X_test)

# Evaluate predictions:
recall = recall_score(y_test, predictions)
print("Loaded model recall: {:6.3f}".format(recall))
# Out:
# Loaded model recall:  0.858

# %% [markdown]
# ___

# %% [markdown]
# ___
