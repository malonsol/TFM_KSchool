# %%
# Import libraries to be used

# Directories/Files management
import os.path

# Timing
import time

# Data analysis and wrangling
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) # Show all columns in DataFrames
## pd.set_option('display.max_rows', None) # It greatly slows down the output display and may freeze the kernel

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot') # choose a style: 'plt.style.available'
sns.set_theme(context='notebook',
              style="darkgrid") # {darkgrid, whitegrid, dark, white, ticks}
palette = sns.color_palette("flare", as_cmap=True);
import altair as alt

# %%
t0 = time.perf_counter()

# %%
# Detect Operating System running and manage paths accordingly

root = os.getcwd()
if os.name == 'nt': # Windows
    print("Running on Windows.")
elif os.name == 'posix': # Ubuntu
    print("Running on Ubuntu.")
print("root path\t", root)

# %% [markdown]
# ___

# %% [markdown]
# # Get the data

# %% [markdown]
# ### OTP (2019)

# %% [markdown]
# Let's first check which airports are present in the OTP dataset, and later compare them to those appearing in the WBAN database. Ideally, all the airports contained in the OTP dataset should appear in the WBAN database. This would mean that there presumably might be a weather station at each of those airports.

# %%
cols = ['ORIGIN', 'DEST']
cols_dtypes = {'ORIGIN' : 'category', 'DEST' : 'category'}

# %%
# %%time

otp = pd.read_csv('../data/output/us_dot/1_otp_2019_raw.csv',
                  encoding='latin1',
                  usecols=cols,
                  dtype=cols_dtypes)
# Out:
# Wall time: 18.4 s

# %%
otp
# Out:
#         ORIGIN DEST
# 0          TYS  ATL
# 1          TYS  ATL
# 2          ATL  SGF
# 3          ATL  SGF
# 4          ATL  SGF
# ...        ...  ...
# 7268227    MCO  SWF
# 7268228    DCA  BOS
# 7268229    PHL  BOS
# 7268230    BOS  SJU
# 7268231    SJU  BOS
#
# [7268232 rows x 2 columns]

# %%
otp_iatas = otp['ORIGIN'].unique()
otp_iatas
# Out:
# ['TYS', 'ATL', 'SGF', 'SRQ', 'DTW', ..., 'AKN', 'DLG', 'HYA', 'PGV', 'XWA']
# Length: 360
# Categories (360, object): ['TYS', 'ATL', 'SGF', 'SRQ', ..., 'DLG', 'HYA', 'PGV', 'XWA']

# %% [markdown]
# ### WBAN list ("MASTER-STN-HIST.txt")

# %% [markdown]
# The reader may find the [file](http://www1.ncdc.noaa.gov/pub/data/inventories/MASTER-STN-HIST.TXT) in the NOAA official website, together with relevant info to explore its content.
# *Please note that the hosting server is occasionally down.*

# %% [markdown]
# #### Import the source TXT file and clean it

# %%
new_file = []
with open ('../data/source/noaa/wban/MASTER-STN-HIST.txt', 'r') as f:
    next(f) # Skip the first row, since it's a header
    i = 0
    for line in f.readlines():
        # Break each line in accordance with the MASTER STATION HISTORY INFORMATION FILE documentation: 
        HOMR_ID = line[0:8]
        wban = line[22:27]
        WMO = line[28:33]
        FAA_LOC_ID = line[34:38]
        NWS_LOC_ID = line[39:44]
        ICAO_ID = line[45:49]
        COUNTRY = line[50:70]
        TIME_ZONE = line[105:110]
        HIST_wban_NAME = line[142:172]
        new_line = [HOMR_ID, wban, WMO, FAA_LOC_ID, NWS_LOC_ID, ICAO_ID, COUNTRY, TIME_ZONE, HIST_wban_NAME]
        new_line_2 = []
        for field in new_line:
            field = field.strip()
            new_line_2.append(field)
        new_line_2 = '^'.join(new_line_2)
        new_file.append(new_line_2)

#         i += 1
#         if i == 15:
#             break
            
new_file[:10]
# Out:
# ['10000001^24285^^^^^UNITED STATES^+8^NEWPORT MUNI AP',
#  '10000001^24285^^^^^UNITED STATES^+8^NEWPORT MUNI AP',
#  '10000001^24285^^^^^UNITED STATES^+8^NEWPORT MUNI AP',
#  '10000001^24285^^^^^UNITED STATES^+8^NEWPORT MUNI AP',
#  '10000001^24285^^^^^UNITED STATES^+8^NEWPORT MUNI AP',
#  '10000001^24285^^ONP^ONP^KONP^UNITED STATES^+8^NEWPORT MUNI AP',
#  '10000001^24285^^ONP^ONP^KONP^UNITED STATES^+8^NEWPORT MUNI AP',
#  '10000001^24285^^ONP^ONP^KONP^UNITED STATES^+8^NEWPORT MUNI AP',
#  '10000001^24285^^ONP^ONP^KONP^UNITED STATES^+8^NEWPORT MUNI AP',
#  '10000158^^^^^^UNITED STATES^+9^GUSTAVUS']

# %%
with open('../data/output/noaa/wban/MASTER-STN-HIST_preprocessed.csv', 'w') as f:
    headers = ['HOMR_ID', 'WBAN', 'WMO', 'FAA_LOC_ID', 'NWS_LOC_ID', 'ICAO_ID', 'COUNTRY', 'TIME_ZONE', 'HIST_WBAN_NAME']
    f.write('^'.join(headers))
    f.write('\n')
    f.write('\n'.join(new_file))

# %% [markdown]
# ___

# %% [markdown]
# #### Import the recently generated CSV file and start exploring it

# %%
wban = pd.read_csv('../data/output/noaa/wban/MASTER-STN-HIST_preprocessed.csv',
                   sep='^',
                   encoding='latin1',
                   low_memory = False)
wban
# Out:
#          HOMR_ID     WBAN  WMO FAA_LOC_ID NWS_LOC_ID ICAO_ID        COUNTRY  \
# 0       10000001  24285.0  NaN        NaN        NaN     NaN  UNITED STATES
# 1       10000001  24285.0  NaN        NaN        NaN     NaN  UNITED STATES
# 2       10000001  24285.0  NaN        NaN        NaN     NaN  UNITED STATES
# 3       10000001  24285.0  NaN        NaN        NaN     NaN  UNITED STATES
# 4       10000001  24285.0  NaN        NaN        NaN     NaN  UNITED STATES
# ...          ...      ...  ...        ...        ...     ...            ...
# 178011  30125303      NaN  NaN        NaN        NaN     NaN  UNITED STATES
# 178012  30125303      NaN  NaN        NaN        NaN     NaN  UNITED STATES
# 178013  30125303      NaN  NaN        NaN        NaN     NaN  UNITED STATES
# 178014  30125303      NaN  NaN        NaN        NaN     NaN  UNITED STATES
# 178015  30125303      NaN  NaN        NaN        NaN     NaN  UNITED STATES
#
#         TIME_ZONE   HIST_WBAN_NAME
# 0             8.0  NEWPORT MUNI AP
# 1             8.0  NEWPORT MUNI AP
# 2             8.0  NEWPORT MUNI AP
# 3             8.0  NEWPORT MUNI AP
# 4             8.0  NEWPORT MUNI AP
# ...           ...              ...
# 178011        5.0           CAMDEN
# 178012        5.0           CAMDEN
# 178013        5.0           CAMDEN
# 178014        5.0           CAMDEN
# 178015        5.0           CAMDEN
#
# [178016 rows x 9 columns]

# %%
# For this study, only stations containing both WBAN will be useful:
wban.drop(wban[wban['WBAN'].isna()].index, axis=0, inplace=True)
# However, several empty values are found for FAA_LOC_ID:
wban.drop(wban[wban['FAA_LOC_ID'].isna()].index, axis=0, inplace=True)
# And many others come in the 4-character long way:
wban.drop(wban[wban['FAA_LOC_ID'].str.len() > 3].index, axis=0, inplace=True)
# Replace NaNs:
wban.fillna({'WMO': 999, 'TIME_ZONE': 999}, inplace=True)
wban.fillna({'NWS_LOC_ID': '', 'ICAO_ID': ''}, inplace=True)
# Drop duplicates:
wban = wban.sort_values(by=['FAA_LOC_ID', 'WBAN'], ascending=True)
wban.drop_duplicates('WBAN', keep='last', inplace=True)
wban.sort_index(inplace=True)
wban = wban.sort_values(by=['FAA_LOC_ID', 'WMO', 'WBAN'], ascending=True)
wban.drop_duplicates('FAA_LOC_ID', keep='last', inplace=True)
wban.sort_index(inplace=True)
# Cast numeric columns type to 'int64':
num_cols = wban.select_dtypes('number').columns
wban[num_cols] = wban[num_cols].astype('int64')
# Generate a unique identifier based on several elements:
wban['UniqueID'] = wban['WMO'].apply(lambda x: str(x)) + '0' \
                   + wban['WBAN'].apply(lambda x: str(x)) #\
#                    + '_' + wban['FAA_LOC_ID'].apply(lambda x: str(x))

wban
# Out:
#          HOMR_ID   WBAN    WMO FAA_LOC_ID NWS_LOC_ID ICAO_ID        COUNTRY  \
# 8       10000001  24285    999        ONP        ONP    KONP  UNITED STATES
# 30      10000239  26489    999        5MK        5MK          UNITED STATES
# 32      10000239  46403    999        INR        INR    PAIN  UNITED STATES
# 40      10000355  25335  70362        SGY        SGY    PAGY  UNITED STATES
# 50      10000485  53864    999        EET        EET    KEET  UNITED STATES
# ...          ...    ...    ...        ...        ...     ...            ...
# 177224  30121168  64779    999        MQE               KMQE  UNITED STATES
# 177234  30121192  94099    999        XWA        XWA    KXWA  UNITED STATES
# 177253  30121791  63904    999        T74               KT74  UNITED STATES
# 177259  30121800  43110    999        LNQ               KLNQ  UNITED STATES
# 177274  30121828  54918    999        SXF                     UNITED STATES
#
#         TIME_ZONE          HIST_WBAN_NAME     UniqueID
# 8               8         NEWPORT MUNI AP    999024285
# 30              9          MCKINLEY NP AP    999026489
# 32              9          MCKINLEY NP AP    999046403
# 40              9              SKAGWAY AP  70362025335
# 50              6  ALABASTER SHELBY CO AP    999053864
# ...           ...                     ...          ...
# 177224          5          BLUE HILL ASOS    999064779
# 177234          6            WILLISTON AP    999094099
# 177253          6          TAYLOR MUNI AP    999063904
# 177259          6     BOOTHVILLE HELIPORT    999043110
# 177274          6             SIOUX FALLS    999054918
#
# [2762 rows x 10 columns]

# %%
pd.set_option('display.max_rows', 10)
wban_otp = wban[wban['FAA_LOC_ID'].isin(otp_iatas)]
wban_otp
# Out:
#          HOMR_ID   WBAN    WMO FAA_LOC_ID NWS_LOC_ID ICAO_ID        COUNTRY  \
# 168     10001177  93193  72389        FAT        FAT    KFAT  UNITED STATES
# 241     10001399  24257  72592        RDD        RDD    KRDD  UNITED STATES
# 266     10001444  23188  72290        SAN        SAN    KSAN  UNITED STATES
# 301     10001448  23234  72494        SFO        SFO    KSFO  UNITED STATES
# 308     10001454  93206    999        SBP               KSBP  UNITED STATES
# ...          ...    ...    ...        ...        ...     ...            ...
# 175156  30015485  73805    999        ECP        ECP    KECP  UNITED STATES
# 175499  30015673  12838    999        MLB        MLB    KMLB  UNITED STATES
# 175661  30071738  94030    999        VEL               KVEL  UNITED STATES
# 176305  30083422    398    999        PSE               TJPS    PUERTO RICO
# 177234  30121192  94099    999        XWA        XWA    KXWA  UNITED STATES
#
#         TIME_ZONE              HIST_WBAN_NAME     UniqueID
# 168             8        FRESNO YOSEMITE INTL  72389093193
# 241             8             REDDING MUNI AP  72592024257
# 266             8           SAN DIEGO INTL AP  72290023188
# 301             8       SAN FRANCISCO INTL AP  72494023234
# 308             8          SAN LUIS OBISPO AP    999093206
# ...           ...                         ...          ...
# 175156          6  NW FLORIDA BEACHES INTL AP    999073805
# 175499          5           MELBOURNE INTL AP    999012838
# 175661          7              VERNAL MUNI AP    999094030
# 176305          4                MERCEDITA AP      9990398
# 177234          6                WILLISTON AP    999094099
#
# [351 rows x 10 columns]

# %%
wban.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2762 entries, 8 to 177274
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   HOMR_ID         2762 non-null   int64
#  1   WBAN            2762 non-null   int64
#  2   WMO             2762 non-null   int64
#  3   FAA_LOC_ID      2762 non-null   object
#  4   NWS_LOC_ID      2762 non-null   object
#  5   ICAO_ID         2762 non-null   object
#  6   COUNTRY         2762 non-null   object
#  7   TIME_ZONE       2762 non-null   int64
#  8   HIST_WBAN_NAME  2762 non-null   object
#  9   UniqueID        2762 non-null   object
# dtypes: int64(4), object(6)
# memory usage: 237.4+ KB

# %%
wban_iatas = wban['FAA_LOC_ID'].unique()
print(wban['FAA_LOC_ID'].nunique())
wban_iatas
# Out:
# 2762
# array(['ONP', '5MK', 'INR', ..., 'T74', 'LNQ', 'SXF'], dtype=object)

# %%
disjointed_iatas = []
for iata in otp_iatas:
    if iata not in wban_iatas:
        disjointed_iatas.append(iata)
print(len(disjointed_iatas))
disjointed_iatas
# Out:
# 9
# ['AZA', 'USA', 'FCA', 'SCE', 'PAH', 'SPN', 'HHH', 'OGS', 'BKG']

# %%
for iata in disjointed_iatas:
    print("{} : {} flights ({:4.2f}%)".format(iata,
                                         len(otp[otp['ORIGIN'] == iata]),
                                         len(otp[otp['ORIGIN'] == iata]) / len(otp) * 100))
# Out:
# AZA : 5665 flights (0.08%)
# USA : 1352 flights (0.02%)
# FCA : 3015 flights (0.04%)
# SCE : 1764 flights (0.02%)
# PAH : 1222 flights (0.02%)
# SPN : 471 flights (0.01%)
# HHH : 2180 flights (0.03%)
# OGS : 502 flights (0.01%)
# BKG : 221 flights (0.00%)

# %% [markdown]
# With this quick check, we have ensured that almost every airport appearing in the OTP dataset is also present in the WBAN database. In other words, we now know that each airport has its corresponding meteorological station.
#
# For those few ones that are not present (listed above), it is fair to simply drop them. This can be performed without the risk of losing model's prediction capability, considering that they account altogether for less than 0.3% of the complete dataset.

# %% [markdown]
# #### Generate the resulting CSV file for later use

# %%
wban.to_csv('../data/output/noaa/wban/MASTER-STN-HIST_postprocessed.csv',
            index=False,
            sep='^',
            encoding='latin1')

# %% [markdown]
# ___

# %% [markdown]
# ### OTP-WBAN merge: IATA check

# %%
pd.set_option('display.max_rows', 400)

# %%
otp_wban = otp[['ORIGIN']].groupby('ORIGIN').count().reset_index() \
                          .merge(wban[['WBAN', 'WMO', 'FAA_LOC_ID', 'UniqueID']],
                                 how='inner', left_on='ORIGIN', right_on='FAA_LOC_ID')
otp_wban
# Out:
#     ORIGIN   WBAN    WMO FAA_LOC_ID     UniqueID
# 0      ABE  14737  72517        ABE  72517014737
# 1      ABQ  23050  72365        ABQ  72365023050
# 2      AEX  93915  74754        AEX  74754093915
# 3      ALB  14735  72518        ALB  72518014735
# 4      AMA  23047  72363        AMA  72363023047
# 5      ATL  13874  72219        ATL  72219013874
# 6      ATW   4825    999        ATW     99904825
# 7      AUS  13958  72254        AUS  72254013958
# 8      AVL   3812  72315        AVL   7231503812
# 9      BDL  14740  72508        BDL  72508014740
# 10     BGR  14606  72607        BGR  72607014606
# 11     BHM  13876  72228        BHM  72228013876
# 12     BIL  24033  72677        BIL  72677024033
# 13     BIS  24011  72764        BIS  72764024011
# 14     BLI  24217    999        BLI    999024217
# 15     BLV  13802    999        BLV    999013802
# 16     BMI  54831    999        BMI    999054831
# 17     BNA  13897  72327        BNA  72327013897
# 18     BOI  24131  72681        BOI  72681024131
# 19     BOS  14739  72509        BOS  72509014739
# 20     BTR  13970  72232        BTR  72232013970
# 21     BTV  14742  72617        BTV  72617014742
# 22     BUF  14733  72528        BUF  72528014733
# 23     BUR  23152    999        BUR    999023152
# 24     BWI  93721  72406        BWI  72406093721
# 25     BZN  24132    999        BZN    999024132
# 26     CAE  13883  72310        CAE  72310013883
# 27     CAK  14895  72521        CAK  72521014895
# 28     CHA  13882  72324        CHA  72324013882
# 29     CHO  93736    999        CHO    999093736
# 30     CHS  13880  72208        CHS  72208013880
# 31     CID  14990  72545        CID  72545014990
# 32     CKB   3802    999        CKB     99903802
# 33     CLE  14820  72524        CLE  72524014820
# 34     CLT  13881  72314        CLT  72314013881
# 35     CMH  14821  72428        CMH  72428014821
# 36     CRP  12924  72251        CRP  72251012924
# 37     CVG  93814  72421        CVG  72421093814
# 38     DAB  12834  74787        DAB  74787012834
# 39     DAL  13960  72258        DAL  72258013960
# 40     DAY  93815  72429        DAY  72429093815
# 41     DCA  13743  72405        DCA  72405013743
# 42     DEN   3017  72565        DEN   7256503017
# 43     DFW   3927  72259        DFW   7225903927
# 44     DSM  14933  72546        DSM  72546014933
# 45     DTW  94847  72537        DTW  72537094847
# 46     ECP  73805    999        ECP    999073805
# 47     ELM  14748    999        ELM    999014748
# 48     ELP  23044  72270        ELP  72270023044
# 49     EUG  24221  72693        EUG  72693024221
# 50     EVV  93817  72432        EVV  72432093817
# 51     EWR  14734  72502        EWR  72502014734
# 52     FAR  14914  72753        FAR  72753014914
# 53     FAT  93193  72389        FAT  72389093193
# 54     FAY  93740    999        FAY    999093740
# 55     FLL  12849  74783        FLL  74783012849
# 56     FNT  14826  72637        FNT  72637014826
# 57     FSD  14944  72651        FSD  72651014944
# 58     FWA  14827  72533        FWA  72533014827
# 59     GEG  24157  72785        GEG  72785024157
# 60     GFK  14916  72757        GFK  72757014916
# 61     GJT  23066  72476        GJT  72476023066
# 62     GNV  12816  74756        GNV  74756012816
# 63     GPT  93874  74757        GPT  74757093874
# 64     GRI  14935  72552        GRI  72552014935
# 65     GRR  94860  72635        GRR  72635094860
# 66     GSO  13723  72317        GSO  72317013723
# 67     GSP   3870  72312        GSP   7231203870
# 68     GTF  24143  72775        GTF  72775024143
# 69     HOU  12918  72244        HOU  72244012918
# 70     HPN  94745    999        HPN    999094745
# 71     HRL  12996    999        HRL    999012996
# 72     HSV   3856  72323        HSV   7232303856
# 73     HTS   3860  72425        HTS   7242503860
# 74     IAD  93738  72403        IAD  72403093738
# 75     IAG   4738    999        IAG     99904738
# 76     ICT   3928  72450        ICT   7245003928
# 77     IDA  24145    999        IDA    999024145
# 78     ILM  13748  72302        ILM  72302013748
# 79     IND  93819  72438        IND  72438093819
# 80     ISP   4781  72505        ISP   7250504781
# 81     ITH  94761    999        ITH    999094761
# 82     JAN   3940  72235        JAN   7223503940
# 83     JAX  13889  72206        JAX  72206013889
# 84     JFK  94789  74486        JFK  74486094789
# 85     LAS  23169  72386        LAS  72386023169
# 86     LAX  23174  72295        LAX  72295023174
# 87     LBB  23042  72267        LBB  72267023042
# 88     LCK  13812    999        LCK    999013812
# 89     LEX  93820  72422        LEX  72422093820
# 90     LFT  13976    999        LFT    999013976
# 91     LGA  14732  72503        LGA  72503014732
# 92     LGB  23129  72297        LGB  72297023129
# 93     LIT  13963    999        LIT    999013963
# 94     LRD  12907    999        LRD    999012907
# 95     MAF  23023  72265        MAF  72265023023
# 96     MCI   3947  72446        MCI   7244603947
# 97     MCO  12815  72205        MCO  72205012815
# 98     MDT  14711  72399        MDT  72399014711
# 99     MDW  14819  72534        MDW  72534014819
# 100    MEM  13893  72334        MEM  72334013893
# 101    MFE  12959    999        MFE    999012959
# 102    MFR  24225  72597        MFR  72597024225
# 103    MGM  13895  72226        MGM  72226013895
# 104    MHT  14710    999        MHT    999014710
# 105    MKE  14839  72640        MKE  72640014839
# 106    MLB  12838    999        MLB    999012838
# 107    MLI  14923  72544        MLI  72544014923
# 108    MOT  24013    999        MOT    999024013
# 109    MRY  23259    999        MRY    999023259
# 110    MSN  14837  72641        MSN  72641014837
# 111    MSO  24153  72773        MSO  72773024153
# 112    MSP  14922  72658        MSP  72658014922
# 113    MSY  12916  72231        MSY  72231012916
# 114    MTJ  93013    999        MTJ    999093013
# 115    MYR  13717  74791        MYR  74791013717
# 116    OAJ  93753    999        OAJ    999093753
# 117    OAK  23230  72493        OAK  72493023230
# 118    OGD  24126    999        OGD    999024126
# 119    OKC  13967  72353        OKC  72353013967
# 120    OMA  14942  72550        OMA  72550014942
# 121    ONT   3102    999        ONT     99903102
# 122    ORD  94846  72530        ORD  72530094846
# 123    ORF  13737  72308        ORF  72308013737
# 124    OWB  53803    999        OWB    999053803
# 125    PBG  64776    999        PBG    999064776
# 126    PBI  12844  72203        PBI  72203012844
# 127    PDX  24229  72698        PDX  72698024229
# 128    PGD  12812    999        PGD    999012812
# 129    PHF  93741    999        PHF    999093741
# 130    PHL  13739  72408        PHL  72408013739
# 131    PHX  23183  72278        PHX  72278023183
# 132    PIA  14842  72532        PIA  72532014842
# 133    PIE  12873    999        PIE    999012873
# 134    PIT  94823  72520        PIT  72520094823
# 135    PNS  13899  72222        PNS  72222013899
# 136    PSC  24163    999        PSC    999024163
# 137    PSM   4743    999        PSM     99904743
# 138    PSP  93138    999        PSP    999093138
# 139    PVD  14765  72507        PVD  72507014765
# 140    PVU  24174    999        PVU    999024174
# 141    PWM  14764  72606        PWM  72606014764
# 142    RAP  24090  72662        RAP  72662024090
# 143    RDU  13722  72306        RDU  72306013722
# 144    RFD  94822  72543        RFD  72543094822
# 145    RIC  13740  72401        RIC  72401013740
# 146    RNO  23185  72488        RNO  72488023185
# 147    ROA  13741  72411        ROA  72411013741
# 148    ROC  14768  72529        ROC  72529014768
# 149    RSW  12894    999        RSW    999012894
# 150    SAN  23188  72290        SAN  72290023188
# 151    SAT  12921  72253        SAT  72253012921
# 152    SAV   3822  72207        SAV   7220703822
# 153    SBN  14848  72535        SBN  72535014848
# 154    SCK  23237  72492        SCK  72492023237
# 155    SDF  93821  72423        SDF  72423093821
# 156    SEA  24233  72793        SEA  72793024233
# 157    SFB  12854    999        SFB    999012854
# 158    SFO  23234  72494        SFO  72494023234
# 159    SGF  13995  72440        SGF  72440013995
# 160    SGU  23186    999        SGU    999023186
# 161    SHV  13957  72248        SHV  72248013957
# 162    SJC  23293    999        SJC    999023293
# 163    SJU  11641  78526        SJU  78526011641
# 164    SLC  24127  72572        SLC  72572024127
# 165    SMF  93225    999        SMF    999093225
# 166    SMX  23273  72394        SMX  72394023273
# 167    SNA  93184    999        SNA    999093184
# 168    SPI  93822  72439        SPI  72439093822
# 169    SRQ  12871    999        SRQ    999012871
# 170    STC  14926  72655        STC  72655014926
# 171    STL  13994  72434        STL  72434013994
# 172    STT  11640    999        STT    999011640
# 173    SWF  14714    999        SWF    999014714
# 174    SYR  14771  72519        SYR  72519014771
# 175    TLH  93805  72214        TLH  72214093805
# 176    TOL  94830  72536        TOL  72536094830
# 177    TPA  12842  72211        TPA  72211012842
# 178    TRI  13877  72335        TRI  72335013877
# 179    TUL  13968  72356        TUL  72356013968
# 180    TUS  23160  72274        TUS  72274023160
# 181    TVC  14850    999        TVC    999014850
# 182    TYS  13891  72326        TYS  72326013891
# 183    VPS  13858  72221        VPS  72221013858
# 184    XNA  53922    999        XNA    999053922
# 185    ABR  14929  72659        ABR  72659014929
# 186    ABY  13869  72216        ABY  72216013869
# 187    ACV  24283    999        ACV    999024283
# 188    APN  94849  72639        APN  72639094849
# 189    ASE  93073    999        ASE    999093073
# 190    AVP  14777  72513        AVP  72513014777
# 191    AZO  94815    999        AZO    999094815
# 192    BFF  24028  72566        BFF  72566024028
# 193    BFL  23155  72384        BFL  72384023155
# 194    BJI  14958  72755        BJI  72755014958
# 195    BQK  53883    999        BQK    999053883
# 196    BQN  11603    999        BQN    999011603
# 197    BRD  94938    999        BRD    999094938
# 198    BRO  12919  72250        BRO  72250012919
# 199    BTM  24135  72774        BTM  72774024135
# 200    CDC  93129    999        CDC    999093129
# 201    CGI   3935  72329        CGI   7232903935
# 202    CIU   4869    999        CIU     99904869
# 203    CLL   3904  74746        CLL   7474603904
# 204    CMX  14858  72744        CMX  72744014858
# 205    CNY  93075    999        CNY    999093075
# 206    COD  24045  72670        COD  72670024045
# 207    COS  93037  72466        COS  72466093037
# 208    COU   3945  72445        COU   7244503945
# 209    CPR  24089  72569        CPR  72569024089
# 210    CRW  13866  72414        CRW  72414013866
# 211    CYS  24018  72564        CYS  72564024018
# 212    DHN  93843    999        DHN    999093843
# 213    DLH  14913  72745        DLH  72745014913
# 214    DRO  93005    999        DRO    999093005
# 215    DVL  94928    999        DVL    999094928
# 216    EAR  14905    999        EAR    999014905
# 217    EAU  14991    999        EAU    999014991
# 218    EGE  23063    999        EGE    999023063
# 219    EKO  24121    999        EKO    999024121
# 220    ERI  14860  72526        ERI  72526014860
# 221    ESC  14824  72648        ESC  72648014824
# 222    FLG   3103    999        FLG     99903103
# 223    GCC  94023  72665        GCC  72665094023
# 224    GRB  14898  72645        GRB  72645014898
# 225    GUC  93007    999        GUC    999093007
# 226    HDN  94025    999        HDN    999094025
# 227    HIB  94931    999        HIB    999094931
# 228    HLN  24144  72772        HLN  72772024144
# 229    HNL  22521  91182        HNL  91182022521
# 230    HYS   3968    999        HYS     99903968
# 231    IAH  12960  72243        IAH  72243012960
# 232    IMT  94893    999        IMT    999094893
# 233    INL  14918  72747        INL  72747014918
# 234    ISN  94014  72767        ISN  72767094014
# 235    JAC  24166    999        JAC    999024166
# 236    JLN  13987    999        JLN    999013987
# 237    JMS  14919    999        JMS    999014919
# 238    KOA  21510    999        KOA    999021510
# 239    LAN  14836  72539        LAN  72539014836
# 240    LAR  24022    999        LAR    999024022
# 241    LAW   3950    999        LAW     99903950
# 242    LBE  54735    999        LBE    999054735
# 243    LBF  24023  72562        LBF  72562024023
# 244    LBL  23020    999        LBL    999023020
# 245    LNK  14939  72551        LNK  72551014939
# 246    LSE  14920  72643        LSE  72643014920
# 247    LWB  53801    999        LWB    999053801
# 248    LWS  24149  72783        LWS  72783024149
# 249    MBS  14845    999        MBS    999014845
# 250    MEI  13865  72234        MEI  72234013865
# 251    MHK   3936    999        MHK     99903936
# 252    MIA  12839  72202        MIA  72202012839
# 253    MKG  14840  72636        MKG  72636014840
# 254    MLU  13942    999        MLU    999013942
# 255    MMH   3181    999        MMH     99903181
# 256    MOB  13894  72223        MOB  72223013894
# 257    MQT  94850  72743        MQT  72743094850
# 258    OGG  22516  91190        OGG  91190022516
# 259    ORH  94746  72510        ORH  72510094746
# 260    OTH  24284    999        OTH    999024284
# 261    PIB  53808    999        PIB    999053808
# 262    PIH  24156  72578        PIH  72578024156
# 263    PLN  14841    999        PLN    999014841
# 264    PRC  23184    999        PRC    999023184
# 265    PSE    398    999        PSE      9990398
# 266    PUB  93058  72464        PUB  72464093058
# 267    RDD  24257  72592        RDD  72592024257
# 268    RDM  24230  72692        RDM  72692024230
# 269    RHI   4803    999        RHI     99904803
# 270    RKS  24027    999        RKS    999024027
# 271    ROW  23009  72268        ROW  72268023009
# 272    RST  14925  72644        RST  72644014925
# 273    SAF  23049    999        SAF    999023049
# 274    SBA  23190  72392        SBA  72392023190
# 275    SBP  93206    999        SBP    999093206
# 276    SHD  93760    999        SHD    999093760
# 277    SLN  93998    999        SLN    999093998
# 278    STS  23274    999        STS    999023274
# 279    SUN  94161    999        SUN    999094161
# 280    TWF  94178    999        TWF    999094178
# 281    UIN  93989  72443        UIN  72443093989
# 282    VEL  94030    999        VEL    999094030
# 283    VLD  93845    999        VLD    999093845
# 284    YUM  23195  72280        YUM  72280023195
# 285    ABI  13962  72266        ABI  72266013962
# 286    ACT  13959  72256        ACT  72256013959
# 287    ANC  26451  70273        ANC  70273026451
# 288    BPT  12917  72241        BPT  72241012917
# 289    CMI  94870    999        CMI    999094870
# 290    CWA  94890    999        CWA    999094890
# 291    DBQ  94908  72547        DBQ  72547094908
# 292    GRK   3902    999        GRK     99903902
# 293    GUM  41415  91212        GUM  91212041415
# 294    LCH   3937  72240        LCH   7224003937
# 295    LIH  22536  91165        LIH  91165022536
# 296    SJT  23034  72263        SJT  72263023034
# 297    SPS  13966  72351        SPS  72351013966
# 298    STX  11624  78551        STX  78551011624
# 299    SUX  14943  72557        SUX  72557014943
# 300    SWO   3965    999        SWO     99903965
# 301    TYR  13972    999        TYR    999013972
# 302    AGS   3820  72218        AGS   7221803820
# 303    BGM   4725  72515        BGM   7251504725
# 304    EYW  12836  72201        EYW  72201012836
# 305    FSM  13964  72344        FSM  72344013964
# 306    ADK  25704  70454        ADK  70454025704
# 307    ADQ  25501  70350        ADQ  70350025501
# 308    BET  26615  70219        BET  70219026615
# 309    BRW  27502  70026        BRW  70026027502
# 310    CDV  26410  70296        CDV  70296026410
# 311    FAI  26411  70261        FAI  70261026411
# 312    ITO  21504  91285        ITO  91285021504
# 313    JNU  25309  70381        JNU  70381025309
# 314    KTN  25325  70395        KTN  70395025325
# 315    OME  26617  70200        OME  70200026617
# 316    OTZ  26616  70133        OTZ  70133026616
# 317    PSG  25329  70386        PSG  70386025329
# 318    SCC  27406    999        SCC    999027406
# 319    SIT  25333  70371        SIT  70371025333
# 320    WRG  25338  70387        WRG  70387025338
# 321    YAK  25339  70361        YAK  70361025339
# 322    CSG  93842    999        CSG    999093842
# 323    GTR  53893    999        GTR    999053893
# 324    ACY  93730  72407        ACY  72407093730
# 325    HGR  93706    999        HGR    999093706
# 326    DRT  22010  72261        DRT  72261022010
# 327    ALO  94910  72548        ALO  72548094910
# 328    GCK  23064    999        GCK    999023064
# 329    TXK  13977    999        TXK    999013977
# 330    EWN  93719    999        EWN    999093719
# 331    TTN  14792    999        TTN    999014792
# 332    PPG  61705  91765        PPG  91765061705
# 333    HOB  93034    999        HOB    999093034
# 334    ART  94790    999        ART    999094790
# 335    HVN  14758    999        HVN    999014758
# 336    GGG   3901    999        GGG     99903901
# 337    LYH  13733  72410        LYH  72410013733
# 338    PAE  24222    999        PAE    999024222
# 339    ATY  14946    999        ATY    999014946
# 340    PIR  24025  72656        PIR  72656024025
# 341    WYS  94163    999        WYS    999094163
# 342    ACK  14756    999        ACK    999014756
# 343    BFM  13838    999        BFM    999013838
# 344    MVY  94724    999        MVY    999094724
# 345    AKN  25503  70326        AKN  70326025503
# 346    DLG  25513  70321        DLG  70321025513
# 347    GST  25322  70367        GST  70367025322
# 348    HYA  94720    999        HYA    999094720
# 349    PGV  13783    999        PGV    999013783
# 350    XWA  94099    999        XWA    999094099

# %% [markdown]
# ___

# %% [markdown]
# ### Local Climatological Data (LCD) → 2019 Master file
#
# Source: https://www.ncei.noaa.gov/data/local-climatological-data/access/2019/

# %% [markdown]
# #### Import the generated CSV files and start exploring them

# %%
pd.set_option('display.max_rows', 10)

# %%
tables = pd.read_html("https://www.ncei.noaa.gov/data/local-climatological-data/access/2019/")
lcd_files = tables[0].loc[2:].copy()
lcd_files
# Out:
#                   Name     Last modified  Size  Description
# 2      01001099999.csv  2020-10-24 23:45  4.2M          NaN
# 3      01001499999.csv  2020-10-25 00:04  3.2M          NaN
# 4      01002099999.csv  2020-10-24 23:44  4.0M          NaN
# 5      01003099999.csv  2020-10-25 00:08  4.3M          NaN
# 6      01006099999.csv  2020-10-25 00:53  4.1M          NaN
# ...                ...               ...   ...          ...
# 13464  A0735700182.csv  2020-10-24 23:26   14M          NaN
# 13465  A0735900240.csv  2020-10-24 23:41   17M          NaN
# 13466  A5125500445.csv  2020-10-24 23:33   13M          NaN
# 13467  A5125600451.csv  2020-10-24 23:32   14M          NaN
# 13468              NaN               NaN   NaN          NaN
#
# [13467 rows x 4 columns]

# %%
lcd_files.drop(labels=['Last modified', 'Size', 'Description'], axis=1, inplace=True)
lcd_files['WBAN'] = lcd_files.loc[:, 'Name'].str.slice(-9, -4)
lcd_files.drop(lcd_files[lcd_files['WBAN'] == '99999'].index, inplace=True)
lcd_files['WBAN'].dropna(inplace=True)
lcd_files.dropna(how='all', axis=0, inplace=True)
lcd_files['WBAN'] = lcd_files['WBAN'].astype('int64')
lcd_files
# Out:
#                   Name   WBAN
# 816    03577035046.csv  35046
# 817    03583035034.csv  35034
# 910    04018016201.csv  16201
# 1605   08449013025.csv  13025
# 2531   16289034113.csv  34113
# ...                ...    ...
# 13463  A0735500241.csv    241
# 13464  A0735700182.csv    182
# 13465  A0735900240.csv    240
# 13466  A5125500445.csv    445
# 13467  A5125600451.csv    451
#
# [2370 rows x 2 columns]

# %%
otp_wban.head()
# Out:
#   ORIGIN   WBAN    WMO FAA_LOC_ID     UniqueID
# 0    ABE  14737  72517        ABE  72517014737
# 1    ABQ  23050  72365        ABQ  72365023050
# 2    AEX  93915  74754        AEX  74754093915
# 3    ALB  14735  72518        ALB  72518014735
# 4    AMA  23047  72363        AMA  72363023047

# %%
lcd_wban = lcd_files.merge(otp_wban[['WBAN', 'WMO', 'FAA_LOC_ID', 'UniqueID']], how='right', left_on='WBAN', right_on='WBAN')
lcd_wban
# Out:
#                 Name   WBAN    WMO FAA_LOC_ID     UniqueID
# 0    72517014737.csv  14737  72517        ABE  72517014737
# 1    72365023050.csv  23050  72365        ABQ  72365023050
# 2    74754093915.csv  93915  74754        AEX  74754093915
# 3    72518014735.csv  14735  72518        ALB  72518014735
# 4    72363023047.csv  23047  72363        AMA  72363023047
# ..               ...    ...    ...        ...          ...
# 346  70321025513.csv  25513  70321        DLG  70321025513
# 347  70367025322.csv  25322  70367        GST  70367025322
# 348  72506794720.csv  94720    999        HYA    999094720
# 349  72306513783.csv  13783    999        PGV    999013783
# 350              NaN  94099    999        XWA    999094099
#
# [351 rows x 5 columns]

# %%
missing_stations = lcd_wban[lcd_wban['Name'].isna()]['FAA_LOC_ID'].to_list()
missing_stations
# Out:
# ['HRL', 'IAG', 'DHN', 'ESC', 'PSE', 'SLN', 'STS', 'YUM', 'XWA']

# %%
for iata in missing_stations:
    print("{} : {} flights ({:4.2f}%)".format(iata,
                                         len(otp[otp['ORIGIN'] == iata]),
                                         len(otp[otp['ORIGIN'] == iata]) / len(otp) * 100))
# Out:
# HRL : 4370 flights (0.06%)
# IAG : 830 flights (0.01%)
# DHN : 1371 flights (0.02%)
# ESC : 597 flights (0.01%)
# PSE : 812 flights (0.01%)
# SLN : 892 flights (0.01%)
# STS : 2613 flights (0.04%)
# YUM : 1909 flights (0.03%)
# XWA : 204 flights (0.00%)

# %% [markdown]
# Once again, with this quick check we have ensured that almost every airport appearing in the OTP dataset is also present in the LCD database. In other words, we now know that each airport has its corresponding meteorological station's readings available.
#
# For those few ones that are not present (listed above), it is fair to simply drop them. This can be performed without the risk of losing model's prediction capability, considering that they account altogether for less than 0.2% of the complete dataset.

# %%
lcd_wban_clean = lcd_files.merge(otp_wban[['WBAN', 'WMO', 'FAA_LOC_ID']], how='inner', left_on='WBAN', right_on='WBAN')
lcd_wban_clean
# Out:
#                 Name   WBAN    WMO FAA_LOC_ID
# 0    70026027502.csv  27502  70026        BRW
# 1    70063727406.csv  27406    999        SCC
# 2    70133026616.csv  26616  70133        OTZ
# 3    70200026617.csv  26617  70200        OME
# 4    70219026615.csv  26615  70219        BET
# ..               ...    ...    ...        ...
# 337  91190022516.csv  22516  91190        OGG
# 338  91197521510.csv  21510    999        KOA
# 339  91212041415.csv  41415  91212        GUM
# 340  91285021504.csv  21504  91285        ITO
# 341  91765061705.csv  61705  91765        PPG
#
# [342 rows x 4 columns]

# %%
wban_available = dict(zip(lcd_wban_clean['WBAN'].to_list(), lcd_wban_clean['Name'].to_list()))
wban_available.items()
# Out:
# dict_items([(27502, '70026027502.csv'), (27406, '70063727406.csv'), (26616, '70133026616.csv'), (26617, '70200026617.csv'), (26615, '70219026615.csv'), (26411, '70261026411.csv'), (26451, '70273026451.csv'), (26410, '70296026410.csv'), (25513, '70321025513.csv'), (25503, '70326025503.csv'), (25501, '70350025501.csv'), (25339, '70361025339.csv'), (25322, '70367025322.csv'), (25333, '70371025333.csv'), (25309, '70381025309.csv'), (25329, '70386025329.csv'), (25338, '70387025338.csv'), (25325, '70395025325.csv'), (25704, '70454025704.csv'), (73805, '72073573805.csv'), (12836, '72201012836.csv'), (12839, '72202012839.csv'), (12844, '72203012844.csv'), (12812, '72203412812.csv'), (12838, '72204012838.csv'), (12815, '72205012815.csv'), (12854, '72205712854.csv'), (13889, '72206013889.csv'), (3822, '72207003822.csv'), (13880, '72208013880.csv'), (12894, '72210812894.csv'), (12842, '72211012842.csv'), (12871, '72211512871.csv'), (12873, '72211612873.csv'), (53883, '72213653883.csv'), (93805, '72214093805.csv'), (13869, '72216013869.csv'), (93845, '72216693845.csv'), (3820, '72218003820.csv'), (13874, '72219013874.csv'), (13858, '72221013858.csv'), (13899, '72222313899.csv'), (13894, '72223013894.csv'), (13838, '72223513838.csv'), (93842, '72225593842.csv'), (13895, '72226013895.csv'), (13876, '72228013876.csv'), (12916, '72231012916.csv'), (13970, '72232013970.csv'), (13865, '72234013865.csv'), (53808, '72234853808.csv'), (3940, '72235003940.csv'), (3937, '72240003937.csv'), (13976, '72240513976.csv'), (12917, '72241012917.csv'), (12960, '72243012960.csv'), (12918, '72244012918.csv'), (13972, '72244813972.csv'), (3901, '72247003901.csv'), (13957, '72248013957.csv'), (13942, '72248613942.csv'), (12919, '72250012919.csv'), (12959, '72250612959.csv'), (12924, '72251012924.csv'), (12907, '72252012907.csv'), (12921, '72253012921.csv'), (13958, '72254413958.csv'), (13959, '72256013959.csv'), (3902, '72257603902.csv'), (13960, '72258013960.csv'), (3927, '72259003927.csv'), (22010, '72261022010.csv'), (23034, '72263023034.csv'), (23023, '72265023023.csv'), (13962, '72266013962.csv'), (23042, '72267023042.csv'), (23009, '72268023009.csv'), (93034, '72268893034.csv'), (23044, '72270023044.csv'), (23160, '72274023160.csv'), (23183, '72278023183.csv'), (93138, '72286893138.csv'), (23152, '72288023152.csv'), (93206, '72289793206.csv'), (23188, '72290023188.csv'), (23174, '72295023174.csv'), (23129, '72297023129.csv'), (93184, '72297793184.csv'), (13748, '72302013748.csv'), (93740, '72303593740.csv'), (13722, '72306013722.csv'), (13783, '72306513783.csv'), (93753, '72306993753.csv'), (13737, '72308013737.csv'), (93741, '72308693741.csv'), (93719, '72309593719.csv'), (13883, '72310013883.csv'), (3870, '72312003870.csv'), (13881, '72314013881.csv'), (3812, '72315003812.csv'), (13723, '72317013723.csv'), (3856, '72323003856.csv'), (13882, '72324013882.csv'), (13891, '72326013891.csv'), (13897, '72327013897.csv'), (3935, '72329003935.csv'), (53893, '72330753893.csv'), (13893, '72334013893.csv'), (13877, '72335013877.csv'), (13963, '72340313963.csv'), (13977, '72341813977.csv'), (53922, '72343653922.csv'), (13964, '72344013964.csv'), (13987, '72349513987.csv'), (13966, '72351013966.csv'), (13967, '72353013967.csv'), (3965, '72354503965.csv'), (13968, '72356013968.csv'), (3950, '72357503950.csv'), (23047, '72363023047.csv'), (23050, '72365023050.csv'), (23049, '72365623049.csv'), (23184, '72372323184.csv'), (3103, '72375003103.csv'), (23155, '72384023155.csv'), (23169, '72386023169.csv'), (93193, '72389093193.csv'), (3181, '72389403181.csv'), (23190, '72392523190.csv'), (23273, '72394023273.csv'), (14711, '72399014711.csv'), (13740, '72401013740.csv'), (93736, '72401693736.csv'), (93738, '72403093738.csv'), (13743, '72405013743.csv'), (93721, '72406093721.csv'), (93706, '72406693706.csv'), (93730, '72407093730.csv'), (13739, '72408013739.csv'), (14792, '72409514792.csv'), (13733, '72410013733.csv'), (93760, '72410593760.csv'), (13741, '72411013741.csv'), ...

# %% [markdown]
# #### Run only the first time to download every individual LCD file (year 2019) corresponding to each WBAN station

# %%
import urllib.request
import time

# Root URL to download the files:
base_url = 'https://www.ncei.noaa.gov/data/local-climatological-data/access/2019/'
# Storage folder:
lcds_folder = '../data/source/noaa/lcd_individual_files/' 

i = 1

for wban, wban_csv_name in wban_available.items():
    iata = lcd_wban_clean.loc[lcd_wban_clean['WBAN'] == wban, 'FAA_LOC_ID'].values[0]
    file_name = iata + "_" + str(wban) + ".csv"
    # Check if the file has already been downloaded:
    if file_name in os.listdir(lcds_folder):
        print("File '" + file_name + "' already exists.\nNo file has been generated (previous one remains).")
        continue
    else:
        if os.listdir(lcds_folder) == []:
            print('Beginning files download with urllib...')
        file_path = lcds_folder + file_name
        url = base_url + wban_csv_name
        print(i, ") IATA:", iata, "/ WBAN:", wban, "/ Link:", url)
        urllib.request.urlretrieve(url, file_path)
    #     time.sleep(5)
        i += 1
    #     if i == 3:
    #         break
# Out:
# File 'BRW_27502.csv' already exists.
# No file has been generated (previous one remains).
# File 'SCC_27406.csv' already exists.
# No file has been generated (previous one remains).
# File 'OTZ_26616.csv' already exists.
# No file has been generated (previous one remains).
# File 'OME_26617.csv' already exists.
# No file has been generated (previous one remains).
# File 'BET_26615.csv' already exists.
# No file has been generated (previous one remains).
# File 'FAI_26411.csv' already exists.
# No file has been generated (previous one remains).
# File 'ANC_26451.csv' already exists.
# No file has been generated (previous one remains).
# File 'CDV_26410.csv' already exists.
# No file has been generated (previous one remains).
# File 'DLG_25513.csv' already exists.
# No file has been generated (previous one remains).
# File 'AKN_25503.csv' already exists.
# No file has been generated (previous one remains).
# File 'ADQ_25501.csv' already exists.
# No file has been generated (previous one remains).
# File 'YAK_25339.csv' already exists.
# No file has been generated (previous one remains).
# File 'GST_25322.csv' already exists.
# No file has been generated (previous one remains).
# File 'SIT_25333.csv' already exists.
# No file has been generated (previous one remains).
# File 'JNU_25309.csv' already exists.
# No file has been generated (previous one remains).
# File 'PSG_25329.csv' already exists.
# No file has been generated (previous one remains).
# File 'WRG_25338.csv' already exists.
# No file has been generated (previous one remains).
# File 'KTN_25325.csv' already exists.
# No file has been generated (previous one remains).
# File 'ADK_25704.csv' already exists.
# No file has been generated (previous one remains).
# File 'ECP_73805.csv' already exists.
# No file has been generated (previous one remains).
# File 'EYW_12836.csv' already exists.
# No file has been generated (previous one remains).
# File 'MIA_12839.csv' already exists.
# No file has been generated (previous one remains).
# File 'PBI_12844.csv' already exists.
# No file has been generated (previous one remains).
# File 'PGD_12812.csv' already exists.
# No file has been generated (previous one remains).
# File 'MLB_12838.csv' already exists.
# No file has been generated (previous one remains).
# File 'MCO_12815.csv' already exists.
# No file has been generated (previous one remains).
# File 'SFB_12854.csv' already exists.
# No file has been generated (previous one remains).
# File 'JAX_13889.csv' already exists.
# No file has been generated (previous one remains).
# File 'SAV_3822.csv' already exists.
# No file has been generated (previous one remains).
# File 'CHS_13880.csv' already exists.
# No file has been generated (previous one remains).
# File 'RSW_12894.csv' already exists.
# No file has been generated (previous one remains).
# File 'TPA_12842.csv' already exists.
# No file has been generated (previous one remains).
# File 'SRQ_12871.csv' already exists.
# No file has been generated (previous one remains).
# File 'PIE_12873.csv' already exists.
# No file has been generated (previous one remains).
# File 'BQK_53883.csv' already exists.
# No file has been generated (previous one remains).
# File 'TLH_93805.csv' already exists.
# No file has been generated (previous one remains).
# File 'ABY_13869.csv' already exists.
# No file has been generated (previous one remains).
# File 'VLD_93845.csv' already exists.
# No file has been generated (previous one remains).
# File 'AGS_3820.csv' already exists.
# No file has been generated (previous one remains).
# File 'ATL_13874.csv' already exists.
# No file has been generated (previous one remains).
# File 'VPS_13858.csv' already exists.
# No file has been generated (previous one remains).
# File 'PNS_13899.csv' already exists.
# No file has been generated (previous one remains).
# File 'MOB_13894.csv' already exists.
# No file has been generated (previous one remains).
# File 'BFM_13838.csv' already exists.
# No file has been generated (previous one remains).
# File 'CSG_93842.csv' already exists.
# No file has been generated (previous one remains).
# File 'MGM_13895.csv' already exists.
# No file has been generated (previous one remains).
# File 'BHM_13876.csv' already exists.
# No file has been generated (previous one remains).
# File 'MSY_12916.csv' already exists.
# No file has been generated (previous one remains).
# File 'BTR_13970.csv' already exists.
# No file has been generated (previous one remains).
# File 'MEI_13865.csv' already exists.
# No file has been generated (previous one remains).
# File 'PIB_53808.csv' already exists.
# No file has been generated (previous one remains).
# File 'JAN_3940.csv' already exists.
# No file has been generated (previous one remains).
# File 'LCH_3937.csv' already exists.
# No file has been generated (previous one remains).
# File 'LFT_13976.csv' already exists.
# No file has been generated (previous one remains).
# File 'BPT_12917.csv' already exists.
# No file has been generated (previous one remains).
# File 'IAH_12960.csv' already exists.
# No file has been generated (previous one remains).
# File 'HOU_12918.csv' already exists.
# No file has been generated (previous one remains).
# File 'TYR_13972.csv' already exists.
# No file has been generated (previous one remains).
# File 'GGG_3901.csv' already exists.
# No file has been generated (previous one remains).
# File 'SHV_13957.csv' already exists.
# No file has been generated (previous one remains).
# File 'MLU_13942.csv' already exists.
# No file has been generated (previous one remains).
# File 'BRO_12919.csv' already exists.
# No file has been generated (previous one remains).
# File 'MFE_12959.csv' already exists.
# No file has been generated (previous one remains).
# File 'CRP_12924.csv' already exists.
# No file has been generated (previous one remains).
# File 'LRD_12907.csv' already exists.
# No file has been generated (previous one remains).
# File 'SAT_12921.csv' already exists.
# No file has been generated (previous one remains).
# File 'AUS_13958.csv' already exists.
# No file has been generated (previous one remains).
# File 'ACT_13959.csv' already exists.
# No file has been generated (previous one remains).
# File 'GRK_3902.csv' already exists.
# No file has been generated (previous one remains).
# File 'DAL_13960.csv' already exists.
# No file has been generated (previous one remains).
# File 'DFW_3927.csv' already exists.
# No file has been generated (previous one remains).
# File 'DRT_22010.csv' already exists.
# No file has been generated (previous one remains).
# File 'SJT_23034.csv' already exists.
# No file has been generated (previous one remains).
# File 'MAF_23023.csv' already exists.
# No file has been generated (previous one remains).
# File 'ABI_13962.csv' already exists.
# No file has been generated (previous one remains).
# File 'LBB_23042.csv' already exists.
# No file has been generated (previous one remains).
# File 'ROW_23009.csv' already exists.
# No file has been generated (previous one remains).
# File 'HOB_93034.csv' already exists.
# No file has been generated (previous one remains).
# File 'ELP_23044.csv' already exists.
# No file has been generated (previous one remains).
# File 'TUS_23160.csv' already exists.
# No file has been generated (previous one remains).
# File 'PHX_23183.csv' already exists.
# No file has been generated (previous one remains).
# File 'PSP_93138.csv' already exists.
# No file has been generated (previous one remains).
# File 'BUR_23152.csv' already exists.
# No file has been generated (previous one remains).
# File 'SBP_93206.csv' already exists.
# No file has been generated (previous one remains).
# File 'SAN_23188.csv' already exists.
# No file has been generated (previous one remains).
# File 'LAX_23174.csv' already exists.
# No file has been generated (previous one remains).
# File 'LGB_23129.csv' already exists.
# No file has been generated (previous one remains).
# File 'SNA_93184.csv' already exists.
# No file has been generated (previous one remains).
# File 'ILM_13748.csv' already exists.
# No file has been generated (previous one remains).
# File 'FAY_93740.csv' already exists.
# No file has been generated (previous one remains).
# File 'RDU_13722.csv' already exists.
# No file has been generated (previous one remains).
# File 'PGV_13783.csv' already exists.
# No file has been generated (previous one remains).
# File 'OAJ_93753.csv' already exists.
# No file has been generated (previous one remains).
# File 'ORF_13737.csv' already exists.
# No file has been generated (previous one remains).
# File 'PHF_93741.csv' already exists.
# No file has been generated (previous one remains).
# File 'EWN_93719.csv' already exists.
# No file has been generated (previous one remains).
# File 'CAE_13883.csv' already exists.
# No file has been generated (previous one remains).
# File 'GSP_3870.csv' already exists.
# No file has been generated (previous one remains).
# File 'CLT_13881.csv' already exists.
# No file has been generated (previous one remains).
# File 'AVL_3812.csv' already exists.
# No file has been generated (previous one remains).
# File 'GSO_13723.csv' already exists.
# No file has been generated (previous one remains).
# File 'HSV_3856.csv' already exists.
# No file has been generated (previous one remains).
# File 'CHA_13882.csv' already exists.
# No file has been generated (previous one remains).
# File 'TYS_13891.csv' already exists.
# No file has been generated (previous one remains).
# File 'BNA_13897.csv' already exists.
# No file has been generated (previous one remains).
# File 'CGI_3935.csv' already exists.
# No file has been generated (previous one remains).
# File 'GTR_53893.csv' already exists.
# No file has been generated (previous one remains).
# File 'MEM_13893.csv' already exists.
# No file has been generated (previous one remains).
# File 'TRI_13877.csv' already exists.
# No file has been generated (previous one remains).
# File 'LIT_13963.csv' already exists.
# No file has been generated (previous one remains).
# File 'TXK_13977.csv' already exists.
# No file has been generated (previous one remains).
# File 'XNA_53922.csv' already exists.
# No file has been generated (previous one remains).
# File 'FSM_13964.csv' already exists.
# No file has been generated (previous one remains).
# File 'JLN_13987.csv' already exists.
# No file has been generated (previous one remains).
# File 'SPS_13966.csv' already exists.
# No file has been generated (previous one remains).
# File 'OKC_13967.csv' already exists.
# No file has been generated (previous one remains).
# File 'SWO_3965.csv' already exists.
# No file has been generated (previous one remains).
# File 'TUL_13968.csv' already exists.
# No file has been generated (previous one remains).
# File 'LAW_3950.csv' already exists.
# No file has been generated (previous one remains).
# File 'AMA_23047.csv' already exists.
# No file has been generated (previous one remains).
# File 'ABQ_23050.csv' already exists.
# No file has been generated (previous one remains).
# File 'SAF_23049.csv' already exists.
# No file has been generated (previous one remains).
# File 'PRC_23184.csv' already exists.
# No file has been generated (previous one remains).
# File 'FLG_3103.csv' already exists.
# No file has been generated (previous one remains).
# File 'BFL_23155.csv' already exists.
# No file has been generated (previous one remains).
# File 'LAS_23169.csv' already exists.
# No file has been generated (previous one remains).
# File 'FAT_93193.csv' already exists.
# No file has been generated (previous one remains).
# File 'MMH_3181.csv' already exists.
# No file has been generated (previous one remains).
# File 'SBA_23190.csv' already exists.
# No file has been generated (previous one remains).
# File 'SMX_23273.csv' already exists.
# No file has been generated (previous one remains).
# File 'MDT_14711.csv' already exists.
# No file has been generated (previous one remains).
# File 'RIC_13740.csv' already exists.
# No file has been generated (previous one remains).
# File 'CHO_93736.csv' already exists.
# No file has been generated (previous one remains).
# File 'IAD_93738.csv' already exists.
# No file has been generated (previous one remains).
# File 'DCA_13743.csv' already exists.
# No file has been generated (previous one remains).
# File 'BWI_93721.csv' already exists.
# No file has been generated (previous one remains).
# File 'HGR_93706.csv' already exists.
# No file has been generated (previous one remains).
# File 'ACY_93730.csv' already exists.
# No file has been generated (previous one remains).
# File 'PHL_13739.csv' already exists.
# No file has been generated (previous one remains).
# File 'TTN_14792.csv' already exists.
# No file has been generated (previous one remains).
# File 'LYH_13733.csv' already exists.
# No file has been generated (previous one remains).
# File 'SHD_93760.csv' already exists.
# No file has been generated (previous one remains).
# File 'ROA_13741.csv' already exists.
# No file has been generated (previous one remains).
# File 'LWB_53801.csv' already exists.
# No file has been generated (previous one remains).
# File 'CRW_13866.csv' already exists.
# No file has been generated (previous one remains).
# File 'CKB_3802.csv' already exists.
# No file has been generated (previous one remains).
# File 'CVG_93814.csv' already exists.
# No file has been generated (previous one remains).
# File 'LEX_93820.csv' already exists.
# No file has been generated (previous one remains).
# File 'SDF_93821.csv' already exists.
# No file has been generated (previous one remains).
# File 'OWB_53803.csv' already exists.
# No file has been generated (previous one remains).
# File 'HTS_3860.csv' already exists.
# No file has been generated (previous one remains).
# File 'CMH_14821.csv' already exists.
# No file has been generated (previous one remains).
# File 'LCK_13812.csv' already exists.
# No file has been generated (previous one remains).
# File 'DAY_93815.csv' already exists.
# No file has been generated (previous one remains).
# File 'EVV_93817.csv' already exists.
# No file has been generated (previous one remains).
# File 'BLV_13802.csv' already exists.
# No file has been generated (previous one remains).
# File 'STL_13994.csv' already exists.
# No file has been generated (previous one remains).
# File 'IND_93819.csv' already exists.
# No file has been generated (previous one remains).
# File 'SPI_93822.csv' already exists.
# No file has been generated (previous one remains).
# File 'BMI_54831.csv' already exists.
# No file has been generated (previous one remains).
# File 'SGF_13995.csv' already exists.
# No file has been generated (previous one remains).
# File 'UIN_93989.csv' already exists.
# No file has been generated (previous one remains).
# File 'COU_3945.csv' already exists.
# No file has been generated (previous one remains).
# File 'MCI_3947.csv' already exists.
# No file has been generated (previous one remains).
# File 'ICT_3928.csv' already exists.
# No file has been generated (previous one remains).
# File 'GCK_23064.csv' already exists.
# No file has been generated (previous one remains).
# File 'LBL_23020.csv' already exists.
# No file has been generated (previous one remains).
# File 'HYS_3968.csv' already exists.
# No file has been generated (previous one remains).
# File 'MHK_3936.csv' already exists.
# No file has been generated (previous one remains).
# File 'DRO_93005.csv' already exists.
# No file has been generated (previous one remains).
# File 'PUB_93058.csv' already exists.
# No file has been generated (previous one remains).
# File 'COS_93037.csv' already exists.
# No file has been generated (previous one remains).
# File 'EGE_23063.csv' already exists.
# No file has been generated (previous one remains).
# File 'ASE_93073.csv' already exists.
# No file has been generated (previous one remains).
# File 'GUC_93007.csv' already exists.
# No file has been generated (previous one remains).
# File 'SGU_23186.csv' already exists.
# No file has been generated (previous one remains).
# File 'CDC_93129.csv' already exists.
# No file has been generated (previous one remains).
# File 'GJT_23066.csv' already exists.
# No file has been generated (previous one remains).
# File 'MTJ_93013.csv' already exists.
# No file has been generated (previous one remains).
# File 'CNY_93075.csv' already exists.
# No file has been generated (previous one remains).
# File 'SMF_93225.csv' already exists.
# No file has been generated (previous one remains).
# File 'RNO_23185.csv' already exists.
# No file has been generated (previous one remains).
# File 'MRY_23259.csv' already exists.
# No file has been generated (previous one remains).
# File 'SCK_23237.csv' already exists.
# No file has been generated (previous one remains).
# File 'OAK_23230.csv' already exists.
# No file has been generated (previous one remains).
# File 'SFO_23234.csv' already exists.
# No file has been generated (previous one remains).
# File 'SJC_23293.csv' already exists.
# No file has been generated (previous one remains).
# File 'EWR_14734.csv' already exists.
# No file has been generated (previous one remains).
# File 'LGA_14732.csv' already exists.
# No file has been generated (previous one remains).
# File 'HPN_94745.csv' already exists.
# No file has been generated (previous one remains).
# File 'SWF_14714.csv' already exists.
# No file has been generated (previous one remains).
# File 'HVN_14758.csv' already exists.
# No file has been generated (previous one remains).
# File 'ISP_4781.csv' already exists.
# No file has been generated (previous one remains).
# File 'ACK_14756.csv' already exists.
# No file has been generated (previous one remains).
# File 'MVY_94724.csv' already exists.
# No file has been generated (previous one remains).
# File 'HYA_94720.csv' already exists.
# No file has been generated (previous one remains).
# File 'PVD_14765.csv' already exists.
# No file has been generated (previous one remains).
# File 'BDL_14740.csv' already exists.
# No file has been generated (previous one remains).
# File 'BOS_14739.csv' already exists.
# No file has been generated (previous one remains).
# File 'ORH_94746.csv' already exists.
# No file has been generated (previous one remains).
# File 'AVP_14777.csv' already exists.
# No file has been generated (previous one remains).
# File 'BGM_4725.csv' already exists.
# No file has been generated (previous one remains).
# File 'ITH_94761.csv' already exists.
# No file has been generated (previous one remains).
# File 'ELM_14748.csv' already exists.
# No file has been generated (previous one remains).
# File 'ABE_14737.csv' already exists.
# No file has been generated (previous one remains).
# File 'ALB_14735.csv' already exists.
# No file has been generated (previous one remains).
# File 'SYR_14771.csv' already exists.
# No file has been generated (previous one remains).
# File 'PIT_94823.csv' already exists.
# No file has been generated (previous one remains).
# File 'LBE_54735.csv' already exists.
# No file has been generated (previous one remains).
# File 'CAK_14895.csv' already exists.
# No file has been generated (previous one remains).
# File 'CLE_14820.csv' already exists.
# No file has been generated (previous one remains).
# File 'ERI_14860.csv' already exists.
# No file has been generated (previous one remains).
# File 'BUF_14733.csv' already exists.
# No file has been generated (previous one remains).
# File 'ROC_14768.csv' already exists.
# No file has been generated (previous one remains).
# File 'ORD_94846.csv' already exists.
# No file has been generated (previous one remains).
# File 'CMI_94870.csv' already exists.
# No file has been generated (previous one remains).
# File 'PIA_14842.csv' already exists.
# No file has been generated (previous one remains).
# File 'FWA_14827.csv' already exists.
# No file has been generated (previous one remains).
# File 'MDW_14819.csv' already exists.
# No file has been generated (previous one remains).
# File 'SBN_14848.csv' already exists.
# No file has been generated (previous one remains).
# File 'TOL_94830.csv' already exists.
# No file has been generated (previous one remains).
# File 'DTW_94847.csv' already exists.
# No file has been generated (previous one remains).
# File 'LAN_14836.csv' already exists.
# No file has been generated (previous one remains).
# File 'RFD_94822.csv' already exists.
# No file has been generated (previous one remains).
# File 'MLI_14923.csv' already exists.
# No file has been generated (previous one remains).
# File 'CID_14990.csv' already exists.
# No file has been generated (previous one remains).
# File 'DSM_14933.csv' already exists.
# No file has been generated (previous one remains).
# File 'DBQ_94908.csv' already exists.
# No file has been generated (previous one remains).
# File 'ALO_94910.csv' already exists.
# No file has been generated (previous one remains).
# File 'OMA_14942.csv' already exists.
# No file has been generated (previous one remains).
# File 'LNK_14939.csv' already exists.
# No file has been generated (previous one remains).
# File 'GRI_14935.csv' already exists.
# No file has been generated (previous one remains).
# File 'EAR_14905.csv' already exists.
# No file has been generated (previous one remains).
# File 'SUX_14943.csv' already exists.
# No file has been generated (previous one remains).
# File 'LBF_24023.csv' already exists.
# No file has been generated (previous one remains).
# File 'CYS_24018.csv' already exists.
# No file has been generated (previous one remains).
# File 'LAR_24022.csv' already exists.
# No file has been generated (previous one remains).
# File 'DEN_3017.csv' already exists.
# No file has been generated (previous one remains).
# File 'BFF_24028.csv' already exists.
# No file has been generated (previous one remains).
# File 'CPR_24089.csv' already exists.
# No file has been generated (previous one remains).
# File 'VEL_94030.csv' already exists.
# No file has been generated (previous one remains).
# File 'HDN_94025.csv' already exists.
# No file has been generated (previous one remains).
# File 'SLC_24127.csv' already exists.
# No file has been generated (previous one remains).
# File 'PVU_24174.csv' already exists.
# No file has been generated (previous one remains).
# File 'RKS_24027.csv' already exists.
# No file has been generated (previous one remains).
# File 'OGD_24126.csv' already exists.
# No file has been generated (previous one remains).
# File 'JAC_24166.csv' already exists.
# No file has been generated (previous one remains).
# File 'PIH_24156.csv' already exists.
# No file has been generated (previous one remains).
# File 'IDA_24145.csv' already exists.
# No file has been generated (previous one remains).
# File 'EKO_24121.csv' already exists.
# No file has been generated (previous one remains).
# File 'SUN_94161.csv' already exists.
# No file has been generated (previous one remains).
# File 'TWF_94178.csv' already exists.
# No file has been generated (previous one remains).
# File 'RDD_24257.csv' already exists.
# No file has been generated (previous one remains).
# File 'ACV_24283.csv' already exists.
# No file has been generated (previous one remains).
# File 'MFR_24225.csv' already exists.
# No file has been generated (previous one remains).
# File 'PSM_4743.csv' already exists.
# No file has been generated (previous one remains).
# File 'PWM_14764.csv' already exists.
# No file has been generated (previous one remains).
# File 'BGR_14606.csv' already exists.
# No file has been generated (previous one remains).
# File 'BTV_14742.csv' already exists.
# No file has been generated (previous one remains).
# File 'PBG_64776.csv' already exists.
# No file has been generated (previous one remains).
# File 'ART_94790.csv' already exists.
# No file has been generated (previous one remains).
# File 'GRR_94860.csv' already exists.
# No file has been generated (previous one remains).
# File 'AZO_94815.csv' already exists.
# No file has been generated (previous one remains).
# File 'MKG_14840.csv' already exists.
# No file has been generated (previous one remains).
# File 'FNT_14826.csv' already exists.
# No file has been generated (previous one remains).
# File 'MBS_14845.csv' already exists.
# No file has been generated (previous one remains).
# File 'TVC_14850.csv' already exists.
# No file has been generated (previous one remains).
# File 'APN_94849.csv' already exists.
# No file has been generated (previous one remains).
# File 'MKE_14839.csv' already exists.
# No file has been generated (previous one remains).
# File 'MSN_14837.csv' already exists.
# No file has been generated (previous one remains).
# File 'LSE_14920.csv' already exists.
# No file has been generated (previous one remains).
# File 'EAU_14991.csv' already exists.
# No file has been generated (previous one remains).
# File 'RST_14925.csv' already exists.
# No file has been generated (previous one remains).
# File 'GRB_14898.csv' already exists.
# No file has been generated (previous one remains).
# File 'ATW_4825.csv' already exists.
# No file has been generated (previous one remains).
# File 'CWA_94890.csv' already exists.
# No file has been generated (previous one remains).
# File 'FSD_14944.csv' already exists.
# No file has been generated (previous one remains).
# File 'ATY_14946.csv' already exists.
# No file has been generated (previous one remains).
# File 'STC_14926.csv' already exists.
# No file has been generated (previous one remains).
# File 'BRD_94938.csv' already exists.
# No file has been generated (previous one remains).
# File 'PIR_24025.csv' already exists.
# No file has been generated (previous one remains).
# File 'MSP_14922.csv' already exists.
# No file has been generated (previous one remains).
# File 'ABR_14929.csv' already exists.
# No file has been generated (previous one remains).
# File 'RAP_24090.csv' already exists.
# No file has been generated (previous one remains).
# File 'GCC_94023.csv' already exists.
# No file has been generated (previous one remains).
# File 'COD_24045.csv' already exists.
# No file has been generated (previous one remains).
# File 'WYS_94163.csv' already exists.
# No file has been generated (previous one remains).
# File 'BIL_24033.csv' already exists.
# No file has been generated (previous one remains).
# File 'BZN_24132.csv' already exists.
# No file has been generated (previous one remains).
# File 'BOI_24131.csv' already exists.
# No file has been generated (previous one remains).
# File 'OTH_24284.csv' already exists.
# No file has been generated (previous one remains).
# File 'RDM_24230.csv' already exists.
# No file has been generated (previous one remains).
# File 'EUG_24221.csv' already exists.
# No file has been generated (previous one remains).
# File 'PDX_24229.csv' already exists.
# No file has been generated (previous one remains).
# File 'CIU_4869.csv' already exists.
# No file has been generated (previous one remains).
# File 'PLN_14841.csv' already exists.
# No file has been generated (previous one remains).
# File 'RHI_4803.csv' already exists.
# No file has been generated (previous one remains).
# File 'MQT_94850.csv' already exists.
# No file has been generated (previous one remains).
# File 'IMT_94893.csv' already exists.
# No file has been generated (previous one remains).
# File 'CMX_14858.csv' already exists.
# No file has been generated (previous one remains).
# File 'DLH_14913.csv' already exists.
# No file has been generated (previous one remains).
# File 'HIB_94931.csv' already exists.
# No file has been generated (previous one remains).
# File 'INL_14918.csv' already exists.
# No file has been generated (previous one remains).
# File 'FAR_14914.csv' already exists.
# No file has been generated (previous one remains).
# File 'JMS_14919.csv' already exists.
# No file has been generated (previous one remains).
# File 'BJI_14958.csv' already exists.
# No file has been generated (previous one remains).
# File 'GFK_14916.csv' already exists.
# No file has been generated (previous one remains).
# File 'DVL_94928.csv' already exists.
# No file has been generated (previous one remains).
# File 'BIS_24011.csv' already exists.
# No file has been generated (previous one remains).
# File 'ISN_94014.csv' already exists.
# No file has been generated (previous one remains).
# File 'MOT_24013.csv' already exists.
# No file has been generated (previous one remains).
# File 'HLN_24144.csv' already exists.
# No file has been generated (previous one remains).
# File 'MSO_24153.csv' already exists.
# No file has been generated (previous one remains).
# File 'BTM_24135.csv' already exists.
# No file has been generated (previous one remains).
# File 'GTF_24143.csv' already exists.
# No file has been generated (previous one remains).
# File 'LWS_24149.csv' already exists.
# No file has been generated (previous one remains).
# File 'PSC_24163.csv' already exists.
# No file has been generated (previous one remains).
# File 'GEG_24157.csv' already exists.
# No file has been generated (previous one remains).
# File 'SEA_24233.csv' already exists.
# No file has been generated (previous one remains).
# File 'PAE_24222.csv' already exists.
# No file has been generated (previous one remains).
# File 'BLI_24217.csv' already exists.
# No file has been generated (previous one remains).
# File 'MHT_14710.csv' already exists.
# No file has been generated (previous one remains).
# File 'JFK_94789.csv' already exists.
# No file has been generated (previous one remains).
# File 'ONT_3102.csv' already exists.
# No file has been generated (previous one remains).
# File 'CLL_3904.csv' already exists.
# No file has been generated (previous one remains).
# File 'AEX_93915.csv' already exists.
# No file has been generated (previous one remains).
# File 'GNV_12816.csv' already exists.
# No file has been generated (previous one remains).
# File 'GPT_93874.csv' already exists.
# No file has been generated (previous one remains).
# File 'FLL_12849.csv' already exists.
# No file has been generated (previous one remains).
# File 'DAB_12834.csv' already exists.
# No file has been generated (previous one remains).
# File 'MYR_13717.csv' already exists.
# No file has been generated (previous one remains).
# File 'BQN_11603.csv' already exists.
# No file has been generated (previous one remains).
# File 'SJU_11641.csv' already exists.
# No file has been generated (previous one remains).
# File 'STT_11640.csv' already exists.
# No file has been generated (previous one remains).
# File 'STX_11624.csv' already exists.
# No file has been generated (previous one remains).
# File 'LIH_22536.csv' already exists.
# No file has been generated (previous one remains).
# File 'HNL_22521.csv' already exists.
# No file has been generated (previous one remains).
# File 'OGG_22516.csv' already exists.
# No file has been generated (previous one remains).
# File 'KOA_21510.csv' already exists.
# No file has been generated (previous one remains).
# File 'GUM_41415.csv' already exists.
# No file has been generated (previous one remains).
# File 'ITO_21504.csv' already exists.
# No file has been generated (previous one remains).
# File 'PPG_61705.csv' already exists.
# No file has been generated (previous one remains).

# %%
disjointed_iatas
# Out:
# ['AZA', 'USA', 'FCA', 'SCE', 'PAH', 'SPN', 'HHH', 'OGS', 'BKG']

# %%
missing_stations
# Out:
# ['HRL', 'IAG', 'DHN', 'ESC', 'PSE', 'SLN', 'STS', 'YUM', 'XWA']

# %%
missingwban_completeList = disjointed_iatas + missing_stations
missingwban_completeList
# Out:
# ['AZA',
#  'USA',
#  'FCA',
#  'SCE',
#  'PAH',
#  'SPN',
#  'HHH',
#  'OGS',
#  'BKG',
#  'HRL',
#  'IAG',
#  'DHN',
#  'ESC',
#  'PSE',
#  'SLN',
#  'STS',
#  'YUM',
#  'XWA']

# %% [markdown]
# To sum up, below is the list of those iata codes that appear in the otp dataset, but have no weather station:
# `['AZA', 'USA', 'FCA', 'SCE', 'PAH', 'SPN', 'HHH', 'OGS', 'BKG', 'DHN', 'ESC', 'HRL', 'IAG', 'PSE', 'SLN', 'STS', 'XWA','YUM']`

# %% [markdown]
# # Cross each IATA with its WBAN in the OTP dataset

# %% [markdown]
# ### OTP (2019)

# %%
otp = pd.read_csv('../data/output/us_dot/1_otp_2019_raw.csv',
                  encoding='latin1',
                  low_memory = False)

# %%
otp_wban_Origin = otp.merge(lcd_wban_clean[['WBAN', 'FAA_LOC_ID']],
                            how='inner', left_on='ORIGIN', right_on='FAA_LOC_ID')
otp_wban_Origin.rename(columns={'WBAN': 'WBAN_Origin'}, inplace=True)
otp_wban_OriginDest = otp_wban_Origin.merge(lcd_wban_clean[['WBAN', 'FAA_LOC_ID']],
                                            how='inner', left_on='DEST', right_on='FAA_LOC_ID')
otp_wban_OriginDest.rename(columns={'WBAN': 'WBAN_Dest'}, inplace=True)
rearranged_cols = [
       'MONTH', 'DAY_OF_MONTH', 'DAY_OF_WEEK', 'OP_UNIQUE_CARRIER', 'TAIL_NUM',
       'ORIGIN', 'ORIGIN_CITY_NAME', 'ORIGIN_STATE_ABR', 'ORIGIN_STATE_NM', 'WBAN_Origin',
       'DEST', 'DEST_CITY_NAME', 'DEST_STATE_ABR', 'DEST_STATE_NM', 'WBAN_Dest',
       'CRS_DEP_TIME', 'DEP_TIME', 'DEP_DELAY', 'DEP_DEL15', 'DEP_TIME_hour', 'TAXI_OUT',
       'TAXI_IN', 'TAXI_OUT_median', 'TAXI_IN_median', 'CRS_ARR_TIME', 'ARR_TIME',
       'ARR_DELAY', 'ARR_DEL15', 'ARR_TIME_hour', 'CANCELLED','CRS_ELAPSED_TIME', 'DISTANCE', 'DISTANCE_GROUP',
       'CARRIER_DELAY', 'WEATHER_DELAY', 'NAS_DELAY', 'SECURITY_DELAY', 'LATE_AIRCRAFT_DELAY'
]

otp_wban_OriginDest = otp_wban_OriginDest[rearranged_cols]
otp_wban_OriginDest
# Out:
#          MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM ORIGIN  \
# 0            1             3            4                9E   N195PQ    TYS
# 1            1             4            5                9E   N919XJ    TYS
# 2            1             1            2                9E   N606LR    TYS
# 3            1             2            3                9E   N920XJ    TYS
# 4            1             3            4                9E   N329PQ    TYS
# ...        ...           ...          ...               ...      ...    ...
# 7208367      8             6            2                AS   N619AS    JNU
# 7208368      8            23            5                AS   N614AS    JNU
# 7208369      8            24            6                AS   N613AS    JNU
# 7208370      8            25            7                AS   N614AS    JNU
# 7208371      8            26            1                AS   N622AS    JNU
#
#         ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM  WBAN_Origin DEST  \
# 0          Knoxville, TN               TN       Tennessee        13891  ATL
# 1          Knoxville, TN               TN       Tennessee        13891  ATL
# 2          Knoxville, TN               TN       Tennessee        13891  ATL
# 3          Knoxville, TN               TN       Tennessee        13891  ATL
# 4          Knoxville, TN               TN       Tennessee        13891  ATL
# ...                  ...              ...             ...          ...  ...
# 7208367       Juneau, AK               AK          Alaska        25309  GST
# 7208368       Juneau, AK               AK          Alaska        25309  GST
# 7208369       Juneau, AK               AK          Alaska        25309  GST
# 7208370       Juneau, AK               AK          Alaska        25309  GST
# 7208371       Juneau, AK               AK          Alaska        25309  GST
#
#         DEST_CITY_NAME DEST_STATE_ABR DEST_STATE_NM  WBAN_Dest  CRS_DEP_TIME  \
# 0          Atlanta, GA             GA       Georgia      13874          1140
# 1          Atlanta, GA             GA       Georgia      13874          1140
# 2          Atlanta, GA             GA       Georgia      13874           706
# 3          Atlanta, GA             GA       Georgia      13874           706
# 4          Atlanta, GA             GA       Georgia      13874           706
# ...                ...            ...           ...        ...           ...
# 7208367   Gustavus, AK             AK        Alaska      25322          1700
# 7208368   Gustavus, AK             AK        Alaska      25322          1700
# 7208369   Gustavus, AK             AK        Alaska      25322          1700
# 7208370   Gustavus, AK             AK        Alaska      25322          1700
# 7208371   Gustavus, AK             AK        Alaska      25322          1700
#
#          DEP_TIME  DEP_DELAY  DEP_DEL15  DEP_TIME_hour  TAXI_OUT  TAXI_IN  \
# 0            1205         25          1             11        30        4
# 1            1250         70          1             11        35        9
# 2             659         -7          0              7        13        4
# 3             700         -6          0              7        17        4
# 4             703         -3          0              7        19        5
# ...           ...        ...        ...            ...       ...      ...
# 7208367      1700          0          0             17        12        6
# 7208368      1639        -21          0             17        12        6
# 7208369      1641        -19          0             17        11        6
# 7208370      1926        146          1             17        22        3
# 7208371      1658         -2          0             17         8        5
#
#          TAXI_OUT_median  TAXI_IN_median  CRS_ARR_TIME  ARR_TIME  ARR_DELAY  \
# 0                     15               8          1250      1315         25
# 1                     15               8          1250      1412         82
# 2                     15               8           813       749        -24
# 3                     15               8           815       753        -22
# 4                     15               8           815       801        -14
# ...                  ...             ...           ...       ...        ...
# 7208367               12               6          1735      1730         -5
# 7208368               12               6          1735      1710        -25
# 7208369               12               6          1735      1717        -18
# 7208370               12               6          1735      2008        153
# 7208371               12               6          1735      1725        -10
#
#          ARR_DEL15  ARR_TIME_hour  CANCELLED  CRS_ELAPSED_TIME  DISTANCE  \
# 0                1             12          0                70       152
# 1                1             12          0                70       152
# 2                0              8          0                67       152
# 3                0              8          0                69       152
# 4                0              8          0                69       152
# ...            ...            ...        ...               ...       ...
# 7208367          0             17          0                35        41
# 7208368          0             17          0                35        41
# 7208369          0             17          0                35        41
# 7208370          1             17          0                35        41
# 7208371          0             17          0                35        41
#
#          DISTANCE_GROUP  CARRIER_DELAY  WEATHER_DELAY  NAS_DELAY  \
# 0                     1              0              0          0
# 1                     1              0              0         12
# 2                     1              0              0          0
# 3                     1              0              0          0
# 4                     1              0              0          0
# ...                 ...            ...            ...        ...
# 7208367               1              0              0          0
# 7208368               1              0              0          0
# 7208369               1              0              0          0
# 7208370               1            146              0          7
# 7208371               1              0              0          0
#
#          SECURITY_DELAY  LATE_AIRCRAFT_DELAY
# 0                     0                   25
# 1                     0                   70
# 2                     0                    0
# 3                     0                    0
# 4                     0                    0
# ...                 ...                  ...
# 7208367               0                    0
# 7208368               0                    0
# 7208369               0                    0
# 7208370               0                    0
# 7208371               0                    0
#
# [7208372 rows x 38 columns]

# %%
otp_wban_OriginDest[otp_wban_OriginDest['ORIGIN'].isin(missingwban_completeList) | \
                    otp_wban_OriginDest['DEST'].isin(missingwban_completeList)]
# Out:
# Empty DataFrame
# Columns: [MONTH, DAY_OF_MONTH, DAY_OF_WEEK, OP_UNIQUE_CARRIER, TAIL_NUM, ORIGIN, ORIGIN_CITY_NAME, ORIGIN_STATE_ABR, ORIGIN_STATE_NM, WBAN_Origin, DEST, DEST_CITY_NAME, DEST_STATE_ABR, DEST_STATE_NM, WBAN_Dest, CRS_DEP_TIME, DEP_TIME, DEP_DELAY, DEP_DEL15, DEP_TIME_hour, TAXI_OUT, TAXI_IN, TAXI_OUT_median, TAXI_IN_median, CRS_ARR_TIME, ARR_TIME, ARR_DELAY, ARR_DEL15, ARR_TIME_hour, CANCELLED, CRS_ELAPSED_TIME, DISTANCE, DISTANCE_GROUP, CARRIER_DELAY, WEATHER_DELAY, NAS_DELAY, SECURITY_DELAY, LATE_AIRCRAFT_DELAY]
# Index: []

# %%
otp[otp['ORIGIN'].isin(missingwban_completeList) | \
    otp['DEST'].isin(missingwban_completeList)]
# Out:
#          MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER TAIL_NUM ORIGIN  \
# 2358         1             4            5                WN   N934WN    HOU
# 2359         1             4            5                WN   N7748A    HOU
# 2360         1             4            5                WN   N405WN    HOU
# 2361         1             4            5                WN   N473WN    HOU
# 2362         1             4            5                WN   N8728Q    HOU
# ...        ...           ...          ...               ...      ...    ...
# 7268150     12            31            2                B6   N637JB    PSE
# 7268187     12            31            2                B6   N958JB    JFK
# 7268188     12            31            2                B6   N958JB    PSE
# 7268195     12            31            2                B6   N591JB    MCO
# 7268196     12            31            2                B6   N653JB    PSE
#
#         ORIGIN_CITY_NAME ORIGIN_STATE_ABR ORIGIN_STATE_NM DEST  \
# 2358         Houston, TX               TX           Texas  HRL
# 2359         Houston, TX               TX           Texas  HRL
# 2360         Houston, TX               TX           Texas  HRL
# 2361         Houston, TX               TX           Texas  HRL
# 2362         Houston, TX               TX           Texas  HRL
# ...                  ...              ...             ...  ...
# 7268150        Ponce, PR               PR     Puerto Rico  MCO
# 7268187     New York, NY               NY        New York  PSE
# 7268188        Ponce, PR               PR     Puerto Rico  JFK
# 7268195      Orlando, FL               FL         Florida  PSE
# 7268196        Ponce, PR               PR     Puerto Rico  MCO
#
#                    DEST_CITY_NAME DEST_STATE_ABR DEST_STATE_NM  CRS_DEP_TIME  \
# 2358     Harlingen/San Benito, TX             TX         Texas          1835
# 2359     Harlingen/San Benito, TX             TX         Texas          1045
# 2360     Harlingen/San Benito, TX             TX         Texas          2210
# 2361     Harlingen/San Benito, TX             TX         Texas           805
# 2362     Harlingen/San Benito, TX             TX         Texas          1340
# ...                           ...            ...           ...           ...
# 7268150               Orlando, FL             FL       Florida           138
# 7268187                 Ponce, PR             PR   Puerto Rico          2059
# 7268188              New York, NY             NY      New York           319
# 7268195                 Ponce, PR             PR   Puerto Rico          2359
# 7268196               Orlando, FL             FL       Florida           501
#
#          DEP_TIME  DEP_DELAY  DEP_DEL15  DEP_TIME_hour  TAXI_OUT  TAXI_IN  \
# 2358         1854         19          1             18         8        2
# 2359         1044         -1          0             10        10        2
# 2360         2254         44          1             22        13        2
# 2361          800         -5          0              8        11        2
# 2362         1407         27          1             13        11        3
# ...           ...        ...        ...            ...       ...      ...
# 7268150       123        -15          0              0        11        4
# 7268187      2055         -4          0             20        16        4
# 7268188       320          1          0              0        22        5
# 7268195         8          9          0             23        18        7
# 7268196       447        -14          0              0        16        5
#
#          CRS_ARR_TIME  ARR_TIME  ARR_DELAY  ARR_DEL15  ARR_TIME_hour  \
# 2358             1935      1947         12          0             19
# 2359             1150      1138        -12          0             11
# 2360             2315      2350         35          1             23
# 2361              910       857        -13          0              9
# 2362             1440      1508         28          1             14
# ...               ...       ...        ...        ...            ...
# 7268150           340       315        -25          0              0
# 7268187           159       134        -25          0              0
# 7268188           628       624         -4          0              6
# 7268195           344       352          8          0              0
# 7268196           707       650        -17          0              7
#
#          CANCELLED  CRS_ELAPSED_TIME  DISTANCE  DISTANCE_GROUP  CARRIER_DELAY  \
# 2358             0                60       277               2              0
# 2359             0                65       277               2              0
# 2360             0                65       277               2              5
# 2361             0                65       277               2              0
# 2362             0                60       277               2             27
# ...            ...               ...       ...             ...            ...
# 7268150          0               182      1179               5              0
# 7268187          0               240      1617               7              0
# 7268188          0               249      1617               7              0
# 7268195          0               165      1179               5              0
# 7268196          0               186      1179               5              0
#
#          WEATHER_DELAY  NAS_DELAY  SECURITY_DELAY  LATE_AIRCRAFT_DELAY  \
# 2358                 0          0               0                    0
# 2359                 0          0               0                    0
# 2360                 0          0               0                   30
# 2361                 0          0               0                    0
# 2362                 0          1               0                    0
# ...                ...        ...             ...                  ...
# 7268150              0          0               0                    0
# 7268187              0          0               0                    0
# 7268188              0          0               0                    0
# 7268195              0          0               0                    0
# 7268196              0          0               0                    0
#
#          TAXI_OUT_median  TAXI_IN_median
# 2358                   9               2
# 2359                   9               2
# 2360                   9               2
# 2361                   9               2
# 2362                   9               2
# ...                  ...             ...
# 7268150               12               8
# 7268187               20               5
# 7268188               12               8
# 7268195               15               5
# 7268196               12               8
#
# [59860 rows x 36 columns]

# %%
(len(otp) - len(otp_wban_OriginDest)) == len(otp[otp['ORIGIN'].isin(missingwban_completeList) | \
                                                 otp['DEST'].isin(missingwban_completeList)])
# Out:
# True

# %% [markdown]
# From this it can be deduced that the result of these merge operations is a new dataset in which only rows corresponding to the previously identified missing WBAN stations are dropped. Just as expected, which is a good sign.

# %%
print("Number of discarded flights: {} ({:5.3f}%)".format((len(otp) - len(otp_wban_OriginDest)),
                                                           100 * (len(otp) - len(otp_wban_OriginDest)) / len(otp)))
# Out:
# Number of discarded flights: 59860 (0.824%)

# %% [markdown]
# As previously calculated, the dismissed flights account for less than 1% of the entire dataset. In return, this will enable us to allocate the applicable weather conditions to each flight. This data could potentially greatly improve the model, so it seems reasonable to just drop them.

# %%
# %%time

otp_wban_OriginDest.to_csv('../data/output/us_dot/2_otp_2019_wban.csv',
                           index=False,
                           encoding='latin1')
# Out:
# Wall time: 1min 35s

# %%
t1 = time.perf_counter() - t0
print("Time elapsed: ", t1) # CPU seconds elapsed (floating point)
# Out:
# Time elapsed:  185.61764889999998

# %% [markdown]
# ___

# %% [markdown]
# ___
