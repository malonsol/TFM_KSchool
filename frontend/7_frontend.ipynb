# %% [markdown]
# ___

# %%
# Import libraries to be used

# Directories/Files management
import os.path

# Timing
import time

# Data analysis and wrangling
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) # Show all columns in DataFrames
## pd.set_option('display.max_rows', None) # It greatly slows down the output display and may freeze the kernel
import missingno as msno
from collections import Counter

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot') # choose a style: 'plt.style.available'
sns.set_theme(context='notebook',
              style="darkgrid") # {darkgrid, whitegrid, dark, white, ticks}
palette = sns.color_palette("flare", as_cmap=True);
import altair as alt

# Machine Learning:
# - Model selection:
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, KFold, cross_val_score, StratifiedKFold, \
                                    GridSearchCV, RandomizedSearchCV
from sklearn.inspection import permutation_importance

# - Basic classes for custom-made transformers:
from sklearn.base import BaseEstimator, TransformerMixin

# - Transformers:
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from category_encoders.target_encoder import TargetEncoder
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA

# - Pipeline:
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# - Models:
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier, plot_importance, plot_tree

# - Metrics:
from sklearn.metrics import fbeta_score, f1_score, recall_score, precision_score, accuracy_score, \
                            confusion_matrix, classification_report, roc_curve, precision_recall_curve, \
                            roc_auc_score, average_precision_score, plot_roc_curve, plot_precision_recall_curve

# Objects storage:
from joblib import dump, load
import pickle

# %%
t0 = time.perf_counter()

# %%
# Detect Operating System running and manage paths accordingly

root = os.getcwd()
if os.name == 'nt': # Windows
    print("Running on Windows.")
elif os.name == 'posix': # Ubuntu
    print("Running on Ubuntu.")
print("root path\t", root)
# Out:
# Running on Windows.
# root path	 C:\Users\turge\Desktop\TFM\notebooks\frontend

# %% [markdown]
# ___

# %% [markdown]
# # Load the dataset

# %%
cols = [
    'MONTH',
#     'DAY_OF_MONTH',
    'DAY_OF_WEEK',
    'OP_UNIQUE_CARRIER',
#     'TAIL_NUM',
    'ORIGIN',
#     'ORIGIN_CITY_NAME',
#     'ORIGIN_STATE_ABR',
#     'ORIGIN_STATE_NM',
#     'WBAN_Origin_OTP',
    'DEST',
#     'DEST_CITY_NAME',
#     'DEST_STATE_ABR',
#     'DEST_STATE_NM',
#     'WBAN_Dest_OTP',
#     'CRS_DEP_TIME',
#     'DEP_TIME',
#     'DEP_DELAY',
#     'DEP_DEL15',
    'DEP_TIME_hour',
#     'TAXI_OUT',
#     'TAXI_IN',
    'TAXI_OUT_median',
    'TAXI_IN_median',
#     'CRS_ARR_TIME',
#     'ARR_TIME',
#     'ARR_DELAY',
    'ARR_DEL15', # → Target !!
    'ARR_TIME_hour',
#     'CANCELLED',
    'CRS_ELAPSED_TIME',
    'DISTANCE',
#     'DISTANCE_GROUP',
#     'CARRIER_DELAY',
#     'WEATHER_DELAY',
#     'NAS_DELAY',
#     'SECURITY_DELAY',
#     'LATE_AIRCRAFT_DELAY',
    
#     'STATION_Origin',
#     'WMO_Origin',
#     'WBAN_Origin_LCD',
    'LATITUDE_Origin',
    'LONGITUDE_Origin',
    'HourlyAltimeterSetting_Origin',
    'HourlyDryBulbTemperature_Origin',
    'HourlyPrecipitation_Origin',
    'HourlyRelativeHumidity_Origin',
    'HourlySkyConditions_Origin',
    'HourlyVisibility_Origin',
#     'HourlyWindDirection_Origin',
    'HourlyWindGustSpeed_Origin',
    'HourlyWindSpeed_Origin',
#     'REM_Origin',
#     'STATION_Dest',
#     'WMO_Dest',
#     'WBAN_Dest_LCD',
    'LATITUDE_Dest',
    'LONGITUDE_Dest',
    'HourlyAltimeterSetting_Dest',
    'HourlyDryBulbTemperature_Dest',
    'HourlyPrecipitation_Dest',
    'HourlyRelativeHumidity_Dest',
    'HourlySkyConditions_Dest',
    'HourlyVisibility_Dest',
#     'HourlyWindDirection_Dest',
    'HourlyWindGustSpeed_Dest',
    'HourlyWindSpeed_Dest',
#     'REM_Dest'
]

# %%
cols_dtypes = {
    'MONTH' : 'string',
#     'DAY_OF_MONTH' : 'string',
    'DAY_OF_WEEK' : 'string',
    'OP_UNIQUE_CARRIER' : 'string',
#     'TAIL_NUM' : 'string',
    'ORIGIN' : 'string',
#     'ORIGIN_CITY_NAME' : 'string',
#     'ORIGIN_STATE_ABR' : 'string',
#     'ORIGIN_STATE_NM' : 'string',
#     'WBAN_Origin_OTP' : 'string',
    'DEST' : 'string',
#     'DEST_CITY_NAME' : 'string',
#     'DEST_STATE_ABR' : 'string',
#     'DEST_STATE_NM' : 'string',
#     'WBAN_Dest_OTP' : 'string',
#     'CRS_DEP_TIME' : 'string',
#     'DEP_TIME' : 'string',
#     'DEP_DELAY' : 'int32',
#     'DEP_DEL15' : 'int32',
    'DEP_TIME_hour' : 'string',
#     'TAXI_OUT' : 'int32',
#     'TAXI_IN' : 'int32',
    'TAXI_OUT_median' : 'int32',
    'TAXI_IN_median' : 'int32',
#     'CRS_ARR_TIME' : 'string',
#     'ARR_TIME' : 'string',
#     'ARR_DELAY' : 'int32',
    'ARR_DEL15' : 'int32', # → Target !!
    'ARR_TIME_hour' : 'string',
#     'CANCELLED' : 'string',
    'CRS_ELAPSED_TIME' : 'int32',
    'DISTANCE' : 'int32',
#     'DISTANCE_GROUP' : 'string',
#     'CARRIER_DELAY' : 'int32',
#     'WEATHER_DELAY' : 'int32',
#     'NAS_DELAY' : 'int32',
#     'SECURITY_DELAY' : 'int32',
#     'LATE_AIRCRAFT_DELAY' : 'int32',

#     'STATION_Origin' : 'string',
#     'WMO_Origin' : 'string',
#     'WBAN_Origin_LCD' : 'string',
    'LATITUDE_Origin' : 'float64',
    'LONGITUDE_Origin' : 'float64',
    'HourlyAltimeterSetting_Origin' : 'float64',
    'HourlyDryBulbTemperature_Origin' : 'int32',
    'HourlyPrecipitation_Origin' : 'float64',
    'HourlyRelativeHumidity_Origin' : 'int32',
    'HourlySkyConditions_Origin' : 'string',
    'HourlyVisibility_Origin' : 'int32',
#     'HourlyWindDirection_Origin' : 'string',
    'HourlyWindGustSpeed_Origin' : 'int32',
    'HourlyWindSpeed_Origin' : 'int32',
#     'REM_Origin' : 'string',
#     'STATION_Dest' : 'string',
#     'WMO_Dest' : 'string',
#     'WBAN_Dest_LCD' : 'string',
    'LATITUDE_Dest' : 'float64',
    'LONGITUDE_Dest' : 'float64',
    'HourlyAltimeterSetting_Dest' : 'float64',
    'HourlyDryBulbTemperature_Dest' : 'int32',
    'HourlyPrecipitation_Dest' : 'float64',
    'HourlyRelativeHumidity_Dest' : 'int32',
    'HourlySkyConditions_Dest' : 'string',
    'HourlyVisibility_Dest' : 'int32',
#     'HourlyWindDirection_Dest' : 'string',
    'HourlyWindGustSpeed_Dest' : 'int32',
    'HourlyWindSpeed_Dest' : 'int32',
#     'REM_Dest' : 'string',
}

# %% [markdown]
# ___

# %% [markdown]
# ## 1. Load the dataset

# %%
# %%time

input_folder = '../../data/output/us_dot-noaa/'
file_name = "3_otp_lcd_2019.csv"

df = pd.read_csv(input_folder + file_name,
                 encoding='latin1',
#                      nrows=1e5,
                 usecols=cols,
                 dtype=cols_dtypes
                )
df.sample(5)
# Out:
# Wall time: 1min 38s
#         MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST DEP_TIME_hour  \
# 302212     09           6                YX    DTW  DCA             6
# 7164184    05           6                HA    HNL  KOA             7
# 2546656    03           5                AA    ORD  SFO            17
# 5169198    06           4                9E    MSN  MSP             9
# 1577251    07           2                OH    ECP  CLT             7
#
#          TAXI_OUT_median  TAXI_IN_median  ARR_DEL15 ARR_TIME_hour  \
# 302212                17               6          0             7
# 7164184               14               5          0             8
# 2546656               17               6          0            19
# 5169198               14               6          1            10
# 1577251               13              13          0            10
#
#          CRS_ELAPSED_TIME  DISTANCE  LATITUDE_Origin  LONGITUDE_Origin  \
# 302212                 97       405         42.23130         -83.33080
# 7164184                47       163         21.32400        -157.92940
# 2546656               286      1846         41.96019         -87.93162
# 5169198                71       228         43.14050         -89.34520
# 1577251               107       437         30.34900         -85.78800
#
#          HourlyAltimeterSetting_Origin  HourlyDryBulbTemperature_Origin  \
# 302212                           29.98                               63
# 7164184                          30.03                               77
# 2546656                          29.95                               46
# 5169198                          30.14                               84
# 1577251                          30.05                               85
#
#          HourlyPrecipitation_Origin  HourlyRelativeHumidity_Origin  \
# 302212                          0.0                             87
# 7164184                         0.0                             74
# 2546656                         0.0                             61
# 5169198                         0.0                             53
# 1577251                         0.0                             65
#
#         HourlySkyConditions_Origin  HourlyVisibility_Origin  \
# 302212                         OVC                       10
# 7164184                        FEW                       10
# 2546656                        OVC                       10
# 5169198                        SCT                       10
# 1577251                        CLR                       10
#
#          HourlyWindGustSpeed_Origin  HourlyWindSpeed_Origin  LATITUDE_Dest  \
# 302212                            0                       8       38.84720
# 7164184                           0                       5       19.73556
# 2546656                           0                      10       37.61970
# 5169198                           0                       7       44.88310
# 1577251                           0                      10       35.22360
#
#          LONGITUDE_Dest  HourlyAltimeterSetting_Dest  \
# 302212        -77.03454                        29.89
# 7164184      -156.04889                        30.01
# 2546656      -122.36470                        30.29
# 5169198       -93.22890                        30.09
# 1577251       -80.95520                        30.02
#
#          HourlyDryBulbTemperature_Dest  HourlyPrecipitation_Dest  \
# 302212                              66                      0.00
# 7164184                             79                      0.00
# 2546656                             53                      0.00
# 5169198                             67                      0.02
# 1577251                             89                      0.00
#
#          HourlyRelativeHumidity_Dest HourlySkyConditions_Dest  \
# 302212                            81                      OVC
# 7164184                           69                      FEW
# 2546656                           80                      FEW
# 5169198                           87                      OVC
# 1577251                           50                      OVC
#
#          HourlyVisibility_Dest  HourlyWindGustSpeed_Dest  HourlyWindSpeed_Dest
# 302212                       9                         0                     0
# 7164184                     10                         0                     6
# 2546656                     10                         0                    18
# 5169198                      8                         0                     5
# 1577251                      9                         0                     6

# %% [markdown]
# # Prepare user input fields

# %% [markdown]
# ### `OP_UNIQUE_CARRIER`

# %%
carriers_dict = {
                    '9E' : '[9E] Endeavor Air Inc.',
                    'AA' : '[AA] American Airlines Inc.',
                    'AS' : '[AS] Alaska Airlines Inc.',
                    'B6' : '[B6] JetBlue Airways',
                    'DL' : '[DL] Delta Air Lines Inc.',
                    'EV' : '[EV] ExpressJet Airlines LLC',
                    'F9' : '[F9] Frontier Airlines Inc.',
                    'G4' : '[G4] Allegiant Air',
                    'HA' : '[HA] Hawaiian Airlines Inc.',
                    'MQ' : '[MQ] Envoy Air',
                    'NK' : '[NK] Spirit Air Lines',
                    'OH' : '[OH] PSA Airlines Inc.',
                    'OO' : '[OO] SkyWest Airlines Inc.',
                    'UA' : '[UA] United Air Lines Inc.',
                    'WN' : '[WN] Southwest Airlines Co.',
                    'YV' : '[YV] Mesa Airlines Inc.',
                    'YX' : '[YX] Republic Airline'
               }
with open("dict_mappers/carriers_dict.pkl", "wb") as f:
    pickle.dump(carriers_dict, f)
carriers_dict
# Out:
# {'9E': '[9E] Endeavor Air Inc.',
#  'AA': '[AA] American Airlines Inc.',
#  'AS': '[AS] Alaska Airlines Inc.',
#  'B6': '[B6] JetBlue Airways',
#  'DL': '[DL] Delta Air Lines Inc.',
#  'EV': '[EV] ExpressJet Airlines LLC',
#  'F9': '[F9] Frontier Airlines Inc.',
#  'G4': '[G4] Allegiant Air',
#  'HA': '[HA] Hawaiian Airlines Inc.',
#  'MQ': '[MQ] Envoy Air',
#  'NK': '[NK] Spirit Air Lines',
#  'OH': '[OH] PSA Airlines Inc.',
#  'OO': '[OO] SkyWest Airlines Inc.',
#  'UA': '[UA] United Air Lines Inc.',
#  'WN': '[WN] Southwest Airlines Co.',
#  'YV': '[YV] Mesa Airlines Inc.',
#  'YX': '[YX] Republic Airline'}

# %%
carriers = df['OP_UNIQUE_CARRIER'].value_counts().index

with open("dict_mappers/carriers_sorted_list.pkl", "wb") as f:
    pickle.dump(carriers, f)
carriers
# Out:
# Index(['WN', 'DL', 'AA', 'OO', 'UA', 'YX', 'MQ', 'B6', 'OH', 'AS', '9E', 'YV',
#        'NK', 'F9', 'EV', 'G4', 'HA'],
#       dtype='object')

# %% [markdown]
# ### `ORIGIN`

# %% [markdown]
# #### Carrier current origins

# %%
carrierOrigins_dict = {}
for carrier in df['OP_UNIQUE_CARRIER'].unique():
    carrierOrigins_dict[carrier] = sorted(df.loc[df['OP_UNIQUE_CARRIER'] == carrier, 'ORIGIN'].unique())
with open("dict_mappers/carrierOrigins_dict.pkl", "wb") as f:
    pickle.dump(carrierOrigins_dict, f)
carrierOrigins_dict
# Out:
# {'9E': ['ABE',
#   'ACK',
#   'AEX',
#   'AGS',
#   'ALB',
#   'ATL',
#   'ATW',
#   'AUS',
#   'AVL',
#   'AVP',
#   'AZO',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIS',
#   'BMI',
#   'BNA',
#   'BOS',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BWI',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'CRW',
#   'CSG',
#   'CVG',
#   'CWA',
#   'DAY',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ELM',
#   'EVV',
#   'EWN',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FAY',
#   'FLL',
#   'FNT',
#   'FSD',
#   'FSM',
#   'FWA',
#   'GNV',
#   'GPT',
#   'GRB',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GTF',
#   'GTR',
#   'HPN',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ILM',
#   'IND',
#   'JAN',
#   'JAX',
#   'JFK',
#   'LAN',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'LNK',
#   'MBS',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MDW',
#   'MEM',
#   'MGM',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MLI',
#   'MOB',
#   'MOT',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MVY',
#   'MYR',
#   'OAJ',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PHF',
#   'PHL',
#   'PIA',
#   'PIT',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'ROA',
#   'ROC',
#   'RST',
#   'RSW',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SDF',
#   'SGF',
#   'SHV',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TLH',
#   'TPA',
#   'TRI',
#   'TUL',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'DL': ['ABE',
#   'ABQ',
#   'AGS',
#   'ALB',
#   'ANC',
#   'ATL',
#   'ATW',
#   'AUS',
#   'AVL',
#   'AVP',
#   'BDL',
#   'BHM',
#   'BIL',
#   'BIS',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'CRW',
#   'CVG',
#   'DAB',
#   'DAL',
#   'DAY',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ECP',
#   'EGE',
#   'ELP',
#   'EWR',
#   'EYW',
#   'FAI',
#   'FAR',
#   'FAY',
#   'FLL',
#   'FNT',
#   'FSD',
#   'GEG',
#   'GNV',
#   'GPT',
#   'GRB',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GTF',
#   'HDN',
#   'HNL',
#   'HOU',
#   'HPN',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAC',
#   'JAN',
#   'JAX',
#   'JFK',
#   'JNU',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LGB',
#   'LIH',
#   'LIT',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MDW',
#   'MEM',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MLB',
#   'MOB',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OAK',
#   'OGG',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHF',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PSC',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROA',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SRQ',
#   'STL',
#   'STT',
#   'STX',
#   'SYR',
#   'TLH',
#   'TPA',
#   'TRI',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'WN': ['ABQ',
#   'ALB',
#   'AMA',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BHM',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BUF',
#   'BUR',
#   'BWI',
#   'CHS',
#   'CLE',
#   'CLT',
#   'CMH',
#   'CRP',
#   'CVG',
#   'DAL',
#   'DCA',
#   'DEN',
#   'DSM',
#   'DTW',
#   'ECP',
#   'ELP',
#   'EWR',
#   'FLL',
#   'GEG',
#   'GRR',
#   'GSP',
#   'HNL',
#   'HOU',
#   'IAD',
#   'ICT',
#   'IND',
#   'ISP',
#   'JAX',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LBB',
#   'LGA',
#   'LGB',
#   'LIH',
#   'LIT',
#   'MAF',
#   'MCI',
#   'MCO',
#   'MDW',
#   'MEM',
#   'MHT',
#   'MKE',
#   'MSP',
#   'MSY',
#   'OAK',
#   'OGG',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'STL',
#   'TPA',
#   'TUL',
#   'TUS'],
#  'YX': ['ABQ',
#   'ACK',
#   'AGS',
#   'ALB',
#   'ATL',
#   'AUS',
#   'AVL',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIL',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BRO',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'CRP',
#   'CVG',
#   'DAB',
#   'DAY',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DRO',
#   'DSM',
#   'DTW',
#   'ELP',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FLL',
#   'FSD',
#   'GEG',
#   'GJT',
#   'GRB',
#   'GRK',
#   'GRR',
#   'GSO',
#   'GSP',
#   'HOU',
#   'HSV',
#   'HVN',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAX',
#   'JFK',
#   'LAN',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'LNK',
#   'MAF',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MLB',
#   'MLI',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MVY',
#   'MYR',
#   'OKC',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PHL',
#   'PIT',
#   'PNS',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'ROA',
#   'ROC',
#   'RSW',
#   'SAT',
#   'SAV',
#   'SDF',
#   'SEA',
#   'SLC',
#   'SMF',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TLH',
#   'TPA',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'OO': ['ABE',
#   'ABQ',
#   'ABR',
#   'ABY',
#   'ACT',
#   'ACV',
#   'AEX',
#   'AGS',
#   'ALB',
#   'AMA',
#   'APN',
#   'ASE',
#   'ATL',
#   'ATW',
#   'ATY',
#   'AUS',
#   'AVL',
#   'AVP',
#   'AZO',
#   'BDL',
#   'BFF',
#   'BFL',
#   'BGM',
#   'BGR',
#   'BHM',
#   'BIL',
#   'BIS',
#   'BJI',
#   'BMI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BQK',
#   'BRD',
#   'BRO',
#   'BTM',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CAK',
#   'CDC',
#   'CGI',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CIU',
#   'CKB',
#   'CLE',
#   'CLL',
#   'CLT',
#   'CMH',
#   'CMX',
#   'CNY',
#   'COD',
#   'COS',
#   'COU',
#   'CPR',
#   'CRP',
#   'CRW',
#   'CVG',
#   'CWA',
#   'CYS',
#   'DAL',
#   'DAY',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DLH',
#   'DRO',
#   'DSM',
#   'DTW',
#   'DVL',
#   'EAR',
#   'EAU',
#   'ECP',
#   'EGE',
#   'EKO',
#   'ELM',
#   'ELP',
#   'ERI',
#   'EUG',
#   'EVV',
#   'EWR',
#   'FAR',
#   'FAT',
#   'FAY',
#   'FLG',
#   'FNT',
#   'FSD',
#   'FSM',
#   'FWA',
#   'GCC',
#   'GEG',
#   'GFK',
#   'GJT',
#   'GNV',
#   'GRB',
#   'GRI',
#   'GRK',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GTF',
#   'GTR',
#   'HDN',
#   'HIB',
#   'HLN',
#   'HOB',
#   'HOU',
#   'HPN',
#   'HSV',
#   'HYS',
#   'IAD',
#   'IAH',
#   'ICT',
#   'IDA',
#   'ILM',
#   'IMT',
#   'IND',
#   'INL',
#   'ISN',
#   'ITH',
#   'JAC',
#   'JAN',
#   'JAX',
#   'JFK',
#   'JLN',
#   'JMS',
#   'KTN',
#   'LAN',
#   'LAR',
#   'LAS',
#   'LAW',
#   'LAX',
#   'LBB',
#   'LBF',
#   'LBL',
#   'LCH',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LGB',
#   'LIT',
#   'LNK',
#   'LRD',
#   'LSE',
#   'LWB',
#   'LWS',
#   'MAF',
#   'MBS',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MDW',
#   'MEI',
#   'MEM',
#   'MFE',
#   'MFR',
#   'MGM',
#   'MHK',
#   'MHT',
#   'MKE',
#   'MKG',
#   'MLI',
#   'MLU',
#   'MMH',
#   'MOB',
#   'MOT',
#   'MQT',
#   'MRY',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OAK',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'ORH',
#   'OTH',
#   'PAE',
#   'PBG',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIA',
#   'PIB',
#   'PIH',
#   'PIR',
#   'PIT',
#   'PLN',
#   'PNS',
#   'PRC',
#   'PSC',
#   'PSP',
#   'PUB',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDD',
#   'RDM',
#   'RDU',
#   'RHI',
#   'RIC',
#   'RKS',
#   'RNO',
#   'ROA',
#   'ROC',
#   'ROW',
#   'RST',
#   'RSW',
#   'SAF',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SBN',
#   'SBP',
#   'SCK',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SGF',
#   'SGU',
#   'SHD',
#   'SHV',
#   'SIT',
#   'SJC',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SPI',
#   'SRQ',
#   'STL',
#   'SUN',
#   'SWF',
#   'SYR',
#   'TLH',
#   'TRI',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TWF',
#   'TYS',
#   'UIN',
#   'VEL',
#   'VLD',
#   'VPS',
#   'WYS',
#   'XNA'],
#  'B6': ['ABQ',
#   'ACK',
#   'ALB',
#   'ANC',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BNA',
#   'BOS',
#   'BQN',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CHS',
#   'CLE',
#   'CLT',
#   'DAB',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DTW',
#   'EWR',
#   'FLL',
#   'HDN',
#   'HOU',
#   'HPN',
#   'HYA',
#   'IAD',
#   'IAH',
#   'JAX',
#   'JFK',
#   'LAS',
#   'LAX',
#   'LGA',
#   'LGB',
#   'MCO',
#   'MSP',
#   'MSY',
#   'MVY',
#   'OAK',
#   'ONT',
#   'ORD',
#   'ORH',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAV',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SRQ',
#   'STT',
#   'STX',
#   'SWF',
#   'SYR',
#   'TPA'],
#  'AA': ['ABQ',
#   'AGS',
#   'ALB',
#   'AMA',
#   'ANC',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BHM',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CHS',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'CVG',
#   'DAB',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DSM',
#   'DTW',
#   'EGE',
#   'ELP',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FAT',
#   'FLL',
#   'GEG',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GUC',
#   'HDN',
#   'HNL',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAC',
#   'JAX',
#   'JFK',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LBB',
#   'LGA',
#   'LIH',
#   'LIT',
#   'MAF',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OAK',
#   'OGG',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SRQ',
#   'STL',
#   'STT',
#   'STX',
#   'SYR',
#   'TPA',
#   'TUL',
#   'TUS',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'YV': ['ABQ',
#   'ALB',
#   'AMA',
#   'ATL',
#   'AUS',
#   'AVL',
#   'BDL',
#   'BFL',
#   'BHM',
#   'BIS',
#   'BMI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BRO',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'COU',
#   'CRP',
#   'CVG',
#   'DAY',
#   'DCA',
#   'DFW',
#   'DRO',
#   'DSM',
#   'DTW',
#   'ECP',
#   'ELP',
#   'EVV',
#   'FAT',
#   'FLG',
#   'FLL',
#   'FSD',
#   'FSM',
#   'GJT',
#   'GPT',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GUC',
#   'HOU',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAN',
#   'JAX',
#   'JLN',
#   'LBB',
#   'LFT',
#   'LGA',
#   'LGB',
#   'LIT',
#   'MAF',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MGM',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MLI',
#   'MLU',
#   'MOB',
#   'MRY',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'OAK',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORF',
#   'PBI',
#   'PHL',
#   'PHX',
#   'PIA',
#   'PIT',
#   'PNS',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROA',
#   'ROC',
#   'RSW',
#   'SAF',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SBP',
#   'SDF',
#   'SHV',
#   'SLC',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TLH',
#   'TPA',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'UA': ['ABQ',
#   'ALB',
#   'ANC',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIL',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BQN',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLL',
#   'CLT',
#   'CMH',
#   'COS',
#   'CRP',
#   'CVG',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DLH',
#   'DSM',
#   'DTW',
#   'EGE',
#   'ELP',
#   'EUG',
#   'EWR',
#   'FAI',
#   'FAT',
#   'FLL',
#   'FSD',
#   'GEG',
#   'GRB',
#   'GRR',
#   'GSP',
#   'GUC',
#   'GUM',
#   'HDN',
#   'HNL',
#   'IAD',
#   'IAH',
#   'ICT',
#   'IND',
#   'ITO',
#   'JAC',
#   'JAX',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LGA',
#   'LIH',
#   'MAF',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MFR',
#   'MIA',
#   'MKE',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OGG',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDM',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SBN',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SRQ',
#   'STL',
#   'STT',
#   'SYR',
#   'TPA',
#   'TUL',
#   'TUS',
#   'TVC'],
#  'MQ': ['ABE',
#   'ABI',
#   'ABQ',
#   'ACT',
#   'AEX',
#   'AGS',
#   'ALB',
#   'ALO',
#   'AMA',
#   'ATL',
#   'ATW',
#   'AUS',
#   'AVP',
#   'AZO',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIL',
#   'BMI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BPT',
#   'BRO',
#   'BTR',
#   'BUF',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLL',
#   'CLT',
#   'CMH',
#   'CMI',
#   'COS',
#   'COU',
#   'CRP',
#   'CVG',
#   'CWA',
#   'DAY',
#   'DBQ',
#   'DCA',
#   'DFW',
#   'DLH',
#   'DRT',
#   'DSM',
#   'DTW',
#   'ELP',
#   'ERI',
#   'EVV',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FAY',
#   'FNT',
#   'FSD',
#   'FSM',
#   'FWA',
#   'GCK',
#   'GEG',
#   'GGG',
#   'GJT',
#   'GNV',
#   'GPT',
#   'GRB',
#   'GRI',
#   'GRK',
#   'GRR',
#   'GSO',
#   'GSP',
#   'HDN',
#   'HOU',
#   'HPN',
#   'HSV',
#   'HTS',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAN',
#   'JAX',
#   'JFK',
#   'JLN',
#   'LAN',
#   'LAW',
#   'LBB',
#   'LCH',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'LRD',
#   'LSE',
#   'MAF',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MGM',
#   'MHK',
#   'MIA',
#   'MKE',
#   'MLI',
#   'MLU',
#   'MOB',
#   'MQT',
#   'MRY',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OKC',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PGV',
#   'PHL',
#   'PIA',
#   'PIT',
#   'PNS',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RIC',
#   'ROA',
#   'ROC',
#   'ROW',
#   'RST',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SBP',
#   'SDF',
#   'SGF',
#   'SHV',
#   'SJT',
#   'SPI',
#   'SPS',
#   'SRQ',
#   'STL',
#   'SUX',
#   'SWO',
#   'SYR',
#   'TLH',
#   'TOL',
#   'TRI',
#   'TUL',
#   'TVC',
#   'TXK',
#   'TYR',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'EV': ['ABE',
#   'ABQ',
#   'AEX',
#   'ALB',
#   'AMA',
#   'ATL',
#   'AUS',
#   'AVL',
#   'AVP',
#   'AZO',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIS',
#   'BNA',
#   'BOS',
#   'BRO',
#   'BTR',
#   'BTV',
#   'BUF',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLL',
#   'CLT',
#   'CMH',
#   'COS',
#   'COU',
#   'CRP',
#   'CRW',
#   'CVG',
#   'CWA',
#   'DAY',
#   'DCA',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ECP',
#   'ELP',
#   'ERI',
#   'EVV',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FNT',
#   'FSD',
#   'GPT',
#   'GRB',
#   'GRK',
#   'GRR',
#   'GSO',
#   'GSP',
#   'HDN',
#   'HOB',
#   'HOU',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAN',
#   'JAX',
#   'LAN',
#   'LBB',
#   'LCH',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'LNK',
#   'LRD',
#   'MAF',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MHK',
#   'MHT',
#   'MKE',
#   'MLI',
#   'MLU',
#   'MOB',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OKC',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PHL',
#   'PIA',
#   'PIT',
#   'PNS',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'ROA',
#   'ROC',
#   'RST',
#   'RSW',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SDF',
#   'SGF',
#   'SHV',
#   'SLC',
#   'STL',
#   'SYR',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'AS': ['ABQ',
#   'ADK',
#   'ADQ',
#   'AKN',
#   'ANC',
#   'ATL',
#   'AUS',
#   'BET',
#   'BLI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BRW',
#   'BUR',
#   'BWI',
#   'CDV',
#   'CHS',
#   'CMH',
#   'DAL',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DLG',
#   'DTW',
#   'EWR',
#   'FAI',
#   'FLL',
#   'GEG',
#   'GST',
#   'HNL',
#   'IAD',
#   'IAH',
#   'IND',
#   'JFK',
#   'JNU',
#   'KOA',
#   'KTN',
#   'LAS',
#   'LAX',
#   'LIH',
#   'MCI',
#   'MCO',
#   'MKE',
#   'MSP',
#   'MSY',
#   'OAK',
#   'OGG',
#   'OKC',
#   'OMA',
#   'OME',
#   'ONT',
#   'ORD',
#   'OTZ',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PSG',
#   'PSP',
#   'RDU',
#   'RNO',
#   'SAN',
#   'SAT',
#   'SBA',
#   'SCC',
#   'SEA',
#   'SFO',
#   'SIT',
#   'SJC',
#   'SLC',
#   'SMF',
#   'SNA',
#   'STL',
#   'TPA',
#   'TUS',
#   'WRG',
#   'YAK'],
#  'F9': ['ABQ',
#   'ALB',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BFM',
#   'BHM',
#   'BIL',
#   'BIS',
#   'BMI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BTV',
#   'BUF',
#   'BWI',
#   'BZN',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'CVG',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ELP',
#   'EWR',
#   'FAR',
#   'FAT',
#   'FLL',
#   'FSD',
#   'GEG',
#   'GRB',
#   'GRR',
#   'GSP',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ICT',
#   'IND',
#   'ISP',
#   'JAC',
#   'JAN',
#   'JAX',
#   'LAS',
#   'LAX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MEM',
#   'MIA',
#   'MKE',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MYR',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PSM',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RNO',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TPA',
#   'TTN',
#   'TUL',
#   'TUS',
#   'TYR',
#   'TYS',
#   'XNA'],
#  'NK': ['ACY',
#   'ATL',
#   'AUS',
#   'AVL',
#   'BDL',
#   'BNA',
#   'BOS',
#   'BQN',
#   'BUR',
#   'BWI',
#   'CAK',
#   'CLE',
#   'CLT',
#   'CMH',
#   'CRW',
#   'DEN',
#   'DFW',
#   'DTW',
#   'EWR',
#   'FLL',
#   'GSO',
#   'IAH',
#   'IND',
#   'JAX',
#   'LAS',
#   'LAX',
#   'LBE',
#   'LGA',
#   'MCI',
#   'MCO',
#   'MSP',
#   'MSY',
#   'MYR',
#   'OAK',
#   'ORD',
#   'PBG',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'RDU',
#   'RIC',
#   'RSW',
#   'SAN',
#   'SEA',
#   'SJU',
#   'SMF',
#   'STT',
#   'STX',
#   'TPA'],
#  'OH': ['ABE',
#   'AGS',
#   'ALB',
#   'ART',
#   'ATL',
#   'AVL',
#   'AVP',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BNA',
#   'BOS',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BWI',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'CRW',
#   'CVG',
#   'DAB',
#   'DAY',
#   'DCA',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ECP',
#   'EVV',
#   'EWN',
#   'FAY',
#   'FNT',
#   'FWA',
#   'GNV',
#   'GPT',
#   'GRR',
#   'GSO',
#   'GSP',
#   'HPN',
#   'HSV',
#   'HTS',
#   'HVN',
#   'IAD',
#   'IAH',
#   'ILM',
#   'IND',
#   'ITH',
#   'JAN',
#   'JAX',
#   'JFK',
#   'LAN',
#   'LEX',
#   'LGA',
#   'LIT',
#   'LYH',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MGM',
#   'MHT',
#   'MKE',
#   'MLB',
#   'MOB',
#   'MSN',
#   'MSY',
#   'MYR',
#   'OAJ',
#   'OKC',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PHF',
#   'PHL',
#   'PIA',
#   'PIT',
#   'PNS',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'ROC',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SDF',
#   'SHV',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TLH',
#   'TOL',
#   'TRI',
#   'TUL',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'G4': ['ABE',
#   'ABQ',
#   'ALB',
#   'ANC',
#   'ATW',
#   'AUS',
#   'AVL',
#   'BGR',
#   'BIL',
#   'BIS',
#   'BLI',
#   'BLV',
#   'BMI',
#   'BNA',
#   'BOI',
#   'BWI',
#   'BZN',
#   'CHA',
#   'CHS',
#   'CID',
#   'CKB',
#   'CLE',
#   'CVG',
#   'DAY',
#   'DEN',
#   'DSM',
#   'ELM',
#   'ELP',
#   'EUG',
#   'EVV',
#   'EWR',
#   'FAR',
#   'FAT',
#   'FLL',
#   'FNT',
#   'FSD',
#   'FWA',
#   'GFK',
#   'GJT',
#   'GPT',
#   'GRI',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GTF',
#   'HGR',
#   'HTS',
#   'ICT',
#   'IDA',
#   'IND',
#   'JAX',
#   'LAS',
#   'LAX',
#   'LCK',
#   'LEX',
#   'LIT',
#   'LRD',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MFR',
#   'MKE',
#   'MLI',
#   'MOT',
#   'MRY',
#   'MSO',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OAK',
#   'OKC',
#   'OMA',
#   'ORF',
#   'OWB',
#   'PBG',
#   'PBI',
#   'PGD',
#   'PIA',
#   'PIE',
#   'PIT',
#   'PSC',
#   'PSM',
#   'PSP',
#   'PVD',
#   'PVU',
#   'RAP',
#   'RDM',
#   'RDU',
#   'RFD',
#   'RIC',
#   'RNO',
#   'ROA',
#   'ROC',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SCK',
#   'SDF',
#   'SFB',
#   'SGF',
#   'SHV',
#   'SJU',
#   'SMX',
#   'SPI',
#   'SRQ',
#   'STC',
#   'SWF',
#   'SYR',
#   'TOL',
#   'TRI',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'HA': ['BOS',
#   'HNL',
#   'ITO',
#   'JFK',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LGB',
#   'LIH',
#   'OAK',
#   'OGG',
#   'PDX',
#   'PHX',
#   'PPG',
#   'SAN',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SMF']}

# %%
    destType = st.radio('Departure airport', options=['Currently operated by the A/L', 'All airports'], index=0, key=1)
    if destType == 'Currently operated by the A/L':
        with open(root + "dict_mappers/carrierDests_dict.pkl", "rb") as f:
            carrierDests_dict = pickle.load(f)
            dests = carrierDests_dict[carrier]
        dest = st.selectbox('Dest', dests)
    elif destType == 'All airports':
    with open(root + "dict_mappers/dests_sorted_list.pkl", "rb") as f:
        dests = pickle.load(f)
    dest = st.selectbox('Destination', dests)

# %% [markdown]
# #### All airports

# %%
origins = sorted(df['ORIGIN'].unique())

with open("dict_mappers/origins_sorted_list.pkl", "wb") as f:
    pickle.dump(origins, f)
origins
# Out:
# ['ABE',
#  'ABI',
#  'ABQ',
#  'ABR',
#  'ABY',
#  'ACK',
#  'ACT',
#  'ACV',
#  'ACY',
#  'ADK',
#  'ADQ',
#  'AEX',
#  'AGS',
#  'AKN',
#  'ALB',
#  'ALO',
#  'AMA',
#  'ANC',
#  'APN',
#  'ART',
#  'ASE',
#  'ATL',
#  'ATW',
#  'ATY',
#  'AUS',
#  'AVL',
#  'AVP',
#  'AZO',
#  'BDL',
#  'BET',
#  'BFF',
#  'BFL',
#  'BFM',
#  'BGM',
#  'BGR',
#  'BHM',
#  'BIL',
#  'BIS',
#  'BJI',
#  'BLI',
#  'BLV',
#  'BMI',
#  'BNA',
#  'BOI',
#  'BOS',
#  'BPT',
#  'BQK',
#  'BQN',
#  'BRD',
#  'BRO',
#  'BRW',
#  'BTM',
#  'BTR',
#  'BTV',
#  'BUF',
#  'BUR',
#  'BWI',
#  'BZN',
#  'CAE',
#  'CAK',
#  'CDC',
#  'CDV',
#  'CGI',
#  'CHA',
#  'CHO',
#  'CHS',
#  'CID',
#  'CIU',
#  'CKB',
#  'CLE',
#  'CLL',
#  'CLT',
#  'CMH',
#  'CMI',
#  'CMX',
#  'CNY',
#  'COD',
#  'COS',
#  'COU',
#  'CPR',
#  'CRP',
#  'CRW',
#  'CSG',
#  'CVG',
#  'CWA',
#  'CYS',
#  'DAB',
#  'DAL',
#  'DAY',
#  'DBQ',
#  'DCA',
#  'DEN',
#  'DFW',
#  'DLG',
#  'DLH',
#  'DRO',
#  'DRT',
#  'DSM',
#  'DTW',
#  'DVL',
#  'EAR',
#  'EAU',
#  'ECP',
#  'EGE',
#  'EKO',
#  'ELM',
#  'ELP',
#  'ERI',
#  'EUG',
#  'EVV',
#  'EWN',
#  'EWR',
#  'EYW',
#  'FAI',
#  'FAR',
#  'FAT',
#  'FAY',
#  'FLG',
#  'FLL',
#  'FNT',
#  'FSD',
#  'FSM',
#  'FWA',
#  'GCC',
#  'GCK',
#  'GEG',
#  'GFK',
#  'GGG',
#  'GJT',
#  'GNV',
#  'GPT',
#  'GRB',
#  'GRI',
#  'GRK',
#  'GRR',
#  'GSO',
#  'GSP',
#  'GST',
#  'GTF',
#  'GTR',
#  'GUC',
#  'GUM',
#  'HDN',
#  'HGR',
#  'HIB',
#  'HLN',
#  'HNL',
#  'HOB',
#  'HOU',
#  'HPN',
#  'HSV',
#  'HTS',
#  'HVN',
#  'HYA',
#  'HYS',
#  'IAD',
#  'IAH',
#  'ICT',
#  'IDA',
#  'ILM',
#  'IMT',
#  'IND',
#  'INL',
#  'ISN',
#  'ISP',
#  'ITH',
#  'ITO',
#  'JAC',
#  'JAN',
#  'JAX',
#  'JFK',
#  'JLN',
#  'JMS',
#  'JNU',
#  'KOA',
#  'KTN',
#  'LAN',
#  'LAR',
#  'LAS',
#  'LAW',
#  'LAX',
#  'LBB',
#  'LBE',
#  'LBF',
#  'LBL',
#  'LCH',
#  'LCK',
#  'LEX',
#  'LFT',
#  'LGA',
#  'LGB',
#  'LIH',
#  'LIT',
#  'LNK',
#  'LRD',
#  'LSE',
#  'LWB',
#  'LWS',
#  'LYH',
#  'MAF',
#  'MBS',
#  'MCI',
#  'MCO',
#  'MDT',
#  'MDW',
#  'MEI',
#  'MEM',
#  'MFE',
#  'MFR',
#  'MGM',
#  'MHK',
#  'MHT',
#  'MIA',
#  'MKE',
#  'MKG',
#  'MLB',
#  'MLI',
#  'MLU',
#  'MMH',
#  'MOB',
#  'MOT',
#  'MQT',
#  'MRY',
#  'MSN',
#  'MSO',
#  'MSP',
#  'MSY',
#  'MTJ',
#  'MVY',
#  'MYR',
#  'OAJ',
#  'OAK',
#  'OGG',
#  'OKC',
#  'OMA',
#  'OME',
#  'ONT',
#  'ORD',
#  'ORF',
#  'ORH',
#  'OTH',
#  'OTZ',
#  'OWB',
#  'PAE',
#  'PBG',
#  'PBI',
#  'PDX',
#  'PGD',
#  'PGV',
#  'PHF',
#  'PHL',
#  'PHX',
#  'PIA',
#  'PIB',
#  'PIE',
#  'PIH',
#  'PIR',
#  'PIT',
#  'PLN',
#  'PNS',
#  'PPG',
#  'PRC',
#  'PSC',
#  'PSG',
#  'PSM',
#  'PSP',
#  'PUB',
#  'PVD',
#  'PVU',
#  'PWM',
#  'RAP',
#  'RDD',
#  'RDM',
#  'RDU',
#  'RFD',
#  'RHI',
#  'RIC',
#  'RKS',
#  'RNO',
#  'ROA',
#  'ROC',
#  'ROW',
#  'RST',
#  'RSW',
#  'SAF',
#  'SAN',
#  'SAT',
#  'SAV',
#  'SBA',
#  'SBN',
#  'SBP',
#  'SCC',
#  'SCK',
#  'SDF',
#  'SEA',
#  'SFB',
#  'SFO',
#  'SGF',
#  'SGU',
#  'SHD',
#  'SHV',
#  'SIT',
#  'SJC',
#  'SJT',
#  'SJU',
#  'SLC',
#  'SMF',
#  'SMX',
#  'SNA',
#  'SPI',
#  'SPS',
#  'SRQ',
#  'STC',
#  'STL',
#  'STT',
#  'STX',
#  'SUN',
#  'SUX',
#  'SWF',
#  'SWO',
#  'SYR',
#  'TLH',
#  'TOL',
#  'TPA',
#  'TRI',
#  'TTN',
#  'TUL',
#  'TUS',
#  'TVC',
#  'TWF',
#  'TXK',
#  'TYR',
#  'TYS',
#  'UIN',
#  'VEL',
#  'VLD',
#  'VPS',
#  'WRG',
#  'WYS',
#  'XNA',
#  'YAK']

# %% [markdown]
# ### `DEST`

# %% [markdown]
# #### Carrier current destinations

# %%
carrierDests_dict = {}
for carrier in df['OP_UNIQUE_CARRIER'].unique():
    carrierDests_dict[carrier] = sorted(df.loc[df['OP_UNIQUE_CARRIER'] == carrier, 'DEST'].unique())
with open("dict_mappers/carrierDests_dict.pkl", "wb") as f:
    pickle.dump(carrierDests_dict, f)
carrierDests_dict
# Out:
# {'9E': ['ABE',
#   'ACK',
#   'AEX',
#   'AGS',
#   'ALB',
#   'ATL',
#   'ATW',
#   'AUS',
#   'AVL',
#   'AVP',
#   'AZO',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIS',
#   'BMI',
#   'BNA',
#   'BOS',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BWI',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'CRW',
#   'CSG',
#   'CVG',
#   'CWA',
#   'DAY',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ELM',
#   'EVV',
#   'EWN',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FAY',
#   'FLL',
#   'FNT',
#   'FSD',
#   'FSM',
#   'FWA',
#   'GNV',
#   'GPT',
#   'GRB',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GTF',
#   'GTR',
#   'HPN',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ILM',
#   'IND',
#   'JAN',
#   'JAX',
#   'JFK',
#   'LAN',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'LNK',
#   'MBS',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MDW',
#   'MEM',
#   'MGM',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MLI',
#   'MOB',
#   'MOT',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MVY',
#   'MYR',
#   'OAJ',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PHF',
#   'PHL',
#   'PIA',
#   'PIT',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'ROA',
#   'ROC',
#   'RST',
#   'RSW',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SDF',
#   'SGF',
#   'SHV',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TLH',
#   'TPA',
#   'TRI',
#   'TUL',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'DL': ['ABE',
#   'ABQ',
#   'AGS',
#   'ALB',
#   'ANC',
#   'ATL',
#   'ATW',
#   'AUS',
#   'AVL',
#   'AVP',
#   'BDL',
#   'BHM',
#   'BIL',
#   'BIS',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'CRW',
#   'CVG',
#   'DAB',
#   'DAL',
#   'DAY',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ECP',
#   'EGE',
#   'ELP',
#   'EWR',
#   'EYW',
#   'FAI',
#   'FAR',
#   'FAY',
#   'FLL',
#   'FNT',
#   'FSD',
#   'GEG',
#   'GNV',
#   'GPT',
#   'GRB',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GTF',
#   'HDN',
#   'HNL',
#   'HOU',
#   'HPN',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAC',
#   'JAN',
#   'JAX',
#   'JFK',
#   'JNU',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LGB',
#   'LIH',
#   'LIT',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MDW',
#   'MEM',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MLB',
#   'MOB',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OAK',
#   'OGG',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHF',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PSC',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROA',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SRQ',
#   'STL',
#   'STT',
#   'STX',
#   'SYR',
#   'TLH',
#   'TPA',
#   'TRI',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'WN': ['ABQ',
#   'ALB',
#   'AMA',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BHM',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BUF',
#   'BUR',
#   'BWI',
#   'CHS',
#   'CLE',
#   'CLT',
#   'CMH',
#   'CRP',
#   'CVG',
#   'DAL',
#   'DCA',
#   'DEN',
#   'DSM',
#   'DTW',
#   'ECP',
#   'ELP',
#   'EWR',
#   'FLL',
#   'GEG',
#   'GRR',
#   'GSP',
#   'HNL',
#   'HOU',
#   'IAD',
#   'ICT',
#   'IND',
#   'ISP',
#   'JAX',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LBB',
#   'LGA',
#   'LGB',
#   'LIH',
#   'LIT',
#   'MAF',
#   'MCI',
#   'MCO',
#   'MDW',
#   'MEM',
#   'MHT',
#   'MKE',
#   'MSP',
#   'MSY',
#   'OAK',
#   'OGG',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'STL',
#   'TPA',
#   'TUL',
#   'TUS'],
#  'YX': ['ABQ',
#   'ACK',
#   'AGS',
#   'ALB',
#   'ATL',
#   'AUS',
#   'AVL',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIL',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BRO',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'CRP',
#   'CVG',
#   'DAB',
#   'DAY',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DRO',
#   'DSM',
#   'DTW',
#   'ELP',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FLL',
#   'FSD',
#   'GEG',
#   'GJT',
#   'GRB',
#   'GRK',
#   'GRR',
#   'GSO',
#   'GSP',
#   'HOU',
#   'HSV',
#   'HVN',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAX',
#   'JFK',
#   'LAN',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'LNK',
#   'MAF',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MLB',
#   'MLI',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MVY',
#   'MYR',
#   'OKC',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PHL',
#   'PIT',
#   'PNS',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'ROA',
#   'ROC',
#   'RSW',
#   'SAT',
#   'SAV',
#   'SDF',
#   'SEA',
#   'SLC',
#   'SMF',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TLH',
#   'TPA',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'OO': ['ABE',
#   'ABQ',
#   'ABR',
#   'ABY',
#   'ACT',
#   'ACV',
#   'AEX',
#   'AGS',
#   'ALB',
#   'AMA',
#   'APN',
#   'ASE',
#   'ATL',
#   'ATW',
#   'ATY',
#   'AUS',
#   'AVL',
#   'AVP',
#   'AZO',
#   'BDL',
#   'BFF',
#   'BFL',
#   'BGM',
#   'BGR',
#   'BHM',
#   'BIL',
#   'BIS',
#   'BJI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BQK',
#   'BRD',
#   'BRO',
#   'BTM',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CAK',
#   'CDC',
#   'CGI',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CIU',
#   'CKB',
#   'CLE',
#   'CLL',
#   'CLT',
#   'CMH',
#   'CMX',
#   'CNY',
#   'COD',
#   'COS',
#   'COU',
#   'CPR',
#   'CRP',
#   'CRW',
#   'CVG',
#   'CWA',
#   'CYS',
#   'DAL',
#   'DAY',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DLH',
#   'DRO',
#   'DSM',
#   'DTW',
#   'DVL',
#   'EAR',
#   'EAU',
#   'ECP',
#   'EGE',
#   'EKO',
#   'ELM',
#   'ELP',
#   'ERI',
#   'EUG',
#   'EVV',
#   'EWR',
#   'FAR',
#   'FAT',
#   'FAY',
#   'FLG',
#   'FNT',
#   'FSD',
#   'FSM',
#   'FWA',
#   'GCC',
#   'GEG',
#   'GFK',
#   'GJT',
#   'GNV',
#   'GRB',
#   'GRI',
#   'GRK',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GTF',
#   'GTR',
#   'HDN',
#   'HIB',
#   'HLN',
#   'HOB',
#   'HOU',
#   'HPN',
#   'HSV',
#   'HYS',
#   'IAD',
#   'IAH',
#   'ICT',
#   'IDA',
#   'ILM',
#   'IMT',
#   'IND',
#   'INL',
#   'ISN',
#   'ITH',
#   'JAC',
#   'JAN',
#   'JAX',
#   'JFK',
#   'JLN',
#   'JMS',
#   'KTN',
#   'LAN',
#   'LAR',
#   'LAS',
#   'LAW',
#   'LAX',
#   'LBB',
#   'LBF',
#   'LBL',
#   'LCH',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LGB',
#   'LIT',
#   'LNK',
#   'LRD',
#   'LSE',
#   'LWB',
#   'LWS',
#   'MAF',
#   'MBS',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MDW',
#   'MEI',
#   'MEM',
#   'MFE',
#   'MFR',
#   'MGM',
#   'MHK',
#   'MHT',
#   'MKE',
#   'MKG',
#   'MLI',
#   'MLU',
#   'MMH',
#   'MOB',
#   'MOT',
#   'MQT',
#   'MRY',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OAK',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'ORH',
#   'OTH',
#   'PAE',
#   'PBG',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIA',
#   'PIB',
#   'PIH',
#   'PIR',
#   'PIT',
#   'PLN',
#   'PNS',
#   'PRC',
#   'PSC',
#   'PSP',
#   'PUB',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDD',
#   'RDM',
#   'RDU',
#   'RHI',
#   'RIC',
#   'RKS',
#   'RNO',
#   'ROA',
#   'ROC',
#   'ROW',
#   'RST',
#   'RSW',
#   'SAF',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SBN',
#   'SBP',
#   'SCK',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SGF',
#   'SGU',
#   'SHD',
#   'SHV',
#   'SIT',
#   'SJC',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SPI',
#   'SRQ',
#   'STL',
#   'SUN',
#   'SWF',
#   'SYR',
#   'TLH',
#   'TRI',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TWF',
#   'TYS',
#   'UIN',
#   'VEL',
#   'VLD',
#   'VPS',
#   'WYS',
#   'XNA'],
#  'B6': ['ABQ',
#   'ACK',
#   'ALB',
#   'ANC',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BNA',
#   'BOS',
#   'BQN',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CHS',
#   'CLE',
#   'CLT',
#   'DAB',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DTW',
#   'EWR',
#   'FLL',
#   'HDN',
#   'HOU',
#   'HPN',
#   'HYA',
#   'IAD',
#   'IAH',
#   'JAX',
#   'JFK',
#   'LAS',
#   'LAX',
#   'LGA',
#   'LGB',
#   'MCO',
#   'MSP',
#   'MSY',
#   'MVY',
#   'OAK',
#   'ONT',
#   'ORD',
#   'ORH',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAV',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SRQ',
#   'STT',
#   'STX',
#   'SWF',
#   'SYR',
#   'TPA'],
#  'AA': ['ABQ',
#   'AGS',
#   'ALB',
#   'AMA',
#   'ANC',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BHM',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CHS',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'CVG',
#   'DAB',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DSM',
#   'DTW',
#   'EGE',
#   'ELP',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FAT',
#   'FLL',
#   'GEG',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GUC',
#   'HDN',
#   'HNL',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAC',
#   'JAX',
#   'JFK',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LBB',
#   'LGA',
#   'LIH',
#   'LIT',
#   'MAF',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OAK',
#   'OGG',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SRQ',
#   'STL',
#   'STT',
#   'STX',
#   'SYR',
#   'TPA',
#   'TUL',
#   'TUS',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'YV': ['ABQ',
#   'ALB',
#   'AMA',
#   'ATL',
#   'AUS',
#   'AVL',
#   'BDL',
#   'BFL',
#   'BHM',
#   'BIS',
#   'BMI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BRO',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'COU',
#   'CRP',
#   'CVG',
#   'DAY',
#   'DCA',
#   'DFW',
#   'DRO',
#   'DSM',
#   'DTW',
#   'ECP',
#   'ELP',
#   'EVV',
#   'FAT',
#   'FLG',
#   'FLL',
#   'FSD',
#   'FSM',
#   'GJT',
#   'GPT',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GUC',
#   'HOU',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAN',
#   'JAX',
#   'JLN',
#   'LBB',
#   'LFT',
#   'LGA',
#   'LGB',
#   'LIT',
#   'MAF',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MGM',
#   'MHT',
#   'MIA',
#   'MKE',
#   'MLI',
#   'MLU',
#   'MOB',
#   'MRY',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'OAK',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORF',
#   'PBI',
#   'PHL',
#   'PHX',
#   'PIA',
#   'PIT',
#   'PNS',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROA',
#   'ROC',
#   'RSW',
#   'SAF',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SBP',
#   'SDF',
#   'SHV',
#   'SLC',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TLH',
#   'TPA',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'UA': ['ABQ',
#   'ALB',
#   'ANC',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIL',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BQN',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BUR',
#   'BWI',
#   'BZN',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLL',
#   'CLT',
#   'CMH',
#   'COS',
#   'CRP',
#   'CVG',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DLH',
#   'DSM',
#   'DTW',
#   'EGE',
#   'ELP',
#   'EUG',
#   'EWR',
#   'FAI',
#   'FAT',
#   'FLL',
#   'FSD',
#   'GEG',
#   'GRB',
#   'GRR',
#   'GSP',
#   'GUC',
#   'GUM',
#   'HDN',
#   'HNL',
#   'IAD',
#   'IAH',
#   'ICT',
#   'IND',
#   'ITO',
#   'JAC',
#   'JAX',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LGA',
#   'LIH',
#   'MAF',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MFR',
#   'MIA',
#   'MKE',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OGG',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDM',
#   'RDU',
#   'RIC',
#   'RNO',
#   'ROC',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SBN',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SRQ',
#   'STL',
#   'STT',
#   'SYR',
#   'TPA',
#   'TUL',
#   'TUS',
#   'TVC'],
#  'MQ': ['ABE',
#   'ABI',
#   'ABQ',
#   'ACT',
#   'AEX',
#   'AGS',
#   'ALB',
#   'ALO',
#   'AMA',
#   'ATL',
#   'ATW',
#   'AUS',
#   'AVP',
#   'AZO',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIL',
#   'BMI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BPT',
#   'BRO',
#   'BTR',
#   'BUF',
#   'BWI',
#   'BZN',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLL',
#   'CLT',
#   'CMH',
#   'CMI',
#   'COS',
#   'COU',
#   'CRP',
#   'CVG',
#   'CWA',
#   'DAY',
#   'DBQ',
#   'DCA',
#   'DFW',
#   'DLH',
#   'DRT',
#   'DSM',
#   'DTW',
#   'ELP',
#   'ERI',
#   'EVV',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FAY',
#   'FNT',
#   'FSD',
#   'FSM',
#   'FWA',
#   'GCK',
#   'GEG',
#   'GGG',
#   'GJT',
#   'GNV',
#   'GPT',
#   'GRB',
#   'GRI',
#   'GRK',
#   'GRR',
#   'GSO',
#   'GSP',
#   'HDN',
#   'HOU',
#   'HPN',
#   'HSV',
#   'HTS',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAN',
#   'JAX',
#   'JFK',
#   'JLN',
#   'LAN',
#   'LAW',
#   'LBB',
#   'LCH',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'LRD',
#   'LSE',
#   'MAF',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MGM',
#   'MHK',
#   'MIA',
#   'MKE',
#   'MLI',
#   'MLU',
#   'MOB',
#   'MRY',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OKC',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PGV',
#   'PHL',
#   'PIA',
#   'PIT',
#   'PNS',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RIC',
#   'ROA',
#   'ROC',
#   'ROW',
#   'RST',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SBP',
#   'SDF',
#   'SGF',
#   'SHV',
#   'SJT',
#   'SPI',
#   'SPS',
#   'SRQ',
#   'STL',
#   'SUX',
#   'SWO',
#   'SYR',
#   'TLH',
#   'TOL',
#   'TRI',
#   'TUL',
#   'TVC',
#   'TXK',
#   'TYR',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'EV': ['ABE',
#   'ABQ',
#   'AEX',
#   'ALB',
#   'AMA',
#   'ATL',
#   'AUS',
#   'AVL',
#   'AVP',
#   'AZO',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BIS',
#   'BNA',
#   'BOS',
#   'BRO',
#   'BTR',
#   'BTV',
#   'BUF',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLL',
#   'CLT',
#   'CMH',
#   'COS',
#   'COU',
#   'CRP',
#   'CRW',
#   'CVG',
#   'CWA',
#   'DAY',
#   'DCA',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ECP',
#   'ELP',
#   'ERI',
#   'EVV',
#   'EWR',
#   'EYW',
#   'FAR',
#   'FNT',
#   'FSD',
#   'GPT',
#   'GRB',
#   'GRK',
#   'GRR',
#   'GSO',
#   'GSP',
#   'HDN',
#   'HOB',
#   'HOU',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ICT',
#   'ILM',
#   'IND',
#   'JAN',
#   'JAX',
#   'LAN',
#   'LBB',
#   'LCH',
#   'LEX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'LNK',
#   'LRD',
#   'MAF',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MHK',
#   'MHT',
#   'MKE',
#   'MLI',
#   'MLU',
#   'MOB',
#   'MSN',
#   'MSP',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OKC',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PHL',
#   'PIA',
#   'PIT',
#   'PNS',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'ROA',
#   'ROC',
#   'RST',
#   'RSW',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SDF',
#   'SGF',
#   'SHV',
#   'SLC',
#   'STL',
#   'SYR',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'AS': ['ABQ',
#   'ADK',
#   'ADQ',
#   'AKN',
#   'ANC',
#   'ATL',
#   'AUS',
#   'BET',
#   'BLI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BRW',
#   'BUR',
#   'BWI',
#   'CDV',
#   'CHS',
#   'CMH',
#   'DAL',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DLG',
#   'DTW',
#   'EWR',
#   'FAI',
#   'FLL',
#   'GEG',
#   'GST',
#   'HNL',
#   'IAD',
#   'IAH',
#   'IND',
#   'JFK',
#   'JNU',
#   'KOA',
#   'KTN',
#   'LAS',
#   'LAX',
#   'LIH',
#   'MCI',
#   'MCO',
#   'MKE',
#   'MSP',
#   'MSY',
#   'OAK',
#   'OGG',
#   'OKC',
#   'OMA',
#   'OME',
#   'ONT',
#   'ORD',
#   'OTZ',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PSG',
#   'PSP',
#   'RDU',
#   'RNO',
#   'SAN',
#   'SAT',
#   'SBA',
#   'SCC',
#   'SEA',
#   'SFO',
#   'SIT',
#   'SJC',
#   'SLC',
#   'SMF',
#   'SNA',
#   'STL',
#   'TPA',
#   'TUS',
#   'WRG',
#   'YAK'],
#  'F9': ['ABQ',
#   'ALB',
#   'ATL',
#   'AUS',
#   'BDL',
#   'BFM',
#   'BHM',
#   'BIL',
#   'BIS',
#   'BMI',
#   'BNA',
#   'BOI',
#   'BOS',
#   'BTV',
#   'BUF',
#   'BWI',
#   'BZN',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'COS',
#   'CVG',
#   'DCA',
#   'DEN',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ELP',
#   'EWR',
#   'FAR',
#   'FAT',
#   'FLL',
#   'FSD',
#   'GEG',
#   'GRB',
#   'GRR',
#   'GSP',
#   'HSV',
#   'IAD',
#   'IAH',
#   'ICT',
#   'IND',
#   'ISP',
#   'JAC',
#   'JAN',
#   'JAX',
#   'LAS',
#   'LAX',
#   'LFT',
#   'LGA',
#   'LIT',
#   'MCI',
#   'MCO',
#   'MDT',
#   'MEM',
#   'MIA',
#   'MKE',
#   'MSN',
#   'MSO',
#   'MSP',
#   'MSY',
#   'MYR',
#   'OKC',
#   'OMA',
#   'ONT',
#   'ORD',
#   'ORF',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'PNS',
#   'PSM',
#   'PSP',
#   'PVD',
#   'PWM',
#   'RDU',
#   'RNO',
#   'RSW',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBA',
#   'SDF',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SJU',
#   'SLC',
#   'SMF',
#   'SNA',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TPA',
#   'TTN',
#   'TUL',
#   'TUS',
#   'TYR',
#   'TYS',
#   'XNA'],
#  'NK': ['ACY',
#   'ATL',
#   'AUS',
#   'AVL',
#   'BDL',
#   'BNA',
#   'BOS',
#   'BQN',
#   'BUR',
#   'BWI',
#   'CAK',
#   'CLE',
#   'CLT',
#   'CMH',
#   'CRW',
#   'DEN',
#   'DFW',
#   'DTW',
#   'EWR',
#   'FLL',
#   'GSO',
#   'IAH',
#   'IND',
#   'JAX',
#   'LAS',
#   'LAX',
#   'LBE',
#   'LGA',
#   'MCI',
#   'MCO',
#   'MSP',
#   'MSY',
#   'MYR',
#   'OAK',
#   'ORD',
#   'PBG',
#   'PBI',
#   'PDX',
#   'PHL',
#   'PHX',
#   'PIT',
#   'RDU',
#   'RIC',
#   'RSW',
#   'SAN',
#   'SEA',
#   'SJU',
#   'SMF',
#   'STT',
#   'STX',
#   'TPA'],
#  'OH': ['ABE',
#   'AGS',
#   'ALB',
#   'ART',
#   'ATL',
#   'AVL',
#   'AVP',
#   'BDL',
#   'BGR',
#   'BHM',
#   'BNA',
#   'BOS',
#   'BTR',
#   'BTV',
#   'BUF',
#   'BWI',
#   'CAE',
#   'CAK',
#   'CHA',
#   'CHO',
#   'CHS',
#   'CID',
#   'CLE',
#   'CLT',
#   'CMH',
#   'CRW',
#   'CVG',
#   'DAB',
#   'DAY',
#   'DCA',
#   'DFW',
#   'DSM',
#   'DTW',
#   'ECP',
#   'EVV',
#   'EWN',
#   'FAY',
#   'FNT',
#   'FWA',
#   'GNV',
#   'GPT',
#   'GRR',
#   'GSO',
#   'GSP',
#   'HPN',
#   'HSV',
#   'HTS',
#   'HVN',
#   'IAD',
#   'IAH',
#   'ILM',
#   'IND',
#   'ITH',
#   'JAN',
#   'JAX',
#   'JFK',
#   'LAN',
#   'LEX',
#   'LGA',
#   'LIT',
#   'LYH',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MGM',
#   'MHT',
#   'MKE',
#   'MLB',
#   'MOB',
#   'MSN',
#   'MSY',
#   'MYR',
#   'OAJ',
#   'OKC',
#   'OMA',
#   'ORD',
#   'ORF',
#   'PHF',
#   'PHL',
#   'PIA',
#   'PIT',
#   'PNS',
#   'PVD',
#   'PWM',
#   'RAP',
#   'RDU',
#   'RIC',
#   'ROC',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SDF',
#   'SHV',
#   'SRQ',
#   'STL',
#   'SYR',
#   'TLH',
#   'TOL',
#   'TRI',
#   'TUL',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'G4': ['ABE',
#   'ABQ',
#   'ALB',
#   'ANC',
#   'ATW',
#   'AUS',
#   'AVL',
#   'BGR',
#   'BIL',
#   'BIS',
#   'BLI',
#   'BLV',
#   'BMI',
#   'BNA',
#   'BOI',
#   'BWI',
#   'BZN',
#   'CHA',
#   'CHS',
#   'CID',
#   'CKB',
#   'CLE',
#   'CVG',
#   'DAY',
#   'DEN',
#   'DSM',
#   'ELM',
#   'ELP',
#   'EUG',
#   'EVV',
#   'EWR',
#   'FAR',
#   'FAT',
#   'FLL',
#   'FNT',
#   'FSD',
#   'FWA',
#   'GFK',
#   'GJT',
#   'GPT',
#   'GRI',
#   'GRR',
#   'GSO',
#   'GSP',
#   'GTF',
#   'HGR',
#   'HTS',
#   'ICT',
#   'IDA',
#   'IND',
#   'JAX',
#   'LAS',
#   'LAX',
#   'LCK',
#   'LEX',
#   'LIT',
#   'LRD',
#   'MCI',
#   'MDT',
#   'MEM',
#   'MFE',
#   'MFR',
#   'MKE',
#   'MLI',
#   'MOT',
#   'MRY',
#   'MSO',
#   'MSY',
#   'MTJ',
#   'MYR',
#   'OAK',
#   'OKC',
#   'OMA',
#   'ORF',
#   'OWB',
#   'PBG',
#   'PBI',
#   'PGD',
#   'PIA',
#   'PIE',
#   'PIT',
#   'PSC',
#   'PSM',
#   'PSP',
#   'PVD',
#   'PVU',
#   'RAP',
#   'RDM',
#   'RDU',
#   'RFD',
#   'RIC',
#   'RNO',
#   'ROA',
#   'ROC',
#   'SAN',
#   'SAT',
#   'SAV',
#   'SBN',
#   'SCK',
#   'SDF',
#   'SFB',
#   'SGF',
#   'SHV',
#   'SJU',
#   'SMX',
#   'SPI',
#   'SRQ',
#   'STC',
#   'SWF',
#   'SYR',
#   'TOL',
#   'TRI',
#   'TUL',
#   'TUS',
#   'TVC',
#   'TYS',
#   'VPS',
#   'XNA'],
#  'HA': ['BOS',
#   'HNL',
#   'ITO',
#   'JFK',
#   'KOA',
#   'LAS',
#   'LAX',
#   'LGB',
#   'LIH',
#   'OAK',
#   'OGG',
#   'PDX',
#   'PHX',
#   'PPG',
#   'SAN',
#   'SEA',
#   'SFO',
#   'SJC',
#   'SMF']}

# %% [markdown]
# #### All airports

# %%
dests = sorted(df['DEST'].unique())

with open("dict_mappers/dests_sorted_list.pkl", "wb") as f:
    pickle.dump(dests, f)
dests
# Out:
# ['ABE',
#  'ABI',
#  'ABQ',
#  'ABR',
#  'ABY',
#  'ACK',
#  'ACT',
#  'ACV',
#  'ACY',
#  'ADK',
#  'ADQ',
#  'AEX',
#  'AGS',
#  'AKN',
#  'ALB',
#  'ALO',
#  'AMA',
#  'ANC',
#  'APN',
#  'ART',
#  'ASE',
#  'ATL',
#  'ATW',
#  'ATY',
#  'AUS',
#  'AVL',
#  'AVP',
#  'AZO',
#  'BDL',
#  'BET',
#  'BFF',
#  'BFL',
#  'BFM',
#  'BGM',
#  'BGR',
#  'BHM',
#  'BIL',
#  'BIS',
#  'BJI',
#  'BLI',
#  'BLV',
#  'BMI',
#  'BNA',
#  'BOI',
#  'BOS',
#  'BPT',
#  'BQK',
#  'BQN',
#  'BRD',
#  'BRO',
#  'BRW',
#  'BTM',
#  'BTR',
#  'BTV',
#  'BUF',
#  'BUR',
#  'BWI',
#  'BZN',
#  'CAE',
#  'CAK',
#  'CDC',
#  'CDV',
#  'CGI',
#  'CHA',
#  'CHO',
#  'CHS',
#  'CID',
#  'CIU',
#  'CKB',
#  'CLE',
#  'CLL',
#  'CLT',
#  'CMH',
#  'CMI',
#  'CMX',
#  'CNY',
#  'COD',
#  'COS',
#  'COU',
#  'CPR',
#  'CRP',
#  'CRW',
#  'CSG',
#  'CVG',
#  'CWA',
#  'CYS',
#  'DAB',
#  'DAL',
#  'DAY',
#  'DBQ',
#  'DCA',
#  'DEN',
#  'DFW',
#  'DLG',
#  'DLH',
#  'DRO',
#  'DRT',
#  'DSM',
#  'DTW',
#  'DVL',
#  'EAR',
#  'EAU',
#  'ECP',
#  'EGE',
#  'EKO',
#  'ELM',
#  'ELP',
#  'ERI',
#  'EUG',
#  'EVV',
#  'EWN',
#  'EWR',
#  'EYW',
#  'FAI',
#  'FAR',
#  'FAT',
#  'FAY',
#  'FLG',
#  'FLL',
#  'FNT',
#  'FSD',
#  'FSM',
#  'FWA',
#  'GCC',
#  'GCK',
#  'GEG',
#  'GFK',
#  'GGG',
#  'GJT',
#  'GNV',
#  'GPT',
#  'GRB',
#  'GRI',
#  'GRK',
#  'GRR',
#  'GSO',
#  'GSP',
#  'GST',
#  'GTF',
#  'GTR',
#  'GUC',
#  'GUM',
#  'HDN',
#  'HGR',
#  'HIB',
#  'HLN',
#  'HNL',
#  'HOB',
#  'HOU',
#  'HPN',
#  'HSV',
#  'HTS',
#  'HVN',
#  'HYA',
#  'HYS',
#  'IAD',
#  'IAH',
#  'ICT',
#  'IDA',
#  'ILM',
#  'IMT',
#  'IND',
#  'INL',
#  'ISN',
#  'ISP',
#  'ITH',
#  'ITO',
#  'JAC',
#  'JAN',
#  'JAX',
#  'JFK',
#  'JLN',
#  'JMS',
#  'JNU',
#  'KOA',
#  'KTN',
#  'LAN',
#  'LAR',
#  'LAS',
#  'LAW',
#  'LAX',
#  'LBB',
#  'LBE',
#  'LBF',
#  'LBL',
#  'LCH',
#  'LCK',
#  'LEX',
#  'LFT',
#  'LGA',
#  'LGB',
#  'LIH',
#  'LIT',
#  'LNK',
#  'LRD',
#  'LSE',
#  'LWB',
#  'LWS',
#  'LYH',
#  'MAF',
#  'MBS',
#  'MCI',
#  'MCO',
#  'MDT',
#  'MDW',
#  'MEI',
#  'MEM',
#  'MFE',
#  'MFR',
#  'MGM',
#  'MHK',
#  'MHT',
#  'MIA',
#  'MKE',
#  'MKG',
#  'MLB',
#  'MLI',
#  'MLU',
#  'MMH',
#  'MOB',
#  'MOT',
#  'MQT',
#  'MRY',
#  'MSN',
#  'MSO',
#  'MSP',
#  'MSY',
#  'MTJ',
#  'MVY',
#  'MYR',
#  'OAJ',
#  'OAK',
#  'OGG',
#  'OKC',
#  'OMA',
#  'OME',
#  'ONT',
#  'ORD',
#  'ORF',
#  'ORH',
#  'OTH',
#  'OTZ',
#  'OWB',
#  'PAE',
#  'PBG',
#  'PBI',
#  'PDX',
#  'PGD',
#  'PGV',
#  'PHF',
#  'PHL',
#  'PHX',
#  'PIA',
#  'PIB',
#  'PIE',
#  'PIH',
#  'PIR',
#  'PIT',
#  'PLN',
#  'PNS',
#  'PPG',
#  'PRC',
#  'PSC',
#  'PSG',
#  'PSM',
#  'PSP',
#  'PUB',
#  'PVD',
#  'PVU',
#  'PWM',
#  'RAP',
#  'RDD',
#  'RDM',
#  'RDU',
#  'RFD',
#  'RHI',
#  'RIC',
#  'RKS',
#  'RNO',
#  'ROA',
#  'ROC',
#  'ROW',
#  'RST',
#  'RSW',
#  'SAF',
#  'SAN',
#  'SAT',
#  'SAV',
#  'SBA',
#  'SBN',
#  'SBP',
#  'SCC',
#  'SCK',
#  'SDF',
#  'SEA',
#  'SFB',
#  'SFO',
#  'SGF',
#  'SGU',
#  'SHD',
#  'SHV',
#  'SIT',
#  'SJC',
#  'SJT',
#  'SJU',
#  'SLC',
#  'SMF',
#  'SMX',
#  'SNA',
#  'SPI',
#  'SPS',
#  'SRQ',
#  'STC',
#  'STL',
#  'STT',
#  'STX',
#  'SUN',
#  'SUX',
#  'SWF',
#  'SWO',
#  'SYR',
#  'TLH',
#  'TOL',
#  'TPA',
#  'TRI',
#  'TTN',
#  'TUL',
#  'TUS',
#  'TVC',
#  'TWF',
#  'TXK',
#  'TYR',
#  'TYS',
#  'UIN',
#  'VEL',
#  'VLD',
#  'VPS',
#  'WRG',
#  'WYS',
#  'XNA',
#  'YAK']

# %% [markdown]
# ### `DEP_TIME_hour`

# %%
depTimeHours = df['DEP_TIME_hour'].unique()

with open("dict_mappers/depTimeHours_list.pkl", "wb") as f:
    pickle.dump(depTimeHours, f)
depTimeHours
# Out:
# <StringArray>
# ['11', '10',  '9',  '8',  '7',  '0',  '6', '12', '23', '17', '18', '20', '16',
#  '15', '13', '14', '19', '22', '21']
# Length: 19, dtype: string

# %% [markdown]
# ### `ARR_TIME_hour`

# %% [markdown]
# #### `arrTimeHour_dict`: known routes
# Based on the most frequent value *(mode)* for the combination of: 'ORIGIN', 'DEST', 'OP_UNIQUE_CARRIER' and 'DEP_TIME_hour'

# %%
df2 = df[['ORIGIN', 'DEST', 'OP_UNIQUE_CARRIER', 'DEP_TIME_hour', 'ARR_TIME_hour']].copy()
df2['key'] = df2['ORIGIN'] + '_' + df2['DEST'] + '_'  + df2['OP_UNIQUE_CARRIER'] + '_'  + df2['DEP_TIME_hour']
df3 = df2.sort_values(by='key', ascending=True)[['key', 'ARR_TIME_hour']]
grp = df3.groupby('key')['ARR_TIME_hour'].agg(lambda x : x.mode()[0]) # .reset_index()
arrTimeHour_dict = dict(zip(grp.index, grp.values))
with open("dict_mappers/arrTimeHour_dict.pkl", "wb") as f:
    pickle.dump(arrTimeHour_dict, f)
arrTimeHour_dict
# Out:
# {'ABE_ATL_9E_13': '15',
#  'ABE_ATL_9E_14': '17',
#  'ABE_ATL_9E_15': '17',
#  'ABE_ATL_9E_17': '20',
#  'ABE_ATL_9E_18': '20',
#  'ABE_ATL_9E_6': '8',
#  'ABE_ATL_DL_17': '20',
#  'ABE_ATL_DL_6': '8',
#  'ABE_BNA_G4_13': '14',
#  'ABE_BNA_G4_14': '15',
#  'ABE_BNA_G4_17': '18',
#  'ABE_BNA_G4_18': '19',
#  'ABE_BNA_G4_19': '20',
#  'ABE_CLT_OH_0': '7',
#  'ABE_CLT_OH_11': '13',
#  'ABE_CLT_OH_16': '19',
#  'ABE_CLT_OH_18': '21',
#  'ABE_CLT_OH_19': '21',
#  'ABE_CLT_OH_6': '8',
#  'ABE_CLT_OH_8': '10',
#  'ABE_DTW_OO_0': '7',
#  'ABE_DTW_OO_12': '14',
#  'ABE_DTW_OO_13': '15',
#  'ABE_DTW_OO_17': '19',
#  'ABE_DTW_OO_6': '7',
#  'ABE_DTW_OO_9': '11',
#  'ABE_FLL_G4_10': '13',
#  'ABE_FLL_G4_11': '13',
#  'ABE_FLL_G4_14': '16',
#  'ABE_FLL_G4_17': '20',
#  'ABE_FLL_G4_18': '21',
#  'ABE_FLL_G4_19': '22',
#  'ABE_FLL_G4_9': '12',
#  'ABE_MYR_G4_11': '12',
#  'ABE_MYR_G4_12': '13',
#  'ABE_MYR_G4_14': '16',
#  'ABE_MYR_G4_15': '16',
#  'ABE_MYR_G4_16': '18',
#  'ABE_MYR_G4_17': '19',
#  'ABE_MYR_G4_18': '20',
#  'ABE_MYR_G4_20': '22',
#  'ABE_MYR_G4_8': '9',
#  'ABE_ORD_EV_12': '13',
#  'ABE_ORD_EV_17': '18',
#  'ABE_ORD_EV_7': '9',
#  'ABE_ORD_MQ_14': '15',
#  'ABE_ORD_MQ_15': '16',
#  'ABE_ORD_MQ_6': '8',
#  'ABE_ORD_MQ_7': '8',
#  'ABE_ORD_MQ_9': '10',
#  'ABE_ORD_OO_12': '13',
#  'ABE_ORD_OO_13': '14',
#  'ABE_ORD_OO_17': '18',
#  'ABE_ORD_OO_6': '7',
#  'ABE_ORD_OO_7': '8',
#  'ABE_ORD_OO_8': '9',
#  'ABE_PGD_G4_0': '0',
#  'ABE_PGD_G4_10': '12',
#  'ABE_PGD_G4_11': '14',
#  'ABE_PGD_G4_12': '14',
#  'ABE_PGD_G4_13': '16',
#  'ABE_PGD_G4_15': '18',
#  'ABE_PGD_G4_16': '19',
#  'ABE_PGD_G4_17': '20',
#  'ABE_PGD_G4_18': '20',
#  'ABE_PGD_G4_19': '22',
#  'ABE_PGD_G4_20': '23',
#  'ABE_PGD_G4_9': '12',
#  'ABE_PIE_G4_10': '13',
#  'ABE_PIE_G4_11': '13',
#  'ABE_PIE_G4_12': '15',
#  'ABE_PIE_G4_13': '16',
#  'ABE_PIE_G4_14': '17',
#  'ABE_PIE_G4_15': '18',
#  'ABE_PIE_G4_16': '18',
#  'ABE_PIE_G4_17': '19',
#  'ABE_PIE_G4_18': '20',
#  'ABE_PIE_G4_19': '21',
#  'ABE_PIE_G4_20': '23',
#  'ABE_PIE_G4_21': '23',
#  'ABE_PIE_G4_9': '12',
#  'ABE_SAV_G4_10': '12',
#  'ABE_SAV_G4_12': '14',
#  'ABE_SAV_G4_14': '16',
#  'ABE_SAV_G4_21': '23',
#  'ABE_SAV_G4_9': '11',
#  'ABE_SFB_G4_0': '0',
#  'ABE_SFB_G4_10': '12',
#  'ABE_SFB_G4_11': '13',
#  'ABE_SFB_G4_12': '14',
#  'ABE_SFB_G4_13': '15',
#  'ABE_SFB_G4_14': '16',
#  'ABE_SFB_G4_15': '17',
#  'ABE_SFB_G4_16': '18',
#  'ABE_SFB_G4_17': '19',
#  'ABE_SFB_G4_18': '21',
#  'ABE_SFB_G4_19': '22',
#  'ABE_SFB_G4_20': '23',
#  'ABE_SFB_G4_21': '23',
#  'ABE_SFB_G4_9': '11',
#  'ABI_DFW_MQ_0': '6',
#  'ABI_DFW_MQ_10': '11',
#  'ABI_DFW_MQ_12': '13',
#  'ABI_DFW_MQ_13': '14',
#  'ABI_DFW_MQ_14': '15',
#  'ABI_DFW_MQ_15': '16',
#  'ABI_DFW_MQ_16': '17',
#  'ABI_DFW_MQ_17': '17',
#  'ABI_DFW_MQ_18': '19',
#  'ABI_DFW_MQ_21': '22',
#  'ABI_DFW_MQ_6': '7',
#  'ABI_DFW_MQ_7': '8',
#  'ABI_DFW_MQ_8': '9',
#  'ABI_DFW_MQ_9': '10',
#  'ABQ_ATL_DL_11': '16',
#  'ABQ_ATL_DL_12': '17',
#  'ABQ_ATL_DL_13': '18',
#  'ABQ_ATL_DL_14': '19',
#  'ABQ_ATL_DL_15': '20',
#  'ABQ_ATL_DL_16': '21',
#  'ABQ_ATL_DL_6': '11',
#  'ABQ_ATL_DL_9': '13',
#  'ABQ_AUS_G4_10': '13',
#  'ABQ_AUS_G4_11': '14',
#  'ABQ_AUS_G4_12': '15',
#  'ABQ_AUS_G4_13': '16',
#  'ABQ_AUS_G4_15': '18',
#  'ABQ_AUS_G4_16': '18',
#  'ABQ_AUS_G4_17': '19',
#  'ABQ_AUS_G4_9': '11',
#  'ABQ_AUS_WN_0': '7',
#  'ABQ_AUS_WN_10': '13',
#  'ABQ_AUS_WN_11': '14',
#  'ABQ_AUS_WN_12': '15',
#  'ABQ_AUS_WN_13': '15',
#  'ABQ_AUS_WN_14': '17',
#  'ABQ_AUS_WN_15': '18',
#  'ABQ_AUS_WN_16': '18',
#  'ABQ_AUS_WN_17': '19',
#  'ABQ_AUS_WN_18': '21',
#  'ABQ_AUS_WN_19': '21',
#  'ABQ_AUS_WN_20': '23',
#  'ABQ_AUS_WN_21': '0',
#  'ABQ_AUS_WN_22': '0',
#  'ABQ_AUS_WN_6': '9',
#  'ABQ_AUS_WN_7': '9',
#  'ABQ_AUS_WN_8': '11',
#  'ABQ_AUS_WN_9': '11',
#  'ABQ_BWI_WN_0': '11',
#  'ABQ_BWI_WN_10': '15',
#  'ABQ_BWI_WN_11': '17',
#  'ABQ_BWI_WN_12': '18',
#  'ABQ_BWI_WN_13': '19',
#  'ABQ_BWI_WN_14': '20',
#  'ABQ_BWI_WN_15': '21',
#  'ABQ_BWI_WN_6': '12',
#  'ABQ_BWI_WN_7': '13',
#  'ABQ_BWI_WN_8': '14',
#  'ABQ_BWI_WN_9': '15',
#  'ABQ_DAL_WN_0': '8',
#  'ABQ_DAL_WN_10': '13',
#  'ABQ_DAL_WN_11': '14',
#  'ABQ_DAL_WN_12': '15',
#  'ABQ_DAL_WN_13': '16',
#  'ABQ_DAL_WN_14': '17',
#  'ABQ_DAL_WN_15': '18',
#  'ABQ_DAL_WN_16': '19',
#  'ABQ_DAL_WN_17': '20',
#  'ABQ_DAL_WN_18': '21',
#  'ABQ_DAL_WN_19': '22',
#  'ABQ_DAL_WN_20': '22',
#  'ABQ_DAL_WN_6': '9',
#  'ABQ_DAL_WN_7': '9',
#  'ABQ_DAL_WN_8': '11',
#  'ABQ_DAL_WN_9': '12',
#  'ABQ_DEN_F9_13': '14',
#  'ABQ_DEN_F9_15': '17',
#  'ABQ_DEN_F9_17': '18',
#  'ABQ_DEN_F9_18': '20',
#  'ABQ_DEN_F9_19': '21',
#  'ABQ_DEN_F9_20': '21',
#  'ABQ_DEN_OO_0': '7',
#  'ABQ_DEN_OO_11': '12',
#  'ABQ_DEN_OO_13': '14',
#  'ABQ_DEN_OO_14': '16',
#  'ABQ_DEN_OO_15': '16',
#  'ABQ_DEN_OO_18': '19',
#  'ABQ_DEN_OO_7': '8',
#  'ABQ_DEN_OO_8': '10',
#  'ABQ_DEN_UA_0': '7',
#  'ABQ_DEN_UA_11': '12',
#  'ABQ_DEN_UA_15': '16',
#  'ABQ_DEN_UA_18': '19',
#  'ABQ_DEN_UA_21': '22',
#  'ABQ_DEN_UA_6': '7',
#  'ABQ_DEN_UA_7': '8',
#  'ABQ_DEN_UA_8': '9',
#  'ABQ_DEN_WN_0': '6',
#  'ABQ_DEN_WN_10': '11',
#  'ABQ_DEN_WN_11': '13',
#  'ABQ_DEN_WN_12': '13',
#  'ABQ_DEN_WN_13': '14',
#  'ABQ_DEN_WN_14': '15',
#  'ABQ_DEN_WN_15': '16',
#  'ABQ_DEN_WN_16': '18',
#  'ABQ_DEN_WN_17': '19',
#  'ABQ_DEN_WN_18': '20',
#  'ABQ_DEN_WN_20': '22',
#  'ABQ_DEN_WN_22': '0',
#  'ABQ_DEN_WN_6': '7',
#  'ABQ_DEN_WN_7': '8',
#  'ABQ_DEN_WN_8': '9',
#  'ABQ_DEN_WN_9': '11',
#  'ABQ_DEN_YX_11': '12',
#  'ABQ_DEN_YX_13': '14',
#  'ABQ_DEN_YX_17': '19',
#  'ABQ_DEN_YX_18': '19',
#  'ABQ_DEN_YX_8': '10',
#  'ABQ_DFW_AA_10': '13',
#  'ABQ_DFW_AA_11': '13',
#  'ABQ_DFW_AA_12': '15',
#  'ABQ_DFW_AA_14': '17',
#  'ABQ_DFW_AA_15': '17',
#  'ABQ_DFW_AA_16': '19',
#  'ABQ_DFW_AA_18': '21',
#  'ABQ_DFW_AA_20': '23',
#  'ABQ_DFW_AA_6': '9',
#  'ABQ_DFW_AA_7': '10',
#  'ABQ_DFW_AA_8': '11',
#  'ABQ_DFW_YV_0': '7',
#  'ABQ_DFW_YV_10': '13',
#  'ABQ_DFW_YV_11': '14',
#  'ABQ_DFW_YV_12': '15',
#  'ABQ_DFW_YV_14': '17',
#  'ABQ_DFW_YV_15': '17',
#  'ABQ_DFW_YV_16': '19',
#  'ABQ_DFW_YV_18': '21',
#  'ABQ_HOU_WN_0': '8',
#  'ABQ_HOU_WN_10': '13',
#  'ABQ_HOU_WN_11': '14',
#  'ABQ_HOU_WN_12': '15',
#  'ABQ_HOU_WN_13': '16',
#  'ABQ_HOU_WN_14': '18',
#  'ABQ_HOU_WN_15': '18',
#  'ABQ_HOU_WN_16': '18',
#  'ABQ_HOU_WN_18': '21',
#  'ABQ_HOU_WN_19': '22',
#  'ABQ_HOU_WN_20': '23',
#  'ABQ_HOU_WN_6': '9',
#  'ABQ_HOU_WN_7': '10',
#  'ABQ_HOU_WN_8': '11',
#  'ABQ_HOU_WN_9': '12',
#  'ABQ_IAH_EV_0': '8',
#  'ABQ_IAH_EV_10': '13',
#  'ABQ_IAH_EV_11': '14',
#  'ABQ_IAH_EV_12': '15',
#  'ABQ_IAH_EV_13': '17',
#  'ABQ_IAH_EV_14': '17',
#  'ABQ_IAH_EV_17': '20',
#  'ABQ_IAH_EV_7': '11',
#  'ABQ_IAH_EV_8': '11',
#  'ABQ_IAH_EV_9': '13',
#  'ABQ_IAH_OO_0': '8',
#  'ABQ_IAH_OO_12': '15',
#  'ABQ_IAH_OO_14': '17',
#  'ABQ_IAH_OO_7': '10',
#  'ABQ_IAH_OO_8': '11',
#  'ABQ_IAH_UA_0': '8',
#  'ABQ_IAH_UA_12': '15',
#  'ABQ_IAH_UA_14': '17',
#  'ABQ_IAH_UA_20': '23',
#  'ABQ_IAH_UA_7': '11',
#  'ABQ_IAH_UA_8': '11',
#  'ABQ_IAH_YV_0': '8',
#  'ABQ_IAH_YV_10': '13',
#  'ABQ_IAH_YV_11': '14',
#  'ABQ_IAH_YV_12': '15',
#  'ABQ_IAH_YV_14': '17',
#  'ABQ_IAH_YV_16': '19',
#  'ABQ_IAH_YV_17': '20',
#  'ABQ_IAH_YV_20': '23',
#  'ABQ_IAH_YV_7': '11',
#  'ABQ_IAH_YV_8': '11',
#  'ABQ_IAH_YV_9': '13',
#  'ABQ_IAH_YX_0': '8',
#  'ABQ_IAH_YX_11': '14',
#  'ABQ_IAH_YX_12': '15',
#  'ABQ_IAH_YX_14': '17',
#  'ABQ_IAH_YX_17': '20',
#  'ABQ_IAH_YX_8': '11',
#  'ABQ_JFK_B6_23': '0',
#  'ABQ_LAS_G4_10': '11',
#  'ABQ_LAS_G4_13': '13',
#  'ABQ_LAS_G4_14': '14',
#  'ABQ_LAS_G4_15': '16',
#  'ABQ_LAS_G4_16': '17',
#  'ABQ_LAS_G4_17': '17',
#  'ABQ_LAS_G4_18': '18',
#  'ABQ_LAS_G4_20': '21',
#  'ABQ_LAS_G4_21': '22',
#  'ABQ_LAS_WN_0': '6',
#  'ABQ_LAS_WN_10': '11',
#  'ABQ_LAS_WN_11': '12',
#  'ABQ_LAS_WN_12': '13',
#  'ABQ_LAS_WN_13': '13',
#  'ABQ_LAS_WN_14': '15',
#  'ABQ_LAS_WN_15': '16',
#  'ABQ_LAS_WN_16': '17',
#  'ABQ_LAS_WN_17': '18',
#  'ABQ_LAS_WN_18': '19',
#  'ABQ_LAS_WN_19': '19',
#  'ABQ_LAS_WN_20': '21',
#  'ABQ_LAS_WN_21': '21',
#  'ABQ_LAS_WN_22': '22',
#  'ABQ_LAS_WN_6': '6',
#  'ABQ_LAS_WN_7': '7',
#  'ABQ_LAS_WN_8': '9',
#  'ABQ_LAS_WN_9': '10',
#  'ABQ_LAX_AA_8': '9',
#  'ABQ_LAX_OO_11': '12',
#  'ABQ_LAX_OO_12': '13',
#  'ABQ_LAX_OO_13': '14',
#  'ABQ_LAX_OO_14': '15',
#  'ABQ_LAX_OO_16': '17',
#  'ABQ_LAX_OO_18': '19',
#  'ABQ_LAX_OO_20': '21',
#  'ABQ_LAX_OO_7': '8',
#  'ABQ_LAX_OO_8': '9',
#  'ABQ_LAX_UA_16': '17',
#  'ABQ_LAX_UA_17': '18',
#  'ABQ_LAX_WN_0': '6',
#  'ABQ_LAX_WN_10': '11',
#  'ABQ_LAX_WN_11': '12',
#  'ABQ_LAX_WN_12': '13',
#  'ABQ_LAX_WN_13': '14',
#  'ABQ_LAX_WN_14': '15',
#  'ABQ_LAX_WN_15': '17',
#  'ABQ_LAX_WN_17': '18',
#  'ABQ_LAX_WN_18': '19',
#  'ABQ_LAX_WN_19': '20',
#  'ABQ_LAX_WN_20': '21',
#  'ABQ_LAX_WN_21': '22',
#  'ABQ_LAX_WN_22': '23',
#  'ABQ_LAX_WN_6': '7',
#  'ABQ_LAX_WN_7': '8',
#  'ABQ_LAX_WN_8': '10',
#  'ABQ_LAX_WN_9': '10',
#  'ABQ_MCI_WN_10': '13',
#  'ABQ_MCI_WN_11': '13',
#  'ABQ_MCI_WN_12': '15',
#  'ABQ_MCI_WN_16': '19',
#  'ABQ_MCI_WN_17': '20',
#  'ABQ_MCI_WN_18': '20',
#  'ABQ_MCI_WN_19': '22',
#  'ABQ_MCI_WN_6': '9',
#  'ABQ_MCI_WN_7': '10',
#  'ABQ_MCI_WN_8': '11',
#  'ABQ_MCI_WN_9': '11',
#  'ABQ_MCO_F9_0': '6',
#  'ABQ_MCO_WN_11': '17',
#  'ABQ_MCO_WN_6': '12',
#  'ABQ_MDW_WN_0': '9',
#  'ABQ_MDW_WN_10': '14',
#  'ABQ_MDW_WN_12': '16',
#  'ABQ_MDW_WN_14': '18',
#  'ABQ_MDW_WN_15': '19',
#  'ABQ_MDW_WN_16': '20',
#  'ABQ_MDW_WN_17': '20',
#  'ABQ_MDW_WN_18': '21',
#  'ABQ_MDW_WN_19': '23',
#  'ABQ_MDW_WN_6': '10',
#  'ABQ_MDW_WN_7': '11',
#  'ABQ_MDW_WN_8': '12',
#  'ABQ_MDW_WN_9': '12',
#  'ABQ_MSP_DL_13': '17',
#  'ABQ_MSP_DL_14': '18',
#  'ABQ_MSP_DL_15': '18',
#  'ABQ_MSP_DL_6': '10',
#  'ABQ_MSP_DL_7': '10',
#  'ABQ_MSP_DL_8': '12',
#  'ABQ_OAK_WN_0': '6',
#  'ABQ_OAK_WN_10': '12',
#  'ABQ_OAK_WN_11': '13',
#  'ABQ_OAK_WN_12': '14',
#  'ABQ_OAK_WN_13': '14',
#  'ABQ_OAK_WN_14': '16',
#  'ABQ_OAK_WN_15': '17',
#  'ABQ_OAK_WN_18': '20',
#  'ABQ_OAK_WN_19': '21',
#  'ABQ_OAK_WN_20': '22',
#  'ABQ_OAK_WN_21': '22',
#  'ABQ_OAK_WN_22': '23',
#  'ABQ_OAK_WN_6': '7',
#  'ABQ_OAK_WN_7': '8',
#  'ABQ_OAK_WN_8': '9',
#  'ABQ_OAK_WN_9': '10',
#  'ABQ_ORD_AA_0': '9',
#  'ABQ_ORD_AA_13': '17',
#  'ABQ_ORD_AA_6': '10',
#  'ABQ_ORD_AA_7': '11',
#  'ABQ_ORD_EV_13': '17',
#  'ABQ_ORD_EV_6': '10',
#  'ABQ_ORD_MQ_12': '16',
#  'ABQ_ORD_MQ_13': '16',
#  'ABQ_ORD_MQ_7': '10',
#  'ABQ_ORD_OO_13': '16',
#  'ABQ_ORD_OO_16': '19',
#  'ABQ_ORD_OO_6': '10',
#  'ABQ_ORD_OO_7': '10',
#  'ABQ_ORD_UA_13': '17',
#  'ABQ_ORD_UA_15': '19',
#  'ABQ_ORD_UA_16': '19',
#  'ABQ_ORD_UA_6': '9',
#  'ABQ_ORD_UA_8': '12',
#  'ABQ_ORD_UA_9': '13',
#  'ABQ_ORD_YX_13': '17',
#  'ABQ_ORD_YX_6': '10',
#  'ABQ_PDX_OO_13': '15',
#  'ABQ_PDX_OO_15': '17',
#  'ABQ_PDX_OO_18': '20',
#  'ABQ_PDX_OO_20': '22',
#  'ABQ_PHX_AA_11': '12',
#  'ABQ_PHX_AA_12': '12',
#  'ABQ_PHX_AA_15': '16',
#  'ABQ_PHX_AA_19': '20',
#  'ABQ_PHX_AA_6': '7',
#  'ABQ_PHX_AA_7': '9',
#  'ABQ_PHX_AA_8': '10',
#  'ABQ_PHX_OO_18': '19',
#  'ABQ_PHX_OO_20': '20',
#  'ABQ_PHX_OO_6': '6',
#  'ABQ_PHX_OO_7': '8',
#  'ABQ_PHX_WN_0': '6',
#  'ABQ_PHX_WN_10': '10',
#  'ABQ_PHX_WN_11': '12',
#  'ABQ_PHX_WN_12': '12',
#  'ABQ_PHX_WN_13': '14',
#  'ABQ_PHX_WN_14': '15',
#  'ABQ_PHX_WN_15': '15',
#  'ABQ_PHX_WN_16': '17',
#  'ABQ_PHX_WN_17': '18',
#  'ABQ_PHX_WN_18': '18',
#  'ABQ_PHX_WN_19': '20',
#  'ABQ_PHX_WN_20': '20',
#  'ABQ_PHX_WN_6': '8',
#  'ABQ_PHX_WN_7': '7',
#  'ABQ_PHX_WN_8': '9',
#  'ABQ_PHX_WN_9': '9',
#  'ABQ_PHX_YV_11': '12',
#  'ABQ_PHX_YV_12': '13',
#  'ABQ_PHX_YV_15': '15',
#  'ABQ_PHX_YV_17': '17',
#  'ABQ_PHX_YV_21': '22',
#  'ABQ_PHX_YV_22': '23',
#  'ABQ_PHX_YV_8': '9',
#  'ABQ_SAN_OO_6': '6',
#  'ABQ_SAN_OO_7': '8',
#  'ABQ_SAN_OO_8': '9',
#  'ABQ_SAN_WN_10': '11',
#  'ABQ_SAN_WN_11': '12',
#  'ABQ_SAN_WN_12': '13',
#  'ABQ_SAN_WN_13': '13',
#  'ABQ_SAN_WN_15': '16',
#  'ABQ_SAN_WN_16': '17',
#  'ABQ_SAN_WN_17': '18',
#  'ABQ_SAN_WN_18': '19',
#  'ABQ_SAN_WN_19': '20',
#  'ABQ_SAN_WN_20': '21',
#  'ABQ_SAN_WN_21': '22',
#  'ABQ_SAN_WN_22': '23',
#  'ABQ_SAN_WN_6': '7',
#  'ABQ_SAN_WN_7': '8',
#  'ABQ_SAN_WN_8': '8',
#  'ABQ_SAN_WN_9': '10',
#  'ABQ_SAT_WN_14': '17',
#  'ABQ_SEA_AS_15': '17',
#  'ABQ_SEA_AS_16': '18',
#  'ABQ_SEA_AS_17': '19',
#  'ABQ_SEA_AS_6': '8',
#  'ABQ_SEA_AS_7': '9',
#  'ABQ_SEA_AS_8': '11',
#  'ABQ_SEA_AS_9': '11',
#  'ABQ_SFO_OO_11': '13',
#  'ABQ_SFO_OO_13': '15',
#  'ABQ_SFO_OO_15': '17',
#  'ABQ_SFO_OO_20': '22',
#  'ABQ_SFO_OO_6': '7',
#  'ABQ_SFO_UA_0': '7',
#  'ABQ_SFO_UA_15': '17',
#  'ABQ_SFO_UA_6': '7',
#  'ABQ_SFO_UA_8': '9',
#  'ABQ_SJC_WN_11': '12',
#  'ABQ_SJC_WN_12': '14',
#  'ABQ_SJC_WN_13': '14',
#  'ABQ_SJC_WN_15': '16',
#  'ABQ_SJC_WN_16': '17',
#  'ABQ_SJC_WN_17': '19',
#  'ABQ_SJC_WN_18': '19',
#  'ABQ_SJC_WN_19': '20',
#  'ABQ_SJC_WN_7': '9',
#  'ABQ_SJC_WN_8': '9',
#  'ABQ_SJC_WN_9': '10',
#  'ABQ_SLC_DL_0': '7',
#  'ABQ_SLC_DL_17': '19',
#  'ABQ_SLC_DL_6': '7',
#  'ABQ_SLC_DL_8': '10',
#  'ABQ_SLC_OO_0': '7',
#  'ABQ_SLC_OO_12': '14',
#  'ABQ_SLC_OO_14': '16',
#  'ABQ_SLC_OO_17': '19',
#  'ABQ_SLC_OO_6': '7',
#  'ABQ_SLC_OO_7': '8',
#  'ABQ_SLC_OO_8': '10',
#  'ABR_MSP_OO_0': '6',
#  'ABR_MSP_OO_13': '14',
#  'ABR_MSP_OO_17': '18',
#  'ABR_MSP_OO_6': '7',
#  'ABR_MSP_OO_7': '8',
#  'ABY_ATL_OO_11': '13',
#  'ABY_ATL_OO_12': '13',
#  'ABY_ATL_OO_13': '14',
#  'ABY_ATL_OO_14': '15',
#  'ABY_ATL_OO_15': '16',
#  'ABY_ATL_OO_16': '17',
#  'ABY_ATL_OO_17': '18',
#  'ABY_ATL_OO_21': '22',
#  'ABY_ATL_OO_6': '7',
#  'ACK_BOS_B6_10': '11',
#  'ACK_BOS_B6_13': '14',
#  'ACK_BOS_B6_17': '18',
#  'ACK_BOS_B6_9': '10',
#  'ACK_CLT_YX_16': '18',
#  'ACK_DCA_B6_12': '14',
#  'ACK_DCA_B6_13': '14',
#  'ACK_DCA_B6_14': '15',
#  'ACK_DCA_YX_10': '12',
#  'ACK_DCA_YX_12': '14',
#  'ACK_DCA_YX_17': '19',
#  'ACK_HPN_B6_10': '11',
#  'ACK_HPN_B6_12': '14',
#  'ACK_HPN_B6_13': '15',
#  'ACK_JFK_B6_11': '12',
#  'ACK_JFK_B6_14': '16',
#  'ACK_JFK_B6_15': '16',
#  'ACK_JFK_B6_16': '17',
#  'ACK_JFK_B6_18': '19',
#  'ACK_JFK_B6_22': '23',
#  'ACK_JFK_B6_7': '8',
#  'ACK_JFK_B6_8': '10',
#  'ACK_LGA_9E_11': '12',
#  'ACK_LGA_9E_12': '14',
#  'ACK_LGA_9E_13': '14',
#  'ACK_LGA_9E_15': '16',
#  'ACK_LGA_B6_10': '11',
#  'ACK_LGA_B6_11': '12',
#  'ACK_LGA_B6_15': '16',
#  'ACK_LGA_B6_17': '18',
#  'ACK_LGA_YX_11': '12',
#  'ACK_LGA_YX_15': '16',
#  'ACT_DFW_MQ_0': '6',
#  'ACT_DFW_MQ_10': '11',
#  'ACT_DFW_MQ_11': '12',
#  'ACT_DFW_MQ_12': '13',
#  'ACT_DFW_MQ_13': '14',
#  'ACT_DFW_MQ_14': '14',
#  'ACT_DFW_MQ_15': '16',
#  'ACT_DFW_MQ_16': '17',
#  'ACT_DFW_MQ_17': '18',
#  'ACT_DFW_MQ_18': '19',
#  'ACT_DFW_MQ_19': '20',
#  'ACT_DFW_MQ_20': '21',
#  'ACT_DFW_MQ_6': '7',
#  'ACT_DFW_MQ_7': '7',
#  'ACT_DFW_MQ_8': '9',
#  'ACT_DFW_MQ_9': '10',
#  'ACT_DFW_OO_8': '9',
#  'ACV_DEN_OO_6': '10',
#  'ACV_LAX_OO_10': '12',
#  'ACV_LAX_OO_11': '13',
#  'ACV_LAX_OO_19': '21',
#  'ACV_LAX_OO_20': '21',
#  'ACV_LAX_OO_6': '8',
#  'ACV_LAX_OO_7': '8',
#  'ACV_LAX_OO_9': '11',
#  'ACV_SFO_OO_0': '7',
#  'ACV_SFO_OO_10': '12',
#  'ACV_SFO_OO_11': '12',
#  'ACV_SFO_OO_12': '13',
#  'ACV_SFO_OO_17': '18',
#  'ACV_SFO_OO_18': '19',
#  'ACV_SFO_OO_19': '20',
#  'ACV_SFO_OO_20': '21',
#  'ACV_SFO_OO_6': '7',
#  'ACV_SFO_OO_7': '8',
#  'ACV_SFO_OO_8': '9',
#  'ACY_ATL_NK_12': '15',
#  'ACY_ATL_NK_13': '15',
#  'ACY_FLL_NK_12': '15',
#  'ACY_FLL_NK_14': '17',
#  'ACY_FLL_NK_17': '19',
#  'ACY_FLL_NK_20': '22',
#  'ACY_FLL_NK_6': '9',
#  'ACY_FLL_NK_7': '9',
#  'ACY_MCO_NK_16': '19',
#  'ACY_MCO_NK_17': '19',
#  'ACY_MCO_NK_18': '20',
#  'ACY_MCO_NK_6': '8',
#  'ACY_MCO_NK_7': '9',
#  'ACY_MCO_NK_8': '10',
#  'ACY_MYR_NK_6': '7',
#  'ACY_MYR_NK_7': '8',
#  'ACY_PBI_NK_13': '15',
#  'ACY_RSW_NK_13': '16',
#  'ACY_RSW_NK_15': '18',
#  'ACY_RSW_NK_17': '20',
#  'ACY_RSW_NK_18': '20',
#  'ACY_RSW_NK_6': '9',
#  'ACY_TPA_NK_10': '13',
#  'ACY_TPA_NK_11': '13',
#  'ACY_TPA_NK_6': '8',
#  'ACY_TPA_NK_9': '11',
#  'ADK_ANC_AS_16': '20',
#  'ADK_ANC_AS_17': '20',
#  'ADQ_ANC_AS_16': '17',
#  'ADQ_ANC_AS_17': '17',
#  'ADQ_ANC_AS_7': '8',
#  'ADQ_ANC_AS_8': '8',
#  'AEX_ATL_9E_10': '13',
#  'AEX_ATL_9E_11': '14',
#  'AEX_ATL_9E_13': '16',
#  'AEX_ATL_9E_14': '17',
#  'AEX_ATL_9E_15': '17',
#  'AEX_ATL_9E_16': '19',
#  'AEX_ATL_9E_17': '20',
#  'AEX_ATL_9E_20': '22',
#  'AEX_ATL_9E_6': '8',
#  'AEX_ATL_OO_15': '18',
#  'AEX_DFW_MQ_0': '6',
#  'AEX_DFW_MQ_10': '11',
#  'AEX_DFW_MQ_12': '13',
#  'AEX_DFW_MQ_16': '17',
#  'AEX_DFW_MQ_6': '7',
#  'AEX_DFW_MQ_8': '9',
#  'AEX_IAH_EV_10': '11',
#  'AEX_IAH_EV_12': '13',
#  'AEX_IAH_EV_16': '17',
#  'AEX_IAH_EV_17': '18',
#  'AEX_IAH_EV_6': '7',
#  'AEX_IAH_EV_7': '8',
#  'AGS_ATL_9E_0': '6',
#  'AGS_ATL_9E_10': '11',
#  'AGS_ATL_9E_11': '12',
#  'AGS_ATL_9E_12': '13',
#  'AGS_ATL_9E_13': '14',
#  'AGS_ATL_9E_14': '15',
#  'AGS_ATL_9E_15': '16',
#  'AGS_ATL_9E_16': '17',
#  'AGS_ATL_9E_17': '18',
#  'AGS_ATL_9E_18': '20',
#  'AGS_ATL_9E_19': '20',
#  'AGS_ATL_9E_6': '7',
#  'AGS_ATL_9E_7': '8',
#  'AGS_ATL_9E_8': '9',
#  'AGS_ATL_9E_9': '10',
#  'AGS_ATL_DL_0': '6',
#  'AGS_ATL_DL_10': '11',
#  'AGS_ATL_DL_11': '12',
#  'AGS_ATL_DL_12': '13',
#  'AGS_ATL_DL_13': '14',
#  'AGS_ATL_DL_14': '15',
#  'AGS_ATL_DL_15': '16',
#  'AGS_ATL_DL_16': '17',
#  'AGS_ATL_DL_17': '18',
#  'AGS_ATL_DL_19': '20',
#  'AGS_ATL_DL_21': '22',
#  'AGS_ATL_DL_6': '7',
#  'AGS_ATL_DL_7': '8',
#  'AGS_ATL_DL_8': '9',
#  'AGS_ATL_DL_9': '10',
#  'AGS_ATL_OO_12': '14',
#  'AGS_ATL_OO_14': '15',
#  'AGS_ATL_OO_15': '16',
#  'AGS_ATL_OO_17': '18',
#  'AGS_CLT_OH_0': '6',
#  'AGS_CLT_OH_11': '12',
#  'AGS_CLT_OH_12': '13',
#  'AGS_CLT_OH_14': '15',
#  'AGS_CLT_OH_15': '17',
#  'AGS_CLT_OH_16': '17',
#  'AGS_CLT_OH_17': '18',
#  'AGS_CLT_OH_18': '19',
#  'AGS_CLT_OH_19': '20',
#  'AGS_CLT_OH_20': '21',
#  'AGS_CLT_OH_21': '23',
#  'AGS_CLT_OH_22': '23',
#  'AGS_CLT_OH_6': '8',
#  'AGS_CLT_OH_7': '8',
#  'AGS_CLT_OH_8': '10',
#  'AGS_CLT_OH_9': '10',
#  'AGS_DCA_OH_10': '12',
#  'AGS_DCA_OH_14': '15',
#  'AGS_DCA_YX_11': '12',
#  'AGS_DCA_YX_12': '14',
#  'AGS_DCA_YX_13': '15',
#  'AGS_DCA_YX_17': '19',
#  'AGS_DCA_YX_19': '21',
#  'AGS_DFW_AA_16': '18',
#  'AGS_DFW_AA_18': '20',
#  'AGS_DFW_AA_9': '11',
#  'AGS_DFW_MQ_15': '16',
#  'AGS_DFW_MQ_16': '18',
#  'AGS_DFW_MQ_19': '21',
#  'AGS_DFW_MQ_7': '9',
#  'AGS_DFW_OO_16': '17',
#  'AGS_LGA_YX_11': '13',
#  'AGS_LGA_YX_12': '15',
#  'AGS_LGA_YX_16': '18',
#  'AGS_LGA_YX_17': '19',
#  'AGS_LGA_YX_20': '23',
#  'AGS_MIA_YX_11': '12',
#  'AGS_MIA_YX_18': '20',
#  'AGS_MIA_YX_19': '21',
#  'AGS_MIA_YX_9': '11',
#  'AGS_ORD_MQ_10': '12',
#  'AGS_ORD_MQ_17': '18',
#  'AGS_ORD_MQ_18': '19',
#  'AGS_ORD_MQ_20': '21',
#  'AGS_ORD_MQ_6': '7',
#  'AGS_PHL_OH_15': '17',
#  'AKN_ANC_AS_17': '18',
#  'ALB_ATL_9E_12': '14',
#  'ALB_ATL_9E_13': '15',
#  'ALB_ATL_9E_14': '17',
#  'ALB_ATL_9E_15': '18',
#  'ALB_ATL_9E_18': '20',
#  'ALB_ATL_DL_0': '8',
#  'ALB_ATL_DL_11': '14',
#  'ALB_ATL_DL_12': '14',
#  'ALB_ATL_DL_13': '15',
#  'ALB_ATL_DL_14': '17',
#  'ALB_ATL_DL_15': '18',
#  'ALB_ATL_DL_16': '18',
#  'ALB_ATL_DL_18': '20',
#  'ALB_ATL_DL_6': '8',
#  'ALB_BWI_WN_0': '6',
#  'ALB_BWI_WN_10': '12',
#  'ALB_BWI_WN_11': '12',
#  'ALB_BWI_WN_12': '14',
#  'ALB_BWI_WN_13': '14',
#  'ALB_BWI_WN_14': '15',
#  'ALB_BWI_WN_15': '16',
#  'ALB_BWI_WN_16': '17',
#  'ALB_BWI_WN_17': '18',
#  'ALB_BWI_WN_18': '19',
#  'ALB_BWI_WN_19': '20',
#  'ALB_BWI_WN_20': '21',
#  'ALB_BWI_WN_22': '0',
#  'ALB_BWI_WN_6': '7',
#  'ALB_BWI_WN_7': '8',
#  'ALB_BWI_WN_8': '9',
#  'ALB_BWI_WN_9': '10',
#  'ALB_CLT_AA_0': '7',
#  'ALB_CLT_AA_10': '12',
#  'ALB_CLT_AA_11': '14',
#  'ALB_CLT_AA_12': '15',
#  'ALB_CLT_AA_13': '15',
#  'ALB_CLT_AA_14': '16',
#  'ALB_CLT_AA_16': '18',
#  'ALB_CLT_AA_18': '21',
#  'ALB_CLT_AA_19': '21',
#  'ALB_CLT_AA_6': '8',
#  'ALB_CLT_AA_7': '10',
#  'ALB_CLT_AA_8': '10',
#  'ALB_CLT_OH_11': '14',
#  'ALB_CLT_OH_12': '14',
#  'ALB_CLT_YX_0': '7',
#  'ALB_CLT_YX_11': '13',
#  'ALB_CLT_YX_6': '8',
#  'ALB_CLT_YX_8': '10',
#  'ALB_DCA_OH_0': '6',
#  'ALB_DCA_OH_11': '13',
#  'ALB_DCA_OH_13': '14',
#  'ALB_DCA_OH_14': '15',
#  'ALB_DCA_OH_16': '18',
#  'ALB_DCA_OH_17': '18',
#  'ALB_DCA_OH_8': '10',
#  'ALB_DCA_OH_9': '10',
#  'ALB_DCA_YX_11': '13',
#  'ALB_DCA_YX_9': '10',
#  'ALB_DEN_F9_17': '20',
#  'ALB_DEN_F9_18': '21',
#  'ALB_DEN_WN_10': '12',
#  'ALB_DEN_WN_12': '14',
#  'ALB_DEN_WN_13': '15',
#  'ALB_DEN_WN_14': '16',
#  'ALB_DEN_WN_17': '19',
#  'ALB_DEN_WN_18': '21',
#  'ALB_DEN_WN_19': '21',
#  'ALB_DEN_WN_6': '9',
#  'ALB_DEN_WN_7': '9',
#  'ALB_DTW_9E_0': '7',
#  'ALB_DTW_9E_12': '14',
#  'ALB_DTW_9E_13': '14',
#  'ALB_DTW_9E_17': '19',
#  'ALB_DTW_DL_0': '7',
#  'ALB_DTW_DL_13': '14',
#  'ALB_DTW_DL_17': '19',
#  'ALB_DTW_DL_6': '7',
#  'ALB_DTW_DL_9': '11',
#  'ALB_DTW_OO_0': '7',
#  'ALB_DTW_OO_12': '14',
#  'ALB_DTW_OO_13': '14',
#  'ALB_DTW_OO_17': '19',
#  'ALB_DTW_OO_6': '8',
#  'ALB_DTW_OO_9': '11',
#  'ALB_EWR_EV_10': '11',
#  'ALB_EWR_EV_17': '18',
#  'ALB_EWR_EV_18': '19',
#  'ALB_EWR_YX_18': '19',
#  'ALB_EWR_YX_6': '7',
#  'ALB_FLL_B6_16': '19',
#  'ALB_FLL_B6_17': '20',
#  'ALB_FLL_WN_10': '13',
#  'ALB_FLL_WN_12': '15',
#  'ALB_FLL_WN_13': '16',
#  'ALB_FLL_WN_16': '19',
#  'ALB_FLL_WN_7': '10',
#  'ALB_FLL_WN_8': '12',
#  'ALB_FLL_WN_9': '12',
#  'ALB_IAD_EV_14': '16',
#  'ALB_IAD_EV_19': '21',
#  'ALB_IAD_YV_14': '16',
#  'ALB_IAD_YV_19': '21',
#  'ALB_MCO_B6_13': '16',
#  'ALB_MCO_B6_14': '17',
#  'ALB_MCO_B6_15': '18',
#  'ALB_MCO_B6_16': '19',
#  'ALB_MCO_F9_12': '15',
#  'ALB_MCO_F9_18': '22',
#  'ALB_MCO_F9_19': '22',
#  'ALB_MCO_F9_20': '23',
#  'ALB_MCO_F9_9': '13',
#  'ALB_MCO_WN_0': '8',
#  'ALB_MCO_WN_10': '13',
#  'ALB_MCO_WN_11': '14',
#  'ALB_MCO_WN_12': '15',
#  'ALB_MCO_WN_13': '16',
#  'ALB_MCO_WN_14': '16',
#  'ALB_MCO_WN_15': '19',
#  'ALB_MCO_WN_16': '19',
#  'ALB_MCO_WN_17': '20',
#  'ALB_MCO_WN_18': '21',
#  'ALB_MCO_WN_19': '22',
#  'ALB_MCO_WN_20': '23',
#  'ALB_MCO_WN_21': '0',
#  'ALB_MCO_WN_6': '9',
#  'ALB_MCO_WN_7': '10',
#  'ALB_MCO_WN_8': '11',
#  'ALB_MCO_WN_9': '12',
#  'ALB_MDW_WN_0': '7',
#  'ALB_MDW_WN_12': '14',
#  'ALB_MDW_WN_13': '15',
#  'ALB_MDW_WN_14': '16',
#  'ALB_MDW_WN_15': '16',
#  'ALB_MDW_WN_16': '17',
#  'ALB_MDW_WN_17': '18',
#  'ALB_MDW_WN_18': '20',
#  'ALB_MDW_WN_6': '7',
#  'ALB_MDW_WN_7': '8',
#  'ALB_MSP_9E_6': '8',
#  'ALB_MSP_DL_6': '7',
#  'ALB_MSP_DL_8': '9',
#  'ALB_MSP_OO_0': '8',
#  'ALB_MSP_OO_6': '8',
#  'ALB_MSP_OO_8': '10',
#  'ALB_MYR_G4_11': '13',
#  'ALB_MYR_G4_12': '14',
#  'ALB_MYR_G4_13': '15',
#  'ALB_MYR_G4_14': '16',
#  'ALB_MYR_G4_16': '18',
#  'ALB_MYR_G4_9': '11',
#  'ALB_ORD_EV_10': '11',
#  'ALB_ORD_EV_12': '14',
#  'ALB_ORD_EV_13': '14',
#  'ALB_ORD_EV_16': '17',
#  'ALB_ORD_EV_17': '18',
#  'ALB_ORD_EV_7': '9',
#  'ALB_ORD_EV_9': '11',
#  'ALB_ORD_MQ_10': '12',
#  'ALB_ORD_MQ_11': '12',
#  'ALB_ORD_MQ_12': '14',
#  'ALB_ORD_MQ_17': '19',
#  'ALB_ORD_MQ_18': '19',
#  'ALB_ORD_MQ_6': '8',
#  'ALB_ORD_MQ_7': '8',
#  'ALB_ORD_OO_10': '11',
#  'ALB_ORD_OO_11': '12',
#  'ALB_ORD_OO_12': '13',
#  'ALB_ORD_OO_13': '14',
#  'ALB_ORD_OO_16': '17',
#  'ALB_ORD_OO_18': '20',
#  'ALB_ORD_OO_19': '21',
#  'ALB_ORD_OO_7': '9',
#  'ALB_ORD_OO_9': '11',
#  'ALB_ORD_UA_10': '11',
#  'ALB_ORD_UA_12': '14',
#  'ALB_ORD_UA_13': '14',
#  'ALB_ORD_UA_14': '15',
#  'ALB_ORD_UA_17': '19',
#  'ALB_ORD_UA_18': '19',
#  'ALB_ORD_UA_19': '20',
#  'ALB_ORD_UA_22': '23',
#  'ALB_ORD_UA_7': '8',
#  'ALB_ORD_UA_9': '11',
#  'ALB_ORD_YX_10': '11',
#  'ALB_ORD_YX_12': '14',
#  'ALB_ORD_YX_13': '14',
#  'ALB_ORD_YX_18': '20',
#  'ALB_PGD_G4_10': '13',
#  'ALB_PGD_G4_11': '14',
#  'ALB_PGD_G4_12': '15',
#  'ALB_PGD_G4_13': '16',
#  'ALB_PGD_G4_15': '18',
#  'ALB_PGD_G4_16': '19',
#  'ALB_PGD_G4_17': '20',
#  'ALB_PGD_G4_18': '21',
#  'ALB_PGD_G4_9': '12',
#  'ALB_PHL_OH_12': '14',
#  'ALB_PHL_OH_6': '7',
#  'ALB_PHL_YX_14': '15',
#  'ALB_PHL_YX_18': '20',
#  'ALB_PIE_G4_10': '13',
#  'ALB_PIE_G4_11': '14',
#  'ALB_PIE_G4_12': '15',
#  'ALB_PIE_G4_15': '18',
#  'ALB_PIE_G4_16': '19',
#  'ALB_PIE_G4_17': '20',
#  'ALB_PIE_G4_18': '20',
#  'ALB_PIE_G4_19': '22',
#  'ALB_PIE_G4_20': '23',
#  'ALB_PIE_G4_9': '12',
#  'ALB_RDU_F9_15': '17',
#  'ALB_RDU_F9_16': '18',
#  'ALB_RSW_F9_15': '19',
#  'ALB_RSW_F9_18': '21',
#  'ALB_RSW_F9_19': '22',
#  'ALB_RSW_WN_12': '16',
#  'ALB_RSW_WN_13': '16',
#  'ALB_RSW_WN_15': '18',
#  'ALB_RSW_WN_7': '11',
#  'ALB_RSW_WN_8': '12',
#  'ALB_SAV_G4_15': '17',
#  'ALB_SAV_G4_16': '18',
#  'ALB_SAV_G4_17': '19',
#  'ALB_SAV_G4_20': '22',
#  'ALB_SAV_G4_21': '23',
#  'ALB_SAV_G4_9': '12',
#  'ALB_SFB_G4_10': '12',
#  'ALB_SFB_G4_11': '14',
#  'ALB_SFB_G4_12': '15',
#  'ALB_SFB_G4_13': '15',
#  'ALB_SFB_G4_14': '16',
#  'ALB_SFB_G4_16': '19',
#  'ALB_SFB_G4_17': '20',
#  'ALB_SFB_G4_18': '21',
#  'ALB_SFB_G4_19': '22',
#  'ALB_SFB_G4_20': '23',
#  'ALB_SFB_G4_9': '12',
#  'ALB_TPA_WN_10': '13',
#  'ALB_TPA_WN_11': '14',
#  'ALB_TPA_WN_12': '15',
#  'ALB_TPA_WN_13': '16',
#  'ALB_TPA_WN_14': '17',
#  'ALB_TPA_WN_16': '19',
#  'ALB_TPA_WN_17': '20',
#  'ALB_TPA_WN_18': '21',
#  'ALB_TPA_WN_21': '0',
#  'ALB_TPA_WN_6': '9',
#  'ALB_TPA_WN_7': '10',
#  'ALB_TPA_WN_8': '11',
#  'ALB_TPA_WN_9': '12',
#  'ALO_ORD_MQ_0': '7',
#  'ALO_ORD_MQ_13': '14',
#  'ALO_ORD_MQ_14': '16',
#  'ALO_ORD_MQ_6': '7',
#  'ALO_ORD_MQ_8': '10',
#  'ALO_ORD_MQ_9': '10',
#  'AMA_DAL_WN_0': '6',
#  'AMA_DAL_WN_10': '11',
#  'AMA_DAL_WN_11': '12',
#  'AMA_DAL_WN_12': '13',
#  'AMA_DAL_WN_13': '14',
#  'AMA_DAL_WN_14': '15',
#  'AMA_DAL_WN_15': '16',
#  'AMA_DAL_WN_16': '17',
#  'AMA_DAL_WN_17': '18',
#  'AMA_DAL_WN_18': '19',
#  'AMA_DAL_WN_19': '20',
#  'AMA_DAL_WN_6': '7',
#  'AMA_DAL_WN_7': '8',
#  ...}

# %%
#  'BOS_ATL_B6_9': '12',
df[(df['ORIGIN'] == 'BOS') & (df['DEST'] == 'ATL') & \
   (df['OP_UNIQUE_CARRIER'] == 'B6') & (df['DEP_TIME_hour'] == '9') & \
   (df['MONTH'] == '02') & (df['DAY_OF_WEEK'] == '1')]['ARR_TIME_hour'].value_counts()
# Out:
# 12    2
# 11    1
# Name: ARR_TIME_hour, dtype: Int64

# %%
arrTimeHour_dict['BOS_ATL_B6_9']
# Out:
# '12'

# %% [markdown]
# #### `arrTimeHour_dict_2`: unknown routes
# - This will be used only in case the first dictionary does not contain the user selected combination of: 'ORIGIN', 'DEST', 'OP_UNIQUE_CARRIER' and 'DEP_TIME_hour'
# - This new dictionary is based on the most frequent value *(mode)* for the combination of: 'ORIGIN' and 'DEST'

# %%
grp = df.groupby(['ORIGIN', 'DEST'], as_index=False)['CRS_ELAPSED_TIME'].agg(lambda x : x.mode()[0])
arrTimeHour_dict_2 = dict(zip(grp['ORIGIN'] + '_' + grp['DEST'],
                              (grp['CRS_ELAPSED_TIME'] / 60).round(decimals=0).astype('int')))
with open("dict_mappers/arrTimeHour_dict_2.pkl", "wb") as f:
    pickle.dump(arrTimeHour_dict_2, f)
arrTimeHour_dict_2
# Out:
# {'ABE_ATL': 2,
#  'ABE_BNA': 2,
#  'ABE_CLT': 2,
#  'ABE_DTW': 2,
#  'ABE_FLL': 3,
#  'ABE_MYR': 2,
#  'ABE_ORD': 2,
#  'ABE_PGD': 3,
#  'ABE_PIE': 3,
#  'ABE_SAV': 2,
#  'ABE_SFB': 2,
#  'ABI_DFW': 1,
#  'ABQ_ATL': 3,
#  'ABQ_AUS': 2,
#  'ABQ_BWI': 4,
#  'ABQ_DAL': 2,
#  'ABQ_DEN': 1,
#  'ABQ_DFW': 2,
#  'ABQ_HOU': 2,
#  'ABQ_IAH': 2,
#  'ABQ_JFK': 4,
#  'ABQ_LAS': 2,
#  'ABQ_LAX': 2,
#  'ABQ_MCI': 2,
#  'ABQ_MCO': 4,
#  'ABQ_MDW': 3,
#  'ABQ_MSP': 3,
#  'ABQ_OAK': 2,
#  'ABQ_ORD': 3,
#  'ABQ_PDX': 3,
#  'ABQ_PHX': 1,
#  'ABQ_SAN': 2,
#  'ABQ_SAT': 2,
#  'ABQ_SEA': 3,
#  'ABQ_SFO': 3,
#  'ABQ_SJC': 2,
#  'ABQ_SLC': 2,
#  'ABR_MSP': 1,
#  'ABY_ATL': 1,
#  'ACK_BOS': 1,
#  'ACK_CLT': 3,
#  'ACK_DCA': 2,
#  'ACK_HPN': 1,
#  'ACK_JFK': 1,
#  'ACK_LGA': 1,
#  'ACT_DFW': 1,
#  'ACV_DEN': 3,
#  'ACV_LAX': 2,
#  'ACV_SFO': 1,
#  'ACY_ATL': 2,
#  'ACY_FLL': 3,
#  'ACY_MCO': 3,
#  'ACY_MYR': 2,
#  'ACY_PBI': 3,
#  'ACY_RSW': 3,
#  'ACY_TPA': 2,
#  'ADK_ANC': 3,
#  'ADQ_ANC': 1,
#  'AEX_ATL': 2,
#  'AEX_DFW': 1,
#  'AEX_IAH': 1,
#  'AGS_ATL': 1,
#  'AGS_CLT': 1,
#  'AGS_DCA': 2,
#  'AGS_DFW': 3,
#  'AGS_LGA': 2,
#  'AGS_MIA': 2,
#  'AGS_ORD': 2,
#  'AGS_PHL': 2,
#  'AKN_ANC': 1,
#  'ALB_ATL': 3,
#  'ALB_BWI': 1,
#  'ALB_CLT': 2,
#  'ALB_DCA': 2,
#  'ALB_DEN': 4,
#  'ALB_DTW': 2,
#  'ALB_EWR': 1,
#  'ALB_FLL': 3,
#  'ALB_IAD': 1,
#  'ALB_MCO': 3,
#  'ALB_MDW': 2,
#  'ALB_MSP': 3,
#  'ALB_MYR': 2,
#  'ALB_ORD': 2,
#  'ALB_PGD': 3,
#  'ALB_PHL': 1,
#  'ALB_PIE': 3,
#  'ALB_RDU': 2,
#  'ALB_RSW': 3,
#  'ALB_SAV': 2,
#  'ALB_SFB': 3,
#  'ALB_TPA': 3,
#  'ALO_ORD': 1,
#  'AMA_DAL': 1,
#  'AMA_DEN': 1,
#  'AMA_DFW': 1,
#  'AMA_HOU': 2,
#  'AMA_IAH': 2,
#  'AMA_LAS': 2,
#  'AMA_PHX': 2,
#  'ANC_ADK': 3,
#  'ANC_ADQ': 1,
#  'ANC_AKN': 1,
#  'ANC_ATL': 7,
#  'ANC_BET': 1,
#  'ANC_BLI': 3,
#  'ANC_BRW': 2,
#  'ANC_CDV': 1,
#  'ANC_DEN': 5,
#  'ANC_DFW': 6,
#  'ANC_DLG': 1,
#  'ANC_EWR': 7,
#  'ANC_FAI': 1,
#  'ANC_HNL': 6,
#  'ANC_IAH': 7,
#  'ANC_JNU': 2,
#  'ANC_KOA': 7,
#  'ANC_LAX': 5,
#  'ANC_MSP': 5,
#  'ANC_OGG': 6,
#  'ANC_OME': 2,
#  'ANC_ORD': 6,
#  'ANC_OTZ': 2,
#  'ANC_PDX': 4,
#  'ANC_PHX': 6,
#  'ANC_SCC': 2,
#  'ANC_SEA': 4,
#  'ANC_SFO': 5,
#  'ANC_SLC': 5,
#  'APN_DTW': 1,
#  'APN_PLN': 1,
#  'ART_PHL': 1,
#  'ASE_ATL': 3,
#  'ASE_DEN': 1,
#  'ASE_DFW': 2,
#  'ASE_IAH': 3,
#  'ASE_LAX': 2,
#  'ASE_MSP': 2,
#  'ASE_ORD': 3,
#  'ASE_PHX': 2,
#  'ASE_SFO': 3,
#  'ASE_SLC': 1,
#  'ATL_ABE': 2,
#  'ATL_ABQ': 3,
#  'ATL_ABY': 1,
#  'ATL_ACY': 2,
#  'ATL_AEX': 2,
#  'ATL_AGS': 1,
#  'ATL_ALB': 2,
#  'ATL_ANC': 8,
#  'ATL_ASE': 4,
#  'ATL_ATW': 2,
#  'ATL_AUS': 2,
#  'ATL_AVL': 1,
#  'ATL_AVP': 2,
#  'ATL_BDL': 2,
#  'ATL_BHM': 1,
#  'ATL_BMI': 2,
#  'ATL_BNA': 1,
#  'ATL_BOS': 3,
#  'ATL_BQK': 1,
#  'ATL_BTR': 2,
#  'ATL_BTV': 2,
#  'ATL_BUF': 2,
#  'ATL_BUR': 5,
#  'ATL_BWI': 2,
#  'ATL_BZN': 4,
#  'ATL_CAE': 1,
#  'ATL_CAK': 2,
#  'ATL_CHA': 1,
#  'ATL_CHO': 2,
#  'ATL_CHS': 1,
#  'ATL_CID': 2,
#  'ATL_CLE': 2,
#  'ATL_CLT': 1,
#  'ATL_CMH': 2,
#  'ATL_COS': 3,
#  'ATL_CRW': 1,
#  'ATL_CSG': 1,
#  'ATL_CVG': 1,
#  'ATL_DAB': 1,
#  'ATL_DAL': 2,
#  'ATL_DAY': 2,
#  'ATL_DCA': 2,
#  'ATL_DEN': 3,
#  'ATL_DFW': 3,
#  'ATL_DSM': 2,
#  'ATL_DTW': 2,
#  'ATL_ECP': 1,
#  'ATL_EGE': 4,
#  'ATL_ELM': 2,
#  'ATL_ELP': 3,
#  'ATL_EVV': 1,
#  'ATL_EWN': 2,
#  'ATL_EWR': 2,
#  'ATL_EYW': 2,
#  'ATL_FAR': 3,
#  'ATL_FAY': 1,
#  'ATL_FLL': 2,
#  'ATL_FNT': 2,
#  'ATL_FSD': 3,
#  'ATL_FSM': 2,
#  'ATL_FWA': 2,
#  'ATL_GNV': 1,
#  'ATL_GPT': 1,
#  'ATL_GRB': 2,
#  'ATL_GRR': 2,
#  'ATL_GSO': 1,
#  'ATL_GSP': 1,
#  'ATL_GTR': 1,
#  'ATL_HDN': 4,
#  'ATL_HNL': 10,
#  'ATL_HOU': 2,
#  'ATL_HPN': 2,
#  'ATL_HSV': 1,
#  'ATL_IAD': 2,
#  'ATL_IAH': 2,
#  'ATL_ICT': 2,
#  'ATL_ILM': 1,
#  'ATL_IND': 2,
#  'ATL_ISP': 2,
#  'ATL_JAC': 4,
#  'ATL_JAN': 1,
#  'ATL_JAX': 1,
#  'ATL_JFK': 2,
#  'ATL_LAS': 5,
#  'ATL_LAX': 5,
#  'ATL_LEX': 1,
#  'ATL_LFT': 2,
#  'ATL_LGA': 2,
#  'ATL_LIT': 2,
#  'ATL_LNK': 2,
#  'ATL_MCI': 2,
#  'ATL_MCO': 2,
#  'ATL_MDT': 2,
#  'ATL_MDW': 2,
#  'ATL_MEM': 1,
#  'ATL_MGM': 1,
#  'ATL_MHT': 3,
#  'ATL_MIA': 2,
#  'ATL_MKE': 2,
#  'ATL_MLB': 2,
#  'ATL_MLI': 2,
#  'ATL_MLU': 2,
#  'ATL_MOB': 1,
#  'ATL_MSN': 2,
#  'ATL_MSO': 5,
#  'ATL_MSP': 3,
#  'ATL_MSY': 2,
#  'ATL_MTJ': 4,
#  'ATL_MYR': 1,
#  'ATL_OAJ': 1,
#  'ATL_OAK': 5,
#  'ATL_OKC': 2,
#  'ATL_OMA': 2,
#  'ATL_ONT': 4,
#  'ATL_ORD': 2,
#  'ATL_ORF': 2,
#  'ATL_PBI': 2,
#  'ATL_PDX': 5,
#  'ATL_PHF': 2,
#  'ATL_PHL': 2,
#  'ATL_PHX': 4,
#  'ATL_PIA': 2,
#  'ATL_PIT': 2,
#  'ATL_PNS': 1,
#  'ATL_PSP': 5,
#  'ATL_PVD': 2,
#  'ATL_PWM': 3,
#  'ATL_RAP': 3,
#  'ATL_RDU': 1,
#  'ATL_RIC': 2,
#  'ATL_RNO': 5,
#  'ATL_ROA': 1,
#  'ATL_ROC': 2,
#  'ATL_RST': 2,
#  'ATL_RSW': 2,
#  'ATL_SAN': 4,
#  'ATL_SAT': 3,
#  'ATL_SAV': 1,
#  'ATL_SBN': 2,
#  'ATL_SDF': 1,
#  'ATL_SEA': 5,
#  'ATL_SFO': 5,
#  'ATL_SGF': 2,
#  'ATL_SHV': 2,
#  'ATL_SJC': 5,
#  'ATL_SJU': 4,
#  'ATL_SLC': 4,
#  'ATL_SMF': 5,
#  'ATL_SNA': 5,
#  'ATL_SRQ': 1,
#  'ATL_STL': 2,
#  'ATL_STT': 4,
#  'ATL_STX': 4,
#  'ATL_SYR': 2,
#  'ATL_TLH': 1,
#  'ATL_TPA': 1,
#  'ATL_TRI': 1,
#  'ATL_TTN': 2,
#  'ATL_TUL': 2,
#  'ATL_TUS': 4,
#  'ATL_TVC': 2,
#  'ATL_TYS': 1,
#  'ATL_VLD': 1,
#  'ATL_VPS': 1,
#  'ATL_XNA': 2,
#  'ATW_ATL': 2,
#  'ATW_DTW': 1,
#  'ATW_LAS': 4,
#  'ATW_MSP': 1,
#  'ATW_ORD': 1,
#  'ATW_PGD': 3,
#  'ATW_PIE': 3,
#  'ATW_SFB': 3,
#  'ATY_DEN': 2,
#  'ATY_ORD': 2,
#  'ATY_PIR': 1,
#  'AUS_ABQ': 2,
#  'AUS_ATL': 2,
#  'AUS_BNA': 2,
#  'AUS_BOS': 4,
#  'AUS_BTR': 2,
#  'AUS_BWI': 3,
#  'AUS_CLE': 3,
#  'AUS_CLT': 3,
#  'AUS_CMH': 3,
#  'AUS_CVG': 3,
#  'AUS_DAL': 1,
#  'AUS_DCA': 3,
#  'AUS_DEN': 2,
#  'AUS_DFW': 1,
#  'AUS_DTW': 3,
#  'AUS_ECP': 2,
#  'AUS_ELP': 2,
#  'AUS_EWR': 4,
#  'AUS_FLL': 3,
#  'AUS_HOU': 1,
#  'AUS_IAD': 3,
#  'AUS_IAH': 1,
#  'AUS_IND': 2,
#  'AUS_JFK': 4,
#  'AUS_LAS': 3,
#  'AUS_LAX': 3,
#  'AUS_LBB': 1,
#  'AUS_LGB': 3,
#  'AUS_MCI': 2,
#  'AUS_MCO': 2,
#  'AUS_MDW': 2,
#  'AUS_MEM': 2,
#  'AUS_MIA': 3,
#  'AUS_MSP': 3,
#  'AUS_MSY': 1,
#  'AUS_OAK': 4,
#  'AUS_ONT': 3,
#  'AUS_ORD': 3,
#  'AUS_PDX': 4,
#  'AUS_PHL': 4,
#  'AUS_PHX': 2,
#  'AUS_PIT': 3,
#  'AUS_PNS': 2,
#  'AUS_RDU': 3,
#  'AUS_SAN': 3,
#  'AUS_SEA': 5,
#  'AUS_SFB': 2,
#  'AUS_SFO': 4,
#  'AUS_SJC': 4,
#  'AUS_SLC': 3,
#  'AUS_SMF': 4,
#  'AUS_SNA': 3,
#  'AUS_STL': 2,
#  'AUS_TPA': 2,
#  'AUS_VPS': 2,
#  'AVL_ATL': 1,
#  'AVL_BWI': 1,
#  'AVL_CLT': 1,
#  'AVL_DEN': 3,
#  'AVL_DFW': 3,
#  'AVL_DTW': 2,
#  'AVL_EWR': 2,
#  'AVL_FLL': 2,
#  'AVL_IAD': 2,
#  'AVL_LGA': 2,
#  'AVL_MCO': 2,
#  'AVL_ORD': 2,
#  'AVL_PBI': 2,
#  'AVL_PGD': 2,
#  'AVL_PHL': 2,
#  'AVL_PIE': 2,
#  'AVL_SFB': 2,
#  'AVL_SRQ': 2,
#  'AVL_TPA': 2,
#  'AVP_ATL': 2,
#  'AVP_CLT': 2,
#  'AVP_DTW': 2,
#  'AVP_IAD': 1,
#  'AVP_ORD': 2,
#  'AZO_DTW': 1,
#  'AZO_MSP': 2,
#  'AZO_ORD': 1,
#  'BDL_ATL': 3,
#  'BDL_BWI': 1,
#  'BDL_CLE': 2,
#  'BDL_CLT': 2,
#  'BDL_CVG': 2,
#  'BDL_DCA': 2,
#  'BDL_DEN': 5,
#  'BDL_DFW': 4,
#  'BDL_DTW': 2,
#  'BDL_FLL': 3,
#  'BDL_IAD': 1,
#  'BDL_IAH': 4,
#  'BDL_LAX': 6,
#  'BDL_MCO': 3,
#  'BDL_MDW': 2,
#  'BDL_MIA': 3,
#  'BDL_MSP': 3,
#  'BDL_MYR': 2,
#  'BDL_ORD': 3,
#  'BDL_PBI': 3,
#  'BDL_PHL': 1,
#  'BDL_RDU': 2,
#  'BDL_RSW': 3,
#  'BDL_SJU': 4,
#  'BDL_STL': 3,
#  'BDL_TPA': 3,
#  'BET_ANC': 1,
#  'BFF_DEN': 1,
#  'BFL_DEN': 3,
#  'BFL_DFW': 3,
#  'BFL_PHX': 2,
#  'BFL_SFO': 1,
#  'BFM_DEN': 3,
#  'BFM_ORD': 3,
#  'BGM_DTW': 2,
#  'BGR_CLT': 3,
#  'BGR_DCA': 2,
#  'BGR_DTW': 2,
#  'BGR_EWR': 2,
#  'BGR_LGA': 2,
#  'BGR_ORD': 3,
#  'BGR_PHL': 2,
#  'BGR_PIE': 4,
#  'BGR_SFB': 3,
#  'BHM_ATL': 1,
#  'BHM_BWI': 2,
#  'BHM_CAE': 2,
#  'BHM_CLL': 2,
#  'BHM_CLT': 2,
#  'BHM_DAL': 2,
#  'BHM_DCA': 2,
#  'BHM_DEN': 3,
#  'BHM_DFW': 2,
#  'BHM_DTW': 2,
#  'BHM_FLL': 2,
#  'BHM_HOU': 2,
#  'BHM_IAH': 2,
#  'BHM_LAS': 4,
#  'BHM_LGA': 3,
#  'BHM_MCO': 2,
#  'BHM_MDW': 2,
#  'BHM_MIA': 2,
#  'BHM_ORD': 2,
#  'BHM_PHL': 2,
#  'BHM_SFO': 5,
#  'BHM_SJC': 5,
#  'BHM_TPA': 1,
#  'BIL_DEN': 2,
#  'BIL_DFW': 3,
#  'BIL_LAS': 2,
#  'BIL_LAX': 3,
#  'BIL_MSP': 2,
#  'BIL_ORD': 3,
#  'BIL_SLC': 1,
#  'BIS_DEN': 2,
#  'BIS_DFW': 3,
#  'BIS_LAS': 3,
#  'BIS_MSP': 2,
#  'BIS_ORD': 2,
#  'BIS_SFB': 4,
#  'BJI_MSP': 1,
#  'BLI_ANC': 3,
#  'BLI_KOA': 7,
#  'BLI_LAS': 2,
#  'BLI_LAX': 3,
#  'BLI_OAK': 2,
#  'BLI_OGG': 7,
#  'BLI_PSP': 3,
#  'BLI_SAN': 3,
#  'BLI_SEA': 1,
#  'BLI_TUS': 3,
#  'BLV_FLL': 3,
#  'BLV_JAX': 2,
#  'BLV_LAS': 3,
#  'BLV_MYR': 2,
#  'BLV_PGD': 2,
#  'BLV_PIE': 2,
#  'BLV_SFB': 2,
#  'BLV_SRQ': 2,
#  'BLV_VPS': 2,
#  'BMI_ATL': 2,
#  'BMI_DEN': 3,
#  'BMI_DFW': 2,
#  'BMI_MCO': 3,
#  'BMI_ORD': 1,
#  'BMI_PIE': 2,
#  'BMI_SFB': 2,
#  'BNA_ABE': 2,
#  'BNA_ATL': 1,
#  'BNA_AUS': 2,
#  'BNA_BOS': 2,
#  'BNA_BUF': 2,
#  'BNA_BUR': 4,
#  'BNA_BWI': 2,
#  'BNA_CHS': 1,
#  'BNA_CID': 2,
#  'BNA_CLE': 1,
#  'BNA_CLT': 2,
#  'BNA_CMH': 1,
#  'BNA_DAL': 2,
#  'BNA_DCA': 2,
#  'BNA_DEN': 3,
#  'BNA_DFW': 2,
#  'BNA_DTW': 2,
#  'BNA_ECP': 1,
#  'BNA_EWR': 2,
#  'BNA_FLL': 2,
#  'BNA_GRR': 1,
#  'BNA_HOU': 2,
#  'BNA_IAD': 2,
#  'BNA_IAH': 2,
#  'BNA_JAX': 1,
#  'BNA_JFK': 3,
#  'BNA_LAS': 4,
#  'BNA_LAX': 5,
#  'BNA_LGA': 2,
#  'BNA_MCI': 2,
#  'BNA_MCO': 2,
#  'BNA_MDT': 2,
#  'BNA_MDW': 2,
#  'BNA_MIA': 2,
#  'BNA_MKE': 2,
#  'BNA_MSN': 2,
#  'BNA_MSP': 2,
#  'BNA_MSY': 2,
#  'BNA_OAK': 5,
#  'BNA_OKC': 2,
#  'BNA_OMA': 2,
#  'BNA_ORD': 2,
#  'BNA_ORF': 2,
#  'BNA_PGD': 2,
#  'BNA_PHL': 2,
#  'BNA_PHX': 4,
#  'BNA_PIE': 2,
#  'BNA_PIT': 1,
#  'BNA_PNS': 1,
#  'BNA_RDU': 2,
#  'BNA_RIC': 2,
#  'BNA_RSW': 2,
#  'BNA_SAN': 4,
#  'BNA_SAT': 2,
#  'BNA_SAV': 1,
#  'BNA_SEA': 5,
#  'BNA_SFB': 2,
#  'BNA_SFO': 5,
#  'BNA_SJC': 5,
#  'BNA_SLC': 4,
#  'BNA_SMF': 5,
#  'BNA_SRQ': 2,
#  'BNA_STL': 1,
#  'BNA_SYR': 2,
#  'BNA_TPA': 2,
#  'BNA_TTN': 2,
#  'BNA_XNA': 1,
#  'BOI_DAL': 3,
#  'BOI_DEN': 2,
#  'BOI_DFW': 3,
#  'BOI_GEG': 1,
#  'BOI_IAH': 4,
#  'BOI_LAS': 2,
#  'BOI_LAX': 2,
#  'BOI_MDW': 3,
#  'BOI_MSP': 3,
#  'BOI_OAK': 2,
#  'BOI_ORD': 4,
#  'BOI_PDX': 1,
#  'BOI_PHX': 2,
#  'BOI_SAN': 2,
#  'BOI_SEA': 2,
#  'BOI_SFO': 2,
#  'BOI_SJC': 2,
#  'BOI_SLC': 1,
#  'BOI_SMF': 2,
#  'BOS_ACK': 1,
#  'BOS_ATL': 3,
#  'BOS_AUS': 4,
#  'BOS_BNA': 3,
#  'BOS_BUF': 2,
#  'BOS_BUR': 7,
#  'BOS_BWI': 2,
#  'BOS_CHS': 2,
#  'BOS_CLE': 2,
#  'BOS_CLT': 2,
#  'BOS_CMH': 2,
#  'BOS_CVG': 2,
#  'BOS_DAL': 4,
#  'BOS_DCA': 2,
#  'BOS_DEN': 5,
#  'BOS_DFW': 4,
#  'BOS_DTW': 2,
#  'BOS_EWR': 1,
#  'BOS_FLL': 3,
#  'BOS_GSP': 3,
#  'BOS_HDN': 5,
#  'BOS_HNL': 11,
#  'BOS_HOU': 5,
#  'BOS_IAD': 2,
#  'BOS_IAH': 4,
#  'BOS_IND': 3,
#  'BOS_JAX': 3,
#  'BOS_JFK': 1,
#  'BOS_LAS': 6,
#  'BOS_LAX': 6,
#  'BOS_LGA': 1,
#  'BOS_LGB': 6,
#  'BOS_MCI': 4,
#  'BOS_MCO': 3,
#  'BOS_MDW': 3,
#  'BOS_MIA': 4,
#  'BOS_MKE': 3,
#  'BOS_MSN': 2,
#  'BOS_MSP': 3,
#  'BOS_MSY': 4,
#  'BOS_MVY': 1,
#  'BOS_MYR': 2,
#  'BOS_OAK': 7,
#  'BOS_ORD': 3,
#  'BOS_ORF': 2,
#  'BOS_PBI': 3,
#  'BOS_PDX': 6,
#  'BOS_PHL': 2,
#  'BOS_PHX': 6,
#  'BOS_PIT': 2,
#  'BOS_PSP': 6,
#  'BOS_RDU': 2,
#  'BOS_RIC': 2,
#  'BOS_ROC': 2,
#  'BOS_RSW': 3,
#  'BOS_SAN': 6,
#  'BOS_SAV': 3,
#  'BOS_SBN': 3,
#  'BOS_SEA': 6,
#  'BOS_SFO': 7,
#  'BOS_SJC': 7,
#  'BOS_SJU': 4,
#  'BOS_SLC': 6,
#  'BOS_SMF': 7,
#  'BOS_SRQ': 4,
#  'BOS_STL': 3,
#  'BOS_STT': 4,
#  'BOS_SYR': 1,
#  'BOS_TPA': 3,
#  'BPT_DFW': 1,
#  'BQK_ATL': 1,
#  'BQN_EWR': 4,
#  'BQN_FLL': 3,
#  'BQN_JFK': 4,
#  'BQN_MCO': 3,
#  'BRD_MSP': 1,
#  'BRO_DEN': 3,
#  'BRO_DFW': 2,
#  'BRO_IAH': 1,
#  'BRO_ORD': 3,
#  'BRW_ANC': 2,
#  'BRW_FAI': 1,
#  'BTM_SLC': 1,
#  'BTR_ATL': 2,
#  'BTR_AUS': 2,
#  'BTR_CLT': 2,
#  'BTR_DCA': 3,
#  'BTR_DFW': 2,
#  'BTR_IAH': 1,
#  'BTV_ATL': 3,
#  'BTV_CLT': 2,
#  'BTV_DCA': 2,
#  'BTV_DEN': 4,
#  'BTV_DTW': 2,
#  'BTV_EWR': 2,
#  'BTV_IAD': 2,
#  'BTV_JFK': 1,
#  'BTV_LGA': 1,
#  'BTV_MCO': 3,
#  'BTV_ORD': 3,
#  'BTV_PHL': 1,
#  'BUF_ATL': 2,
#  'BUF_BNA': 2,
#  'BUF_BOS': 1,
#  'BUF_BWI': 1,
#  'BUF_CLT': 2,
#  'BUF_DCA': 1,
#  'BUF_DEN': 4,
#  'BUF_DFW': 3,
#  'BUF_DTW': 1,
#  'BUF_EWR': 1,
#  'BUF_FLL': 3,
#  'BUF_IAD': 1,
#  'BUF_JFK': 1,
#  'BUF_LAS': 5,
#  'BUF_LAX': 5,
#  'BUF_LGA': 1,
#  'BUF_MCO': 3,
#  'BUF_MDW': 2,
#  'BUF_MIA': 4,
#  'BUF_MSP': 2,
#  'BUF_ORD': 2,
#  'BUF_PHL': 2,
#  'BUF_PHX': 5,
#  'BUF_RDU': 2,
#  'BUF_RSW': 3,
#  'BUF_TPA': 3,
#  'BUR_ATL': 4,
#  'BUR_BNA': 4,
#  'BUR_BOS': 5,
#  'BUR_DAL': 3,
#  'BUR_DEN': 2,
#  'BUR_DFW': 3,
#  'BUR_HOU': 3,
#  'BUR_JFK': 6,
#  'BUR_LAS': 1,
#  'BUR_MDW': 4,
#  'BUR_OAK': 1,
#  'BUR_PDX': 2,
#  'BUR_PHX': 2,
#  'BUR_SEA': 3,
#  'BUR_SFO': 1,
#  'BUR_SJC': 1,
#  'BUR_SLC': 2,
#  'BUR_SMF': 1,
#  'BWI_ABQ': 4,
#  'BWI_ALB': 1,
#  'BWI_ATL': 2,
#  'BWI_AUS': 4,
#  'BWI_AVL': 1,
#  'BWI_BDL': 1,
#  'BWI_BHM': 2,
#  'BWI_BNA': 2,
#  'BWI_BOS': 2,
#  'BWI_BUF': 1,
#  'BWI_CHS': 2,
#  'BWI_CLE': 1,
#  'BWI_CLT': 2,
#  'BWI_CMH': 1,
#  'BWI_CVG': 2,
#  'BWI_DAL': 3,
#  'BWI_DEN': 4,
#  'BWI_DFW': 3,
#  'BWI_DTW': 2,
#  'BWI_ECP': 2,
#  'BWI_EWR': 1,
#  'BWI_FLL': 3,
#  'BWI_GRR': 2,
#  'BWI_GSP': 2,
#  'BWI_HOU': 3,
#  'BWI_IAH': 4,
#  'BWI_IND': 2,
#  'BWI_ISP': 1,
#  'BWI_JAX': 2,
#  'BWI_JFK': 1,
#  'BWI_LAS': 5,
#  'BWI_LAX': 6,
#  'BWI_MCI': 3,
#  'BWI_MCO': 2,
#  'BWI_MDW': 2,
#  'BWI_MEM': 2,
#  'BWI_MHT': 1,
#  'BWI_MIA': 3,
#  'BWI_MKE': 2,
#  'BWI_MSP': 3,
#  'BWI_MSY': 3,
#  'BWI_MYR': 1,
#  'BWI_OAK': 6,
#  'BWI_OKC': 3,
#  'BWI_ORD': 2,
#  'BWI_ORF': 1,
#  'BWI_PBI': 3,
#  'BWI_PDX': 6,
#  'BWI_PHL': 1,
#  'BWI_PHX': 5,
#  'BWI_PIT': 1,
#  'BWI_PVD': 1,
#  'BWI_PWM': 2,
#  'BWI_RDU': 1,
#  'BWI_ROC': 1,
#  'BWI_RSW': 3,
#  'BWI_SAN': 5,
#  'BWI_SAT': 4,
#  'BWI_SAV': 2,
#  'BWI_SDF': 2,
#  'BWI_SEA': 6,
#  'BWI_SFO': 6,
#  'BWI_SJC': 6,
#  'BWI_SJU': 4,
#  'BWI_SLC': 5,
#  'BWI_SMF': 6,
#  'BWI_SRQ': 2,
#  'BWI_STL': 2,
#  'BWI_TPA': 2,
#  'BWI_TYS': 1,
#  'BWI_VPS': 2,
#  'BZN_ATL': 4,
#  'BZN_DEN': 2,
#  'BZN_DFW': 3,
#  'BZN_DTW': 3,
#  'BZN_EWR': 4,
#  'BZN_IAH': 3,
#  'BZN_LAS': 2,
#  'BZN_LAX': 3,
#  'BZN_LGA': 4,
#  'BZN_LGB': 3,
#  'BZN_MSP': 2,
#  'BZN_ORD': 3,
#  'BZN_PDX': 2,
#  'BZN_SEA': 2,
#  'BZN_SFO': 3,
#  'BZN_SLC': 1,
#  'CAE_ATL': 1,
#  'CAE_BHM': 2,
#  'CAE_CLT': 1,
#  'CAE_DCA': 1,
#  'CAE_DFW': 3,
#  'CAE_IAD': 1,
#  'CAE_IAH': 3,
#  'CAE_LGA': 2,
#  'CAE_MIA': 2,
#  'CAK_ATL': 2,
#  'CAK_CLT': 2,
#  'CAK_DCA': 1,
#  'CAK_EWR': 2,
#  'CAK_IAH': 3,
#  'CAK_LGA': 2,
#  'CAK_MCO': 2,
#  'CAK_ORD': 2,
#  'CAK_PHL': 1,
#  'CAK_RSW': 3,
#  'CAK_TPA': 3,
#  'CDC_SLC': 1,
#  'CDV_ANC': 1,
#  'CDV_YAK': 1,
#  'CGI_ORD': 2,
#  'CGI_UIN': 1,
#  'CHA_ATL': 1,
#  'CHA_CLT': 1,
#  'CHA_DCA': 2,
#  'CHA_DFW': 2,
#  'CHA_DTW': 2,
#  'CHA_IAD': 2,
#  'CHA_LGA': 2,
#  'CHA_MSP': 2,
#  'CHA_ORD': 2,
#  'CHA_PHL': 2,
#  'CHA_PIE': 2,
#  'CHA_SFB': 1,
#  'CHO_ATL': 2,
#  'CHO_CLT': 1,
#  'CHO_LGA': 1,
#  'CHO_ORD': 2,
#  'CHS_ATL': 1,
#  'CHS_BNA': 1,
#  'CHS_BOS': 2,
#  'CHS_BWI': 2,
#  'CHS_CLE': 2,
#  'CHS_CLT': 1,
#  'CHS_CVG': 2,
#  'CHS_DAL': 3,
#  'CHS_DCA': 2,
#  'CHS_DEN': 4,
#  'CHS_DFW': 3,
#  'CHS_DTW': 2,
#  'CHS_EWR': 2,
#  'CHS_FLL': 2,
#  'CHS_HOU': 3,
#  'CHS_IAD': 2,
#  'CHS_IAH': 3,
#  'CHS_IND': 2,
#  'CHS_JFK': 2,
#  'CHS_LCK': 2,
#  'CHS_LGA': 2,
#  'CHS_MDW': 2,
#  'CHS_MIA': 2,
#  'CHS_MSP': 3,
#  'CHS_ORD': 2,
#  'CHS_PGD': 1,
#  'CHS_PHL': 2,
#  'CHS_PIT': 2,
#  'CHS_SEA': 6,
#  'CHS_STL': 2,
#  'CHS_TTN': 2,
#  'CID_ATL': 2,
#  'CID_BNA': 1,
#  'CID_CLT': 2,
#  'CID_DEN': 2,
#  'CID_DFW': 2,
#  'CID_DTW': 2,
#  'CID_LAS': 3,
#  'CID_LAX': 4,
#  'CID_MSP': 1,
#  'CID_ORD': 1,
#  'CID_PGD': 3,
#  'CID_PHX': 4,
#  'CID_PIE': 3,
#  'CID_SFB': 3,
#  'CIU_DTW': 1,
#  'CIU_MSP': 2,
#  'CKB_AVL': 1,
#  'CKB_IAD': 1,
#  'CKB_MYR': 1,
#  'CKB_ORD': 2,
#  'CKB_SFB': 2,
#  'CLE_ATL': 2,
#  'CLE_AUS': 3,
#  'CLE_BDL': 2,
#  'CLE_BNA': 2,
#  'CLE_BOS': 2,
#  'CLE_BWI': 1,
#  'CLE_CHS': 2,
#  'CLE_CLT': 2,
#  'CLE_DAL': 3,
#  'CLE_DCA': 1,
#  'CLE_DEN': 3,
#  'CLE_DFW': 3,
#  'CLE_DTW': 1,
#  'CLE_EWR': 2,
#  'CLE_FLL': 3,
#  'CLE_IAD': 1,
#  'CLE_IAH': 3,
#  'CLE_JAX': 2,
#  'CLE_JFK': 2,
#  'CLE_LAS': 5,
#  'CLE_LAX': 5,
#  'CLE_LGA': 2,
#  'CLE_MCO': 2,
#  'CLE_MDW': 1,
#  'CLE_MIA': 3,
#  'CLE_MKE': 1,
#  'CLE_MSP': 2,
#  'CLE_MSY': 3,
#  'CLE_MYR': 2,
#  'CLE_ORD': 2,
#  'CLE_ORF': 1,
#  'CLE_PBI': 3,
#  'CLE_PGD': 2,
#  'CLE_PHL': 2,
#  'CLE_PHX': 4,
#  'CLE_PIE': 2,
#  'CLE_RDU': 2,
#  'CLE_RSW': 3,
#  'CLE_SAN': 5,
#  'CLE_SAV': 2,
#  'CLE_SEA': 5,
#  'CLE_SFB': 2,
#  'CLE_SFO': 5,
#  'CLE_SLC': 4,
#  'CLE_SRQ': 2,
#  'CLE_STL': 2,
#  'CLE_TPA': 3,
#  'CLE_VPS': 2,
#  'CLL_BHM': 2,
#  'CLL_DFW': 1,
#  'CLL_IAH': 1,
#  'CLT_ABE': 2,
#  'CLT_ACK': 2,
#  'CLT_AGS': 1,
#  'CLT_ALB': 2,
#  'CLT_ATL': 1,
#  'CLT_AUS': 3,
#  'CLT_AVL': 1,
#  'CLT_AVP': 2,
#  'CLT_BDL': 2,
#  'CLT_BGR': 2,
#  'CLT_BHM': 1,
#  'CLT_BNA': 1,
#  'CLT_BOS': 2,
#  'CLT_BTR': 2,
#  'CLT_BTV': 2,
#  'CLT_BUF': 2,
#  'CLT_BWI': 1,
#  'CLT_CAE': 1,
#  'CLT_CAK': 1,
#  'CLT_CHA': 1,
#  'CLT_CHO': 1,
#  'CLT_CHS': 1,
#  'CLT_CID': 2,
#  'CLT_CLE': 2,
#  'CLT_CMH': 1,
#  'CLT_CMI': 2,
#  'CLT_CRW': 1,
#  'CLT_CVG': 1,
#  'CLT_DAB': 2,
#  'CLT_DAL': 3,
#  'CLT_DAY': 2,
#  ...}

# %% [markdown]
# ### `TAXI_OUT`

# %%
df['ORIGIN'] + '_' + df['OP_UNIQUE_CARRIER']
# Out:
# 0          TYS_9E
# 1          SRQ_DL
# 2          DTW_WN
# 3          DTW_DL
# 4          LGA_WN
#             ...
# 7200048    JNU_AS
# 7200049    JNU_AS
# 7200050    JNU_AS
# 7200051    JNU_AS
# 7200052    JNU_AS
# Length: 7200053, dtype: string

# %%
col = 'TAXI_OUT_median'
cols = ['ORIGIN', 'OP_UNIQUE_CARRIER']
taxi_out_df = df.drop_duplicates(subset=cols, keep='first')
taxi_out_dict = dict(zip(taxi_out_df[cols[0]] + '_' + taxi_out_df[cols[1]], taxi_out_df[col]))
with open("dict_mappers/taxi_out_dict.pkl", "wb") as f:
    pickle.dump(taxi_out_dict, f)
taxi_out_dict
# Out:
# {'TYS_9E': 15,
#  'SRQ_DL': 11,
#  'DTW_WN': 11,
#  'DTW_DL': 16,
#  'LGA_WN': 20,
#  'LGA_YX': 25,
#  'LGA_DL': 22,
#  'ROA_OO': 16,
#  'TPA_DL': 13,
#  'RDU_WN': 9,
#  'RDU_DL': 15,
#  'BOS_B6': 16,
#  'BOS_DL': 19,
#  'MSP_DL': 14,
#  'JAX_DL': 13,
#  'IND_WN': 10,
#  'IND_DL': 13,
#  'BTR_9E': 15,
#  'TLH_9E': 14,
#  'GSP_WN': 10,
#  'DAY_DL': 13,
#  'MEM_DL': 13,
#  'CMH_WN': 9,
#  'CMH_DL': 11,
#  'SAT_WN': 8,
#  'DFW_AA': 16,
#  'BWI_DL': 13,
#  'CAE_9E': 16,
#  'CLE_DL': 12,
#  'DEN_OO': 19,
#  'DEN_DL': 14,
#  'FLL_DL': 16,
#  'LAS_WN': 12,
#  'LAS_DL': 14,
#  'MCI_WN': 9,
#  'MCO_DL': 16,
#  'PBI_DL': 14,
#  'PHL_AA': 20,
#  'PHL_DL': 14,
#  'PHX_WN': 10,
#  'PNS_DL': 15,
#  'RSW_DL': 12,
#  'SLC_DL': 16,
#  'STL_WN': 9,
#  'STL_DL': 11,
#  'TUS_DL': 12,
#  'CLT_DL': 18,
#  'DCA_WN': 13,
#  'DCA_DL': 15,
#  'LEX_9E': 16,
#  'XNA_OO': 16,
#  'GPT_9E': 16,
#  'IAH_YV': 17,
#  'IAH_DL': 13,
#  'TYS_OO': 14,
#  'LGA_OO': 23,
#  'LGA_UA': 19,
#  'ORF_OO': 14,
#  'RDU_AA': 17,
#  'MSP_YX': 18,
#  'MSP_AA': 16,
#  'PIT_MQ': 13,
#  'GSP_EV': 16,
#  'AUS_UA': 14,
#  'CMH_MQ': 14,
#  'BDL_AA': 13,
#  'DFW_YX': 17,
#  'OMA_UA': 13,
#  'SAV_OO': 14,
#  'LAS_UA': 16,
#  'LAX_UA': 18,
#  'LAX_AA': 16,
#  'MCO_AA': 15,
#  'PDX_AA': 13,
#  'PDX_AS': 14,
#  'PHX_UA': 13,
#  'PHX_AA': 15,
#  'RSW_F9': 14,
#  'SAN_UA': 17,
#  'SEA_UA': 18,
#  'SFO_UA': 21,
#  'SLC_OO': 17,
#  'SNA_UA': 14,
#  'BNA_OO': 15,
#  'CLT_OO': 22,
#  'DCA_AA': 18,
#  'PIA_MQ': 12,
#  'IAH_UA': 18,
#  'MIA_AA': 16,
#  'ATL_DL': 15,
#  'IND_MQ': 12,
#  'SYR_MQ': 13,
#  'BNA_EV': 16,
#  'CVG_EV': 17,
#  'ATW_OO': 15,
#  'JAX_MQ': 12,
#  'BWI_MQ': 15,
#  'EWR_OO': 19,
#  'CLT_AA': 17,
#  'DTW_OO': 17,
#  'PDX_UA': 12,
#  'JAN_OO': 14,
#  'ROC_MQ': 12,
#  'RIC_OO': 15,
#  'HSV_MQ': 12,
#  'ICT_OO': 14,
#  'CHA_MQ': 12,
#  'BUF_OO': 13,
#  'BUF_MQ': 13,
#  'GRR_MQ': 13,
#  'MDT_MQ': 13,
#  'MDT_OO': 15,
#  'ASE_OO': 17,
#  'DBQ_MQ': 12,
#  'TYS_EV': 16,
#  'TPA_UA': 14,
#  'RDU_YX': 19,
#  'BHM_EV': 16,
#  'JAX_EV': 16,
#  'ORD_UA': 21,
#  'IND_YX': 14,
#  'BTR_EV': 14,
#  'PIT_YX': 14,
#  'CMH_YV': 12,
#  'TUL_EV': 15,
#  'DFW_YV': 17,
#  'DEN_UA': 16,
#  'FLL_UA': 18,
#  'MCO_UA': 15,
#  'MSY_UA': 12,
#  'STL_EV': 16,
#  'MIA_UA': 16,
#  'ATL_YV': 17,
#  'MCI_EV': 15,
#  'LAX_NK': 14,
#  'EWR_UA': 22,
#  'CLT_YV': 21,
#  'DTW_YX': 17,
#  'MEM_OO': 15,
#  'CHS_YV': 13,
#  'SAT_UA': 12,
#  'JAN_EV': 14,
#  'LBB_EV': 15,
#  'MAF_YX': 13,
#  'RSW_UA': 13,
#  'CRP_EV': 13,
#  'MFE_YV': 11,
#  'LCH_EV': 9,
#  'GRK_EV': 15,
#  'OKC_YV': 13,
#  'LFT_EV': 15,
#  'ICT_EV': 14,
#  'LIT_EV': 14,
#  'PNS_EV': 14,
#  'AMA_EV': 13,
#  'GPT_EV': 13,
#  'MOB_EV': 12,
#  'BRO_EV': 14,
#  'SRQ_F9': 12,
#  'DEN_YX': 18,
#  'MFE_EV': 12,
#  'SGF_9E': 16,
#  'CHA_OO': 14,
#  'SBN_OO': 14,
#  'AVL_9E': 17,
#  'BUF_DL': 11,
#  'GRR_DL': 12,
#  'ILM_9E': 13,
#  'PHF_9E': 13,
#  'CAK_9E': 13,
#  'MKE_DL': 12,
#  'SHV_9E': 12,
#  'TUL_DL': 13,
#  'CVG_DL': 11,
#  'ATW_DL': 11,
#  'CHS_DL': 14,
#  'SYR_DL': 12,
#  'CID_DL': 15,
#  'BWI_WN': 11,
#  'ELM_9E': 19,
#  'LFT_9E': 16,
#  'SDF_DL': 15,
#  'ROC_DL': 11,
#  'IAD_DL': 13,
#  'SAV_DL': 14,
#  'HOU_DL': 11,
#  'HOU_WN': 9,
#  'ICT_DL': 11,
#  'LIT_DL': 12,
#  'MCI_DL': 12,
#  'MCO_NK': 15,
#  'MDW_DL': 12,
#  'MSY_DL': 13,
#  'PHL_WN': 13,
#  'PVD_DL': 12,
#  'RIC_DL': 14,
#  'ALB_DL': 11,
#  'BNA_DL': 13,
#  'FNT_OO': 15,
#  'ABE_9E': 14,
#  'EVV_9E': 16,
#  'FWA_OO': 14,
#  'LEX_DL': 14,
#  'MDT_DL': 12,
#  'GPT_DL': 13,
#  'DAB_DL': 14,
#  'HSV_DL': 14,
#  'MLU_OO': 12,
#  'MOB_OO': 15,
#  'VLD_OO': 12,
#  'AVP_DL': 11,
#  'MIA_F9': 16,
#  'GTR_9E': 16,
#  'EWN_9E': 14,
#  'TYS_OH': 14,
#  'DTW_OH': 14,
#  'JFK_AA': 21,
#  'LGA_AA': 22,
#  'CHA_OH': 12,
#  'TPA_F9': 16,
#  'TPA_AA': 13,
#  'BOS_AA': 19,
#  'AVL_OH': 16,
#  'BTV_OH': 14,
#  'GRR_OH': 14,
#  'ILM_AA': 13,
#  'IND_AA': 13,
#  'GSO_OH': 15,
#  'PIT_AA': 13,
#  'MKE_OH': 12,
#  'AUS_AA': 13,
#  'CMH_YX': 14,
#  'CVG_OH': 14,
#  'CHS_AA': 15,
#  'BWI_AA': 14,
#  'OAJ_OH': 15,
#  'SDF_OH': 13,
#  'SAV_OH': 14,
#  'FLL_AA': 16,
#  'LAS_AA': 16,
#  'MSY_AA': 14,
#  'PNS_OH': 13,
#  'RIC_AA': 15,
#  'BNA_AA': 15,
#  'ABE_OH': 12,
#  'CHO_OH': 14,
#  'AVP_OH': 12,
#  'ATL_AA': 17,
#  'ORD_AA': 17,
#  'IAD_OH': 17,
#  'EWR_AA': 19,
#  'SAT_AA': 13,
#  'SGF_MQ': 13,
#  'SRQ_AA': 12,
#  'ORF_AA': 13,
#  'MYR_OH': 14,
#  'BTR_OH': 12,
#  'GSP_OH': 14,
#  'HPN_OH': 13,
#  'CAK_OH': 12,
#  'DAY_OH': 12,
#  'MEM_AA': 14,
#  'SYR_AA': 12,
#  'CAE_OH': 13,
#  'JAN_OH': 13,
#  'EVV_OH': 12,
#  'TOL_OH': 11,
#  'FAY_OH': 13,
#  'HSV_OH': 13,
#  'IAH_AA': 16,
#  'CMI_MQ': 11,
#  'AGS_OH': 13,
#  'DTW_AA': 15,
#  'MSP_UA': 16,
#  'JAX_AA': 13,
#  'GSO_EV': 19,
#  'HPN_OO': 16,
#  'MEM_UA': 13,
#  'BWI_NK': 12,
#  'IAD_UA': 16,
#  'PBI_UA': 14,
#  'STL_AA': 13,
#  'DCA_UA': 15,
#  'BOS_UA': 16,
#  'CVG_OO': 16,
#  'DLH_UA': 12,
#  'SDF_OO': 15,
#  'ORF_UA': 12,
#  'DSM_MQ': 11,
#  'OMA_YX': 14,
#  'RIC_UA': 15,
#  'ANC_AS': 12,
#  'BOS_WN': 16,
#  'AVL_OO': 17,
#  'TRI_9E': 13,
#  'MSP_WN': 11,
#  'BHM_DL': 16,
#  'ORD_DL': 17,
#  'MGM_9E': 17,
#  'PIT_WN': 9,
#  'PIT_DL': 11,
#  'HPN_DL': 12,
#  'AUS_WN': 10,
#  'AEX_9E': 14,
#  'BDL_DL': 12,
#  'JAN_9E': 17,
#  'OMA_DL': 12,
#  'EWR_YX': 22,
#  'EWR_DL': 17,
#  'LAX_DL': 15,
#  'PIA_9E': 16,
#  'MIA_DL': 15,
#  'DTW_NK': 12,
#  'SAT_9E': 14,
#  'MCO_F9': 15,
#  'OKC_OO': 14,
#  'JFK_DL': 23,
#  'DSM_9E': 15,
#  'BOI_DL': 12,
#  'GTF_9E': 11,
#  'BIS_DL': 15,
#  'FSD_DL': 14,
#  'MSO_DL': 16,
#  'GFK_OO': 14,
#  'BZN_DL': 13,
#  'BIL_DL': 11,
#  'RAP_OO': 13,
#  'HLN_OO': 14,
#  'TYS_G4': 10,
#  'JFK_B6': 20,
#  'LGA_NK': 19,
#  'LGA_B6': 18,
#  'RDU_B6': 16,
#  'ORD_NK': 16,
#  'PIT_B6': 11,
#  'PIT_NK': 10,
#  'SYR_B6': 11,
#  'DFW_NK': 16,
#  'BWI_B6': 13,
#  'CLE_B6': 12,
#  'EWR_WN': 19,
#  'EWR_NK': 16,
#  'PHL_NK': 15,
#  'PHL_B6': 17,
#  'DCA_B6': 15,
#  'ATL_NK': 14,
#  'ATL_WN': 13,
#  'MYR_NK': 10,
#  'ACY_NK': 10,
#  'BHM_OH': 13,
#  'PVD_AA': 12,
#  'SFO_AA': 18,
#  'MOB_OH': 10,
#  'MSP_OO': 17,
#  'MEM_YX': 14,
#  'BDL_UA': 13,
#  'OMA_OO': 14,
#  'ORF_YX': 14,
#  'GSP_MQ': 13,
#  'ALB_MQ': 11,
#  'BTV_UA': 12,
#  'LGA_MQ': 24,
#  'TPA_NK': 12,
#  'ORD_OO': 23,
#  'IND_9E': 14,
#  'SDF_YX': 15,
#  'IAD_YV': 18,
#  'MCI_YX': 15,
#  'MLI_OO': 15,
#  'IAH_NK': 13,
#  'MKE_OO': 13,
#  'CHS_YX': 14,
#  'RSW_NK': 11,
#  'ATW_9E': 16,
#  'CID_OO': 14,
#  'CWA_9E': 15,
#  'CVG_9E': 14,
#  'MBS_OO': 14,
#  'GRB_9E': 14,
#  'JAX_F9': 13,
#  'JAX_B6': 12,
#  'CHS_B6': 12,
#  'MCO_WN': 13,
#  'MSY_NK': 12,
#  'RIC_B6': 11,
#  'BNA_WN': 10,
#  'ATL_B6': 15,
#  'CMH_NK': 10,
#  'SFO_B6': 16,
#  'STL_OH': 12,
#  'MDW_WN': 10,
#  'CHS_9E': 15,
#  'AVL_G4': 10,
#  'FSD_YX': 17,
#  'MCI_9E': 15,
#  'ROA_DL': 16,
#  'TPA_WN': 10,
#  'TRI_OO': 13,
#  'GNV_9E': 14,
#  'MYR_DL': 13,
#  'JAX_WN': 10,
#  'GSP_9E': 13,
#  'VPS_DL': 16,
#  'OAJ_9E': 15,
#  'ECP_DL': 13,
#  'FLL_WN': 16,
#  'MSY_WN': 9,
#  'RIC_WN': 12,
#  'CHO_DL': 13,
#  'MLB_DL': 14,
#  'FAY_DL': 12,
#  'ABY_OO': 11,
#  'BQK_OO': 13,
#  'CRW_9E': 14,
#  'HNL_DL': 18,
#  'AGS_9E': 15,
#  'IND_OO': 15,
#  'CAK_MQ': 13,
#  'TUL_OO': 15,
#  'CLE_MQ': 15,
#  'MCI_AA': 14,
#  'XNA_YX': 15,
#  'MSN_YX': 13,
#  'GRB_OO': 14,
#  'SYR_OO': 14,
#  'EVV_MQ': 15,
#  'LEX_MQ': 14,
#  'SPI_OO': 12,
#  'HNL_AA': 18,
#  'GSO_MQ': 16,
#  'TUL_MQ': 13,
#  'CHS_UA': 13,
#  'FSD_OO': 16,
#  'FAR_MQ': 12,
#  'RST_MQ': 12,
#  'RST_EV': 18,
#  'EAU_OO': 14,
#  'COU_MQ': 13,
#  'MHK_MQ': 11,
#  'SUX_MQ': 12,
#  'CWA_MQ': 10,
#  'ALO_MQ': 11,
#  'SGF_OO': 15,
#  'RDU_UA': 17,
#  'GRR_EV': 17,
#  'JAX_YX': 13,
#  'CAK_EV': 18,
#  'DAY_EV': 18,
#  'MEM_YV': 14,
#  'CAE_EV': 14,
#  'ELP_YV': 15,
#  'LIT_YV': 12,
#  'RIC_YV': 14,
#  'BNA_UA': 15,
#  'LEX_EV': 16,
#  'STL_YV': 14,
#  'DSM_YV': 12,
#  'GSP_YV': 12,
#  'TUL_UA': 12,
#  'XNA_EV': 14,
#  'ICT_YV': 12,
#  'PHL_UA': 15,
#  'PNS_YV': 12,
#  'COS_OO': 20,
#  'CVG_YV': 14,
#  'ECP_EV': 13,
#  'HNL_UA': 19,
#  'HOB_EV': 13,
#  'ORF_DL': 11,
#  'GSO_DL': 14,
#  'TLH_DL': 13,
#  'GSP_DL': 15,
#  'FLL_NK': 14,
#  'PBI_WN': 10,
#  'RSW_WN': 10,
#  'CSG_9E': 13,
#  'CLE_UA': 12,
#  'LAS_NK': 14,
#  'LAS_F9': 17,
#  'FWA_MQ': 11,
#  'MSN_MQ': 11,
#  'SEA_AA': 18,
#  'SEA_AS': 20,
#  'AZO_MQ': 12,
#  'BUF_UA': 12,
#  'BWI_UA': 12,
#  'TVC_OO': 14,
#  'CMX_OO': 15,
#  'MKG_OO': 15,
#  'DSM_UA': 13,
#  'CVG_MQ': 15,
#  'CID_MQ': 12,
#  'OMA_MQ': 13,
#  'RIC_MQ': 15,
#  'BMI_MQ': 10,
#  'MSN_EV': 15,
#  'MEM_MQ': 13,
#  'TOL_MQ': 11,
#  'MLI_MQ': 12,
#  'XNA_MQ': 13,
#  'LSE_MQ': 10,
#  'RDU_OO': 18,
#  'BUF_YX': 14,
#  'BTV_YX': 16,
#  'SYR_OH': 12,
#  'CLE_OH': 13,
#  'MCO_B6': 15,
#  'PVD_OH': 12,
#  'ATL_YX': 17,
#  'DTW_YV': 15,
#  'MSP_YV': 15,
#  'BHM_YV': 14,
#  'JAX_UA': 12,
#  'PIT_YV': 11,
#  'SHV_OO': 13,
#  'MEM_EV': 17,
#  'SAV_EV': 18,
#  'MCI_UA': 14,
#  'HSV_EV': 14,
#  'TUS_YV': 14,
#  'AEX_EV': 17,
#  'MAF_UA': 12,
#  'MFE_UA': 12,
#  'MLU_EV': 14,
#  'ATL_UA': 18,
#  'LIT_OO': 14,
#  'TYS_DL': 15,
#  'CHA_DL': 13,
#  'ORD_MQ': 20,
#  'SAT_DL': 11,
#  'CID_9E': 14,
#  'DFW_DL': 16,
#  'OKC_DL': 11,
#  'SEA_DL': 18,
#  'SFO_DL': 18,
#  'SJU_DL': 14,
#  'SJU_F9': 15,
#  'SMF_DL': 12,
#  'SNA_DL': 14,
#  'CLT_OH': 21,
#  'DAL_WN': 10,
#  'DCA_YX': 19,
#  'PIA_OO': 13,
#  'IAH_OO': 19,
#  'RST_OO': 15,
#  'EYW_DL': 8,
#  'JFK_9E': 24,
#  'GSP_OO': 13,
#  'DAY_9E': 16,
#  'CMH_9E': 13,
#  'IAD_9E': 18,
#  'PHX_DL': 12,
#  'SAN_DL': 17,
#  'SJC_DL': 13,
#  'ABE_OO': 14,
#  'GSO_OO': 16,
#  'MDW_OO': 14,
#  'PDX_DL': 11,
#  'PVD_9E': 13,
#  'PIT_9E': 14,
#  'SYR_YX': 13,
#  'LAN_OO': 12,
#  'ERI_OO': 14,
#  'IMT_OO': 11,
#  'AZO_OO': 14,
#  'BGM_OO': 12,
#  'TRI_DL': 17,
#  'BTV_9E': 18,
#  'ORD_YX': 22,
#  'ILM_DL': 12,
#  'BTR_OO': 14,
#  'MGM_OO': 14,
#  'PWM_DL': 12,
#  'CAE_DL': 13,
#  'JAN_DL': 14,
#  'CLE_WN': 9,
#  'DAL_DL': 11,
#  'MLI_9E': 13,
#  'BMI_9E': 13,
#  'MSN_DL': 12,
#  'LNK_9E': 17,
#  'AGS_DL': 15,
#  'EYW_9E': 12,
#  'FSM_9E': 16,
#  'ORF_MQ': 14,
#  'RDU_MQ': 17,
#  'CLE_EV': 16,
#  'MSY_9E': 16,
#  'STL_9E': 14,
#  'BNA_MQ': 14,
#  'IAH_YX': 17,
#  'PWM_MQ': 13,
#  'OMA_9E': 15,
#  'RSW_9E': 14,
#  'CVG_G4': 10,
#  'BHM_MQ': 14,
#  'LIT_MQ': 13,
#  'PBI_AA': 12,
#  'ATL_OO': 16,
#  'CVG_UA': 13,
#  'ALB_UA': 12,
#  'GRR_UA': 14,
#  'ABQ_AA': 13,
#  'ABE_EV': 15,
#  'LAN_MQ': 12,
#  'UIN_OO': 13,
#  'AVP_MQ': 13,
#  'PBI_B6': 12,
#  'RIC_EV': 17,
#  'CHO_9E': 16,
#  'TYS_MQ': 14,
#  'MSN_UA': 12,
#  'SGF_EV': 14,
#  'ORF_YV': 12,
#  'SHV_EV': 13,
#  'DFW_UA': 16,
#  'CLE_YV': 12,
#  'SAV_YV': 13,
#  'STL_UA': 12,
#  'CLT_UA': 21,
#  'PHL_YV': 16,
#  'CLL_EV': 10,
#  'IAD_WN': 12,
#  'FNT_9E': 11,
#  'LAX_WN': 11,
#  'SFO_F9': 19,
#  'XNA_DL': 14,
#  'MTJ_DL': 16,
#  'STT_DL': 11,
#  'HDN_DL': 15,
#  'CRW_OO': 14,
#  'EGE_DL': 16,
#  'JAC_DL': 14,
#  'TUL_G4': 14,
#  'ELM_G4': 10,
#  'LEX_G4': 10,
#  'PHL_YX': 21,
#  'MSN_9E': 14,
#  'IAH_9E': 16,
#  'GRR_OO': 15,
#  'STL_OO': 15,
#  'CLE_OO': 15,
#  'SWF_OO': 12,
#  'ITH_OO': 15,
#  'PIT_G4': 11,
#  'GRR_G4': 11,
#  'FNT_G4': 10,
#  'IND_OH': 13,
#  'FLL_B6': 17,
#  'MHT_YX': 13,
#  'MEM_9E': 14,
#  'MSN_OO': 13,
#  'CHA_9E': 14,
#  'BOS_OO': 20,
#  'PIT_OO': 14,
#  'JAX_OO': 15,
#  'ORF_EV': 17,
#  'RSW_AA': 12,
#  'SJU_UA': 13,
#  'ROC_G4': 11,
#  'CLE_NK': 11,
#  'OAK_WN': 11,
#  'EWR_EV': 24,
#  'BNA_YX': 14,
#  'RDU_OH': 16,
#  'PWM_YX': 13,
#  'BDL_YX': 12,
#  'OKC_YX': 14,
#  'MLI_G4': 10,
#  'BUF_9E': 14,
#  'GNV_DL': 13,
#  'DSM_OO': 13,
#  'TUL_YX': 14,
#  'MKE_WN': 10,
#  'DEN_WN': 12,
#  'FAR_OO': 15,
#  'TYS_YX': 14,
#  'DTW_9E': 19,
#  'BDL_B6': 13,
#  'MSY_YX': 13,
#  'BDL_OH': 11,
#  'ALB_OH': 11,
#  'CRW_OH': 12,
#  'AUS_DL': 14,
#  'CLE_9E': 15,
#  'LEX_OO': 15,
#  'GRR_YV': 14,
#  'JAX_YV': 12,
#  'ECP_YV': 12,
#  'HSV_YV': 14,
#  'MCI_YV': 13,
#  'IND_UA': 12,
#  'MOB_YV': 11,
#  'BOS_NK': 15,
#  'LFT_OO': 15,
#  'SDF_9E': 16,
#  'LIT_9E': 15,
#  'SRQ_OO': 16,
#  'CHA_YV': 13,
#  'DEN_AA': 15,
#  'ELP_AA': 14,
#  'HOU_MQ': 13,
#  'SAN_AA': 19,
#  'SMF_AA': 12,
#  'JAC_AA': 14,
#  'TUS_AA': 12,
#  'BZN_AA': 15,
#  'SDF_YV': 14,
#  'LBB_YV': 13,
#  'SJC_AA': 14,
#  'VPS_AA': 15,
#  'CVG_AA': 14,
#  'CAE_AA': 12,
#  'GRR_AA': 14,
#  'TLH_MQ': 11,
#  'SHV_MQ': 13,
#  'AEX_MQ': 12,
#  'LFT_YV': 14,
#  'MAF_YV': 14,
#  'PNS_AA': 12,
#  'SLC_AA': 15,
#  'AMA_YV': 13,
#  'BOI_AA': 13,
#  'FAT_AA': 12,
#  'MFE_MQ': 11,
#  'EVV_YV': 16,
#  'LRD_OO': 13,
#  'PIA_YV': 15,
#  'GUC_AA': 11,
#  'ABI_MQ': 10,
#  'SJT_MQ': 10,
#  'GRK_MQ': 13,
#  'BPT_MQ': 12,
#  'DRT_MQ': 12,
#  'ILM_YV': 12,
#  'CMH_AA': 14,
#  'SPI_MQ': 12,
#  'BMI_YV': 14,
#  'MSP_NK': 14,
#  'PHL_OH': 19,
#  'MDT_9E': 15,
#  'HSV_9E': 15,
#  'PBG_G4': 11,
#  'TYS_F9': 11,
#  'SNA_WN': 10,
#  'GRR_F9': 14,
#  'DFW_OO': 22,
#  'PDX_OO': 13,
#  'SEA_OO': 17,
#  'SAN_WN': 12,
#  'SJC_F9': 13,
#  'SMF_WN': 10,
#  'LBB_WN': 9,
#  'MAF_OO': 14,
#  'ABQ_YX': 13,
#  'FAT_OO': 14,
#  'LBF_OO': 14,
#  'HYS_OO': 12,
#  'GCC_OO': 16,
#  'PUB_OO': 14,
#  'LAR_OO': 15,
#  'COD_OO': 15,
#  'ISN_OO': 19,
#  'OMA_WN': 9,
#  'DEN_NK': 12,
#  'SJC_WN': 10,
#  'ATL_F9': 17,
#  'DSM_G4': 10,
#  'SHV_G4': 9,
#  'CID_G4': 9,
#  'LGB_B6': 12,
#  'OKC_WN': 9,
#  'RNO_WN': 9,
#  'SFO_AS': 20,
#  'BUR_WN': 11,
#  'FAT_G4': 9,
#  'PIA_G4': 10,
#  'CLT_YX': 21,
#  'OKC_EV': 15,
#  'PIT_UA': 12,
#  'SAT_MQ': 11,
#  'SNA_AA': 14,
#  'SDF_MQ': 15,
#  'CKB_OO': 15,
#  'SHD_OO': 13,
#  'SJU_AA': 16,
#  'PWM_AA': 12,
#  'STT_AA': 13,
#  'IND_EV': 15,
#  'GNV_OO': 13,
#  'LAX_F9': 17,
#  'XNA_9E': 15,
#  'LGA_F9': 23,
#  'DSM_DL': 12,
#  'SLC_F9': 14,
#  'FAY_OO': 13,
#  'STX_DL': 12,
#  'LGA_9E': 27,
#  'RIC_OH': 14,
#  'CMH_OH': 14,
#  'ATL_OH': 19,
#  'ALB_AA': 11,
#  'TUL_9E': 14,
#  'SBN_9E': 13,
#  'HPN_9E': 16,
#  'TUL_WN': 10,
#  'SFO_WN': 14,
#  'SLC_WN': 11,
#  'ELP_OO': 17,
#  'RDU_G4': 13,
#  'SJU_G4': 17,
#  'ABQ_OO': 14,
#  'SMF_OO': 15,
#  'BOI_WN': 9,
#  'SJC_OO': 13,
#  'GJT_YX': 15,
#  'TLH_OH': 12,
#  'CHS_OH': 14,
#  'CAE_YX': 13,
#  'LEX_OH': 13,
#  'GNV_OH': 11,
#  'ILM_OH': 13,
#  'DAB_OH': 13,
#  'EWN_OH': 13,
#  'GRR_YX': 15,
#  'BOS_9E': 22,
#  'GSO_YX': 15,
#  'ORF_OH': 13,
#  'CLE_AA': 13,
#  'MHT_AA': 15,
#  'ART_OH': 10,
#  'HVN_OH': 12,
#  'TLH_YX': 12,
#  'LGA_YV': 21,
#  'BUF_YV': 11,
#  'SYR_YV': 13,
#  'BTV_YV': 13,
#  'IND_YV': 12,
#  'AVL_DL': 15,
#  'PHF_DL': 12,
#  'CAK_DL': 12,
#  'LFT_DL': 13,
#  'DCA_OH': 17,
#  'FNT_DL': 11,
#  'ABE_DL': 14,
#  'MOB_DL': 13,
#  'CRW_DL': 13,
#  'MIA_YX': 17,
#  'SAT_OO': 13,
#  'GTF_OO': 11,
#  'SJU_WN': 14,
#  'TYS_YV': 13,
#  'BUF_AA': 12,
#  'DSM_AA': 12,
#  'BIS_YV': 13,
#  'RAP_YV': 13,
#  'SBN_EV': 16,
#  'HOU_YV': 13,
#  'IAD_AA': 16,
#  'TUL_AA': 16,
#  'ELP_MQ': 14,
#  'ICT_AA': 12,
#  'CRP_OO': 13,
#  'MLI_YV': 14,
#  'FSD_YV': 13,
#  'GJT_MQ': 13,
#  'JLN_OO': 19,
#  'ROW_OO': 13,
#  'SAF_OO': 16,
#  'OMA_EV': 13,
#  'HSV_OO': 14,
#  'ECP_OO': 16,
#  'LYH_OH': 15,
#  'MKE_AA': 12,
#  'CRP_MQ': 11,
#  'MYR_AA': 14,
#  'PVD_WN': 9,
#  'ISP_WN': 9,
#  'ELP_DL': 14,
#  'PWM_OH': 10,
#  'BHM_9E': 16,
#  'DSM_OH': 12,
#  'MCI_OO': 16,
#  'JFK_YX': 23,
#  'PWM_EV': 17,
#  'ATW_MQ': 11,
#  'SBN_G4': 9,
#  'SGF_G4': 10,
#  'BUF_EV': 15,
#  'GSO_9E': 17,
#  'TLH_OO': 15,
#  'TTN_F9': 13,
#  'JFK_OO': 23,
#  'MEM_OH': 13,
#  'LIT_OH': 12,
#  'ABQ_YV': 13,
#  'PIT_OH': 12,
#  'VPS_OH': 14,
#  'AUS_YV': 14,
#  'AUS_YX': 14,
#  'OKC_UA': 12,
#  'ABQ_EV': 16,
#  'TUL_YV': 13,
#  'ATL_EV': 21,
#  'MAF_EV': 18,
#  'SAT_YV': 13,
#  'DFW_EV': 20,
#  'MSP_EV': 23,
#  'PSP_OO': 14,
#  'ABQ_DL': 12,
#  'DAY_MQ': 13,
#  'MKE_EV': 15,
#  'ONT_AA': 12,
#  'LRD_MQ': 11,
#  'CHA_EV': 14,
#  'BTV_OO': 15,
#  'TVC_MQ': 11,
#  'BZN_UA': 14,
#  'GRB_MQ': 9,
#  'BDL_YV': 13,
#  'BNA_YV': 15,
#  'ROC_EV': 16,
#  'AUS_F9': 13,
#  'PWM_YV': 12,
#  'PBG_OO': 14,
#  'LWB_OO': 12,
#  'COS_DL': 16,
#  'MSP_9E': 19,
#  'ROC_OO': 14,
#  'RDU_YV': 17,
#  'MKE_MQ': 17,
#  'CID_EV': 14,
#  'PVD_YV': 13,
#  'JAC_UA': 14,
#  'ROA_9E': 17,
#  'ROC_UA': 14,
#  'CMH_OO': 13,
#  'BOS_YV': 15,
#  'VPS_9E': 17,
#  'GRB_DL': 13,
#  'PIA_OH': 12,
#  'FSD_9E': 16,
#  'BMI_OO': 21,
#  'MKE_UA': 12,
#  'RDU_9E': 19,
#  'OKC_AA': 14,
#  'DRO_YV': 13,
#  'VPS_G4': 12,
#  'CHS_OO': 13,
#  'LAX_B6': 15,
#  'AUS_B6': 13,
#  'EWR_B6': 20,
#  'JAX_OH': 12,
#  'MDT_AA': 15,
#  'MLB_OH': 13,
#  'EYW_YX': 12,
#  'SRQ_OH': 13,
#  'PHF_OH': 13,
#  'MHT_OH': 13,
#  'MSN_OH': 13,
#  'GPT_OH': 11,
#  'STL_YX': 13,
#  'HSV_YX': 12,
#  'SRQ_9E': 17,
#  'DTW_MQ': 18,
#  'ILM_MQ': 13,
#  'BOS_YX': 21,
#  'SAV_MQ': 13,
#  'BTR_DL': 13,
#  'MRY_OO': 15,
#  'FAR_G4': 11,
#  'FSD_G4': 10,
#  'BDL_MQ': 11,
#  'CHS_MQ': 14,
#  'SRQ_MQ': 14,
#  'SRQ_UA': 13,
#  'SDF_EV': 16,
#  'BHM_OO': 15,
#  'SAV_UA': 14,
#  'BIL_UA': 11,
#  'SLC_UA': 12,
#  'BOI_UA': 12,
#  'LNK_OO': 14,
#  'MMH_OO': 18,
#  'ALB_G4': 11,
#  'RIC_G4': 13,
#  'PNS_MQ': 12,
#  'JAN_YV': 13,
#  'LBB_MQ': 13,
#  'PSP_AA': 13,
#  'BIL_MQ': 11,
#  'GPT_YV': 13,
#  'EGE_AA': 15,
#  'CLL_OO': 14,
#  'LAW_OO': 13,
#  'TYR_MQ': 12,
#  'FSM_YV': 11,
#  'TXK_MQ': 10,
#  'AUS_NK': 12,
#  'EYW_MQ': 11,
#  ...}

# %%
df[(df['ORIGIN'] == 'PSG') & (df['OP_UNIQUE_CARRIER'] == 'AS')]['TAXI_OUT_median'].unique()
# Out:
# array([9])

# %% [markdown]
# ### `TAXI_IN`

# %%
df['DEST'] + '_' + df['OP_UNIQUE_CARRIER']
# Out:
# 0          ATL_9E
# 1          ATL_DL
# 2          ATL_WN
# 3          ATL_DL
# 4          ATL_WN
#             ...
# 7200048    GST_AS
# 7200049    GST_AS
# 7200050    GST_AS
# 7200051    GST_AS
# 7200052    GST_AS
# Length: 7200053, dtype: string

# %%
col = 'TAXI_IN_median'
cols = ['DEST', 'OP_UNIQUE_CARRIER']
taxi_in_df = df.drop_duplicates(subset=cols, keep='first')
taxi_in_dict = dict(zip(taxi_in_df[cols[0]] + '_' + taxi_in_df[cols[1]], taxi_in_df[col]))
with open("dict_mappers/taxi_in_dict.pkl", "wb") as f:
    pickle.dump(taxi_in_dict, f)
taxi_in_dict
# Out:
# {'ATL_9E': 8,
#  'ATL_DL': 8,
#  'ATL_WN': 7,
#  'ATL_YX': 9,
#  'ATL_OO': 8,
#  'ATL_B6': 9,
#  'ATL_AA': 9,
#  'ATL_YV': 8,
#  'ORD_OO': 13,
#  'ORD_UA': 11,
#  'ORD_AA': 14,
#  'ORD_YX': 12,
#  'ORD_MQ': 13,
#  'ORD_EV': 13,
#  'ORD_AS': 14,
#  'ORD_F9': 13,
#  'ORD_DL': 11,
#  'IAH_EV': 8,
#  'IAH_UA': 7,
#  'IAH_YX': 8,
#  'IAH_YV': 8,
#  'IAH_AA': 8,
#  'IAH_OO': 9,
#  'IAH_NK': 9,
#  'ATL_F9': 10,
#  'ATL_UA': 7,
#  'ATL_NK': 10,
#  'CLT_OH': 13,
#  'CLT_AA': 9,
#  'CLT_F9': 10,
#  'CLT_YX': 11,
#  'CLT_OO': 12,
#  'CLT_MQ': 15,
#  'ORD_B6': 15,
#  'ORD_NK': 13,
#  'MSP_9E': 6,
#  'MSP_NK': 6,
#  'MSP_UA': 4,
#  'MSP_YX': 5,
#  'MSP_DL': 5,
#  'MSP_F9': 7,
#  'MSP_OO': 6,
#  'FLL_G4': 8,
#  'FLL_NK': 7,
#  'FLL_B6': 6,
#  'FLL_WN': 7,
#  'FLL_UA': 7,
#  'FLL_AA': 6,
#  'FLL_DL': 7,
#  'PGD_G4': 6,
#  'DTW_9E': 8,
#  'DTW_MQ': 9,
#  'DTW_DL': 7,
#  'DTW_NK': 10,
#  'DTW_OO': 9,
#  'DTW_YX': 9,
#  'DTW_YV': 8,
#  'DTW_WN': 7,
#  'DTW_F9': 10,
#  'MSP_B6': 7,
#  'ORD_OH': 10,
#  'DCA_OH': 4,
#  'DCA_OO': 4,
#  'DCA_B6': 4,
#  'DCA_YX': 6,
#  'DCA_AA': 5,
#  'IAH_DL': 7,
#  'ATL_MQ': 7,
#  'ATL_OH': 8,
#  'LGA_9E': 8,
#  'LGA_DL': 8,
#  'LGA_MQ': 8,
#  'LGA_B6': 4,
#  'LGA_AA': 6,
#  'LGA_OO': 7,
#  'LGA_UA': 5,
#  'LGA_YX': 8,
#  'LGA_EV': 8,
#  'LGA_NK': 10,
#  'LGA_WN': 7,
#  'EWR_EV': 11,
#  'EWR_UA': 8,
#  'EWR_YX': 9,
#  'EWR_B6': 9,
#  'EWR_NK': 9,
#  'SFB_G4': 6,
#  'DCA_WN': 4,
#  'DCA_DL': 4,
#  'EWR_OO': 6,
#  'DCA_EV': 5,
#  'DCA_9E': 4,
#  'DCA_MQ': 5,
#  'DFW_OO': 11,
#  'DFW_DL': 9,
#  'DFW_AA': 12,
#  'DFW_NK': 10,
#  'DFW_YV': 10,
#  'DFW_B6': 11,
#  'DFW_MQ': 11,
#  'DFW_YX': 11,
#  'DFW_EV': 11,
#  'ATL_AS': 7,
#  'PIE_G4': 6,
#  'DEN_F9': 10,
#  'DEN_UA': 8,
#  'DEN_WN': 6,
#  'DEN_NK': 8,
#  'DEN_YX': 10,
#  'DEN_OO': 9,
#  'DEN_AA': 8,
#  'DEN_DL': 8,
#  'LAS_G4': 6,
#  'LAS_DL': 6,
#  'LAS_UA': 7,
#  'LAS_AA': 7,
#  'LAS_WN': 5,
#  'LAS_NK': 7,
#  'LAS_F9': 10,
#  'LAS_AS': 7,
#  'LAS_B6': 8,
#  'PHL_OH': 6,
#  'PHL_DL': 5,
#  'PHL_UA': 6,
#  'PHL_YX': 8,
#  'PHL_NK': 9,
#  'PHL_AA': 7,
#  'PHL_WN': 5,
#  'PHL_AS': 7,
#  'MIA_MQ': 5,
#  'MIA_AA': 8,
#  'MIA_DL': 6,
#  'MIA_YX': 7,
#  'MIA_UA': 5,
#  'MIA_F9': 9,
#  'CLT_9E': 8,
#  'CLT_DL': 7,
#  'CLT_WN': 7,
#  'CLT_YV': 8,
#  'PHL_9E': 6,
#  'IAD_EV': 6,
#  'IAD_YV': 5,
#  'IAD_UA': 5,
#  'IAD_OO': 6,
#  'CLT_EV': 10,
#  'MSP_AA': 5,
#  'DTW_AA': 10,
#  'MSP_WN': 4,
#  'DFW_AS': 9,
#  'ORD_9E': 11,
#  'IAD_B6': 4,
#  'IAD_DL': 5,
#  'IAD_OH': 5,
#  'IAD_F9': 9,
#  'DFW_9E': 10,
#  'DFW_UA': 9,
#  'EWR_G4': 6,
#  'EWR_AA': 7,
#  'EWR_WN': 8,
#  'EWR_DL': 6,
#  'EWR_9E': 6,
#  'LGA_OH': 8,
#  'LGA_F9': 9,
#  'PHL_B6': 7,
#  'IAD_WN': 5,
#  'IAH_9E': 8,
#  'LGA_YV': 6,
#  'DTW_UA': 7,
#  'CLT_B6': 8,
#  'DCA_UA': 3,
#  'DTW_B6': 8,
#  'PHL_F9': 9,
#  'DTW_AS': 7,
#  'DTW_OH': 9,
#  'DEN_B6': 8,
#  'EWR_MQ': 7,
#  'DFW_F9': 11,
#  'IAH_F9': 10,
#  'BWI_G4': 7,
#  'BWI_NK': 7,
#  'BWI_9E': 6,
#  'BWI_UA': 5,
#  'BWI_WN': 4,
#  'BWI_AA': 6,
#  'BWI_DL': 6,
#  'FLL_F9': 9,
#  'DEN_G4': 8,
#  'VPS_G4': 8,
#  'VPS_AA': 9,
#  'VPS_DL': 7,
#  'PHL_YV': 6,
#  'DTW_EV': 7,
#  'PIT_G4': 6,
#  'PIT_YX': 6,
#  'PIT_UA': 5,
#  'PIT_MQ': 5,
#  'PIT_AS': 5,
#  'PIT_NK': 6,
#  'ATL_EV': 7,
#  'DEN_AS': 7,
#  'FLL_AS': 8,
#  'CLT_NK': 8,
#  'PIT_9E': 6,
#  'PIT_WN': 5,
#  'PIT_DL': 6,
#  'BWI_B6': 5,
#  'DCA_YV': 4,
#  'IAD_AA': 5,
#  'IAD_YX': 7,
#  'DFW_OH': 16,
#  'LAS_OO': 7,
#  'SRQ_G4': 7,
#  'CLT_UA': 8,
#  'EWR_AS': 8,
#  'SRQ_DL': 4,
#  'MCO_F9': 10,
#  'MCO_B6': 8,
#  'MCO_AA': 8,
#  'MCO_WN': 7,
#  'MCO_UA': 7,
#  'MCO_DL': 8,
#  'MCO_NK': 11,
#  'VPS_OH': 8,
#  'VPS_YV': 7,
#  'PBI_G4': 6,
#  'PBI_F9': 6,
#  'PBI_B6': 4,
#  'SRQ_OH': 3,
#  'LAS_HA': 10,
#  'IAH_AS': 10,
#  'LAX_G4': 9,
#  'LAX_DL': 9,
#  'LAX_AA': 9,
#  'LAX_B6': 9,
#  'LAX_AS': 11,
#  'LAX_UA': 9,
#  'LAX_WN': 7,
#  'LAX_NK': 9,
#  'LAX_OO': 11,
#  'LAX_HA': 12,
#  'LAX_F9': 10,
#  'CLE_F9': 9,
#  'CLE_B6': 6,
#  'CLE_EV': 6,
#  'CLE_AA': 7,
#  'CLE_WN': 4,
#  'CLE_NK': 8,
#  'CLE_UA': 5,
#  'CLE_YV': 6,
#  'CLE_9E': 7,
#  'IND_G4': 7,
#  'IND_OO': 6,
#  'IND_YX': 6,
#  'IND_UA': 6,
#  'IND_DL': 5,
#  'JFK_B6': 8,
#  'JFK_AA': 10,
#  'JFK_9E': 9,
#  'JFK_DL': 10,
#  'JFK_MQ': 9,
#  'JFK_OO': 9,
#  'IND_WN': 4,
#  'BOS_B6': 6,
#  'BOS_YX': 11,
#  'BOS_AA': 7,
#  'BOS_WN': 6,
#  'BOS_UA': 5,
#  'BOS_AS': 7,
#  'BOS_DL': 9,
#  'JFK_OH': 7,
#  'JFK_YX': 11,
#  'BOS_9E': 9,
#  'BOS_NK': 8,
#  'CLE_MQ': 7,
#  'CLE_OH': 6,
#  'CLE_DL': 6,
#  'IND_OH': 7,
#  'IND_EV': 7,
#  'BOS_OO': 9,
#  'BWI_MQ': 6,
#  'BWI_AS': 6,
#  'IND_MQ': 6,
#  'PIT_AA': 5,
#  'CVG_G4': 6,
#  'CVG_F9': 8,
#  'CVG_9E': 5,
#  'CVG_DL': 5,
#  'PHL_OO': 5,
#  'JFK_AS': 10,
#  'BWI_F9': 8,
#  'BOS_YV': 5,
#  'CVG_YX': 6,
#  'SYR_G4': 5,
#  'SYR_B6': 4,
#  'SYR_EV': 6,
#  'SYR_9E': 4,
#  'GRR_G4': 6,
#  'GRR_MQ': 6,
#  'GRR_OH': 6,
#  'BNA_G4': 7,
#  'BNA_MQ': 6,
#  'BNA_WN': 5,
#  'BNA_AA': 6,
#  'BNA_UA': 7,
#  'BNA_OH': 6,
#  'BNA_YX': 7,
#  'BNA_YV': 7,
#  'BOS_EV': 6,
#  'CLE_G4': 7,
#  'RIC_G4': 7,
#  'RIC_B6': 4,
#  'RIC_AA': 6,
#  'LCK_G4': 6,
#  'GRR_EV': 7,
#  'MDT_G4': 6,
#  'CLE_OO': 6,
#  'GRR_YX': 6,
#  'SYR_YV': 4,
#  'RIC_9E': 6,
#  'RIC_OH': 5,
#  'GRR_F9': 7,
#  'CLE_YX': 7,
#  'BNA_F9': 8,
#  'SYR_AA': 4,
#  'IND_AA': 6,
#  'IND_YV': 5,
#  'SYR_YX': 5,
#  'AVL_G4': 7,
#  'BNA_DL': 6,
#  'BNA_9E': 7,
#  'BNA_OO': 6,
#  'SYR_OO': 5,
#  'RIC_YX': 7,
#  'SYR_DL': 4,
#  'CVG_MQ': 6,
#  'CVG_OH': 5,
#  'CVG_YV': 6,
#  'RIC_OO': 6,
#  'GRR_OO': 5,
#  'SYR_F9': 5,
#  'CVG_WN': 5,
#  'PIT_B6': 5,
#  'GRR_DL': 4,
#  'GRR_UA': 6,
#  'PIT_OO': 6,
#  'GRR_9E': 4,
#  'RIC_WN': 4,
#  'IND_9E': 5,
#  'GRR_WN': 5,
#  'BOS_OH': 4,
#  'BOS_MQ': 6,
#  'RFD_G4': 7,
#  'FNT_G4': 7,
#  'FNT_MQ': 4,
#  'BLV_G4': 5,
#  'MDT_MQ': 5,
#  'MDT_AA': 6,
#  'MDT_9E': 4,
#  'CVG_EV': 6,
#  'IND_NK': 6,
#  'GRR_AA': 7,
#  'SYR_MQ': 4,
#  'MDT_OH': 5,
#  'EWR_F9': 14,
#  'SBN_G4': 5,
#  'SYR_OH': 4,
#  'FWA_G4': 5,
#  'FWA_OO': 5,
#  'CVG_UA': 6,
#  'TYS_G4': 7,
#  'TYS_MQ': 5,
#  'TYS_OO': 5,
#  'TYS_DL': 4,
#  'RIC_MQ': 6,
#  'FNT_9E': 3,
#  'DSM_G4': 6,
#  'DSM_9E': 5,
#  'DSM_OO': 5,
#  'PIT_F9': 8,
#  'JAX_NK': 7,
#  'JAX_WN': 4,
#  'JAX_YX': 6,
#  'JAX_AA': 6,
#  'MDW_WN': 4,
#  'PHX_AA': 6,
#  'PHX_WN': 5,
#  'PHX_UA': 6,
#  'PHX_YV': 7,
#  'PHX_DL': 6,
#  'PHX_F9': 7,
#  'PHX_OO': 7,
#  'RSW_DL': 4,
#  'RSW_NK': 5,
#  'RSW_AA': 4,
#  'RSW_F9': 7,
#  'RSW_B6': 4,
#  'RSW_UA': 4,
#  'RSW_WN': 3,
#  'BUF_OO': 5,
#  'BUF_WN': 3,
#  'BUF_YV': 3,
#  'BUF_AA': 3,
#  'BWI_OO': 6,
#  'DAL_WN': 4,
#  'MDW_DL': 5,
#  'MKE_9E': 5,
#  'MKE_WN': 4,
#  'MKE_F9': 8,
#  'MKE_AA': 4,
#  'TPA_NK': 6,
#  'TPA_WN': 4,
#  'TPA_UA': 5,
#  'TPA_AA': 4,
#  'TPA_F9': 6,
#  'SLC_DL': 6,
#  'SLC_OO': 6,
#  'SLC_WN': 3,
#  'SLC_AA': 6,
#  'BDL_DL': 4,
#  'BDL_MQ': 4,
#  'LAN_OO': 3,
#  'ERI_OO': 3,
#  'ABE_OO': 4,
#  'IND_F9': 7,
#  'MCI_9E': 5,
#  'MCI_OO': 6,
#  'MCI_YX': 5,
#  'MCI_WN': 4,
#  'MCI_NK': 6,
#  'MCI_AA': 5,
#  'MCI_DL': 5,
#  'MSY_NK': 5,
#  'MSY_DL': 4,
#  'MSY_WN': 4,
#  'MSY_AA': 5,
#  'TPA_DL': 3,
#  'TPA_B6': 5,
#  'ORF_YX': 5,
#  'ORF_9E': 4,
#  'ORF_OH': 3,
#  'ORF_WN': 3,
#  'ROC_9E': 6,
#  'ROC_WN': 5,
#  'ROC_OH': 5,
#  'ROC_DL': 5,
#  'ROC_OO': 6,
#  'MSN_OO': 4,
#  'MSN_9E': 3,
#  'MSN_EV': 5,
#  'TYS_9E': 3,
#  'PWM_OO': 4,
#  'PWM_AA': 4,
#  'MEM_YX': 5,
#  'MEM_WN': 4,
#  'MEM_MQ': 5,
#  'MEM_OO': 6,
#  'MEM_DL': 4,
#  'ALB_OO': 4,
#  'ALB_EV': 5,
#  'ALB_MQ': 3,
#  'ATW_OO': 4,
#  'BTV_9E': 5,
#  'BTV_UA': 4,
#  'MHT_OO': 5,
#  'MHT_OH': 4,
#  'MHT_WN': 3,
#  'ITH_OO': 3,
#  'BGM_OO': 4,
#  'RDU_DL': 5,
#  'RDU_B6': 6,
#  'RDU_MQ': 6,
#  'RDU_WN': 3,
#  'RDU_AA': 5,
#  'CID_OO': 6,
#  'CID_MQ': 5,
#  'CMH_9E': 4,
#  'CMH_YX': 6,
#  'CMH_AA': 6,
#  'CMH_WN': 4,
#  'CMH_F9': 8,
#  'MKE_DL': 5,
#  'MKE_OO': 5,
#  'MKE_EV': 7,
#  'RSW_9E': 4,
#  'SEA_AS': 9,
#  'SEA_DL': 9,
#  'SEA_OO': 9,
#  'SEA_WN': 8,
#  'SEA_UA': 9,
#  'CVG_OO': 6,
#  'OMA_OO': 4,
#  'OMA_9E': 4,
#  'OMA_YX': 5,
#  'OMA_WN': 3,
#  'OMA_DL': 4,
#  'DAY_9E': 4,
#  'DAY_MQ': 4,
#  'DAY_OH': 4,
#  'TVC_OO': 4,
#  'AZO_OO': 4,
#  'JAX_DL': 4,
#  'JAX_B6': 5,
#  'PHX_NK': 7,
#  'STL_WN': 4,
#  'IMT_OO': 5,
#  'ELM_9E': 3,
#  'GRB_9E': 4,
#  'JAX_9E': 4,
#  'STL_EV': 7,
#  'STL_F9': 7,
#  'GRB_DL': 4,
#  'AVP_OO': 4,
#  'RIC_NK': 5,
#  'RIC_DL': 5,
#  'MDT_OO': 5,
#  'MDT_DL': 4,
#  'STL_9E': 5,
#  'STL_AA': 5,
#  'STL_OH': 5,
#  'STL_YX': 7,
#  'STL_DL': 5,
#  'ATW_MQ': 3,
#  'RSW_YV': 4,
#  'IAD_9E': 5,
#  'PHX_B6': 6,
#  'PHX_AS': 6,
#  'MCO_AS': 8,
#  'CHS_9E': 6,
#  'CHS_YV': 5,
#  'CHS_YX': 6,
#  'CHS_AA': 5,
#  'CHS_B6': 5,
#  'GSP_DL': 3,
#  'GSP_OO': 4,
#  'GSP_MQ': 4,
#  'GSP_9E': 3,
#  'GSP_YV': 4,
#  'GSP_EV': 5,
#  'JAX_F9': 8,
#  'JAX_MQ': 5,
#  'TPA_9E': 3,
#  'MSY_YX': 6,
#  'MSY_G4': 7,
#  'TYS_F9': 6,
#  'MEM_YV': 5,
#  'CID_F9': 6,
#  'OMA_EV': 4,
#  'RDU_YV': 6,
#  'SEA_F9': 11,
#  'OMA_F9': 6,
#  'RSW_YX': 5,
#  'IAD_AS': 5,
#  'HPN_OO': 4,
#  'HPN_B6': 4,
#  'ORF_OO': 4,
#  'ORF_EV': 5,
#  'ORF_DL': 4,
#  'ORF_G4': 6,
#  'PVD_9E': 4,
#  'PVD_EV': 6,
#  'PVD_B6': 4,
#  'PVD_OH': 3,
#  'BTV_EV': 5,
#  'BTV_OH': 4,
#  'EVV_9E': 4,
#  'EVV_MQ': 4,
#  'GSO_OO': 5,
#  'GSO_MQ': 5,
#  'GSO_OH': 5,
#  'GSO_YX': 6,
#  'ABE_EV': 5,
#  'ABE_9E': 4,
#  'GSP_OH': 3,
#  'AUS_DL': 7,
#  'AUS_UA': 5,
#  'AUS_AA': 6,
#  'AUS_WN': 4,
#  'AUS_B6': 5,
#  'AUS_F9': 7,
#  'AUS_AS': 5,
#  'AUS_OO': 5,
#  'BNA_AS': 6,
#  'IND_AS': 4,
#  'MDW_OO': 5,
#  'MSY_F9': 6,
#  'MSY_UA': 3,
#  'RDU_YX': 7,
#  'RDU_UA': 5,
#  'RDU_9E': 6,
#  'RDU_OH': 5,
#  'SFO_DL': 7,
#  'SFO_UA': 6,
#  'SFO_AA': 6,
#  'SFO_OO': 5,
#  'SFO_AS': 5,
#  'SFO_WN': 6,
#  'SDF_9E': 6,
#  'SDF_OO': 7,
#  'SDF_WN': 4,
#  'SDF_OH': 6,
#  'SDF_YX': 7,
#  'SDF_DL': 5,
#  'BDL_UA': 5,
#  'BDL_AA': 5,
#  'BDL_NK': 5,
#  'BDL_B6': 6,
#  'DSM_YX': 6,
#  'MLI_OO': 4,
#  'MLI_9E': 4,
#  'ATW_9E': 4,
#  'GRB_OO': 4,
#  'MBS_9E': 4,
#  'CHA_OO': 4,
#  'SBN_OO': 4,
#  'GSO_DL': 5,
#  'HPN_OH': 4,
#  'HPN_DL': 4,
#  'CID_9E': 6,
#  'AUS_YV': 6,
#  'CMH_MQ': 6,
#  'CMH_UA': 5,
#  'CMH_DL': 5,
#  'JAX_EV': 5,
#  'MCI_UA': 5,
#  'RIC_EV': 7,
#  'RIC_YV': 6,
#  'SAT_DL': 4,
#  'SAT_AA': 4,
#  'SAT_UA': 3,
#  'SAT_WN': 3,
#  'FWA_MQ': 4,
#  'SFO_B6': 9,
#  'SFO_F9': 12,
#  'SEA_AA': 10,
#  'SEA_B6': 9,
#  'SEA_HA': 7,
#  'OKC_OO': 5,
#  'OKC_YV': 5,
#  'OKC_WN': 3,
#  'OKC_AA': 5,
#  'PVD_DL': 4,
#  'PVD_WN': 4,
#  'PVD_MQ': 4,
#  'PVD_YX': 5,
#  'PVD_AA': 4,
#  'PDX_DL': 4,
#  'PDX_AA': 4,
#  'PDX_UA': 4,
#  'PDX_AS': 4,
#  'PDX_WN': 3,
#  'PDX_OO': 6,
#  'SDF_YV': 6,
#  'DAY_OO': 5,
#  'BDL_YV': 5,
#  'HSV_OO': 5,
#  'HSV_EV': 6,
#  'HSV_DL': 4,
#  'DSM_UA': 4,
#  'DSM_OH': 5,
#  'DSM_MQ': 5,
#  'DSM_WN': 3,
#  'AVP_MQ': 4,
#  'MLI_MQ': 4,
#  'PLN_OO': 5,
#  'CWA_9E': 4,
#  'DCA_F9': 6,
#  'GSO_9E': 5,
#  'GSO_AA': 6,
#  'BHM_9E': 4,
#  'CID_OH': 5,
#  'JAX_OO': 5,
#  'JAX_UA': 4,
#  'MSY_9E': 5,
#  'BUF_9E': 5,
#  'BUF_MQ': 3,
#  'BUF_DL': 4,
#  'BUF_YX': 5,
#  'TYS_OH': 4,
#  'BDL_WN': 4,
#  'BDL_9E': 5,
#  'BTV_OO': 5,
#  'MSP_YV': 5,
#  'PIT_YV': 5,
#  'PIT_OH': 5,
#  'MCI_OH': 4,
#  'SEA_NK': 11,
#  'SLC_YV': 6,
#  'MSN_OH': 4,
#  'DSM_AA': 5,
#  'TVC_9E': 4,
#  'SWF_OO': 5,
#  'APN_OO': 4,
#  'BNA_B6': 7,
#  'ALB_WN': 3,
#  'ALB_G4': 7,
#  'IAH_MQ': 8,
#  'PBI_DL': 4,
#  'PBI_WN': 4,
#  'PBI_AA': 5,
#  'CHA_MQ': 5,
#  'CHA_OH': 4,
#  'CHA_EV': 5,
#  'CMH_OO': 5,
#  'CMH_YV': 5,
#  'MCI_F9': 7,
#  'MSY_B6': 5,
#  'MSY_YV': 3,
#  'SAN_DL': 4,
#  'SAN_UA': 3,
#  'SAN_AA': 4,
#  'SAN_AS': 4,
#  'SAN_WN': 3,
#  'SAT_9E': 4,
#  'SAT_F9': 7,
#  'SAT_YV': 3,
#  'LEX_OO': 5,
#  'LEX_OH': 4,
#  'LEX_9E': 4,
#  'SLC_UA': 5,
#  'SLC_B6': 5,
#  'SJC_DL': 4,
#  'SJC_AA': 4,
#  'SJC_WN': 3,
#  'SJC_UA': 3,
#  'SJC_OO': 5,
#  'SNA_DL': 6,
#  'SNA_AA': 6,
#  'SNA_WN': 3,
#  'SNA_AS': 5,
#  'ROC_YX': 7,
#  'ROC_MQ': 5,
#  'MSN_F9': 6,
#  'DAY_DL': 5,
#  'MBS_OO': 4,
#  'AZO_MQ': 3,
#  'SFO_HA': 11,
#  'PBI_NK': 5,
#  'PVD_F9': 7,
#  'ATW_G4': 5,
#  'GSO_G4': 6,
#  'BUF_F9': 7,
#  'SAN_G4': 7,
#  'GSP_AA': 4,
#  'SAN_NK': 4,
#  'SAN_HA': 6,
#  'SAT_OO': 4,
#  'LEX_EV': 5,
#  'MSN_DL': 4,
#  'MSN_UA': 4,
#  'MSN_MQ': 4,
#  'STL_OO': 6,
#  'SLC_F9': 6,
#  'LAN_OH': 3,
#  'SRQ_9E': 4,
#  'SRQ_YX': 4,
#  'SRQ_AA': 4,
#  'BNA_EV': 9,
#  'MKE_MQ': 4,
#  'MKE_G4': 6,
#  'LEX_G4': 6,
#  'DCA_AS': 4,
#  'DAL_OO': 5,
#  'MEM_9E': 5,
#  'MEM_AA': 5,
#  'MEM_UA': 5,
#  'MSN_YV': 5,
#  'MSN_YX': 4,
#  'PIT_EV': 6,
#  'ALB_9E': 4,
#  'ALB_AA': 4,
#  'ALB_DL': 4,
#  'MCI_G4': 6,
#  'OMA_AA': 5,
#  'AUS_YX': 7,
#  'MSY_OO': 4,
#  'DSM_F9': 7,
#  'BUF_B6': 3,
#  'ALB_OH': 3,
#  'BDL_OH': 4,
#  'LEX_MQ': 5,
#  'LEX_DL': 4,
#  'TYS_YV': 4,
#  'MCO_9E': 8,
#  'MSP_AS': 5,
#  'PBI_UA': 4,
#  'AVP_9E': 4,
#  'LAN_9E': 3,
#  'CMH_EV': 7,
#  'TYS_EV': 4,
#  'SBN_EV': 4,
#  'JAX_OH': 5,
#  'SAN_OO': 4,
#  'CVG_AA': 6,
#  'OKC_OH': 5,
#  'OKC_YX': 6,
#  'HSV_YV': 4,
#  'AUS_9E': 7,
#  'RDU_F9': 7,
#  'SDF_MQ': 6,
#  'CIU_OO': 4,
#  'MCI_MQ': 4,
#  'MKE_YX': 6,
#  'TPA_AS': 5,
#  'BTV_YV': 3,
#  'LAN_MQ': 3,
#  'MCI_YV': 5,
#  'CHS_OO': 5,
#  'CHS_MQ': 6,
#  'MDT_F9': 6,
#  'AVP_OH': 4,
#  'RDU_OO': 5,
#  'ATW_DL': 4,
#  'SDF_G4': 7,
#  'PBI_YX': 5,
#  'SRQ_UA': 3,
#  'SNA_OO': 5,
#  'OMA_UA': 4,
#  'JAX_G4': 7,
#  'MCO_YX': 9,
#  'ROC_G4': 7,
#  'LEX_YX': 6,
#  'AZO_9E': 4,
#  'ABE_OH': 4,
#  'ABE_G4': 5,
#  'MSY_OH': 3,
#  'SDF_EV': 9,
#  'MHT_AA': 4,
#  'MSP_EV': 5,
#  'BWI_OH': 5,
#  'CMH_OH': 6,
#  'GSP_WN': 3,
#  'RDU_AS': 5,
#  'SAT_G4': 6,
#  'SNA_F9': 6,
#  'ROC_AA': 5,
#  'MEM_EV': 6,
#  'SJC_F9': 6,
#  'CID_G4': 6,
#  'MYR_NK': 6,
#  'MYR_OH': 4,
#  'JAX_YV': 4,
#  'SNA_UA': 5,
#  'OMA_G4': 5,
#  'BUF_EV': 4,
#  'CID_UA': 5,
#  'AUS_NK': 7,
#  'TYS_YX': 6,
#  'MCI_EV': 6,
#  'ORF_F9': 7,
#  'MHT_YX': 6,
#  'AUS_G4': 6,
#  'DSM_YV': 5,
#  'MSP_MQ': 4,
#  'BTV_B6': 4,
#  'MYR_DL': 4,
#  'SRQ_B6': 4,
#  'BHM_F9': 7,
#  'CID_EV': 6,
#  'GSP_YX': 5,
#  'MSY_AS': 4,
#  'SLC_EV': 5,
#  'RDU_G4': 7,
#  'RIC_UA': 5,
#  'MEM_OH': 4,
#  'BDL_YX': 5,
#  'LAN_EV': 5,
#  'ROC_UA': 6,
#  'MKE_OH': 4,
#  'STL_AS': 6,
#  'ROC_EV': 8,
#  'CMH_NK': 6,
#  'HPN_9E': 4,
#  'DAL_DL': 4,
#  'SAN_B6': 3,
#  'BUF_OH': 3,
#  'CHA_DL': 4,
#  'EVV_OO': 4,
#  'BHM_OO': 4,
#  'BHM_WN': 2,
#  'BHM_OH': 3,
#  'BHM_YX': 5,
#  'BHM_DL': 3,
#  'ORF_MQ': 4,
#  'ORF_AA': 4,
#  'ORF_YV': 3,
#  'SAV_9E': 5,
#  'SAV_AA': 6,
#  'SAV_OH': 5,
#  'SAV_DL': 4,
#  'LIT_OO': 6,
#  'LIT_MQ': 5,
#  'LIT_YV': 5,
#  'AVP_DL': 4,
#  'BTV_DL': 5,
#  'SBN_9E': 4,
#  'ORF_UA': 3,
#  'DSM_DL': 4,
#  'SJC_AS': 5,
#  'SAN_F9': 6,
#  'GSP_G4': 7,
#  'SWF_G4': 6,
#  'LSE_OO': 3,
#  'EVV_EV': 5,
#  'PHX_HA': 8,
#  'SYR_UA': 5,
#  'SAV_EV': 6,
#  'RDU_EV': 7,
#  'PVD_OO': 4,
#  'BTV_F9': 10,
#  'TPA_YX': 6,
#  'AUS_EV': 8,
#  'SAT_YX': 4,
#  'BZN_OO': 4,
#  'BZN_DL': 4,
#  'MCO_OO': 9,
#  'BHM_YV': 3,
#  'EVV_G4': 6,
#  'SAV_YV': 5,
#  'LIT_EV': 7,
#  'LIT_YX': 7,
#  'MLI_G4': 6,
#  'CHA_9E': 5,
#  'MDT_EV': 4,
#  'BHM_EV': 6,
#  'LIT_WN': 3,
#  'DSM_EV': 5,
#  'ALB_UA': 4,
#  'MDT_UA': 4,
#  'DAY_G4': 6,
#  'MIA_9E': 13,
#  'CMH_AS': 5,
#  'EVV_OH': 4,
#  'CHS_UA': 5,
#  'CHS_WN': 5,
#  'CHS_DL': 5,
#  'ABE_MQ': 4,
#  'ABE_DL': 4,
#  'STL_YV': 6,
#  'SAV_OO': 5,
#  'HSV_YX': 6,
#  'TVC_DL': 5,
#  'FLL_YX': 5,
#  'PVD_YV': 3,
#  'BDL_OO': 5,
#  'SDF_AA': 6,
#  'SDF_F9': 10,
#  'GRB_MQ': 3,
#  'BDL_F9': 7,
#  'SLC_YX': 7,
#  'BOS_F9': 9,
#  'MKE_AS': 4,
#  'SAV_YX': 6,
#  'STL_MQ': 6,
#  'PWM_DL': 4,
#  'PWM_MQ': 3,
#  'PWM_OH': 3,
#  'MYR_F9': 6,
#  'OMA_MQ': 5,
#  'RDU_NK': 7,
#  'FWA_9E': 4,
#  'CHS_OH': 5,
#  'BTV_YX': 5,
#  'BHM_MQ': 4,
#  'OAK_NK': 6,
#  'OAK_WN': 5,
#  'OAK_AS': 5,
#  'OAK_DL': 5,
#  'OKC_DL': 4,
#  'MKE_UA': 5,
#  'PDX_NK': 5,
#  'CWA_EV': 4,
#  'MSY_MQ': 4,
#  'ROC_B6': 4,
#  'SDF_UA': 6,
#  'MYR_G4': 6,
#  'OKC_F9': 7,
#  'OKC_G4': 5,
#  'OMA_YV': 4,
#  'MYR_YX': 6,
#  'DAL_AS': 4,
#  'MYR_UA': 5,
#  'HPN_MQ': 4,
#  'GRB_EV': 5,
#  'MEM_G4': 8,
#  'PBI_OO': 4,
#  'TVC_MQ': 3,
#  'MIA_YV': 7,
#  'SMF_DL': 5,
#  'SMF_AA': 5,
#  'SMF_OO': 5,
#  'SMF_WN': 4,
#  'SMF_AS': 5,
#  'STL_UA': 5,
#  'LIT_G4': 7,
#  'PWM_UA': 3,
#  'PWM_YX': 4,
#  'HSV_OH': 4,
#  'MYR_AA': 6,
#  'GSO_YV': 5,
#  'ALB_B6': 3,
#  'SAV_G4': 6,
#  ...}

# %%
df[(df['DEST'] == 'IAH') & (df['OP_UNIQUE_CARRIER'] == 'UA')]['TAXI_IN_median'].unique()
# Out:
# array([7])

# %% [markdown]
# ### `HourlySkyConditions`

# %%
sky_dict = {
            'CLR' : '[CLR] Clear sky',
            'FEW' : '[FEW] Few clouds',
            'SCT' : '[SCT] Scattered clouds',
            'BKN' : '[BKN] Broken clouds',
            'OVC' : '[OVC] Overcast',
            'VV' : '[VV] Obscured sky'
           }
with open("dict_mappers/sky_dict.pkl", "wb") as f:
    pickle.dump(sky_dict, f)
sky_dict
# Out:
# {'CLR': '[CLR] Clear sky',
#  'FEW': '[FEW] Few clouds',
#  'SCT': '[SCT] Scattered clouds',
#  'BKN': '[BKN] Broken clouds',
#  'OVC': '[OVC] Overcast',
#  'VV': '[VV] Obscured sky'}

# %% [markdown]
# ### `DISTANCE`

# %%
# Haversine formula : determines the great-circle distance between two points on a sphere given their longitudes and latitudes

from math import cos, asin, sqrt, pi

def distance(lat1, lon1, lat2, lon2):
    p = pi/180
    a = 0.5 - cos((lat2-lat1)*p)/2 + cos(lat1*p) * cos(lat2*p) * (1-cos((lon2-lon1)*p))/2
    return 12742 * asin(sqrt(a))

# %%
airports_df = df.drop_duplicates(subset=['ORIGIN'], keep='first')[['ORIGIN', 'LATITUDE_Origin', 'LONGITUDE_Origin']]
airports_df = airports_df.round(decimals=4)
airports_df
# Out:
#         ORIGIN  LATITUDE_Origin  LONGITUDE_Origin
# 0          TYS          35.8181          -83.9858
# 1          SRQ          27.4014          -82.5586
# 2          DTW          42.2313          -83.3308
# 4          LGA          40.7794          -73.8804
# 7          ROA          37.3169          -79.9741
# ...        ...              ...               ...
# 6621341    WRG          56.4732         -132.3874
# 6621359    PSG          56.8055         -132.9372
# 6622180    DLG          59.0500         -158.5167
# 7193994    YAK          59.5120         -139.6712
# 7194973    GST          58.4111         -135.7089
#
# [341 rows x 3 columns]

# %%
airportCoordinates_dict = dict(zip(airports_df['ORIGIN'], zip(airports_df['LATITUDE_Origin'], airports_df['LONGITUDE_Origin'])))
airportCoordinates_dict
# Out:
# {'TYS': (35.8181, -83.9858),
#  'SRQ': (27.4014, -82.5586),
#  'DTW': (42.2313, -83.3308),
#  'LGA': (40.7794, -73.8804),
#  'ROA': (37.3169, -79.9741),
#  'TPA': (27.9619, -82.5403),
#  'RDU': (35.8923, -78.7819),
#  'BOS': (42.3606, -71.0097),
#  'MSP': (44.8831, -93.2289),
#  'JAX': (30.495, -81.6936),
#  'IND': (39.7252, -86.2817),
#  'BTR': (30.5372, -91.1469),
#  'TLH': (30.3931, -84.3533),
#  'GSP': (34.9061, -82.2125),
#  'DAY': (39.9064, -84.2185),
#  'MEM': (35.0564, -89.9865),
#  'CMH': (39.9907, -82.877),
#  'SAT': (29.5443, -98.4839),
#  'DFW': (32.8978, -97.0189),
#  'BWI': (39.1733, -76.684),
#  'CAE': (33.9423, -81.118),
#  'CLE': (41.4057, -81.852),
#  'DEN': (39.8328, -104.6575),
#  'FLL': (26.0788, -80.1622),
#  'LAS': (36.0719, -115.1634),
#  'MCI': (39.2972, -94.7306),
#  'MCO': (28.4339, -81.325),
#  'PBI': (26.6847, -80.0994),
#  'PHL': (39.8733, -75.2268),
#  'PHX': (33.4277, -112.0038),
#  'PNS': (30.4781, -87.1869),
#  'RSW': (26.5361, -81.755),
#  'SLC': (40.7781, -111.9694),
#  'STL': (38.7525, -90.3736),
#  'TUS': (32.1313, -110.9552),
#  'CLT': (35.2236, -80.9552),
#  'DCA': (38.8472, -77.0345),
#  'LEX': (38.0408, -84.6058),
#  'XNA': (36.2833, -94.3),
#  'GPT': (30.4119, -89.0808),
#  'IAH': (29.98, -95.36),
#  'ORF': (36.9033, -76.1922),
#  'PIT': (40.4846, -80.2144),
#  'AUS': (30.3208, -97.7604),
#  'BDL': (41.9375, -72.6819),
#  'OMA': (41.3102, -95.8991),
#  'SAV': (32.1313, -81.2024),
#  'LAX': (33.938, -118.3888),
#  'PDX': (45.5958, -122.6093),
#  'SAN': (32.7336, -117.1831),
#  'SEA': (47.4444, -122.3138),
#  'SFO': (37.6197, -122.3647),
#  'SNA': (33.68, -117.8664),
#  'BNA': (36.1189, -86.6892),
#  'PIA': (40.6675, -89.6839),
#  'MIA': (25.7881, -80.3169),
#  'ATL': (33.6301, -84.4418),
#  'SYR': (43.1111, -76.1038),
#  'CVG': (39.0444, -84.6724),
#  'ATW': (44.2667, -88.5167),
#  'EWR': (40.6825, -74.1694),
#  'JAN': (32.3205, -90.0777),
#  'ROC': (43.1172, -77.6754),
#  'RIC': (37.5115, -77.3234),
#  'HSV': (34.6441, -86.7869),
#  'ICT': (37.6475, -97.43),
#  'CHA': (35.0336, -85.2004),
#  'BUF': (42.94, -78.7362),
#  'GRR': (42.8825, -85.5239),
#  'MDT': (40.1962, -76.7724),
#  'ASE': (39.23, -106.8706),
#  'DBQ': (42.3978, -90.7036),
#  'BHM': (33.5656, -86.745),
#  'ORD': (41.9602, -87.9316),
#  'TUL': (36.1994, -95.8872),
#  'MSY': (29.9969, -90.2775),
#  'CHS': (32.8994, -80.0408),
#  'LBB': (33.6656, -101.8231),
#  'MAF': (31.9475, -102.2086),
#  'CRP': (27.7742, -97.5122),
#  'MFE': (26.1839, -98.2539),
#  'LCH': (30.1247, -93.2283),
#  'GRK': (31.0667, -97.8333),
#  'OKC': (35.3889, -97.6006),
#  'LFT': (30.205, -91.9875),
#  'LIT': (34.7273, -92.2389),
#  'AMA': (35.2295, -101.7042),
#  'MOB': (30.6883, -88.2456),
#  'BRO': (25.9141, -97.423),
#  'SGF': (37.2398, -93.3901),
#  'SBN': (41.7072, -86.3163),
#  'AVL': (35.4319, -82.5375),
#  'ILM': (34.2675, -77.8997),
#  'PHF': (37.1319, -76.4931),
#  'CAK': (40.9181, -81.4435),
#  'MKE': (42.955, -87.9044),
#  'SHV': (32.4472, -93.8244),
#  'CID': (41.8833, -91.7166),
#  'ELM': (42.1594, -76.8919),
#  'SDF': (38.1811, -85.7391),
#  'IAD': (38.9349, -77.4473),
#  'HOU': (29.6381, -95.2819),
#  'MDW': (41.7861, -87.7522),
#  'PVD': (41.7225, -71.4325),
#  'ALB': (42.7472, -73.7991),
#  'FNT': (42.9666, -83.7494),
#  'ABE': (40.6498, -75.4477),
#  'EVV': (38.0441, -87.5205),
#  'FWA': (40.9705, -85.2063),
#  'DAB': (29.1828, -81.0483),
#  'MLU': (32.5155, -92.0405),
#  'VLD': (30.7825, -83.2767),
#  'AVP': (41.3336, -75.7269),
#  'GTR': (33.45, -88.5833),
#  'EWN': (35.0677, -77.048),
#  'JFK': (40.6392, -73.764),
#  'BTV': (44.4683, -73.1499),
#  'GSO': (36.0969, -79.9432),
#  'OAJ': (34.8333, -77.6167),
#  'CHO': (38.1374, -78.4552),
#  'MYR': (33.6833, -78.9333),
#  'HPN': (41.0624, -73.7046),
#  'TOL': (41.5871, -83.8055),
#  'FAY': (34.9914, -78.8803),
#  'CMI': (40.0397, -88.2778),
#  'AGS': (33.3644, -81.9633),
#  'DLH': (46.8369, -92.1833),
#  'DSM': (41.5338, -93.653),
#  'ANC': (61.169, -150.0278),
#  'TRI': (36.4797, -82.399),
#  'MGM': (32.2997, -86.4075),
#  'AEX': (31.3347, -92.5586),
#  'BOI': (43.5666, -116.2405),
#  'GTF': (47.4733, -111.3822),
#  'BIS': (46.7825, -100.7572),
#  'FSD': (43.5778, -96.7539),
#  'MSO': (46.9208, -114.0925),
#  'GFK': (47.9428, -97.1839),
#  'BZN': (45.788, -111.1608),
#  'BIL': (45.8069, -108.5422),
#  'RAP': (44.0458, -103.0544),
#  'HLN': (46.6056, -111.9636),
#  'ACY': (39.452, -74.567),
#  'MLI': (41.4653, -90.5233),
#  'CWA': (44.7833, -89.6667),
#  'MBS': (43.5331, -84.0797),
#  'GRB': (44.4794, -88.1366),
#  'GNV': (29.6919, -82.2755),
#  'VPS': (30.4833, -86.5167),
#  'ECP': (30.349, -85.788),
#  'MLB': (28.1011, -80.6439),
#  'ABY': (31.5356, -84.1944),
#  'BQK': (31.2589, -81.4661),
#  'CRW': (38.3794, -81.59),
#  'HNL': (21.324, -157.9294),
#  'MSN': (43.1405, -89.3452),
#  'SPI': (39.8447, -89.6839),
#  'FAR': (46.9253, -96.8111),
#  'RST': (43.9041, -92.4916),
#  'EAU': (44.8665, -91.4879),
#  'COU': (38.8169, -92.2183),
#  'MHK': (39.1346, -96.6788),
#  'SUX': (42.3913, -96.3791),
#  'ALO': (42.5544, -92.4011),
#  'ELP': (31.8111, -106.3758),
#  'COS': (38.81, -104.6884),
#  'HOB': (32.6933, -103.2125),
#  'CSG': (32.5161, -84.9422),
#  'AZO': (42.2347, -85.5519),
#  'TVC': (44.7408, -85.5825),
#  'CMX': (47.1686, -88.4889),
#  'MKG': (43.1711, -86.2367),
#  'BMI': (40.4833, -88.95),
#  'LSE': (43.8788, -91.2527),
#  'SJU': (18.4325, -66.0108),
#  'SMF': (38.6956, -121.5897),
#  'DAL': (32.8519, -96.8555),
#  'EYW': (24.5571, -81.7554),
#  'SJC': (37.3591, -121.924),
#  'LAN': (42.7761, -84.5997),
#  'ERI': (42.0803, -80.1824),
#  'IMT': (45.8183, -88.1144),
#  'BGM': (42.2068, -75.98),
#  'PWM': (43.6422, -70.3044),
#  'LNK': (40.8508, -96.7475),
#  'FSM': (35.333, -94.3625),
#  'ABQ': (35.0419, -106.6155),
#  'UIN': (39.9369, -91.1919),
#  'CLL': (30.5892, -96.3647),
#  'MTJ': (38.5058, -107.8989),
#  'STT': (18.3363, -64.98),
#  'HDN': (40.4811, -107.2175),
#  'EGE': (39.65, -106.9167),
#  'JAC': (43.6, -110.7333),
#  'SWF': (41.5, -74.1),
#  'ITH': (42.4833, -76.4667),
#  'MHT': (42.9296, -71.4357),
#  'OAK': (37.7214, -122.2208),
#  'FAT': (36.78, -119.7194),
#  'LRD': (27.5333, -99.4667),
#  'GUC': (38.5333, -106.9333),
#  'ABI': (32.4105, -99.6822),
#  'SJT': (31.3516, -100.495),
#  'BPT': (29.9506, -94.0206),
#  'DRT': (29.3784, -100.927),
#  'PBG': (44.65, -73.4667),
#  'LBF': (41.1213, -100.6694),
#  'HYS': (38.85, -99.2667),
#  'GCC': (44.3394, -105.5419),
#  'PUB': (38.2887, -104.5057),
#  'LAR': (41.3167, -105.6833),
#  'COD': (44.5167, -109.0167),
#  'ISN': (48.1738, -103.6366),
#  'LGB': (33.8116, -118.1463),
#  'RNO': (39.4838, -119.7711),
#  'BUR': (34.2006, -118.3575),
#  'CKB': (39.2956, -80.2289),
#  'SHD': (38.2636, -78.8964),
#  'STX': (17.6997, -64.8125),
#  'GJT': (39.1342, -108.54),
#  'ART': (43.9887, -76.0262),
#  'HVN': (41.2639, -72.8872),
#  'JLN': (37.1522, -94.4953),
#  'ROW': (33.3075, -104.5083),
#  'SAF': (35.6169, -106.0889),
#  'LYH': (37.3213, -79.2066),
#  'ISP': (40.7939, -73.1019),
#  'TTN': (40.2768, -74.8159),
#  'PSP': (33.8222, -116.5043),
#  'ONT': (34.0561, -117.6003),
#  'LWB': (37.8667, -80.4),
#  'DRO': (37.1431, -107.7603),
#  'MRY': (36.5881, -121.8453),
#  'MMH': (37.6333, -118.85),
#  'LAW': (34.5584, -98.4172),
#  'TYR': (32.3542, -95.4025),
#  'TXK': (33.456, -93.9878),
#  'BGR': (44.7978, -68.8185),
#  'PLN': (45.5644, -84.7927),
#  'GRI': (40.9611, -98.3136),
#  'SWO': (36.1624, -97.0894),
#  'GCK': (37.9272, -100.7247),
#  'RFD': (42.1927, -89.093),
#  'GEG': (47.6216, -117.528),
#  'APN': (45.0716, -83.5644),
#  'MOT': (48.2552, -101.2733),
#  'HTS': (38.3653, -82.5548),
#  'STC': (45.5433, -94.0513),
#  'SGU': (37.1, -113.6),
#  'PIR': (44.3813, -100.2855),
#  'MEI': (32.3347, -88.7442),
#  'SBA': (34.4258, -119.8425),
#  'CYS': (41.1578, -104.8069),
#  'SPS': (33.9786, -98.4928),
#  'CIU': (46.25, -84.4667),
#  'HIB': (47.3864, -92.8389),
#  'GGG': (32.3847, -94.7117),
#  'RHI': (45.6314, -89.4823),
#  'LCK': (39.8167, -82.9333),
#  'IDA': (43.519, -112.0639),
#  'CNY': (38.75, -109.7628),
#  'BFM': (30.6264, -88.0681),
#  'CGI': (37.2252, -89.5705),
#  'ACK': (41.2531, -70.0608),
#  'BRD': (46.4047, -94.1308),
#  'EAR': (40.7333, -99.0),
#  'RKS': (41.5947, -109.053),
#  'BFF': (41.8705, -103.593),
#  'JMS': (46.9258, -98.6691),
#  'LBE': (40.2833, -79.4),
#  'ORH': (42.2706, -71.8731),
#  'FAI': (64.8039, -147.8761),
#  'MVY': (41.3931, -70.615),
#  'CPR': (42.8978, -106.4737),
#  'PIB': (31.4667, -89.3333),
#  'ACT': (31.6189, -97.2283),
#  'PSM': (43.0833, -70.8167),
#  'BFL': (35.4344, -119.0542),
#  'FLG': (35.1441, -111.6663),
#  'ABR': (45.4433, -98.413),
#  'BJI': (47.5, -94.9333),
#  'BLI': (48.7939, -122.5372),
#  'PGV': (35.6333, -77.3833),
#  'PSC': (46.2667, -119.1167),
#  'BLV': (38.55, -89.85),
#  'OGG': (20.8997, -156.4286),
#  'MQT': (46.5313, -87.5491),
#  'BQN': (18.4977, -67.1294),
#  'SCK': (37.8891, -121.2258),
#  'MFR': (42.375, -122.8771),
#  'RDM': (44.2558, -121.1392),
#  'SUN': (43.5, -114.3),
#  'TWF': (42.4819, -114.4869),
#  'HGR': (39.7062, -77.7304),
#  'LBL': (37.05, -100.9667),
#  'EUG': (44.1278, -123.2206),
#  'SBP': (35.2372, -120.6414),
#  'SFB': (28.7797, -81.2436),
#  'PGD': (26.9172, -81.9914),
#  'ATY': (44.9047, -97.1494),
#  'PIE': (27.9106, -82.6875),
#  'LWS': (46.3747, -117.0156),
#  'PIH': (42.9202, -112.5711),
#  'CDC': (37.7086, -113.0944),
#  'ACV': (40.9781, -124.1086),
#  'VEL': (40.4428, -109.5128),
#  'RDD': (40.5175, -122.2986),
#  'KOA': (19.7356, -156.0489),
#  'LIH': (21.9839, -159.3406),
#  'BTM': (45.9647, -112.5006),
#  'OTH': (43.4133, -124.2436),
#  'KTN': (55.35, -131.65),
#  'SMX': (34.8994, -120.4486),
#  'INL': (48.5614, -93.3981),
#  'PVU': (40.2189, -111.7233),
#  'JNU': (58.3566, -134.564),
#  'PRC': (34.6517, -112.4208),
#  'PAE': (47.9078, -122.2803),
#  'SIT': (57.0481, -135.3647),
#  'ITO': (19.7191, -155.053),
#  'WYS': (44.6833, -111.1167),
#  'HYA': (41.6686, -70.28),
#  'DVL': (48.1167, -98.9),
#  'OWB': (37.75, -87.1667),
#  'EKO': (40.8288, -115.7886),
#  'ADK': (51.8833, -176.65),
#  'BRW': (71.2834, -156.7815),
#  'BET': (60.785, -161.8293),
#  'OME': (64.5111, -165.44),
#  'OTZ': (66.8667, -162.6333),
#  'ADQ': (57.7511, -152.4855),
#  'AKN': (58.6829, -156.6563),
#  'SCC': (70.1917, -148.4772),
#  'GUM': (13.4833, 144.8),
#  'PPG': (-14.3306, -170.7136),
#  'CDV': (60.4888, -145.4511),
#  'WRG': (56.4732, -132.3874),
#  'PSG': (56.8055, -132.9372),
#  'DLG': (59.05, -158.5167),
#  'YAK': (59.512, -139.6712),
#  'GST': (58.4111, -135.7089)}

# %%
distance_dict = {}
for airport in airportCoordinates_dict.keys():
    lat1, lon1 = airportCoordinates_dict[airport][0], airportCoordinates_dict[airport][1]
    for aprt, coordinates in airportCoordinates_dict.items():
        lat2, lon2 = airportCoordinates_dict[aprt][0], airportCoordinates_dict[aprt][1]
        dist = int(round(distance(lat1, lon1, lat2, lon2)) * 0.621371) # km to miles (mi)
        distance_dict[airport + '_' + aprt] = dist

# %% [raw]
# {'TYS_ATL': 152,
#  'SRQ_ATL': 444,
#  'DTW_ATL': 594,

# %%
# Quick check to validate results:
distance_dict['TYS_ATL'], distance_dict['SRQ_ATL'], distance_dict['DTW_ATL']
# Out:
# (153, 444, 597)

# %%
with open("dict_mappers/distance_dict.pkl", "wb") as f:
    pickle.dump(distance_dict, f)
distance_dict
# Out:
# {'TYS_TYS': 0,
#  'TYS_SRQ': 587,
#  'TYS_DTW': 444,
#  'TYS_LGA': 645,
#  'TYS_ROA': 245,
#  'TYS_TPA': 549,
#  'TYS_RDU': 291,
#  'TYS_BOS': 828,
#  'TYS_MSP': 792,
#  'TYS_JAX': 390,
#  'TYS_IND': 297,
#  'TYS_BTR': 551,
#  'TYS_TLH': 375,
#  'TYS_GSP': 118,
#  'TYS_DAY': 282,
#  'TYS_MEM': 341,
#  'TYS_CMH': 294,
#  'TYS_SAT': 946,
#  'TYS_DFW': 769,
#  'TYS_BWI': 462,
#  'TYS_CAE': 208,
#  'TYS_CLE': 402,
#  'TYS_DEN': 1158,
#  'TYS_FLL': 709,
#  'TYS_LAS': 1736,
#  'TYS_MCI': 635,
#  'TYS_MCO': 533,
#  'TYS_PBI': 671,
#  'TYS_PHL': 553,
#  'TYS_PHX': 1596,
#  'TYS_PNS': 412,
#  'TYS_RSW': 654,
#  'TYS_SLC': 1548,
#  'TYS_STL': 405,
#  'TYS_TUS': 1560,
#  'TYS_CLT': 175,
#  'TYS_DCA': 435,
#  'TYS_LEX': 157,
#  'TYS_XNA': 576,
#  'TYS_GPT': 475,
#  'TYS_IAH': 772,
#  'TYS_ORF': 439,
#  'TYS_PIT': 382,
#  'TYS_AUS': 882,
#  'TYS_BDL': 739,
#  'TYS_OMA': 746,
#  'TYS_SAV': 300,
#  'TYS_LAX': 1944,
#  'TYS_PDX': 2109,
#  'TYS_SAN': 1898,
#  'TYS_SEA': 2110,
#  'TYS_SFO': 2114,
#  'TYS_SNA': 1919,
#  'TYS_BNA': 152,
#  'TYS_PIA': 455,
#  'TYS_MIA': 726,
#  'TYS_ATL': 153,
#  'TYS_SYR': 655,
#  'TYS_CVG': 226,
#  'TYS_ATW': 630,
#  'TYS_EWR': 629,
#  'TYS_JAN': 423,
#  'TYS_ROC': 605,
#  'TYS_RIC': 387,
#  'TYS_HSV': 177,
#  'TYS_ICT': 754,
#  'TYS_CHA': 86,
#  'TYS_BUF': 566,
#  'TYS_GRR': 495,
#  'TYS_MDT': 495,
#  'TYS_ASE': 1272,
#  'TYS_DBQ': 579,
#  'TYS_BHM': 220,
#  'TYS_ORD': 474,
#  'TYS_TUL': 665,
#  'TYS_MSY': 543,
#  'TYS_CHS': 301,
#  'TYS_LBB': 1022,
#  'TYS_MAF': 1076,
#  'TYS_CRP': 968,
#  'TYS_MFE': 1073,
#  'TYS_LCH': 664,
#  'TYS_GRK': 862,
#  'TYS_OKC': 764,
#  'TYS_LFT': 603,
#  'TYS_LIT': 471,
#  'TYS_AMA': 996,
#  'TYS_MOB': 431,
#  'TYS_BRO': 1048,
#  'TYS_SGF': 531,
#  'TYS_SBN': 425,
#  'TYS_AVL': 85,
#  'TYS_ILM': 360,
#  'TYS_PHF': 425,
#  'TYS_CAK': 378,
#  'TYS_MKE': 535,
#  'TYS_SHV': 608,
#  'TYS_CID': 589,
#  'TYS_ELM': 580,
#  'TYS_SDF': 189,
#  'TYS_IAD': 418,
#  'TYS_HOU': 782,
#  'TYS_MDW': 459,
#  'TYS_PVD': 788,
#  'TYS_ALB': 724,
#  'TYS_FNT': 493,
#  'TYS_ABE': 570,
#  'TYS_EVV': 248,
#  'TYS_FWA': 362,
#  'TYS_DAB': 489,
#  'TYS_MLU': 513,
#  'TYS_VLD': 350,
#  'TYS_AVP': 585,
#  'TYS_GTR': 308,
#  'TYS_EWN': 393,
#  'TYS_JFK': 646,
#  'TYS_BTV': 825,
#  'TYS_GSO': 226,
#  'TYS_OAJ': 365,
#  'TYS_CHO': 344,
#  'TYS_MYR': 322,
#  'TYS_HPN': 663,
#  'TYS_TOL': 398,
#  'TYS_FAY': 293,
#  'TYS_CMI': 374,
#  'TYS_AGS': 205,
#  'TYS_DLH': 871,
#  'TYS_DSM': 653,
#  'TYS_ANC': 3303,
#  'TYS_TRI': 99,
#  'TYS_MGM': 279,
#  'TYS_AEX': 582,
#  'TYS_BOI': 1783,
#  'TYS_GTF': 1614,
#  'TYS_BIS': 1149,
#  'TYS_FSD': 863,
#  'TYS_MSO': 1724,
#  'TYS_GFK': 1074,
#  'TYS_BZN': 1568,
#  'TYS_BIL': 1449,
#  'TYS_RAP': 1155,
#  'TYS_HLN': 1622,
#  'TYS_ACY': 572,
#  'TYS_MLI': 525,
#  'TYS_CWA': 687,
#  'TYS_MBS': 533,
#  'TYS_GRB': 636,
#  'TYS_GNV': 434,
#  'TYS_VPS': 396,
#  'TYS_ECP': 392,
#  'TYS_MLB': 567,
#  'TYS_ABY': 296,
#  'TYS_BQK': 346,
#  'TYS_CRW': 220,
#  'TYS_HNL': 4494,
#  'TYS_MSN': 580,
#  'TYS_SPI': 416,
#  'TYS_FAR': 1012,
#  'TYS_RST': 717,
#  'TYS_EAU': 738,
#  'TYS_COU': 497,
#  'TYS_MHK': 731,
#  'TYS_SUX': 803,
#  'TYS_ALO': 647,
#  'TYS_ELP': 1311,
#  'TYS_COS': 1153,
#  'TYS_HOB': 1117,
#  'TYS_CSG': 234,
#  'TYS_AZO': 451,
#  'TYS_TVC': 621,
#  'TYS_CMX': 817,
#  'TYS_MKG': 521,
#  'TYS_BMI': 420,
#  'TYS_LSE': 676,
#  'TYS_SJU': 1626,
#  'TYS_SMF': 2062,
#  'TYS_DAL': 761,
#  'TYS_EYW': 789,
#  'TYS_SJC': 2093,
#  'TYS_LAN': 481,
#  'TYS_ERI': 478,
#  'TYS_IMT': 723,
#  'TYS_BGM': 615,
#  'TYS_PWM': 904,
#  'TYS_LNK': 772,
#  'TYS_FSM': 584,
#  'TYS_ABQ': 1272,
#  'TYS_UIN': 484,
#  'TYS_CLL': 800,
#  'TYS_MTJ': 1326,
#  'TYS_STT': 1674,
#  'TYS_HDN': 1298,
#  'TYS_EGE': 1276,
#  'TYS_JAC': 1511,
#  'TYS_SWF': 661,
#  'TYS_ITH': 611,
#  'TYS_MHT': 829,
#  'TYS_OAK': 2105,
#  'TYS_FAT': 1979,
#  'TYS_LRD': 1073,
#  'TYS_GUC': 1273,
#  'TYS_ABI': 927,
#  'TYS_SJT': 997,
#  'TYS_BPT': 708,
#  'TYS_DRT': 1079,
#  'TYS_PBG': 823,
#  'TYS_LBF': 971,
#  'TYS_HYS': 864,
#  'TYS_GCC': 1277,
#  'TYS_PUB': 1142,
#  'TYS_LAR': 1228,
#  'TYS_COD': 1444,
#  'TYS_ISN': 1314,
#  'TYS_LGB': 1933,
#  'TYS_RNO': 1961,
#  'TYS_BUR': 1938,
#  'TYS_CKB': 316,
#  'TYS_SHD': 327,
#  'TYS_STX': 1715,
#  'TYS_GJT': 1361,
#  'TYS_ART': 704,
#  'TYS_HVN': 707,
#  'TYS_JLN': 590,
#  'TYS_ROW': 1178,
#  'TYS_SAF': 1237,
#  'TYS_LYH': 284,
#  'TYS_ISP': 682,
#  'TYS_TTN': 585,
#  'TYS_PSP': 1841,
#  'TYS_ONT': 1898,
#  'TYS_LWB': 243,
#  'TYS_DRO': 1320,
#  'TYS_MRY': 2097,
#  'TYS_MMH': 1923,
#  'TYS_LAW': 818,
#  'TYS_TYR': 695,
#  'TYS_TXK': 590,
#  'TYS_BGR': 1009,
#  'TYS_PLN': 674,
#  'TYS_GRI': 851,
#  'TYS_SWO': 732,
#  'TYS_GCK': 935,
#  'TYS_RFD': 518,
#  'TYS_GEG': 1892,
#  'TYS_APN': 640,
#  'TYS_MOT': 1229,
#  'TYS_HTS': 192,
#  'TYS_STC': 852,
#  'TYS_SGU': 1641,
#  'TYS_PIR': 1042,
#  'TYS_MEI': 363,
#  'TYS_SBA': 2017,
#  'TYS_CYS': 1181,
#  'TYS_SPS': 830,
#  'TYS_CIU': 721,
#  'TYS_HIB': 919,
#  'TYS_GGG': 657,
#  'TYS_RHI': 736,
#  'TYS_LCK': 282,
#  'TYS_IDA': 1576,
#  'TYS_CNY': 1426,
#  'TYS_BFM': 429,
#  'TYS_CGI': 324,
#  'TYS_ACK': 839,
#  'TYS_BRD': 900,
#  'TYS_EAR': 881,
#  'TYS_RKS': 1403,
#  'TYS_BFF': 1131,
#  'TYS_JMS': 1077,
#  'TYS_LBE': 396,
#  'TYS_ORH': 786,
#  'TYS_FAI': 3250,
#  'TYS_MVY': 817,
#  'TYS_CPR': 1291,
#  'TYS_PIB': 429,
#  'TYS_ACT': 813,
#  'TYS_PSM': 861,
#  'TYS_BFL': 1959,
#  'TYS_FLG': 1552,
#  'TYS_ABR': 1004,
#  'TYS_BJI': 983,
#  'TYS_BLI': 2135,
#  'TYS_PGV': 370,
#  'TYS_PSC': 1948,
#  'TYS_BLV': 374,
#  'TYS_OGG': 4426,
#  'TYS_MQT': 763,
#  'TYS_BQN': 1577,
#  'TYS_SCK': 2049,
#  'TYS_MFR': 2114,
#  'TYS_RDM': 2030,
#  'TYS_SUN': 1686,
#  'TYS_TWF': 1687,
#  'TYS_HGR': 434,
#  'TYS_LBL': 946,
#  'TYS_EUG': 2133,
#  'TYS_SBP': 2049,
#  'TYS_SFB': 512,
#  'TYS_PGD': 626,
#  'TYS_ATY': 932,
#  'TYS_PIE': 551,
#  'TYS_LWS': 1851,
#  'TYS_PIH': 1595,
#  'TYS_CDC': 1609,
#  'TYS_ACV': 2182,
#  'TYS_VEL': 1418,
#  'TYS_RDD': 2089,
#  'TYS_KOA': 4447,
#  'TYS_LIH': 4549,
#  'TYS_BTM': 1634,
#  'TYS_OTH': 2183,
#  'TYS_KTN': 2600,
#  'TYS_SMX': 2043,
#  'TYS_INL': 1001,
#  'TYS_PVU': 1533,
#  'TYS_JNU': 2749,
#  'TYS_PRC': 1601,
#  'TYS_PAE': 2113,
#  'TYS_SIT': 2761,
#  'TYS_ITO': 4392,
#  'TYS_WYS': 1547,
#  'TYS_HYA': 840,
#  'TYS_DVL': 1140,
#  'TYS_OWB': 220,
#  'TYS_EKO': 1748,
#  'TYS_ADK': 4427,
#  'TYS_BRW': 3513,
#  'TYS_BET': 3700,
#  'TYS_OME': 3768,
#  'TYS_OTZ': 3666,
#  'TYS_ADQ': 3398,
#  'TYS_AKN': 3543,
#  'TYS_SCC': 3317,
#  'TYS_GUM': 7774,
#  'TYS_PPG': 6615,
#  'TYS_CDV': 3148,
#  'TYS_WRG': 2643,
#  'TYS_PSG': 2668,
#  'TYS_DLG': 3605,
#  'TYS_YAK': 2942,
#  'TYS_GST': 2790,
#  'SRQ_TYS': 587,
#  'SRQ_SRQ': 0,
#  'SRQ_DTW': 1025,
#  'SRQ_LGA': 1047,
#  'SRQ_ROA': 701,
#  'SRQ_TPA': 38,
#  'SRQ_RDU': 626,
#  'SRQ_BOS': 1220,
#  'SRQ_MSP': 1344,
#  'SRQ_JAX': 219,
#  'SRQ_IND': 877,
#  'SRQ_BTR': 562,
#  'SRQ_TLH': 233,
#  'SRQ_GSP': 518,
#  'SRQ_DAY': 869,
#  'SRQ_MEM': 686,
#  'SRQ_CMH': 869,
#  'SRQ_SAT': 977,
#  'SRQ_DFW': 942,
#  'SRQ_BWI': 880,
#  'SRQ_CAE': 459,
#  'SRQ_CLE': 968,
#  'SRQ_DEN': 1527,
#  'SRQ_FLL': 173,
#  'SRQ_LAS': 1996,
#  'SRQ_MCI': 1079,
#  'SRQ_MCO': 103,
#  'SRQ_PBI': 159,
#  'SRQ_PHL': 958,
#  'SRQ_PHX': 1797,
#  'SRQ_PNS': 351,
#  'SRQ_RSW': 77,
#  'SRQ_SLC': 1906,
#  'SRQ_STL': 904,
#  'SRQ_TUS': 1729,
#  'SRQ_CLT': 548,
#  'SRQ_DCA': 852,
#  'SRQ_LEX': 744,
#  'SRQ_XNA': 921,
#  'SRQ_GPT': 446,
#  'SRQ_IAH': 795,
#  'SRQ_ORF': 754,
#  'SRQ_PIT': 914,
#  'SRQ_AUS': 940,
#  'SRQ_BDL': 1148,
#  'SRQ_OMA': 1222,
#  'SRQ_SAV': 336,
#  'SRQ_LAX': 2165,
#  'SRQ_PDX': 2519,
#  'SRQ_SAN': 2093,
#  'SRQ_SEA': 2543,
#  'SRQ_SFO': 2404,
#  'SRQ_SNA': 2134,
#  'SRQ_BNA': 649,
#  'SRQ_PIA': 1002,
#  'SRQ_MIA': 177,
#  'SRQ_ATL': 444,
#  'SRQ_SYR': 1143,
#  'SRQ_CVG': 813,
#  'SRQ_ATW': 1211,
#  'SRQ_EWR': 1034,
#  'SRQ_JAN': 564,
#  'SRQ_ROC': 1119,
#  'SRQ_RIC': 761,
#  'SRQ_HSV': 559,
#  'SRQ_ICT': 1115,
#  'SRQ_CHA': 549,
#  'SRQ_BUF': 1094,
#  'SRQ_GRR': 1082,
#  'SRQ_MDT': 943,
#  'SRQ_ASE': 1616,
#  'SRQ_DBQ': 1132,
#  'SRQ_BHM': 493,
#  'SRQ_ORD': 1050,
#  'SRQ_TUL': 989,
#  'SRQ_MSY': 500,
#  'SRQ_CHS': 408,
#  'SRQ_LBB': 1222,
#  'SRQ_MAF': 1218,
#  'SRQ_CRP': 915,
#  'SRQ_MFE': 971,
#  'SRQ_LCH': 672,
#  'SRQ_GRK': 954,
#  'SRQ_OKC': 1042,
#  'SRQ_LFT': 602,
#  'SRQ_LIT': 763,
#  'SRQ_AMA': 1250,
#  'SRQ_MOB': 411,
#  'SRQ_BRO': 922,
#  'SRQ_SGF': 927,
#  'SRQ_SBN': 1010,
#  'SRQ_AVL': 554,
#  'SRQ_ILM': 548,
#  'SRQ_PHF': 759,
#  'SRQ_CAK': 935,
#  'SRQ_MKE': 1115,
#  'SRQ_SHV': 758,
#  'SRQ_CID': 1126,
#  'SRQ_ELM': 1068,
#  'SRQ_SDF': 767,
#  'SRQ_IAD': 849,
#  'SRQ_HOU': 787,
#  'SRQ_MDW': 1036,
#  'SRQ_PVD': 1172,
#  'SRQ_ALB': 1168,
#  'SRQ_FNT': 1077,
#  'SRQ_ABE': 1001,
#  'SRQ_EVV': 789,
#  'SRQ_FWA': 949,
#  'SRQ_DAB': 153,
#  'SRQ_MLU': 667,
#  'SRQ_VLD': 237,
#  'SRQ_AVP': 1037,
#  'SRQ_GTR': 550,
#  'SRQ_EWN': 621,
#  'SRQ_JFK': 1042,
#  'SRQ_BTV': 1289,
#  'SRQ_GSO': 620,
#  'SRQ_OAJ': 590,
#  'SRQ_CHO': 779,
#  'SRQ_MYR': 484,
#  'SRQ_HPN': 1069,
#  'SRQ_TOL': 982,
#  'SRQ_FAY': 567,
#  'SRQ_CMI': 932,
#  'SRQ_AGS': 413,
#  'SRQ_DLH': 1440,
#  'SRQ_DSM': 1160,
#  'SRQ_ANC': 3830,
#  'SRQ_TRI': 627,
#  'SRQ_MGM': 409,
#  'SRQ_AEX': 660,
#  'SRQ_BOI': 2177,
#  'SRQ_GTF': 2081,
#  'SRQ_BIS': 1664,
#  'SRQ_FSD': 1369,
#  'SRQ_MSO': 2173,
#  'SRQ_GFK': 1623,
#  'SRQ_BZN': 2013,
#  'SRQ_BIL': 1906,
#  'SRQ_RAP': 1617,
#  'SRQ_HLN': 2074,
#  'SRQ_ACY': 950,
#  'SRQ_MLI': 1071,
#  'SRQ_CWA': 1263,
#  'SRQ_MBS': 1117,
#  'SRQ_GRB': 1219,
#  'SRQ_GNV': 159,
#  'SRQ_VPS': 320,
#  'SRQ_ECP': 282,
#  'SRQ_MLB': 126,
#  'SRQ_ABY': 301,
#  'SRQ_BQK': 274,
#  'SRQ_CRW': 760,
#  'SRQ_HNL': 4691,
#  'SRQ_MSN': 1152,
#  'SRQ_SPI': 951,
#  'SRQ_FAR': 1555,
#  'SRQ_RST': 1266,
#  'SRQ_EAU': 1303,
#  'SRQ_COU': 965,
#  'SRQ_MHK': 1147,
#  'SRQ_SUX': 1294,
#  'SRQ_ALO': 1183,
#  'SRQ_ELP': 1459,
#  'SRQ_COS': 1497,
#  'SRQ_HOB': 1285,
#  'SRQ_CSG': 380,
#  'SRQ_AZO': 1038,
#  'SRQ_TVC': 1209,
#  'SRQ_CMX': 1403,
#  'SRQ_MKG': 1109,
#  'SRQ_BMI': 974,
#  'SRQ_LSE': 1237,
#  'SRQ_SJU': 1219,
#  'SRQ_SMF': 2370,
#  'SRQ_DAL': 932,
#  'SRQ_EYW': 202,
#  'SRQ_SJC': 2378,
#  'SRQ_LAN': 1068,
#  'SRQ_ERI': 1022,
#  'SRQ_IMT': 1308,
#  'SRQ_BGM': 1088,
#  'SRQ_PWM': 1313,
#  'SRQ_LNK': 1230,
#  'SRQ_FSM': 884,
#  'SRQ_ABQ': 1511,
#  'SRQ_UIN': 997,
#  'SRQ_CLL': 862,
#  'SRQ_MTJ': 1649,
#  'SRQ_STT': 1280,
#  'SRQ_HDN': 1668,
#  'SRQ_EGE': 1630,
#  'SRQ_JAC': 1924,
#  'SRQ_SWF': 1085,
#  'SRQ_ITH': 1096,
#  'SRQ_MHT': 1240,
#  'SRQ_OAK': 2397,
#  'SRQ_FAT': 2253,
#  'SRQ_LRD': 1035,
#  'SRQ_GUC': 1601,
#  'SRQ_ABI': 1081,
#  'SRQ_SJT': 1112,
#  'SRQ_BPT': 716,
#  'SRQ_DRT': 1123,
#  'SRQ_PBG': 1293,
#  'SRQ_LBF': 1397,
#  'SRQ_HYS': 1245,
#  'SRQ_GCC': 1728,
#  'SRQ_PUB': 1473,
#  'SRQ_LAR': 1623,
#  'SRQ_COD': 1879,
#  'SRQ_ISN': 1826,
#  'SRQ_LGB': 2151,
#  'SRQ_RNO': 2282,
#  'SRQ_BUR': 2164,
#  'SRQ_CKB': 832,
#  'SRQ_SHD': 779,
#  'SRQ_STX': 1313,
#  'SRQ_GJT': 1696,
#  'SRQ_ART': 1202,
#  'SRQ_HVN': 1103,
#  'SRQ_JLN': 968,
#  'SRQ_ROW': 1367,
#  'SRQ_SAF': 1493,
#  'SRQ_LYH': 712,
#  'SRQ_ISP': 1070,
#  'SRQ_TTN': 993,
#  'SRQ_PSP': 2056,
#  'SRQ_ONT': 2120,
#  'SRQ_LWB': 733,
#  'SRQ_DRO': 1612,
#  'SRQ_MRY': 2369,
#  'SRQ_MMH': 2213,
#  'SRQ_LAW': 1060,
#  'SRQ_TYR': 841,
#  'SRQ_TXK': 798,
#  'SRQ_BGR': 1421,
#  'SRQ_PLN': 1260,
#  'SRQ_GRI': 1295,
#  'SRQ_SWO': 1044,
#  'SRQ_GCK': 1278,
#  'SRQ_RFD': 1086,
#  'SRQ_GEG': 2340,
#  'SRQ_APN': 1222,
#  'SRQ_MOT': 1755,
#  'SRQ_HTS': 757,
#  'SRQ_STC': 1403,
#  'SRQ_SGU': 1923,
#  'SRQ_PIR': 1529,
#  'SRQ_MEI': 503,
#  'SRQ_SBA': 2249,
#  'SRQ_CYS': 1578,
#  'SRQ_SPS': 1048,
#  'SRQ_CIU': 1306,
#  'SRQ_HIB': 1488,
#  'SRQ_GGG': 804,
#  'SRQ_RHI': 1315,
#  'SRQ_LCK': 858,
#  'SRQ_IDA': 1982,
#  'SRQ_CNY': 1750,
#  'SRQ_BFM': 400,
#  'SRQ_CGI': 792,
#  'SRQ_ACK': 1190,
#  'SRQ_BRD': 1456,
#  'SRQ_EAR': 1312,
#  'SRQ_RKS': 1787,
#  'SRQ_BFF': 1550,
#  'SRQ_JMS': 1607,
#  'SRQ_LBE': 908,
#  'SRQ_ORH': 1190,
#  'SRQ_FAI': 3796,
#  'SRQ_MVY': 1179,
#  'SRQ_CPR': 1713,
#  'SRQ_PIB': 494,
#  'SRQ_ACT': 928,
#  'SRQ_PSM': 1266,
#  'SRQ_BFL': 2208,
#  'SRQ_FLG': 1792,
#  'SRQ_ABR': 1520,
#  'SRQ_BJI': 1541,
#  'SRQ_BLI': 2584,
#  'SRQ_PGV': 644,
#  'SRQ_PSC': 2373,
#  'SRQ_BLV': 877,
#  'SRQ_OGG': 4612,
#  'SRQ_MQT': 1349,
#  'SRQ_BQN': 1156,
#  'SRQ_SCK': 2344,
#  'SRQ_MFR': 2479,
#  'SRQ_RDM': 2424,
#  'SRQ_SUN': 2085,
#  'SRQ_TWF': 2069,
#  'SRQ_HGR': 894,
#  'SRQ_LBL': 1262,
#  'SRQ_EUG': 2522,
#  'SRQ_SBP': 2297,
#  'SRQ_SFB': 124,
#  'SRQ_PGD': 48,
#  'SRQ_ATY': 1452,
#  'SRQ_PIE': 36,
#  'SRQ_LWS': 2283,
#  'SRQ_PIH': 1989,
#  'SRQ_CDC': 1905,
#  'SRQ_ACV': 2524,
#  'SRQ_VEL': 1778,
#  'SRQ_RDD': 2426,
#  'SRQ_KOA': 4619,
#  'SRQ_LIH': 4758,
#  'SRQ_BTM': 2076,
#  'SRQ_OTH': 2561,
#  'SRQ_KTN': 3097,
#  'SRQ_SMX': 2285,
#  'SRQ_INL': 1572,
#  'SRQ_PVU': 1881,
#  'SRQ_JNU': 3265,
#  'SRQ_PRC': 1829,
#  'SRQ_PAE': 2552,
#  'SRQ_SIT': 3268,
#  'SRQ_ITO': 4560,
#  'SRQ_WYS': 1975,
#  'SRQ_HYA': 1205,
#  'SRQ_DVL': 1678,
#  'SRQ_OWB': 763,
#  'SRQ_EKO': 2098,
#  'SRQ_ADK': 4916,
#  'SRQ_BRW': 4084,
#  'SRQ_BET': 4225,
#  'SRQ_OME': 4313,
#  'SRQ_OTZ': 4221,
#  'SRQ_ADQ': 3904,
#  'SRQ_AKN': 4055,
#  'SRQ_SCC': 3885,
#  'SRQ_GUM': 8189,
#  'SRQ_PPG': 6560,
#  'SRQ_CDV': 3672,
#  'SRQ_WRG': 3149,
#  'SRQ_PSG': 3175,
#  'SRQ_DLG': 4120,
#  'SRQ_YAK': 3462,
#  'SRQ_GST': 3306,
#  'DTW_TYS': 444,
#  'DTW_SRQ': 1025,
#  'DTW_DTW': 0,
#  'DTW_LGA': 498,
#  'DTW_ROA': 383,
#  'DTW_TPA': 986,
#  'DTW_RDU': 501,
#  'DTW_BOS': 629,
#  'DTW_MSP': 528,
#  'DTW_JAX': 815,
#  'DTW_IND': 231,
#  'DTW_BTR': 916,
#  'DTW_TLH': 820,
#  'DTW_GSP': 509,
#  'DTW_DAY': 167,
#  'DTW_MEM': 611,
#  'DTW_CMH': 156,
#  'DTW_SAT': 1216,
#  'DTW_DFW': 986,
#  'DTW_BWI': 406,
#  'DTW_CAE': 585,
#  'DTW_CLE': 95,
#  'DTW_DEN': 1120,
#  'DTW_FLL': 1130,
#  'DTW_LAS': 1746,
#  'DTW_MCI': 629,
#  'DTW_MCO': 960,
#  'DTW_PBI': 1089,
#  'DTW_PHL': 452,
#  'DTW_PHX': 1669,
#  'DTW_PNS': 839,
#  'DTW_RSW': 1088,
#  'DTW_SLC': 1478,
#  'DTW_STL': 441,
#  'DTW_TUS': 1663,
#  'DTW_CLT': 500,
#  'DTW_DCA': 404,
#  'DTW_LEX': 297,
#  'DTW_XNA': 715,
#  'DTW_GPT': 876,
#  'DTW_IAH': 1078,
#  'DTW_ORF': 528,
#  'DTW_PIT': 201,
#  'DTW_AUS': 1147,
#  'DTW_BDL': 546,
#  'DTW_OMA': 649,
#  'DTW_SAV': 707,
#  'DTW_LAX': 1975,
#  'DTW_PDX': 1949,
#  'DTW_SAN': 1953,
#  'DTW_SEA': 1922,
#  'DTW_SFO': 2074,
#  'DTW_SNA': 1956,
#  'DTW_BNA': 459,
#  'DTW_PIA': 346,
#  'DTW_MIA': 1148,
#  'DTW_ATL': 597,
#  'DTW_SYR': 372,
#  'DTW_CVG': 231,
#  'DTW_ATW': 296,
#  'DTW_EWR': 485,
#  'DTW_JAN': 777,
#  'DTW_ROC': 293,
#  'DTW_RIC': 455,
#  'DTW_HSV': 556,
#  'DTW_ICT': 810,
#  'DTW_CHA': 507,
#  'DTW_BUF': 238,
#  'DTW_GRR': 120,
#  'DTW_MDT': 368,
#  'DTW_ASE': 1245,
#  'DTW_DBQ': 376,
#  'DTW_BHM': 626,
#  'DTW_ORD': 236,
#  'DTW_TUL': 789,
#  'DTW_MSY': 928,
#  'DTW_CHS': 669,
#  'DTW_LBB': 1165,
#  'DTW_MAF': 1255,
#  'DTW_CRP': 1277,
#  'DTW_MFE': 1394,
#  'DTW_LCH': 1000,
#  'DTW_GRK': 1111,
#  'DTW_OKC': 900,
#  'DTW_LFT': 959,
#  'DTW_LIT': 707,
#  'DTW_AMA': 1099,
#  'DTW_MOB': 842,
#  'DTW_BRO': 1381,
#  'DTW_SGF': 635,
#  'DTW_SBN': 157,
#  'DTW_AVL': 471,
#  'DTW_ILM': 623,
#  'DTW_PHF': 505,
#  'DTW_CAK': 132,
#  'DTW_MKE': 237,
#  'DTW_SHV': 886,
#  'DTW_CID': 430,
#  'DTW_ELM': 329,
#  'DTW_SDF': 307,
#  'DTW_IAD': 383,
#  'DTW_HOU': 1094,
#  'DTW_MDW': 229,
#  'DTW_PVD': 611,
#  'DTW_ALB': 486,
#  'DTW_FNT': 55,
#  'DTW_ABE': 422,
#  'DTW_EVV': 364,
#  'DTW_FWA': 130,
#  'DTW_DAB': 910,
#  'DTW_MLU': 823,
#  'DTW_VLD': 791,
#  'DTW_AVP': 396,
#  'DTW_GTR': 670,
#  'DTW_EWN': 599,
#  'DTW_JFK': 507,
#  'DTW_BTV': 533,
#  'DTW_GSO': 461,
#  'DTW_OAJ': 597,
#  'DTW_CHO': 382,
#  'DTW_MYR': 636,
#  'DTW_HPN': 503,
#  'DTW_TOL': 50,
#  'DTW_FAY': 554,
#  'DTW_CMI': 298,
#  'DTW_AGS': 617,
#  'DTW_DLH': 539,
#  'DTW_DSM': 533,
#  'DTW_ANC': 2978,
#  'DTW_TRI': 400,
#  'DTW_MGM': 706,
#  'DTW_AEX': 908,
#  'DTW_BOI': 1657,
#  'DTW_GTF': 1412,
#  'DTW_BIS': 912,
#  'DTW_FSD': 684,
#  'DTW_MSO': 1537,
#  'DTW_GFK': 781,
#  'DTW_BZN': 1397,
#  'DTW_BIL': 1271,
#  'DTW_RAP': 999,
#  'DTW_HLN': 1436,
#  'DTW_ACY': 496,
#  'DTW_MLI': 374,
#  'DTW_CWA': 362,
#  'DTW_MBS': 97,
#  'DTW_GRB': 287,
#  'DTW_GNV': 868,
#  'DTW_VPS': 830,
#  'DTW_ECP': 832,
#  'DTW_MLB': 987,
#  'DTW_ABY': 740,
#  'DTW_BQK': 764,
#  'DTW_CRW': 281,
#  'DTW_HNL': 4469,
#  'DTW_MSN': 311,
#  'DTW_SPI': 369,
#  'DTW_FAR': 736,
#  'DTW_RST': 476,
#  'DTW_EAU': 446,
#  'DTW_COU': 522,
#  'DTW_MHK': 730,
#  'DTW_SUX': 666,
#  'DTW_ALO': 462,
#  'DTW_ELP': 1454,
#  'DTW_COS': 1143,
#  'DTW_HOB': 1269,
#  'DTW_CSG': 677,
#  'DTW_AZO': 113,
#  'DTW_TVC': 206,
#  'DTW_CMX': 424,
#  'DTW_MKG': 160,
#  'DTW_BMI': 315,
#  'DTW_LSE': 415,
#  'DTW_SJU': 1933,
#  'DTW_SMF': 2008,
#  'DTW_DAL': 982,
#  'DTW_EYW': 1224,
#  'DTW_SJC': 2058,
#  'DTW_LAN': 74,
#  'DTW_ERI': 161,
#  'DTW_IMT': 342,
#  'DTW_BGM': 375,
#  'DTW_PWM': 665,
#  'DTW_LNK': 699,
#  'DTW_FSM': 760,
#  'DTW_ABQ': 1345,
#  'DTW_UIN': 438,
#  'DTW_CLL': 1079,
#  'DTW_MTJ': 1313,
#  'DTW_STT': 1971,
#  'DTW_HDN': 1240,
#  'DTW_EGE': 1239,
#  'DTW_JAC': 1383,
#  'DTW_SWF': 477,
#  'DTW_ITH': 351,
#  'DTW_MHT': 606,
#  'DTW_OAK': 2064,
#  'DTW_FAT': 1960,
#  'DTW_LRD': 1362,
#  'DTW_GUC': 1263,
#  'DTW_ABI': 1122,
#  'DTW_SJT': 1207,
#  'DTW_BPT': 1035,
#  'DTW_DRT': 1322,
#  'DTW_PBG': 521,
#  'DTW_LBF': 896,
#  'DTW_HYS': 867,
#  'DTW_GCC': 1122,
#  'DTW_PUB': 1145,
#  'DTW_LAR': 1150,
#  'DTW_COD': 1294,
#  'DTW_ISN': 1066,
#  'DTW_LGB': 1966,
#  'DTW_RNO': 1898,
#  'DTW_BUR': 1965,
#  'DTW_CKB': 259,
#  'DTW_SHD': 360,
#  'DTW_STX': 2015,
#  'DTW_GJT': 1332,
#  'DTW_ART': 387,
#  'DTW_HVN': 541,
#  'DTW_JLN': 688,
#  'DTW_ROW': 1305,
#  'DTW_SAF': 1301,
#  'DTW_LYH': 403,
#  'DTW_ISP': 538,
#  'DTW_TTN': 462,
#  'DTW_PSP': 1882,
#  'DTW_ONT': 1931,
#  'DTW_LWB': 339,
#  'DTW_DRO': 1340,
#  'DTW_MRY': 2074,
#  'DTW_MMH': 1894,
#  'DTW_LAW': 971,
#  'DTW_TYR': 950,
#  'DTW_TXK': 838,
#  'DTW_BGR': 747,
#  'DTW_PLN': 241,
#  'DTW_GRI': 777,
#  'DTW_SWO': 846,
#  'DTW_GCK': 964,
#  'DTW_RFD': 294,
#  'DTW_GEG': 1699,
#  'DTW_APN': 196,
#  'DTW_MOT': 963,
#  'DTW_HTS': 270,
#  'DTW_STC': 580,
#  'DTW_SGU': 1639,
#  'DTW_PIR': 863,
#  'DTW_MEI': 745,
#  'DTW_SBA': 2034,
#  'DTW_CYS': 1107,
#  'DTW_SPS': 999,
#  'DTW_CIU': 283,
#  'DTW_HIB': 585,
#  'DTW_GGG': 922,
#  'DTW_RHI': 385,
#  'DTW_LCK': 168,
#  'DTW_IDA': 1450,
#  'DTW_CNY': 1403,
#  'DTW_BFM': 843,
#  'DTW_CGI': 479,
#  'DTW_ACK': 686,
#  'DTW_BRD': 605,
#  'DTW_EAR': 816,
#  'DTW_RKS': 1318,
#  'DTW_BFF': 1037,
#  'DTW_JMS': 819,
#  'DTW_LBE': 244,
#  'DTW_ORH': 585,
#  'DTW_FAI': 2898,
#  'DTW_MVY': 656,
#  'DTW_CPR': 1175,
#  'DTW_PIB': 813,
#  'DTW_ACT': 1058,
#  'DTW_PSM': 638,
#  'DTW_BFL': 1963,
#  'DTW_FLG': 1596,
#  'DTW_ABR': 782,
#  'DTW_BJI': 673,
#  'DTW_BLI': 1928,
#  'DTW_PGV': 556,
#  'DTW_PSC': 1777,
#  'DTW_BLV': 426,
#  'DTW_OGG': 4411,
#  'DTW_MQT': 362,
#  'DTW_BQN': 1895,
#  'DTW_SCK': 2009,
#  'DTW_MFR': 2002,
#  'DTW_RDM': 1891,
#  'DTW_SUN': 1561,
#  'DTW_TWF': 1582,
#  'DTW_HGR': 339,
#  'DTW_LBL': 1002,
#  'DTW_EUG': 1994,
#  'DTW_SBP': 2050,
#  'DTW_SFB': 936,
#  'DTW_PGD': 1060,
#  'DTW_ATY': 715,
#  'DTW_PIE': 989,
#  'DTW_LWS': 1677,
#  'DTW_PIH': 1480,
#  'DTW_CDC': 1598,
#  'DTW_ACV': 2088,
#  'DTW_VEL': 1358,
#  'DTW_RDD': 2006,
#  'DTW_KOA': 4440,
#  'DTW_LIH': 4513,
#  'DTW_BTM': 1461,
#  'DTW_OTH': 2054,
#  'DTW_KTN': 2322,
#  'DTW_SMX': 2050,
#  'DTW_INL': 654,
#  'DTW_PVU': 1475,
#  'DTW_JNU': 2443,
#  'DTW_PRC': 1649,
#  'DTW_PAE': 1919,
#  ...}

# %% [markdown]
# ### `LATITUDE` / `LONGITUDE`

# %%
latitude = df.drop_duplicates(subset=['ORIGIN'], keep='first')[['ORIGIN', 'LATITUDE_Origin', 'LONGITUDE_Origin']]
latitude_dict = dict(zip(latitude['ORIGIN'], latitude['LATITUDE_Origin']))
with open("dict_mappers/latitude_dict.pkl", "wb") as f:
    pickle.dump(latitude_dict, f)
latitude_dict
# Out:
# {'TYS': 35.8181,
#  'SRQ': 27.40139000000001,
#  'DTW': 42.2313,
#  'LGA': 40.77944,
#  'ROA': 37.3169,
#  'TPA': 27.96194,
#  'RDU': 35.8923,
#  'BOS': 42.3606,
#  'MSP': 44.8831,
#  'JAX': 30.495,
#  'IND': 39.72517,
#  'BTR': 30.5372,
#  'TLH': 30.39306,
#  'GSP': 34.90611,
#  'DAY': 39.9064,
#  'MEM': 35.0564,
#  'CMH': 39.9907,
#  'SAT': 29.5443,
#  'DFW': 32.8978,
#  'BWI': 39.1733,
#  'CAE': 33.94228,
#  'CLE': 41.4057,
#  'DEN': 39.8328,
#  'FLL': 26.07875,
#  'LAS': 36.0719,
#  'MCI': 39.2972,
#  'MCO': 28.4339,
#  'PBI': 26.6847,
#  'PHL': 39.87327,
#  'PHX': 33.4277,
#  'PNS': 30.47806,
#  'RSW': 26.53611,
#  'SLC': 40.7781,
#  'STL': 38.7525,
#  'TUS': 32.1313,
#  'CLT': 35.2236,
#  'DCA': 38.8472,
#  'LEX': 38.0408,
#  'XNA': 36.28333,
#  'GPT': 30.4119,
#  'IAH': 29.98,
#  'ORF': 36.9033,
#  'PIT': 40.4846,
#  'AUS': 30.3208,
#  'BDL': 41.9375,
#  'OMA': 41.3102,
#  'SAV': 32.13133,
#  'LAX': 33.938,
#  'PDX': 45.5958,
#  'SAN': 32.7336,
#  'SEA': 47.4444,
#  'SFO': 37.6197,
#  'SNA': 33.68,
#  'BNA': 36.11889,
#  'PIA': 40.6675,
#  'MIA': 25.7881,
#  'ATL': 33.6301,
#  'SYR': 43.1111,
#  'CVG': 39.0444,
#  'ATW': 44.26667,
#  'EWR': 40.6825,
#  'JAN': 32.3205,
#  'ROC': 43.11722,
#  'RIC': 37.51151,
#  'HSV': 34.6441,
#  'ICT': 37.6475,
#  'CHA': 35.03362,
#  'BUF': 42.93997,
#  'GRR': 42.8825,
#  'MDT': 40.1962,
#  'ASE': 39.23,
#  'DBQ': 42.39778,
#  'BHM': 33.56556,
#  'ORD': 41.96019,
#  'TUL': 36.1994,
#  'MSY': 29.99691,
#  'CHS': 32.899429999999995,
#  'LBB': 33.6656,
#  'MAF': 31.9475,
#  'CRP': 27.7742,
#  'MFE': 26.18389,
#  'LCH': 30.12472,
#  'GRK': 31.06667,
#  'OKC': 35.3889,
#  'LFT': 30.205,
#  'LIT': 34.7273,
#  'AMA': 35.2295,
#  'MOB': 30.68833,
#  'BRO': 25.9141,
#  'SGF': 37.23985,
#  'SBN': 41.7072,
#  'AVL': 35.4319,
#  'ILM': 34.2675,
#  'PHF': 37.13194,
#  'CAK': 40.9181,
#  'MKE': 42.955,
#  'SHV': 32.4472,
#  'CID': 41.8833,
#  'ELM': 42.15944,
#  'SDF': 38.1811,
#  'IAD': 38.93486,
#  'HOU': 29.63806,
#  'MDW': 41.78611,
#  'PVD': 41.7225,
#  'ALB': 42.74722,
#  'FNT': 42.9666,
#  'ABE': 40.64985,
#  'EVV': 38.0441,
#  'FWA': 40.9705,
#  'DAB': 29.1828,
#  'MLU': 32.5155,
#  'VLD': 30.7825,
#  'AVP': 41.3336,
#  'GTR': 33.45,
#  'EWN': 35.0677,
#  'JFK': 40.63915,
#  'BTV': 44.4683,
#  'GSO': 36.0969,
#  'OAJ': 34.83333,
#  'CHO': 38.1374,
#  'MYR': 33.68333,
#  'HPN': 41.06236,
#  'TOL': 41.5871,
#  'FAY': 34.99139,
#  'CMI': 40.03972,
#  'AGS': 33.3644,
#  'DLH': 46.8369,
#  'DSM': 41.5338,
#  'ANC': 61.169,
#  'TRI': 36.47967,
#  'MGM': 32.2997,
#  'AEX': 31.33472,
#  'BOI': 43.5666,
#  'GTF': 47.4733,
#  'BIS': 46.7825,
#  'FSD': 43.5778,
#  'MSO': 46.9208,
#  'GFK': 47.9428,
#  'BZN': 45.788,
#  'BIL': 45.8069,
#  'RAP': 44.04584000000001,
#  'HLN': 46.6056,
#  'ACY': 39.45202000000001,
#  'MLI': 41.46528,
#  'CWA': 44.78333,
#  'MBS': 43.53306,
#  'GRB': 44.4794,
#  'GNV': 29.6919,
#  'VPS': 30.48333,
#  'ECP': 30.349,
#  'MLB': 28.1011,
#  'ABY': 31.53556,
#  'BQK': 31.25889,
#  'CRW': 38.3794,
#  'HNL': 21.324,
#  'MSN': 43.1405,
#  'SPI': 39.8447,
#  'FAR': 46.9253,
#  'RST': 43.9041,
#  'EAU': 44.8665,
#  'COU': 38.8169,
#  'MHK': 39.1346,
#  'SUX': 42.3913,
#  'ALO': 42.5544,
#  'ELP': 31.81111,
#  'COS': 38.81,
#  'HOB': 32.6933,
#  'CSG': 32.5161,
#  'AZO': 42.23472,
#  'TVC': 44.74083,
#  'CMX': 47.16861,
#  'MKG': 43.17111,
#  'BMI': 40.48333,
#  'LSE': 43.8788,
#  'SJU': 18.4325,
#  'SMF': 38.69556,
#  'DAL': 32.8519,
#  'EYW': 24.5571,
#  'SJC': 37.3591,
#  'LAN': 42.7761,
#  'ERI': 42.0803,
#  'IMT': 45.81833,
#  'BGM': 42.2068,
#  'PWM': 43.64222,
#  'LNK': 40.8508,
#  'FSM': 35.333,
#  'ABQ': 35.0419,
#  'UIN': 39.9369,
#  'CLL': 30.58917000000001,
#  'MTJ': 38.50583,
#  'STT': 18.3363,
#  'HDN': 40.48111,
#  'EGE': 39.65,
#  'JAC': 43.6,
#  'SWF': 41.5,
#  'ITH': 42.48333,
#  'MHT': 42.92963,
#  'OAK': 37.7214,
#  'FAT': 36.78,
#  'LRD': 27.53333,
#  'GUC': 38.53333,
#  'ABI': 32.4105,
#  'SJT': 31.3516,
#  'BPT': 29.95056,
#  'DRT': 29.3784,
#  'PBG': 44.65,
#  'LBF': 41.1213,
#  'HYS': 38.85,
#  'GCC': 44.33944,
#  'PUB': 38.28871,
#  'LAR': 41.3167,
#  'COD': 44.51667,
#  'ISN': 48.1738,
#  'LGB': 33.8116,
#  'RNO': 39.4838,
#  'BUR': 34.20056,
#  'CKB': 39.29556,
#  'SHD': 38.26361,
#  'STX': 17.6997,
#  'GJT': 39.1342,
#  'ART': 43.98867,
#  'HVN': 41.26389,
#  'JLN': 37.15221,
#  'ROW': 33.3075,
#  'SAF': 35.61694,
#  'LYH': 37.32126,
#  'ISP': 40.79388,
#  'TTN': 40.27679000000001,
#  'PSP': 33.8222,
#  'ONT': 34.05611,
#  'LWB': 37.86667,
#  'DRO': 37.14306,
#  'MRY': 36.5881,
#  'MMH': 37.63333,
#  'LAW': 34.5584,
#  'TYR': 32.35417,
#  'TXK': 33.456,
#  'BGR': 44.7978,
#  'PLN': 45.5644,
#  'GRI': 40.9611,
#  'SWO': 36.1624,
#  'GCK': 37.92722,
#  'RFD': 42.1927,
#  'GEG': 47.6216,
#  'APN': 45.0716,
#  'MOT': 48.2552,
#  'HTS': 38.36532,
#  'STC': 45.5433,
#  'SGU': 37.1,
#  'PIR': 44.3813,
#  'MEI': 32.3347,
#  'SBA': 34.4258,
#  'CYS': 41.15778,
#  'SPS': 33.9786,
#  'CIU': 46.25,
#  'HIB': 47.38639000000001,
#  'GGG': 32.38472,
#  'RHI': 45.6314,
#  'LCK': 39.81667,
#  'IDA': 43.519,
#  'CNY': 38.75,
#  'BFM': 30.62639,
#  'CGI': 37.2252,
#  'ACK': 41.25306,
#  'BRD': 46.40472000000001,
#  'EAR': 40.73333,
#  'RKS': 41.59466,
#  'BFF': 41.8705,
#  'JMS': 46.9258,
#  'LBE': 40.28333,
#  'ORH': 42.2706,
#  'FAI': 64.8039,
#  'MVY': 41.39306,
#  'CPR': 42.89779,
#  'PIB': 31.46667,
#  'ACT': 31.618890000000004,
#  'PSM': 43.08333,
#  'BFL': 35.4344,
#  'FLG': 35.1441,
#  'ABR': 45.4433,
#  'BJI': 47.5,
#  'BLI': 48.79389000000001,
#  'PGV': 35.63333,
#  'PSC': 46.26667,
#  'BLV': 38.55,
#  'OGG': 20.89972,
#  'MQT': 46.5313,
#  'BQN': 18.4977,
#  'SCK': 37.8891,
#  'MFR': 42.37505,
#  'RDM': 44.2558,
#  'SUN': 43.5,
#  'TWF': 42.48194,
#  'HGR': 39.7062,
#  'LBL': 37.05,
#  'EUG': 44.1278,
#  'SBP': 35.23722,
#  'SFB': 28.77972,
#  'PGD': 26.91722,
#  'ATY': 44.9047,
#  'PIE': 27.91056,
#  'LWS': 46.3747,
#  'PIH': 42.9202,
#  'CDC': 37.7086,
#  'ACV': 40.97806,
#  'VEL': 40.44278,
#  'RDD': 40.5175,
#  'KOA': 19.73556,
#  'LIH': 21.98389,
#  'BTM': 45.9647,
#  'OTH': 43.41333,
#  'KTN': 55.35,
#  'SMX': 34.8994,
#  'INL': 48.5614,
#  'PVU': 40.21889,
#  'JNU': 58.3566,
#  'PRC': 34.65167,
#  'PAE': 47.90778,
#  'SIT': 57.0481,
#  'ITO': 19.7191,
#  'WYS': 44.68333,
#  'HYA': 41.66861,
#  'DVL': 48.11667,
#  'OWB': 37.75,
#  'EKO': 40.8288,
#  'ADK': 51.88333,
#  'BRW': 71.2834,
#  'BET': 60.785,
#  'OME': 64.5111,
#  'OTZ': 66.8667,
#  'ADQ': 57.7511,
#  'AKN': 58.6829,
#  'SCC': 70.1917,
#  'GUM': 13.48333,
#  'PPG': -14.33056,
#  'CDV': 60.4888,
#  'WRG': 56.4732,
#  'PSG': 56.8055,
#  'DLG': 59.05,
#  'YAK': 59.512,
#  'GST': 58.4111}

# %%
longitude = df.drop_duplicates(subset=['ORIGIN'], keep='first')[['ORIGIN', 'LATITUDE_Origin', 'LONGITUDE_Origin']]
longitude_dict = dict(zip(longitude['ORIGIN'], longitude['LONGITUDE_Origin']))
with open("dict_mappers/longitude_dict.pkl", "wb") as f:
    pickle.dump(longitude_dict, f)
longitude_dict
# Out:
# {'TYS': -83.9858,
#  'SRQ': -82.55861,
#  'DTW': -83.3308,
#  'LGA': -73.88035,
#  'ROA': -79.9741,
#  'TPA': -82.5403,
#  'RDU': -78.7819,
#  'BOS': -71.0097,
#  'MSP': -93.2289,
#  'JAX': -81.6936,
#  'IND': -86.28168000000002,
#  'BTR': -91.1469,
#  'TLH': -84.35333,
#  'GSP': -82.21255,
#  'DAY': -84.2185,
#  'MEM': -89.9865,
#  'CMH': -82.87700000000002,
#  'SAT': -98.4839,
#  'DFW': -97.0189,
#  'BWI': -76.684,
#  'CAE': -81.11803,
#  'CLE': -81.852,
#  'DEN': -104.6575,
#  'FLL': -80.16216999999997,
#  'LAS': -115.1634,
#  'MCI': -94.7306,
#  'MCO': -81.325,
#  'PBI': -80.0994,
#  'PHL': -75.22678,
#  'PHX': -112.0038,
#  'PNS': -87.18694,
#  'RSW': -81.755,
#  'SLC': -111.9694,
#  'STL': -90.3736,
#  'TUS': -110.9552,
#  'CLT': -80.9552,
#  'DCA': -77.03454,
#  'LEX': -84.6058,
#  'XNA': -94.3,
#  'GPT': -89.0808,
#  'IAH': -95.36,
#  'ORF': -76.1922,
#  'PIT': -80.2144,
#  'AUS': -97.7604,
#  'BDL': -72.6819,
#  'OMA': -95.8991,
#  'SAV': -81.20237,
#  'LAX': -118.3888,
#  'PDX': -122.6093,
#  'SAN': -117.1831,
#  'SEA': -122.3138,
#  'SFO': -122.3647,
#  'SNA': -117.86639,
#  'BNA': -86.68916999999998,
#  'PIA': -89.6839,
#  'MIA': -80.3169,
#  'ATL': -84.4418,
#  'SYR': -76.1038,
#  'CVG': -84.6724,
#  'ATW': -88.51666999999998,
#  'EWR': -74.1694,
#  'JAN': -90.0777,
#  'ROC': -77.67541,
#  'RIC': -77.32344,
#  'HSV': -86.7869,
#  'ICT': -97.43,
#  'CHA': -85.20044,
#  'BUF': -78.73615,
#  'GRR': -85.52389000000002,
#  'MDT': -76.7724,
#  'ASE': -106.87056,
#  'DBQ': -90.70361,
#  'BHM': -86.745,
#  'ORD': -87.93162,
#  'TUL': -95.8872,
#  'MSY': -90.27751,
#  'CHS': -80.04075,
#  'LBB': -101.8231,
#  'MAF': -102.2086,
#  'CRP': -97.5122,
#  'MFE': -98.25389,
#  'LCH': -93.22833,
#  'GRK': -97.83333,
#  'OKC': -97.6006,
#  'LFT': -91.9875,
#  'LIT': -92.2389,
#  'AMA': -101.7042,
#  'MOB': -88.24556,
#  'BRO': -97.423,
#  'SGF': -93.39007,
#  'SBN': -86.3163,
#  'AVL': -82.5375,
#  'ILM': -77.8997,
#  'PHF': -76.49306,
#  'CAK': -81.4435,
#  'MKE': -87.9044,
#  'SHV': -93.8244,
#  'CID': -91.7166,
#  'ELM': -76.89194,
#  'SDF': -85.7391,
#  'IAD': -77.44728,
#  'HOU': -95.28194,
#  'MDW': -87.75222,
#  'PVD': -71.4325,
#  'ALB': -73.79912,
#  'FNT': -83.7494,
#  'ABE': -75.44771,
#  'EVV': -87.5205,
#  'FWA': -85.2063,
#  'DAB': -81.0483,
#  'MLU': -92.0405,
#  'VLD': -83.27667,
#  'AVP': -75.7269,
#  'GTR': -88.58333,
#  'EWN': -77.048,
#  'JFK': -73.76401,
#  'BTV': -73.1499,
#  'GSO': -79.9432,
#  'OAJ': -77.61667,
#  'CHO': -78.4552,
#  'MYR': -78.93333,
#  'HPN': -73.70463000000002,
#  'TOL': -83.8055,
#  'FAY': -78.88028,
#  'CMI': -88.27778,
#  'AGS': -81.9633,
#  'DLH': -92.1833,
#  'DSM': -93.653,
#  'ANC': -150.0278,
#  'TRI': -82.39898000000002,
#  'MGM': -86.4075,
#  'AEX': -92.55861,
#  'BOI': -116.2405,
#  'GTF': -111.3822,
#  'BIS': -100.7572,
#  'FSD': -96.7539,
#  'MSO': -114.0925,
#  'GFK': -97.1839,
#  'BZN': -111.1608,
#  'BIL': -108.5422,
#  'RAP': -103.05443,
#  'HLN': -111.9636,
#  'ACY': -74.56699,
#  'MLI': -90.52333,
#  'CWA': -89.66667,
#  'MBS': -84.07972,
#  'GRB': -88.1366,
#  'GNV': -82.2755,
#  'VPS': -86.51666999999998,
#  'ECP': -85.788,
#  'MLB': -80.6439,
#  'ABY': -84.19444,
#  'BQK': -81.46611,
#  'CRW': -81.59,
#  'HNL': -157.9294,
#  'MSN': -89.3452,
#  'SPI': -89.6839,
#  'FAR': -96.8111,
#  'RST': -92.4916,
#  'EAU': -91.4879,
#  'COU': -92.2183,
#  'MHK': -96.6788,
#  'SUX': -96.3791,
#  'ALO': -92.4011,
#  'ELP': -106.37583,
#  'COS': -104.6884,
#  'HOB': -103.2125,
#  'CSG': -84.9422,
#  'AZO': -85.55194,
#  'TVC': -85.5825,
#  'CMX': -88.48889,
#  'MKG': -86.23666999999998,
#  'BMI': -88.95,
#  'LSE': -91.2527,
#  'SJU': -66.0108,
#  'SMF': -121.58972,
#  'DAL': -96.8555,
#  'EYW': -81.7554,
#  'SJC': -121.924,
#  'LAN': -84.5997,
#  'ERI': -80.1824,
#  'IMT': -88.11444,
#  'BGM': -75.98,
#  'PWM': -70.30444,
#  'LNK': -96.7475,
#  'FSM': -94.3625,
#  'ABQ': -106.6155,
#  'UIN': -91.1919,
#  'CLL': -96.36472,
#  'MTJ': -107.89889,
#  'STT': -64.98,
#  'HDN': -107.2175,
#  'EGE': -106.91667,
#  'JAC': -110.73333,
#  'SWF': -74.1,
#  'ITH': -76.46667,
#  'MHT': -71.43566,
#  'OAK': -122.2208,
#  'FAT': -119.7194,
#  'LRD': -99.46667,
#  'GUC': -106.93333,
#  'ABI': -99.6822,
#  'SJT': -100.495,
#  'BPT': -94.02056,
#  'DRT': -100.927,
#  'PBG': -73.46667,
#  'LBF': -100.6694,
#  'HYS': -99.26667,
#  'GCC': -105.54194,
#  'PUB': -104.50569,
#  'LAR': -105.6833,
#  'COD': -109.01667,
#  'ISN': -103.6366,
#  'LGB': -118.1463,
#  'RNO': -119.7711,
#  'BUR': -118.3575,
#  'CKB': -80.22889,
#  'SHD': -78.89639,
#  'STX': -64.8125,
#  'GJT': -108.54,
#  'ART': -76.02623,
#  'HVN': -72.88722,
#  'JLN': -94.49527,
#  'ROW': -104.5083,
#  'SAF': -106.08889,
#  'LYH': -79.20656,
#  'ISP': -73.10189,
#  'TTN': -74.81594,
#  'PSP': -116.5043,
#  'ONT': -117.60028,
#  'LWB': -80.4,
#  'DRO': -107.76028,
#  'MRY': -121.8453,
#  'MMH': -118.85,
#  'LAW': -98.4172,
#  'TYR': -95.4025,
#  'TXK': -93.98776,
#  'BGR': -68.8185,
#  'PLN': -84.7927,
#  'GRI': -98.3136,
#  'SWO': -97.0894,
#  'GCK': -100.72472,
#  'RFD': -89.09299999999998,
#  'GEG': -117.528,
#  'APN': -83.5644,
#  'MOT': -101.2733,
#  'HTS': -82.55485,
#  'STC': -94.0513,
#  'SGU': -113.6,
#  'PIR': -100.2855,
#  'MEI': -88.7442,
#  'SBA': -119.8425,
#  'CYS': -104.80694,
#  'SPS': -98.4928,
#  'CIU': -84.46667,
#  'HIB': -92.83889,
#  'GGG': -94.71167,
#  'RHI': -89.4823,
#  'LCK': -82.93333,
#  'IDA': -112.0639,
#  'CNY': -109.76278,
#  'BFM': -88.06806,
#  'CGI': -89.5705,
#  'ACK': -70.06083000000001,
#  'BRD': -94.13083,
#  'EAR': -99.0,
#  'RKS': -109.05296,
#  'BFF': -103.593,
#  'JMS': -98.6691,
#  'LBE': -79.4,
#  'ORH': -71.8731,
#  'FAI': -147.8761,
#  'MVY': -70.615,
#  'CPR': -106.47371,
#  'PIB': -89.33333,
#  'ACT': -97.22833,
#  'PSM': -70.81667,
#  'BFL': -119.0542,
#  'FLG': -111.6663,
#  'ABR': -98.413,
#  'BJI': -94.93333,
#  'BLI': -122.53722,
#  'PGV': -77.38333,
#  'PSC': -119.11667,
#  'BLV': -89.85,
#  'OGG': -156.42861000000005,
#  'MQT': -87.5491,
#  'BQN': -67.1294,
#  'SCK': -121.2258,
#  'MFR': -122.8771,
#  'RDM': -121.1392,
#  'SUN': -114.3,
#  'TWF': -114.48694,
#  'HGR': -77.7304,
#  'LBL': -100.96667,
#  'EUG': -123.2206,
#  'SBP': -120.64139,
#  'SFB': -81.24361,
#  'PGD': -81.99139,
#  'ATY': -97.1494,
#  'PIE': -82.6875,
#  'LWS': -117.0156,
#  'PIH': -112.5711,
#  'CDC': -113.0944,
#  'ACV': -124.10861,
#  'VEL': -109.51278,
#  'RDD': -122.2986,
#  'KOA': -156.04889,
#  'LIH': -159.34056,
#  'BTM': -112.5006,
#  'OTH': -124.24361,
#  'KTN': -131.65,
#  'SMX': -120.4486,
#  'INL': -93.3981,
#  'PVU': -111.72333,
#  'JNU': -134.564,
#  'PRC': -112.42083,
#  'PAE': -122.28028,
#  'SIT': -135.3647,
#  'ITO': -155.053,
#  'WYS': -111.11667,
#  'HYA': -70.28,
#  'DVL': -98.9,
#  'OWB': -87.16667,
#  'EKO': -115.7886,
#  'ADK': -176.65,
#  'BRW': -156.7815,
#  'BET': -161.8293,
#  'OME': -165.44,
#  'OTZ': -162.6333,
#  'ADQ': -152.4855,
#  'AKN': -156.6563,
#  'SCC': -148.4772,
#  'GUM': 144.8,
#  'PPG': -170.71361000000005,
#  'CDV': -145.4511,
#  'WRG': -132.3874,
#  'PSG': -132.9372,
#  'DLG': -158.5167,
#  'YAK': -139.6712,
#  'GST': -135.7089}

# %% [markdown]
# ### Weather Forecast API

# %% [markdown]
# **Openweather NWP model**
#
# Openweather NWP (numerical weather prediction) allows to calculate weather data for any location. We use proprietary convolutional neural network that collects and processes wide range of data sources to cover any location and consider the local nuances of climate. ML technology allows us to reach resolution about 500 m and very high accuracy between 90% and 100% with inaccuracy about 1%. Amongst data sources we feed to the NWP are 82,000 weather stations spread globally; national meteorological agencies (NOAA, Environment Canada, Met Office, etc.), radars, weather satellites.

# %%
import requests

# Get/Build the url:
coord_API_endpoint = "http://api.openweathermap.org/data/2.5/onecall?"
join_key = "&appid="
API_key = "b51fbb9d87131aabef6d7c2cd42b128e"
units = "&units=imperial"
exclude = "&exclude=current,minutely,daily,alerts"

lat, lon = 33.63, -84.45
lat_lon = "lat=" + str(round(lat, 2))+ "&lon=" + str(round(lon, 2))

url = coord_API_endpoint + lat_lon + exclude + join_key + API_key + units
print(url)

# Instantiate the request:
res = requests.get(url)
# Retrieve the corresponding JSON data:
data = res.json()

data['hourly']
# Out:
# http://api.openweathermap.org/data/2.5/onecall?lat=33.63&lon=-84.45&exclude=current,minutely,daily,alerts&appid=b51fbb9d87131aabef6d7c2cd42b128e&units=imperial
# [{'dt': 1620054000,
#   'temp': 68.88,
#   'feels_like': 69.66,
#   'pressure': 1012,
#   'humidity': 89,
#   'dew_point': 65.52,
#   'uvi': 2.05,
#   'clouds': 92,
#   'visibility': 10000,
#   'wind_speed': 9.98,
#   'wind_deg': 207,
#   'wind_gust': 27.07,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.55}},
#  {'dt': 1620057600,
#   'temp': 68.81,
#   'feels_like': 69.53,
#   'pressure': 1012,
#   'humidity': 88,
#   'dew_point': 65.12,
#   'uvi': 4.69,
#   'clouds': 90,
#   'visibility': 10000,
#   'wind_speed': 10.38,
#   'wind_deg': 213,
#   'wind_gust': 24.87,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.21}},
#  {'dt': 1620061200,
#   'temp': 69.78,
#   'feels_like': 70.56,
#   'pressure': 1012,
#   'humidity': 87,
#   'dew_point': 65.73,
#   'uvi': 5.57,
#   'clouds': 92,
#   'visibility': 10000,
#   'wind_speed': 13.67,
#   'wind_deg': 213,
#   'wind_gust': 24.81,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'pop': 0.8},
#  {'dt': 1620064800,
#   'temp': 71.15,
#   'feels_like': 71.91,
#   'pressure': 1012,
#   'humidity': 84,
#   'dew_point': 66.07,
#   'uvi': 5.67,
#   'clouds': 91,
#   'visibility': 10000,
#   'wind_speed': 11.7,
#   'wind_deg': 210,
#   'wind_gust': 23.31,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.81}},
#  {'dt': 1620068400,
#   'temp': 73.33,
#   'feels_like': 74.21,
#   'pressure': 1011,
#   'humidity': 82,
#   'dew_point': 67.5,
#   'uvi': 7.77,
#   'clouds': 55,
#   'visibility': 10000,
#   'wind_speed': 12.66,
#   'wind_deg': 217,
#   'wind_gust': 22.44,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.98}},
#  {'dt': 1620072000,
#   'temp': 75.11,
#   'feels_like': 76.03,
#   'pressure': 1010,
#   'humidity': 79,
#   'dew_point': 68.16,
#   'uvi': 5.8,
#   'clouds': 68,
#   'visibility': 10000,
#   'wind_speed': 11.59,
#   'wind_deg': 219,
#   'wind_gust': 22.39,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.93}},
#  {'dt': 1620075600,
#   'temp': 77.47,
#   'feels_like': 78.39,
#   'pressure': 1010,
#   'humidity': 74,
#   'dew_point': 68.88,
#   'uvi': 3.56,
#   'clouds': 71,
#   'visibility': 10000,
#   'wind_speed': 11.34,
#   'wind_deg': 221,
#   'wind_gust': 22.55,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.39}},
#  {'dt': 1620079200,
#   'temp': 76.69,
#   'feels_like': 77.59,
#   'pressure': 1010,
#   'humidity': 75,
#   'dew_point': 68.65,
#   'uvi': 1.66,
#   'clouds': 79,
#   'visibility': 10000,
#   'wind_speed': 10.45,
#   'wind_deg': 225,
#   'wind_gust': 22.48,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.23}},
#  {'dt': 1620082800,
#   'temp': 75.4,
#   'feels_like': 76.26,
#   'pressure': 1010,
#   'humidity': 77,
#   'dew_point': 68.2,
#   'uvi': 0.53,
#   'clouds': 83,
#   'visibility': 10000,
#   'wind_speed': 9.8,
#   'wind_deg': 221,
#   'wind_gust': 23.85,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.15}},
#  {'dt': 1620086400,
#   'temp': 74.01,
#   'feels_like': 74.82,
#   'pressure': 1010,
#   'humidity': 79,
#   'dew_point': 67.46,
#   'uvi': 0,
#   'clouds': 85,
#   'visibility': 10000,
#   'wind_speed': 8.97,
#   'wind_deg': 222,
#   'wind_gust': 25.61,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'pop': 0.8},
#  {'dt': 1620090000,
#   'temp': 72.73,
#   'feels_like': 73.47,
#   'pressure': 1011,
#   'humidity': 80,
#   'dew_point': 66.7,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 6.85,
#   'wind_deg': 227,
#   'wind_gust': 26.08,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'pop': 0.11},
#  {'dt': 1620093600,
#   'temp': 71.1,
#   'feels_like': 71.91,
#   'pressure': 1012,
#   'humidity': 85,
#   'dew_point': 66.78,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 5.59,
#   'wind_deg': 221,
#   'wind_gust': 24,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'pop': 0.12},
#  {'dt': 1620097200,
#   'temp': 69.8,
#   'feels_like': 70.66,
#   'pressure': 1012,
#   'humidity': 89,
#   'dew_point': 66.79,
#   'uvi': 0,
#   'clouds': 97,
#   'visibility': 10000,
#   'wind_speed': 5.12,
#   'wind_deg': 209,
#   'wind_gust': 23.49,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'pop': 0.12},
#  {'dt': 1620100800,
#   'temp': 69.28,
#   'feels_like': 70.18,
#   'pressure': 1012,
#   'humidity': 91,
#   'dew_point': 66.72,
#   'uvi': 0,
#   'clouds': 90,
#   'visibility': 10000,
#   'wind_speed': 5.77,
#   'wind_deg': 208,
#   'wind_gust': 25.46,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'pop': 0.1},
#  {'dt': 1620104400,
#   'temp': 69.08,
#   'feels_like': 69.93,
#   'pressure': 1012,
#   'humidity': 90,
#   'dew_point': 66.56,
#   'uvi': 0,
#   'clouds': 74,
#   'visibility': 10000,
#   'wind_speed': 7.11,
#   'wind_deg': 208,
#   'wind_gust': 25.81,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'pop': 0.1},
#  {'dt': 1620108000,
#   'temp': 68.45,
#   'feels_like': 69.31,
#   'pressure': 1012,
#   'humidity': 92,
#   'dew_point': 66.22,
#   'uvi': 0,
#   'clouds': 63,
#   'visibility': 10000,
#   'wind_speed': 7.14,
#   'wind_deg': 207,
#   'wind_gust': 25.75,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'pop': 0.1},
#  {'dt': 1620111600,
#   'temp': 67.75,
#   'feels_like': 68.59,
#   'pressure': 1011,
#   'humidity': 93,
#   'dew_point': 66.04,
#   'uvi': 0,
#   'clouds': 3,
#   'visibility': 10000,
#   'wind_speed': 6.89,
#   'wind_deg': 208,
#   'wind_gust': 26.19,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'pop': 0},
#  {'dt': 1620115200,
#   'temp': 67.39,
#   'feels_like': 68.25,
#   'pressure': 1011,
#   'humidity': 94,
#   'dew_point': 65.88,
#   'uvi': 0,
#   'clouds': 3,
#   'visibility': 10000,
#   'wind_speed': 6.93,
#   'wind_deg': 207,
#   'wind_gust': 26.51,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'pop': 0},
#  {'dt': 1620118800,
#   'temp': 67.01,
#   'feels_like': 67.87,
#   'pressure': 1011,
#   'humidity': 95,
#   'dew_point': 66,
#   'uvi': 0,
#   'clouds': 4,
#   'visibility': 10000,
#   'wind_speed': 6.49,
#   'wind_deg': 207,
#   'wind_gust': 26.22,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'pop': 0},
#  {'dt': 1620122400,
#   'temp': 66.7,
#   'feels_like': 67.64,
#   'pressure': 1011,
#   'humidity': 97,
#   'dew_point': 66.09,
#   'uvi': 0,
#   'clouds': 9,
#   'visibility': 10000,
#   'wind_speed': 6.38,
#   'wind_deg': 202,
#   'wind_gust': 26.26,
#   'weather': [{'id': 800,
#     'main': 'Clear',
#     'description': 'clear sky',
#     'icon': '01n'}],
#   'pop': 0.15},
#  {'dt': 1620126000,
#   'temp': 66.56,
#   'feels_like': 67.51,
#   'pressure': 1012,
#   'humidity': 98,
#   'dew_point': 66.27,
#   'uvi': 0,
#   'clouds': 16,
#   'visibility': 10000,
#   'wind_speed': 5.97,
#   'wind_deg': 201,
#   'wind_gust': 25.75,
#   'weather': [{'id': 801,
#     'main': 'Clouds',
#     'description': 'few clouds',
#     'icon': '02d'}],
#   'pop': 0.19},
#  {'dt': 1620129600,
#   'temp': 68.52,
#   'feels_like': 69.49,
#   'pressure': 1013,
#   'humidity': 94,
#   'dew_point': 67.05,
#   'uvi': 0.25,
#   'clouds': 24,
#   'visibility': 10000,
#   'wind_speed': 6.58,
#   'wind_deg': 206,
#   'wind_gust': 24.32,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 0.38,
#   'rain': {'1h': 0.22}},
#  {'dt': 1620133200,
#   'temp': 70.07,
#   'feels_like': 71.1,
#   'pressure': 1013,
#   'humidity': 92,
#   'dew_point': 67.96,
#   'uvi': 0.78,
#   'clouds': 95,
#   'visibility': 10000,
#   'wind_speed': 8.61,
#   'wind_deg': 212,
#   'wind_gust': 23.49,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 0.71,
#   'rain': {'1h': 0.99}},
#  {'dt': 1620136800,
#   'temp': 72.37,
#   'feels_like': 73.45,
#   'pressure': 1013,
#   'humidity': 88,
#   'dew_point': 68.74,
#   'uvi': 1.81,
#   'clouds': 96,
#   'visibility': 10000,
#   'wind_speed': 9.35,
#   'wind_deg': 214,
#   'wind_gust': 24,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 0.75,
#   'rain': {'1h': 0.17}},
#  {'dt': 1620140400,
#   'temp': 72.9,
#   'feels_like': 73.98,
#   'pressure': 1013,
#   'humidity': 87,
#   'dew_point': 68.99,
#   'uvi': 3.12,
#   'clouds': 96,
#   'visibility': 8015,
#   'wind_speed': 8.23,
#   'wind_deg': 216,
#   'wind_gust': 22.75,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 0.91,
#   'rain': {'1h': 0.63}},
#  {'dt': 1620144000,
#   'temp': 70.36,
#   'feels_like': 71.46,
#   'pressure': 1013,
#   'humidity': 93,
#   'dew_point': 68.54,
#   'uvi': 5.83,
#   'clouds': 96,
#   'visibility': 10000,
#   'wind_speed': 10.76,
#   'wind_deg': 206,
#   'wind_gust': 25.57,
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'}],
#   'pop': 0.95,
#   'rain': {'1h': 4.44}},
#  {'dt': 1620147600,
#   'temp': 72.81,
#   'feels_like': 73.87,
#   'pressure': 1012,
#   'humidity': 87,
#   'dew_point': 68.97,
#   'uvi': 6.91,
#   'clouds': 91,
#   'visibility': 10000,
#   'wind_speed': 9.95,
#   'wind_deg': 204,
#   'wind_gust': 21.61,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.76}},
#  {'dt': 1620151200,
#   'temp': 76.41,
#   'feels_like': 77.56,
#   'pressure': 1011,
#   'humidity': 81,
#   'dew_point': 70.39,
#   'uvi': 7.05,
#   'clouds': 87,
#   'visibility': 10000,
#   'wind_speed': 12.1,
#   'wind_deg': 215,
#   'wind_gust': 21.16,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.76}},
#  {'dt': 1620154800,
#   'temp': 76.82,
#   'feels_like': 78.06,
#   'pressure': 1011,
#   'humidity': 82,
#   'dew_point': 71.51,
#   'uvi': 7.92,
#   'clouds': 54,
#   'visibility': 7620,
#   'wind_speed': 12.01,
#   'wind_deg': 219,
#   'wind_gust': 21.27,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 1.11}},
#  {'dt': 1620158400,
#   'temp': 77.2,
#   'feels_like': 78.48,
#   'pressure': 1011,
#   'humidity': 82,
#   'dew_point': 71.74,
#   'uvi': 5.92,
#   'clouds': 70,
#   'visibility': 10000,
#   'wind_speed': 10.56,
#   'wind_deg': 219,
#   'wind_gust': 21.59,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.97}},
#  {'dt': 1620162000,
#   'temp': 77.77,
#   'feels_like': 78.93,
#   'pressure': 1010,
#   'humidity': 78,
#   'dew_point': 70.68,
#   'uvi': 3.64,
#   'clouds': 80,
#   'visibility': 10000,
#   'wind_speed': 9.57,
#   'wind_deg': 225,
#   'wind_gust': 18.9,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.69}},
#  {'dt': 1620165600,
#   'temp': 75.76,
#   'feels_like': 76.89,
#   'pressure': 1010,
#   'humidity': 82,
#   'dew_point': 70.12,
#   'uvi': 1.62,
#   'clouds': 85,
#   'visibility': 10000,
#   'wind_speed': 9.53,
#   'wind_deg': 229,
#   'wind_gust': 20.36,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 0.79}},
#  {'dt': 1620169200,
#   'temp': 66.97,
#   'feels_like': 67.75,
#   'pressure': 1012,
#   'humidity': 93,
#   'dew_point': 65.28,
#   'uvi': 0.52,
#   'clouds': 88,
#   'visibility': 7340,
#   'wind_speed': 17,
#   'wind_deg': 231,
#   'wind_gust': 32.32,
#   'weather': [{'id': 502,
#     'main': 'Rain',
#     'description': 'heavy intensity rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 5.34}},
#  {'dt': 1620172800,
#   'temp': 63.82,
#   'feels_like': 64.18,
#   'pressure': 1014,
#   'humidity': 91,
#   'dew_point': 61.41,
#   'uvi': 0,
#   'clouds': 90,
#   'visibility': 10000,
#   'wind_speed': 9.78,
#   'wind_deg': 255,
#   'wind_gust': 28.41,
#   'weather': [{'id': 501,
#     'main': 'Rain',
#     'description': 'moderate rain',
#     'icon': '10d'}],
#   'pop': 1,
#   'rain': {'1h': 3.3}},
#  {'dt': 1620176400,
#   'temp': 63.43,
#   'feels_like': 63.79,
#   'pressure': 1013,
#   'humidity': 92,
#   'dew_point': 61.38,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 4,
#   'wind_deg': 197,
#   'wind_gust': 6.78,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'pop': 0.7,
#   'rain': {'1h': 0.12}},
#  {'dt': 1620180000,
#   'temp': 63.18,
#   'feels_like': 63.52,
#   'pressure': 1014,
#   'humidity': 92,
#   'dew_point': 61.12,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 9.42,
#   'wind_deg': 201,
#   'wind_gust': 27.4,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'pop': 0.78,
#   'rain': {'1h': 0.21}},
#  {'dt': 1620183600,
#   'temp': 63.07,
#   'feels_like': 63.45,
#   'pressure': 1013,
#   'humidity': 93,
#   'dew_point': 61.52,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 8.32,
#   'wind_deg': 231,
#   'wind_gust': 29.93,
#   'weather': [{'id': 500,
#     'main': 'Rain',
#     'description': 'light rain',
#     'icon': '10n'}],
#   'pop': 0.74,
#   'rain': {'1h': 0.19}},
#  {'dt': 1620187200,
#   'temp': 63.32,
#   'feels_like': 63.77,
#   'pressure': 1014,
#   'humidity': 94,
#   'dew_point': 61.77,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 10.18,
#   'wind_deg': 221,
#   'wind_gust': 28.57,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'pop': 0.72},
#  {'dt': 1620190800,
#   'temp': 63.21,
#   'feels_like': 63.61,
#   'pressure': 1014,
#   'humidity': 93,
#   'dew_point': 61.63,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 9.17,
#   'wind_deg': 238,
#   'wind_gust': 23.4,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'pop': 0.68},
#  {'dt': 1620194400,
#   'temp': 62.58,
#   'feels_like': 62.96,
#   'pressure': 1013,
#   'humidity': 94,
#   'dew_point': 60.98,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 8.16,
#   'wind_deg': 245,
#   'wind_gust': 23.87,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'pop': 0.68},
#  {'dt': 1620198000,
#   'temp': 61.88,
#   'feels_like': 62.19,
#   'pressure': 1013,
#   'humidity': 94,
#   'dew_point': 60.48,
#   'uvi': 0,
#   'clouds': 100,
#   'visibility': 10000,
#   'wind_speed': 8.28,
#   'wind_deg': 256,
#   'wind_gust': 24.65,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1620201600,
#   'temp': 61.81,
#   'feels_like': 62.01,
#   'pressure': 1013,
#   'humidity': 92,
#   'dew_point': 59.77,
#   'uvi': 0,
#   'clouds': 90,
#   'visibility': 10000,
#   'wind_speed': 7.52,
#   'wind_deg': 275,
#   'wind_gust': 26.37,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1620205200,
#   'temp': 61,
#   'feels_like': 61.16,
#   'pressure': 1014,
#   'humidity': 93,
#   'dew_point': 59.25,
#   'uvi': 0,
#   'clouds': 76,
#   'visibility': 10000,
#   'wind_speed': 6.76,
#   'wind_deg': 275,
#   'wind_gust': 25.5,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1620208800,
#   'temp': 60.31,
#   'feels_like': 60.51,
#   'pressure': 1014,
#   'humidity': 95,
#   'dew_point': 59.04,
#   'uvi': 0,
#   'clouds': 61,
#   'visibility': 10000,
#   'wind_speed': 5.95,
#   'wind_deg': 271,
#   'wind_gust': 22.97,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04n'}],
#   'pop': 0},
#  {'dt': 1620212400,
#   'temp': 59.85,
#   'feels_like': 60.04,
#   'pressure': 1014,
#   'humidity': 96,
#   'dew_point': 59.07,
#   'uvi': 0,
#   'clouds': 54,
#   'visibility': 10000,
#   'wind_speed': 5.84,
#   'wind_deg': 262,
#   'wind_gust': 21.52,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1620216000,
#   'temp': 61.77,
#   'feels_like': 61.93,
#   'pressure': 1015,
#   'humidity': 91,
#   'dew_point': 59.58,
#   'uvi': 0.21,
#   'clouds': 56,
#   'visibility': 10000,
#   'wind_speed': 7.4,
#   'wind_deg': 270,
#   'wind_gust': 19.91,
#   'weather': [{'id': 803,
#     'main': 'Clouds',
#     'description': 'broken clouds',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1620219600,
#   'temp': 62.76,
#   'feels_like': 62.92,
#   'pressure': 1016,
#   'humidity': 89,
#   'dew_point': 59.88,
#   'uvi': 0.6,
#   'clouds': 98,
#   'visibility': 10000,
#   'wind_speed': 7.54,
#   'wind_deg': 283,
#   'wind_gust': 18.52,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'pop': 0},
#  {'dt': 1620223200,
#   'temp': 63.79,
#   'feels_like': 63.81,
#   'pressure': 1017,
#   'humidity': 84,
#   'dew_point': 59.04,
#   'uvi': 1.36,
#   'clouds': 99,
#   'visibility': 10000,
#   'wind_speed': 9.01,
#   'wind_deg': 278,
#   'wind_gust': 18.41,
#   'weather': [{'id': 804,
#     'main': 'Clouds',
#     'description': 'overcast clouds',
#     'icon': '04d'}],
#   'pop': 0}]

# %%
import requests

# Get/Build the url:
coord_API_endpoint = "http://api.openweathermap.org/data/2.5/onecall?"
join_key = "&appid="
API_key = "b51fbb9d87131aabef6d7c2cd42b128e"
units = "&units=imperial"
exclude = "&exclude=current,minutely,daily,alerts"

lat, lon = 33.63, -84.45
lat_lon = "lat=" + str(round(lat, 2))+ "&lon=" + str(round(lon, 2))

url = coord_API_endpoint + lat_lon + exclude + join_key + API_key + units


forecast_json_data = requests.get(url).json()
df_predictions = pd.DataFrame()


# Creating empty lists
days = []
hours = []
pressures = []
temperatures = []
precipitations = []
relHumidities = []
skyConditions = []
visibilities = []
windGusts = []
winds = []


# Loop Through the JSON
for num_forecasts in forecast_json_data['hourly']: # Hourly forecast for next 48 hours
    days.append(datetime.datetime.fromtimestamp(num_forecasts['dt']).strftime('%Y-%m-%d'))
    hours.append(int(datetime.datetime.fromtimestamp(num_forecasts['dt']).strftime('%H')))
    pressures.append(round(num_forecasts['pressure'] * 0.029529983071445, 2)) # hPa to inHg
    temperatures.append(int(round(num_forecasts['temp'], 0))) # imperial: Fahrenheit
    try: # "Where available"
        precipitations.append(round(num_forecasts['rain']['1h'] * 0.03937007874015748, 2)) # mm to in
    except KeyError:
        precipitations.append(0)
    relHumidities.append(num_forecasts['humidity']) # Humidity, %
    skyConditions.append(num_forecasts['clouds']) # Cloudiness, %
    visibilities.append(int(round(num_forecasts['visibility'] * 0.0006213712, 0))) # m to mi
    try: # "Where available"
        windGusts.append(int(round(num_forecasts['wind_gust'] * 0.8689762, 0))) # mi/h to kt
    except KeyError:
        windGusts.append(0)
    winds.append(int(round(num_forecasts['wind_speed'] * 0.8689762, 0))) # mi/h to kt

# Put data into a dataframe

def skycond(x):
    if x == 0:
        return 'CLR'
    elif x < 2/8 * 100:
        return 'FEW'
    elif x < 4/8 * 100:
        return 'SCT'
    elif x < 7/8 * 100:
        return 'BKN'
    elif x <= 8/8 * 100:
        return 'OVC'

skyConditions = list(map(skycond, skyConditions))

df_predictions['day'] = days
df_predictions['hour'] = [str(hour) for hour in hours]
df_predictions['pressure_inHg'] = pressures
df_predictions['temperature_F'] = temperatures
df_predictions['precipitation_in'] = precipitations
df_predictions['relHumidity_%'] = relHumidities
df_predictions['skyCondition'] = skyConditions
df_predictions['visibility_mi'] = visibilities
df_predictions['windGust_kt'] = windGusts
df_predictions['wind_kt'] = winds

df_predictions
# Out:
#            day hour  pressure_inHg  temperature_F  precipitation_in  \
# 0   2021-05-03   19          29.85             72              0.05
# 1   2021-05-03   20          29.85             71              0.00
# 2   2021-05-03   21          29.85             72              0.00
# 3   2021-05-03   22          29.85             73              0.00
# 4   2021-05-03   23          29.83             75              0.02
# 5   2021-05-04    0          29.83             76              0.01
# 6   2021-05-04    1          29.83             75              0.01
# 7   2021-05-04    2          29.83             74              0.00
# 8   2021-05-04    3          29.85             73              0.00
# 9   2021-05-04    4          29.88             71              0.00
# 10  2021-05-04    5          29.88             70              0.00
# 11  2021-05-04    6          29.88             69              0.00
# 12  2021-05-04    7          29.88             69              0.00
# 13  2021-05-04    8          29.88             68              0.00
# 14  2021-05-04    9          29.85             68              0.00
# 15  2021-05-04   10          29.85             67              0.00
# 16  2021-05-04   11          29.85             67              0.00
# 17  2021-05-04   12          29.85             67              0.00
# 18  2021-05-04   13          29.88             67              0.00
# 19  2021-05-04   14          29.91             69              0.01
# 20  2021-05-04   15          29.91             70              0.04
# 21  2021-05-04   16          29.91             72              0.01
# 22  2021-05-04   17          29.91             73              0.02
# 23  2021-05-04   18          29.91             70              0.17
# 24  2021-05-04   19          29.88             73              0.03
# 25  2021-05-04   20          29.85             76              0.03
# 26  2021-05-04   21          29.85             77              0.04
# 27  2021-05-04   22          29.85             77              0.04
# 28  2021-05-04   23          29.83             78              0.03
# 29  2021-05-05    0          29.83             76              0.03
# 30  2021-05-05    1          29.88             67              0.21
# 31  2021-05-05    2          29.94             64              0.13
# 32  2021-05-05    3          29.91             63              0.00
# 33  2021-05-05    4          29.94             63              0.01
# 34  2021-05-05    5          29.91             63              0.01
# 35  2021-05-05    6          29.94             63              0.00
# 36  2021-05-05    7          29.94             63              0.00
# 37  2021-05-05    8          29.91             63              0.00
# 38  2021-05-05    9          29.91             62              0.00
# 39  2021-05-05   10          29.91             62              0.00
# 40  2021-05-05   11          29.94             61              0.00
# 41  2021-05-05   12          29.94             60              0.00
# 42  2021-05-05   13          29.94             60              0.00
# 43  2021-05-05   14          29.97             62              0.00
# 44  2021-05-05   15          30.00             63              0.00
# 45  2021-05-05   16          30.03             64              0.00
# 46  2021-05-05   17          30.03             65              0.00
# 47  2021-05-05   18          30.03             67              0.00
#
#     relHumidity_% skyCondition  visibility_mi  windGust_kt  wind_kt
# 0              87          OVC              6           22       12
# 1              88          OVC              6           20       10
# 2              86          BKN              6           19       11
# 3              83          BKN              6           19       10
# 4              79          BKN              6           20       10
# 5              77          BKN              6           20        9
# 6              77          BKN              6           21        9
# 7              79          BKN              6           22        8
# 8              80          OVC              6           23        6
# 9              85          OVC              6           21        5
# 10             89          OVC              6           20        4
# 11             91          OVC              6           22        5
# 12             90          BKN              6           22        6
# 13             92          BKN              6           22        6
# 14             93          FEW              6           23        6
# 15             94          FEW              6           23        6
# 16             95          FEW              6           23        6
# 17             97          FEW              6           23        6
# 18             98          FEW              6           22        5
# 19             94          FEW              6           21        6
# 20             92          OVC              6           20        7
# 21             88          OVC              6           21        8
# 22             87          OVC              5           20        7
# 23             93          OVC              6           22        9
# 24             87          OVC              6           19        9
# 25             81          BKN              6           18       11
# 26             82          BKN              5           18       10
# 27             82          BKN              6           19        9
# 28             78          BKN              6           16        8
# 29             82          BKN              6           18        8
# 30             93          OVC              5           28       15
# 31             91          OVC              6           25        8
# 32             92          OVC              6            6        3
# 33             92          OVC              6           24        8
# 34             93          OVC              6           26        7
# 35             94          OVC              6           25        9
# 36             93          OVC              6           20        8
# 37             94          OVC              6           21        7
# 38             94          OVC              6           21        7
# 39             92          OVC              6           23        7
# 40             93          BKN              6           22        6
# 41             95          BKN              6           20        5
# 42             96          BKN              6           19        5
# 43             91          BKN              6           17        6
# 44             89          OVC              6           16        7
# 45             84          OVC              6           16        8
# 46             80          OVC              6           16        8
# 47             71          OVC              6           14        9

# %%
def weather_forecast(lat=33.63, lon=-84.45):
    
    # Get/Build the url:
    coord_API_endpoint = "http://api.openweathermap.org/data/2.5/onecall?"
    join_key = "&appid="
    API_key = "b51fbb9d87131aabef6d7c2cd42b128e"
    units = "&units=imperial"
    exclude = "&exclude=current,minutely,daily,alerts"

    lat_lon = "lat=" + str(round(lat, 2))+ "&lon=" + str(round(lon, 2))

    url = coord_API_endpoint + lat_lon + exclude + join_key + API_key + units

    forecast_json_data = requests.get(url).json()
    df_predictions = pd.DataFrame()

    # Creating empty lists
    days = []
    hours = []
    pressures = []
    temperatures = []
    precipitations = []
    relHumidities = []
    skyConditions = []
    visibilities = []
    windGusts = []
    winds = []

    # Loop Through the JSON
    for num_forecasts in forecast_json_data['hourly']: # Hourly forecast for next 48 hours
        days.append(datetime.datetime.fromtimestamp(num_forecasts['dt']).strftime('%Y-%m-%d'))
        hours.append(int(datetime.datetime.fromtimestamp(num_forecasts['dt']).strftime('%H')))
        pressures.append(round(num_forecasts['pressure'] * 0.029529983071445, 2)) # hPa to inHg
        temperatures.append(int(round(num_forecasts['temp'], 0))) # imperial: Fahrenheit
        try: # "Where available"
            precipitations.append(round(num_forecasts['rain']['1h'] * 0.03937007874015748, 2)) # mm to in
        except KeyError:
            precipitations.append(0)
        relHumidities.append(num_forecasts['humidity']) # Humidity, %
        skyConditions.append(num_forecasts['clouds']) # Cloudiness, %
        visibilities.append(int(round(num_forecasts['visibility'] * 0.0006213712, 0))) # m to mi
        try: # "Where available"
            windGusts.append(int(round(num_forecasts['wind_gust'] * 0.8689762, 0))) # mi/h to kt
        except KeyError:
            windGusts.append(0)
        winds.append(int(round(num_forecasts['wind_speed'] * 0.8689762, 0))) # mi/h to kt

    # Put data into a dataframe

    def skycond(x):
        if x == 0:
            return 'CLR'
        elif x < 2/8 * 100:
            return 'FEW'
        elif x < 4/8 * 100:
            return 'SCT'
        elif x < 7/8 * 100:
            return 'BKN'
        elif x <= 8/8 * 100:
            return 'OVC'

    skyConditions = list(map(skycond, skyConditions))

    df_predictions['day'] = days
    df_predictions['hour'] = [str(hour) for hour in hours]
    df_predictions['pressure_inHg'] = pressures
    df_predictions['temperature_F'] = temperatures
    df_predictions['precipitation_in'] = precipitations
    df_predictions['relHumidity_%'] = relHumidities
    df_predictions['skyCondition'] = skyConditions
    df_predictions['visibility_mi'] = visibilities
    df_predictions['windGust_kt'] = windGusts
    df_predictions['wind_kt'] = winds
    
    return df_predictions

# %%
weather_forecast(lat=33.63, lon=-84.45)
# Out:
#            day hour  pressure_inHg  temperature_F  precipitation_in  \
# 0   2021-05-03   19          29.85             72              0.05
# 1   2021-05-03   20          29.85             71              0.00
# 2   2021-05-03   21          29.85             72              0.00
# 3   2021-05-03   22          29.85             73              0.00
# 4   2021-05-03   23          29.83             75              0.02
# 5   2021-05-04    0          29.83             76              0.01
# 6   2021-05-04    1          29.83             75              0.01
# 7   2021-05-04    2          29.83             74              0.00
# 8   2021-05-04    3          29.85             73              0.00
# 9   2021-05-04    4          29.88             71              0.00
# 10  2021-05-04    5          29.88             70              0.00
# 11  2021-05-04    6          29.88             69              0.00
# 12  2021-05-04    7          29.88             69              0.00
# 13  2021-05-04    8          29.88             68              0.00
# 14  2021-05-04    9          29.85             68              0.00
# 15  2021-05-04   10          29.85             67              0.00
# 16  2021-05-04   11          29.85             67              0.00
# 17  2021-05-04   12          29.85             67              0.00
# 18  2021-05-04   13          29.88             67              0.00
# 19  2021-05-04   14          29.91             69              0.01
# 20  2021-05-04   15          29.91             70              0.04
# 21  2021-05-04   16          29.91             72              0.01
# 22  2021-05-04   17          29.91             73              0.02
# 23  2021-05-04   18          29.91             70              0.17
# 24  2021-05-04   19          29.88             73              0.03
# 25  2021-05-04   20          29.85             76              0.03
# 26  2021-05-04   21          29.85             77              0.04
# 27  2021-05-04   22          29.85             77              0.04
# 28  2021-05-04   23          29.83             78              0.03
# 29  2021-05-05    0          29.83             76              0.03
# 30  2021-05-05    1          29.88             67              0.21
# 31  2021-05-05    2          29.94             64              0.13
# 32  2021-05-05    3          29.91             63              0.00
# 33  2021-05-05    4          29.94             63              0.01
# 34  2021-05-05    5          29.91             63              0.01
# 35  2021-05-05    6          29.94             63              0.00
# 36  2021-05-05    7          29.94             63              0.00
# 37  2021-05-05    8          29.91             63              0.00
# 38  2021-05-05    9          29.91             62              0.00
# 39  2021-05-05   10          29.91             62              0.00
# 40  2021-05-05   11          29.94             61              0.00
# 41  2021-05-05   12          29.94             60              0.00
# 42  2021-05-05   13          29.94             60              0.00
# 43  2021-05-05   14          29.97             62              0.00
# 44  2021-05-05   15          30.00             63              0.00
# 45  2021-05-05   16          30.03             64              0.00
# 46  2021-05-05   17          30.03             65              0.00
# 47  2021-05-05   18          30.03             67              0.00
#
#     relHumidity_% skyCondition  visibility_mi  windGust_kt  wind_kt
# 0              87          OVC              6           22       12
# 1              88          OVC              6           20       10
# 2              86          BKN              6           19       11
# 3              83          BKN              6           19       10
# 4              79          BKN              6           20       10
# 5              77          BKN              6           20        9
# 6              77          BKN              6           21        9
# 7              79          BKN              6           22        8
# 8              80          OVC              6           23        6
# 9              85          OVC              6           21        5
# 10             89          OVC              6           20        4
# 11             91          OVC              6           22        5
# 12             90          BKN              6           22        6
# 13             92          BKN              6           22        6
# 14             93          FEW              6           23        6
# 15             94          FEW              6           23        6
# 16             95          FEW              6           23        6
# 17             97          FEW              6           23        6
# 18             98          FEW              6           22        5
# 19             94          FEW              6           21        6
# 20             92          OVC              6           20        7
# 21             88          OVC              6           21        8
# 22             87          OVC              5           20        7
# 23             93          OVC              6           22        9
# 24             87          OVC              6           19        9
# 25             81          BKN              6           18       11
# 26             82          BKN              5           18       10
# 27             82          BKN              6           19        9
# 28             78          BKN              6           16        8
# 29             82          BKN              6           18        8
# 30             93          OVC              5           28       15
# 31             91          OVC              6           25        8
# 32             92          OVC              6            6        3
# 33             92          OVC              6           24        8
# 34             93          OVC              6           26        7
# 35             94          OVC              6           25        9
# 36             93          OVC              6           20        8
# 37             94          OVC              6           21        7
# 38             94          OVC              6           21        7
# 39             92          OVC              6           23        7
# 40             93          BKN              6           22        6
# 41             95          BKN              6           20        5
# 42             96          BKN              6           19        5
# 43             91          BKN              6           17        6
# 44             89          OVC              6           16        7
# 45             84          OVC              6           16        8
# 46             80          OVC              6           16        8
# 47             71          OVC              6           14        9

# %% [markdown]
# ### PRUEBAS !!!

# %%
with open("dict_mappers/arrTimeHour_dict.pkl", "rb") as f:
    arrTimeHour_dict = pickle.load(f)
arrTimeHour_dict
# Out:
# {'ABE_ATL_9E_13': '15',
#  'ABE_ATL_9E_14': '17',
#  'ABE_ATL_9E_15': '17',
#  'ABE_ATL_9E_17': '20',
#  'ABE_ATL_9E_18': '20',
#  'ABE_ATL_9E_6': '8',
#  'ABE_ATL_DL_17': '20',
#  'ABE_ATL_DL_6': '8',
#  'ABE_BNA_G4_13': '14',
#  'ABE_BNA_G4_14': '15',
#  'ABE_BNA_G4_17': '18',
#  'ABE_BNA_G4_18': '19',
#  'ABE_BNA_G4_19': '20',
#  'ABE_CLT_OH_0': '7',
#  'ABE_CLT_OH_11': '13',
#  'ABE_CLT_OH_16': '19',
#  'ABE_CLT_OH_18': '21',
#  'ABE_CLT_OH_19': '21',
#  'ABE_CLT_OH_6': '8',
#  'ABE_CLT_OH_8': '10',
#  'ABE_DTW_OO_0': '7',
#  'ABE_DTW_OO_12': '14',
#  'ABE_DTW_OO_13': '15',
#  'ABE_DTW_OO_17': '19',
#  'ABE_DTW_OO_6': '7',
#  'ABE_DTW_OO_9': '11',
#  'ABE_FLL_G4_10': '13',
#  'ABE_FLL_G4_11': '13',
#  'ABE_FLL_G4_14': '16',
#  'ABE_FLL_G4_17': '20',
#  'ABE_FLL_G4_18': '21',
#  'ABE_FLL_G4_19': '22',
#  'ABE_FLL_G4_9': '12',
#  'ABE_MYR_G4_11': '12',
#  'ABE_MYR_G4_12': '13',
#  'ABE_MYR_G4_14': '16',
#  'ABE_MYR_G4_15': '16',
#  'ABE_MYR_G4_16': '18',
#  'ABE_MYR_G4_17': '19',
#  'ABE_MYR_G4_18': '20',
#  'ABE_MYR_G4_20': '22',
#  'ABE_MYR_G4_8': '9',
#  'ABE_ORD_EV_12': '13',
#  'ABE_ORD_EV_17': '18',
#  'ABE_ORD_EV_7': '9',
#  'ABE_ORD_MQ_14': '15',
#  'ABE_ORD_MQ_15': '16',
#  'ABE_ORD_MQ_6': '8',
#  'ABE_ORD_MQ_7': '8',
#  'ABE_ORD_MQ_9': '10',
#  'ABE_ORD_OO_12': '13',
#  'ABE_ORD_OO_13': '14',
#  'ABE_ORD_OO_17': '18',
#  'ABE_ORD_OO_6': '7',
#  'ABE_ORD_OO_7': '8',
#  'ABE_ORD_OO_8': '9',
#  'ABE_PGD_G4_0': '0',
#  'ABE_PGD_G4_10': '12',
#  'ABE_PGD_G4_11': '14',
#  'ABE_PGD_G4_12': '14',
#  'ABE_PGD_G4_13': '16',
#  'ABE_PGD_G4_15': '18',
#  'ABE_PGD_G4_16': '19',
#  'ABE_PGD_G4_17': '20',
#  'ABE_PGD_G4_18': '20',
#  'ABE_PGD_G4_19': '22',
#  'ABE_PGD_G4_20': '23',
#  'ABE_PGD_G4_9': '12',
#  'ABE_PIE_G4_10': '13',
#  'ABE_PIE_G4_11': '13',
#  'ABE_PIE_G4_12': '15',
#  'ABE_PIE_G4_13': '16',
#  'ABE_PIE_G4_14': '17',
#  'ABE_PIE_G4_15': '18',
#  'ABE_PIE_G4_16': '18',
#  'ABE_PIE_G4_17': '19',
#  'ABE_PIE_G4_18': '20',
#  'ABE_PIE_G4_19': '21',
#  'ABE_PIE_G4_20': '23',
#  'ABE_PIE_G4_21': '23',
#  'ABE_PIE_G4_9': '12',
#  'ABE_SAV_G4_10': '12',
#  'ABE_SAV_G4_12': '14',
#  'ABE_SAV_G4_14': '16',
#  'ABE_SAV_G4_21': '23',
#  'ABE_SAV_G4_9': '11',
#  'ABE_SFB_G4_0': '0',
#  'ABE_SFB_G4_10': '12',
#  'ABE_SFB_G4_11': '13',
#  'ABE_SFB_G4_12': '14',
#  'ABE_SFB_G4_13': '15',
#  'ABE_SFB_G4_14': '16',
#  'ABE_SFB_G4_15': '17',
#  'ABE_SFB_G4_16': '18',
#  'ABE_SFB_G4_17': '19',
#  'ABE_SFB_G4_18': '21',
#  'ABE_SFB_G4_19': '22',
#  'ABE_SFB_G4_20': '23',
#  'ABE_SFB_G4_21': '23',
#  'ABE_SFB_G4_9': '11',
#  'ABI_DFW_MQ_0': '6',
#  'ABI_DFW_MQ_10': '11',
#  'ABI_DFW_MQ_12': '13',
#  'ABI_DFW_MQ_13': '14',
#  'ABI_DFW_MQ_14': '15',
#  'ABI_DFW_MQ_15': '16',
#  'ABI_DFW_MQ_16': '17',
#  'ABI_DFW_MQ_17': '17',
#  'ABI_DFW_MQ_18': '19',
#  'ABI_DFW_MQ_21': '22',
#  'ABI_DFW_MQ_6': '7',
#  'ABI_DFW_MQ_7': '8',
#  'ABI_DFW_MQ_8': '9',
#  'ABI_DFW_MQ_9': '10',
#  'ABQ_ATL_DL_11': '16',
#  'ABQ_ATL_DL_12': '17',
#  'ABQ_ATL_DL_13': '18',
#  'ABQ_ATL_DL_14': '19',
#  'ABQ_ATL_DL_15': '20',
#  'ABQ_ATL_DL_16': '21',
#  'ABQ_ATL_DL_6': '11',
#  'ABQ_ATL_DL_9': '13',
#  'ABQ_AUS_G4_10': '13',
#  'ABQ_AUS_G4_11': '14',
#  'ABQ_AUS_G4_12': '15',
#  'ABQ_AUS_G4_13': '16',
#  'ABQ_AUS_G4_15': '18',
#  'ABQ_AUS_G4_16': '18',
#  'ABQ_AUS_G4_17': '19',
#  'ABQ_AUS_G4_9': '11',
#  'ABQ_AUS_WN_0': '7',
#  'ABQ_AUS_WN_10': '13',
#  'ABQ_AUS_WN_11': '14',
#  'ABQ_AUS_WN_12': '15',
#  'ABQ_AUS_WN_13': '15',
#  'ABQ_AUS_WN_14': '17',
#  'ABQ_AUS_WN_15': '18',
#  'ABQ_AUS_WN_16': '18',
#  'ABQ_AUS_WN_17': '19',
#  'ABQ_AUS_WN_18': '21',
#  'ABQ_AUS_WN_19': '21',
#  'ABQ_AUS_WN_20': '23',
#  'ABQ_AUS_WN_21': '0',
#  'ABQ_AUS_WN_22': '0',
#  'ABQ_AUS_WN_6': '9',
#  'ABQ_AUS_WN_7': '9',
#  'ABQ_AUS_WN_8': '11',
#  'ABQ_AUS_WN_9': '11',
#  'ABQ_BWI_WN_0': '11',
#  'ABQ_BWI_WN_10': '15',
#  'ABQ_BWI_WN_11': '17',
#  'ABQ_BWI_WN_12': '18',
#  'ABQ_BWI_WN_13': '19',
#  'ABQ_BWI_WN_14': '20',
#  'ABQ_BWI_WN_15': '21',
#  'ABQ_BWI_WN_6': '12',
#  'ABQ_BWI_WN_7': '13',
#  'ABQ_BWI_WN_8': '14',
#  'ABQ_BWI_WN_9': '15',
#  'ABQ_DAL_WN_0': '8',
#  'ABQ_DAL_WN_10': '13',
#  'ABQ_DAL_WN_11': '14',
#  'ABQ_DAL_WN_12': '15',
#  'ABQ_DAL_WN_13': '16',
#  'ABQ_DAL_WN_14': '17',
#  'ABQ_DAL_WN_15': '18',
#  'ABQ_DAL_WN_16': '19',
#  'ABQ_DAL_WN_17': '20',
#  'ABQ_DAL_WN_18': '21',
#  'ABQ_DAL_WN_19': '22',
#  'ABQ_DAL_WN_20': '22',
#  'ABQ_DAL_WN_6': '9',
#  'ABQ_DAL_WN_7': '9',
#  'ABQ_DAL_WN_8': '11',
#  'ABQ_DAL_WN_9': '12',
#  'ABQ_DEN_F9_13': '14',
#  'ABQ_DEN_F9_15': '17',
#  'ABQ_DEN_F9_17': '18',
#  'ABQ_DEN_F9_18': '20',
#  'ABQ_DEN_F9_19': '21',
#  'ABQ_DEN_F9_20': '21',
#  'ABQ_DEN_OO_0': '7',
#  'ABQ_DEN_OO_11': '12',
#  'ABQ_DEN_OO_13': '14',
#  'ABQ_DEN_OO_14': '16',
#  'ABQ_DEN_OO_15': '16',
#  'ABQ_DEN_OO_18': '19',
#  'ABQ_DEN_OO_7': '8',
#  'ABQ_DEN_OO_8': '10',
#  'ABQ_DEN_UA_0': '7',
#  'ABQ_DEN_UA_11': '12',
#  'ABQ_DEN_UA_15': '16',
#  'ABQ_DEN_UA_18': '19',
#  'ABQ_DEN_UA_21': '22',
#  'ABQ_DEN_UA_6': '7',
#  'ABQ_DEN_UA_7': '8',
#  'ABQ_DEN_UA_8': '9',
#  'ABQ_DEN_WN_0': '6',
#  'ABQ_DEN_WN_10': '11',
#  'ABQ_DEN_WN_11': '13',
#  'ABQ_DEN_WN_12': '13',
#  'ABQ_DEN_WN_13': '14',
#  'ABQ_DEN_WN_14': '15',
#  'ABQ_DEN_WN_15': '16',
#  'ABQ_DEN_WN_16': '18',
#  'ABQ_DEN_WN_17': '19',
#  'ABQ_DEN_WN_18': '20',
#  'ABQ_DEN_WN_20': '22',
#  'ABQ_DEN_WN_22': '0',
#  'ABQ_DEN_WN_6': '7',
#  'ABQ_DEN_WN_7': '8',
#  'ABQ_DEN_WN_8': '9',
#  'ABQ_DEN_WN_9': '11',
#  'ABQ_DEN_YX_11': '12',
#  'ABQ_DEN_YX_13': '14',
#  'ABQ_DEN_YX_17': '19',
#  'ABQ_DEN_YX_18': '19',
#  'ABQ_DEN_YX_8': '10',
#  'ABQ_DFW_AA_10': '13',
#  'ABQ_DFW_AA_11': '13',
#  'ABQ_DFW_AA_12': '15',
#  'ABQ_DFW_AA_14': '17',
#  'ABQ_DFW_AA_15': '17',
#  'ABQ_DFW_AA_16': '19',
#  'ABQ_DFW_AA_18': '21',
#  'ABQ_DFW_AA_20': '23',
#  'ABQ_DFW_AA_6': '9',
#  'ABQ_DFW_AA_7': '10',
#  'ABQ_DFW_AA_8': '11',
#  'ABQ_DFW_YV_0': '7',
#  'ABQ_DFW_YV_10': '13',
#  'ABQ_DFW_YV_11': '14',
#  'ABQ_DFW_YV_12': '15',
#  'ABQ_DFW_YV_14': '17',
#  'ABQ_DFW_YV_15': '17',
#  'ABQ_DFW_YV_16': '19',
#  'ABQ_DFW_YV_18': '21',
#  'ABQ_HOU_WN_0': '8',
#  'ABQ_HOU_WN_10': '13',
#  'ABQ_HOU_WN_11': '14',
#  'ABQ_HOU_WN_12': '15',
#  'ABQ_HOU_WN_13': '16',
#  'ABQ_HOU_WN_14': '18',
#  'ABQ_HOU_WN_15': '18',
#  'ABQ_HOU_WN_16': '18',
#  'ABQ_HOU_WN_18': '21',
#  'ABQ_HOU_WN_19': '22',
#  'ABQ_HOU_WN_20': '23',
#  'ABQ_HOU_WN_6': '9',
#  'ABQ_HOU_WN_7': '10',
#  'ABQ_HOU_WN_8': '11',
#  'ABQ_HOU_WN_9': '12',
#  'ABQ_IAH_EV_0': '8',
#  'ABQ_IAH_EV_10': '13',
#  'ABQ_IAH_EV_11': '14',
#  'ABQ_IAH_EV_12': '15',
#  'ABQ_IAH_EV_13': '17',
#  'ABQ_IAH_EV_14': '17',
#  'ABQ_IAH_EV_17': '20',
#  'ABQ_IAH_EV_7': '11',
#  'ABQ_IAH_EV_8': '11',
#  'ABQ_IAH_EV_9': '13',
#  'ABQ_IAH_OO_0': '8',
#  'ABQ_IAH_OO_12': '15',
#  'ABQ_IAH_OO_14': '17',
#  'ABQ_IAH_OO_7': '10',
#  'ABQ_IAH_OO_8': '11',
#  'ABQ_IAH_UA_0': '8',
#  'ABQ_IAH_UA_12': '15',
#  'ABQ_IAH_UA_14': '17',
#  'ABQ_IAH_UA_20': '23',
#  'ABQ_IAH_UA_7': '11',
#  'ABQ_IAH_UA_8': '11',
#  'ABQ_IAH_YV_0': '8',
#  'ABQ_IAH_YV_10': '13',
#  'ABQ_IAH_YV_11': '14',
#  'ABQ_IAH_YV_12': '15',
#  'ABQ_IAH_YV_14': '17',
#  'ABQ_IAH_YV_16': '19',
#  'ABQ_IAH_YV_17': '20',
#  'ABQ_IAH_YV_20': '23',
#  'ABQ_IAH_YV_7': '11',
#  'ABQ_IAH_YV_8': '11',
#  'ABQ_IAH_YV_9': '13',
#  'ABQ_IAH_YX_0': '8',
#  'ABQ_IAH_YX_11': '14',
#  'ABQ_IAH_YX_12': '15',
#  'ABQ_IAH_YX_14': '17',
#  'ABQ_IAH_YX_17': '20',
#  'ABQ_IAH_YX_8': '11',
#  'ABQ_JFK_B6_23': '0',
#  'ABQ_LAS_G4_10': '11',
#  'ABQ_LAS_G4_13': '13',
#  'ABQ_LAS_G4_14': '14',
#  'ABQ_LAS_G4_15': '16',
#  'ABQ_LAS_G4_16': '17',
#  'ABQ_LAS_G4_17': '17',
#  'ABQ_LAS_G4_18': '18',
#  'ABQ_LAS_G4_20': '21',
#  'ABQ_LAS_G4_21': '22',
#  'ABQ_LAS_WN_0': '6',
#  'ABQ_LAS_WN_10': '11',
#  'ABQ_LAS_WN_11': '12',
#  'ABQ_LAS_WN_12': '13',
#  'ABQ_LAS_WN_13': '13',
#  'ABQ_LAS_WN_14': '15',
#  'ABQ_LAS_WN_15': '16',
#  'ABQ_LAS_WN_16': '17',
#  'ABQ_LAS_WN_17': '18',
#  'ABQ_LAS_WN_18': '19',
#  'ABQ_LAS_WN_19': '19',
#  'ABQ_LAS_WN_20': '21',
#  'ABQ_LAS_WN_21': '21',
#  'ABQ_LAS_WN_22': '22',
#  'ABQ_LAS_WN_6': '6',
#  'ABQ_LAS_WN_7': '7',
#  'ABQ_LAS_WN_8': '9',
#  'ABQ_LAS_WN_9': '10',
#  'ABQ_LAX_AA_8': '9',
#  'ABQ_LAX_OO_11': '12',
#  'ABQ_LAX_OO_12': '13',
#  'ABQ_LAX_OO_13': '14',
#  'ABQ_LAX_OO_14': '15',
#  'ABQ_LAX_OO_16': '17',
#  'ABQ_LAX_OO_18': '19',
#  'ABQ_LAX_OO_20': '21',
#  'ABQ_LAX_OO_7': '8',
#  'ABQ_LAX_OO_8': '9',
#  'ABQ_LAX_UA_16': '17',
#  'ABQ_LAX_UA_17': '18',
#  'ABQ_LAX_WN_0': '6',
#  'ABQ_LAX_WN_10': '11',
#  'ABQ_LAX_WN_11': '12',
#  'ABQ_LAX_WN_12': '13',
#  'ABQ_LAX_WN_13': '14',
#  'ABQ_LAX_WN_14': '15',
#  'ABQ_LAX_WN_15': '17',
#  'ABQ_LAX_WN_17': '18',
#  'ABQ_LAX_WN_18': '19',
#  'ABQ_LAX_WN_19': '20',
#  'ABQ_LAX_WN_20': '21',
#  'ABQ_LAX_WN_21': '22',
#  'ABQ_LAX_WN_22': '23',
#  'ABQ_LAX_WN_6': '7',
#  'ABQ_LAX_WN_7': '8',
#  'ABQ_LAX_WN_8': '10',
#  'ABQ_LAX_WN_9': '10',
#  'ABQ_MCI_WN_10': '13',
#  'ABQ_MCI_WN_11': '13',
#  'ABQ_MCI_WN_12': '15',
#  'ABQ_MCI_WN_16': '19',
#  'ABQ_MCI_WN_17': '20',
#  'ABQ_MCI_WN_18': '20',
#  'ABQ_MCI_WN_19': '22',
#  'ABQ_MCI_WN_6': '9',
#  'ABQ_MCI_WN_7': '10',
#  'ABQ_MCI_WN_8': '11',
#  'ABQ_MCI_WN_9': '11',
#  'ABQ_MCO_F9_0': '6',
#  'ABQ_MCO_WN_11': '17',
#  'ABQ_MCO_WN_6': '12',
#  'ABQ_MDW_WN_0': '9',
#  'ABQ_MDW_WN_10': '14',
#  'ABQ_MDW_WN_12': '16',
#  'ABQ_MDW_WN_14': '18',
#  'ABQ_MDW_WN_15': '19',
#  'ABQ_MDW_WN_16': '20',
#  'ABQ_MDW_WN_17': '20',
#  'ABQ_MDW_WN_18': '21',
#  'ABQ_MDW_WN_19': '23',
#  'ABQ_MDW_WN_6': '10',
#  'ABQ_MDW_WN_7': '11',
#  'ABQ_MDW_WN_8': '12',
#  'ABQ_MDW_WN_9': '12',
#  'ABQ_MSP_DL_13': '17',
#  'ABQ_MSP_DL_14': '18',
#  'ABQ_MSP_DL_15': '18',
#  'ABQ_MSP_DL_6': '10',
#  'ABQ_MSP_DL_7': '10',
#  'ABQ_MSP_DL_8': '12',
#  'ABQ_OAK_WN_0': '6',
#  'ABQ_OAK_WN_10': '12',
#  'ABQ_OAK_WN_11': '13',
#  'ABQ_OAK_WN_12': '14',
#  'ABQ_OAK_WN_13': '14',
#  'ABQ_OAK_WN_14': '16',
#  'ABQ_OAK_WN_15': '17',
#  'ABQ_OAK_WN_18': '20',
#  'ABQ_OAK_WN_19': '21',
#  'ABQ_OAK_WN_20': '22',
#  'ABQ_OAK_WN_21': '22',
#  'ABQ_OAK_WN_22': '23',
#  'ABQ_OAK_WN_6': '7',
#  'ABQ_OAK_WN_7': '8',
#  'ABQ_OAK_WN_8': '9',
#  'ABQ_OAK_WN_9': '10',
#  'ABQ_ORD_AA_0': '9',
#  'ABQ_ORD_AA_13': '17',
#  'ABQ_ORD_AA_6': '10',
#  'ABQ_ORD_AA_7': '11',
#  'ABQ_ORD_EV_13': '17',
#  'ABQ_ORD_EV_6': '10',
#  'ABQ_ORD_MQ_12': '16',
#  'ABQ_ORD_MQ_13': '16',
#  'ABQ_ORD_MQ_7': '10',
#  'ABQ_ORD_OO_13': '16',
#  'ABQ_ORD_OO_16': '19',
#  'ABQ_ORD_OO_6': '10',
#  'ABQ_ORD_OO_7': '10',
#  'ABQ_ORD_UA_13': '17',
#  'ABQ_ORD_UA_15': '19',
#  'ABQ_ORD_UA_16': '19',
#  'ABQ_ORD_UA_6': '9',
#  'ABQ_ORD_UA_8': '12',
#  'ABQ_ORD_UA_9': '13',
#  'ABQ_ORD_YX_13': '17',
#  'ABQ_ORD_YX_6': '10',
#  'ABQ_PDX_OO_13': '15',
#  'ABQ_PDX_OO_15': '17',
#  'ABQ_PDX_OO_18': '20',
#  'ABQ_PDX_OO_20': '22',
#  'ABQ_PHX_AA_11': '12',
#  'ABQ_PHX_AA_12': '12',
#  'ABQ_PHX_AA_15': '16',
#  'ABQ_PHX_AA_19': '20',
#  'ABQ_PHX_AA_6': '7',
#  'ABQ_PHX_AA_7': '9',
#  'ABQ_PHX_AA_8': '10',
#  'ABQ_PHX_OO_18': '19',
#  'ABQ_PHX_OO_20': '20',
#  'ABQ_PHX_OO_6': '6',
#  'ABQ_PHX_OO_7': '8',
#  'ABQ_PHX_WN_0': '6',
#  'ABQ_PHX_WN_10': '10',
#  'ABQ_PHX_WN_11': '12',
#  'ABQ_PHX_WN_12': '12',
#  'ABQ_PHX_WN_13': '14',
#  'ABQ_PHX_WN_14': '15',
#  'ABQ_PHX_WN_15': '15',
#  'ABQ_PHX_WN_16': '17',
#  'ABQ_PHX_WN_17': '18',
#  'ABQ_PHX_WN_18': '18',
#  'ABQ_PHX_WN_19': '20',
#  'ABQ_PHX_WN_20': '20',
#  'ABQ_PHX_WN_6': '8',
#  'ABQ_PHX_WN_7': '7',
#  'ABQ_PHX_WN_8': '9',
#  'ABQ_PHX_WN_9': '9',
#  'ABQ_PHX_YV_11': '12',
#  'ABQ_PHX_YV_12': '13',
#  'ABQ_PHX_YV_15': '15',
#  'ABQ_PHX_YV_17': '17',
#  'ABQ_PHX_YV_21': '22',
#  'ABQ_PHX_YV_22': '23',
#  'ABQ_PHX_YV_8': '9',
#  'ABQ_SAN_OO_6': '6',
#  'ABQ_SAN_OO_7': '8',
#  'ABQ_SAN_OO_8': '9',
#  'ABQ_SAN_WN_10': '11',
#  'ABQ_SAN_WN_11': '12',
#  'ABQ_SAN_WN_12': '13',
#  'ABQ_SAN_WN_13': '13',
#  'ABQ_SAN_WN_15': '16',
#  'ABQ_SAN_WN_16': '17',
#  'ABQ_SAN_WN_17': '18',
#  'ABQ_SAN_WN_18': '19',
#  'ABQ_SAN_WN_19': '20',
#  'ABQ_SAN_WN_20': '21',
#  'ABQ_SAN_WN_21': '22',
#  'ABQ_SAN_WN_22': '23',
#  'ABQ_SAN_WN_6': '7',
#  'ABQ_SAN_WN_7': '8',
#  'ABQ_SAN_WN_8': '8',
#  'ABQ_SAN_WN_9': '10',
#  'ABQ_SAT_WN_14': '17',
#  'ABQ_SEA_AS_15': '17',
#  'ABQ_SEA_AS_16': '18',
#  'ABQ_SEA_AS_17': '19',
#  'ABQ_SEA_AS_6': '8',
#  'ABQ_SEA_AS_7': '9',
#  'ABQ_SEA_AS_8': '11',
#  'ABQ_SEA_AS_9': '11',
#  'ABQ_SFO_OO_11': '13',
#  'ABQ_SFO_OO_13': '15',
#  'ABQ_SFO_OO_15': '17',
#  'ABQ_SFO_OO_20': '22',
#  'ABQ_SFO_OO_6': '7',
#  'ABQ_SFO_UA_0': '7',
#  'ABQ_SFO_UA_15': '17',
#  'ABQ_SFO_UA_6': '7',
#  'ABQ_SFO_UA_8': '9',
#  'ABQ_SJC_WN_11': '12',
#  'ABQ_SJC_WN_12': '14',
#  'ABQ_SJC_WN_13': '14',
#  'ABQ_SJC_WN_15': '16',
#  'ABQ_SJC_WN_16': '17',
#  'ABQ_SJC_WN_17': '19',
#  'ABQ_SJC_WN_18': '19',
#  'ABQ_SJC_WN_19': '20',
#  'ABQ_SJC_WN_7': '9',
#  'ABQ_SJC_WN_8': '9',
#  'ABQ_SJC_WN_9': '10',
#  'ABQ_SLC_DL_0': '7',
#  'ABQ_SLC_DL_17': '19',
#  'ABQ_SLC_DL_6': '7',
#  'ABQ_SLC_DL_8': '10',
#  'ABQ_SLC_OO_0': '7',
#  'ABQ_SLC_OO_12': '14',
#  'ABQ_SLC_OO_14': '16',
#  'ABQ_SLC_OO_17': '19',
#  'ABQ_SLC_OO_6': '7',
#  'ABQ_SLC_OO_7': '8',
#  'ABQ_SLC_OO_8': '10',
#  'ABR_MSP_OO_0': '6',
#  'ABR_MSP_OO_13': '14',
#  'ABR_MSP_OO_17': '18',
#  'ABR_MSP_OO_6': '7',
#  'ABR_MSP_OO_7': '8',
#  'ABY_ATL_OO_11': '13',
#  'ABY_ATL_OO_12': '13',
#  'ABY_ATL_OO_13': '14',
#  'ABY_ATL_OO_14': '15',
#  'ABY_ATL_OO_15': '16',
#  'ABY_ATL_OO_16': '17',
#  'ABY_ATL_OO_17': '18',
#  'ABY_ATL_OO_21': '22',
#  'ABY_ATL_OO_6': '7',
#  'ACK_BOS_B6_10': '11',
#  'ACK_BOS_B6_13': '14',
#  'ACK_BOS_B6_17': '18',
#  'ACK_BOS_B6_9': '10',
#  'ACK_CLT_YX_16': '18',
#  'ACK_DCA_B6_12': '14',
#  'ACK_DCA_B6_13': '14',
#  'ACK_DCA_B6_14': '15',
#  'ACK_DCA_YX_10': '12',
#  'ACK_DCA_YX_12': '14',
#  'ACK_DCA_YX_17': '19',
#  'ACK_HPN_B6_10': '11',
#  'ACK_HPN_B6_12': '14',
#  'ACK_HPN_B6_13': '15',
#  'ACK_JFK_B6_11': '12',
#  'ACK_JFK_B6_14': '16',
#  'ACK_JFK_B6_15': '16',
#  'ACK_JFK_B6_16': '17',
#  'ACK_JFK_B6_18': '19',
#  'ACK_JFK_B6_22': '23',
#  'ACK_JFK_B6_7': '8',
#  'ACK_JFK_B6_8': '10',
#  'ACK_LGA_9E_11': '12',
#  'ACK_LGA_9E_12': '14',
#  'ACK_LGA_9E_13': '14',
#  'ACK_LGA_9E_15': '16',
#  'ACK_LGA_B6_10': '11',
#  'ACK_LGA_B6_11': '12',
#  'ACK_LGA_B6_15': '16',
#  'ACK_LGA_B6_17': '18',
#  'ACK_LGA_YX_11': '12',
#  'ACK_LGA_YX_15': '16',
#  'ACT_DFW_MQ_0': '6',
#  'ACT_DFW_MQ_10': '11',
#  'ACT_DFW_MQ_11': '12',
#  'ACT_DFW_MQ_12': '13',
#  'ACT_DFW_MQ_13': '14',
#  'ACT_DFW_MQ_14': '14',
#  'ACT_DFW_MQ_15': '16',
#  'ACT_DFW_MQ_16': '17',
#  'ACT_DFW_MQ_17': '18',
#  'ACT_DFW_MQ_18': '19',
#  'ACT_DFW_MQ_19': '20',
#  'ACT_DFW_MQ_20': '21',
#  'ACT_DFW_MQ_6': '7',
#  'ACT_DFW_MQ_7': '7',
#  'ACT_DFW_MQ_8': '9',
#  'ACT_DFW_MQ_9': '10',
#  'ACT_DFW_OO_8': '9',
#  'ACV_DEN_OO_6': '10',
#  'ACV_LAX_OO_10': '12',
#  'ACV_LAX_OO_11': '13',
#  'ACV_LAX_OO_19': '21',
#  'ACV_LAX_OO_20': '21',
#  'ACV_LAX_OO_6': '8',
#  'ACV_LAX_OO_7': '8',
#  'ACV_LAX_OO_9': '11',
#  'ACV_SFO_OO_0': '7',
#  'ACV_SFO_OO_10': '12',
#  'ACV_SFO_OO_11': '12',
#  'ACV_SFO_OO_12': '13',
#  'ACV_SFO_OO_17': '18',
#  'ACV_SFO_OO_18': '19',
#  'ACV_SFO_OO_19': '20',
#  'ACV_SFO_OO_20': '21',
#  'ACV_SFO_OO_6': '7',
#  'ACV_SFO_OO_7': '8',
#  'ACV_SFO_OO_8': '9',
#  'ACY_ATL_NK_12': '15',
#  'ACY_ATL_NK_13': '15',
#  'ACY_FLL_NK_12': '15',
#  'ACY_FLL_NK_14': '17',
#  'ACY_FLL_NK_17': '19',
#  'ACY_FLL_NK_20': '22',
#  'ACY_FLL_NK_6': '9',
#  'ACY_FLL_NK_7': '9',
#  'ACY_MCO_NK_16': '19',
#  'ACY_MCO_NK_17': '19',
#  'ACY_MCO_NK_18': '20',
#  'ACY_MCO_NK_6': '8',
#  'ACY_MCO_NK_7': '9',
#  'ACY_MCO_NK_8': '10',
#  'ACY_MYR_NK_6': '7',
#  'ACY_MYR_NK_7': '8',
#  'ACY_PBI_NK_13': '15',
#  'ACY_RSW_NK_13': '16',
#  'ACY_RSW_NK_15': '18',
#  'ACY_RSW_NK_17': '20',
#  'ACY_RSW_NK_18': '20',
#  'ACY_RSW_NK_6': '9',
#  'ACY_TPA_NK_10': '13',
#  'ACY_TPA_NK_11': '13',
#  'ACY_TPA_NK_6': '8',
#  'ACY_TPA_NK_9': '11',
#  'ADK_ANC_AS_16': '20',
#  'ADK_ANC_AS_17': '20',
#  'ADQ_ANC_AS_16': '17',
#  'ADQ_ANC_AS_17': '17',
#  'ADQ_ANC_AS_7': '8',
#  'ADQ_ANC_AS_8': '8',
#  'AEX_ATL_9E_10': '13',
#  'AEX_ATL_9E_11': '14',
#  'AEX_ATL_9E_13': '16',
#  'AEX_ATL_9E_14': '17',
#  'AEX_ATL_9E_15': '17',
#  'AEX_ATL_9E_16': '19',
#  'AEX_ATL_9E_17': '20',
#  'AEX_ATL_9E_20': '22',
#  'AEX_ATL_9E_6': '8',
#  'AEX_ATL_OO_15': '18',
#  'AEX_DFW_MQ_0': '6',
#  'AEX_DFW_MQ_10': '11',
#  'AEX_DFW_MQ_12': '13',
#  'AEX_DFW_MQ_16': '17',
#  'AEX_DFW_MQ_6': '7',
#  'AEX_DFW_MQ_8': '9',
#  'AEX_IAH_EV_10': '11',
#  'AEX_IAH_EV_12': '13',
#  'AEX_IAH_EV_16': '17',
#  'AEX_IAH_EV_17': '18',
#  'AEX_IAH_EV_6': '7',
#  'AEX_IAH_EV_7': '8',
#  'AGS_ATL_9E_0': '6',
#  'AGS_ATL_9E_10': '11',
#  'AGS_ATL_9E_11': '12',
#  'AGS_ATL_9E_12': '13',
#  'AGS_ATL_9E_13': '14',
#  'AGS_ATL_9E_14': '15',
#  'AGS_ATL_9E_15': '16',
#  'AGS_ATL_9E_16': '17',
#  'AGS_ATL_9E_17': '18',
#  'AGS_ATL_9E_18': '20',
#  'AGS_ATL_9E_19': '20',
#  'AGS_ATL_9E_6': '7',
#  'AGS_ATL_9E_7': '8',
#  'AGS_ATL_9E_8': '9',
#  'AGS_ATL_9E_9': '10',
#  'AGS_ATL_DL_0': '6',
#  'AGS_ATL_DL_10': '11',
#  'AGS_ATL_DL_11': '12',
#  'AGS_ATL_DL_12': '13',
#  'AGS_ATL_DL_13': '14',
#  'AGS_ATL_DL_14': '15',
#  'AGS_ATL_DL_15': '16',
#  'AGS_ATL_DL_16': '17',
#  'AGS_ATL_DL_17': '18',
#  'AGS_ATL_DL_19': '20',
#  'AGS_ATL_DL_21': '22',
#  'AGS_ATL_DL_6': '7',
#  'AGS_ATL_DL_7': '8',
#  'AGS_ATL_DL_8': '9',
#  'AGS_ATL_DL_9': '10',
#  'AGS_ATL_OO_12': '14',
#  'AGS_ATL_OO_14': '15',
#  'AGS_ATL_OO_15': '16',
#  'AGS_ATL_OO_17': '18',
#  'AGS_CLT_OH_0': '6',
#  'AGS_CLT_OH_11': '12',
#  'AGS_CLT_OH_12': '13',
#  'AGS_CLT_OH_14': '15',
#  'AGS_CLT_OH_15': '17',
#  'AGS_CLT_OH_16': '17',
#  'AGS_CLT_OH_17': '18',
#  'AGS_CLT_OH_18': '19',
#  'AGS_CLT_OH_19': '20',
#  'AGS_CLT_OH_20': '21',
#  'AGS_CLT_OH_21': '23',
#  'AGS_CLT_OH_22': '23',
#  'AGS_CLT_OH_6': '8',
#  'AGS_CLT_OH_7': '8',
#  'AGS_CLT_OH_8': '10',
#  'AGS_CLT_OH_9': '10',
#  'AGS_DCA_OH_10': '12',
#  'AGS_DCA_OH_14': '15',
#  'AGS_DCA_YX_11': '12',
#  'AGS_DCA_YX_12': '14',
#  'AGS_DCA_YX_13': '15',
#  'AGS_DCA_YX_17': '19',
#  'AGS_DCA_YX_19': '21',
#  'AGS_DFW_AA_16': '18',
#  'AGS_DFW_AA_18': '20',
#  'AGS_DFW_AA_9': '11',
#  'AGS_DFW_MQ_15': '16',
#  'AGS_DFW_MQ_16': '18',
#  'AGS_DFW_MQ_19': '21',
#  'AGS_DFW_MQ_7': '9',
#  'AGS_DFW_OO_16': '17',
#  'AGS_LGA_YX_11': '13',
#  'AGS_LGA_YX_12': '15',
#  'AGS_LGA_YX_16': '18',
#  'AGS_LGA_YX_17': '19',
#  'AGS_LGA_YX_20': '23',
#  'AGS_MIA_YX_11': '12',
#  'AGS_MIA_YX_18': '20',
#  'AGS_MIA_YX_19': '21',
#  'AGS_MIA_YX_9': '11',
#  'AGS_ORD_MQ_10': '12',
#  'AGS_ORD_MQ_17': '18',
#  'AGS_ORD_MQ_18': '19',
#  'AGS_ORD_MQ_20': '21',
#  'AGS_ORD_MQ_6': '7',
#  'AGS_PHL_OH_15': '17',
#  'AKN_ANC_AS_17': '18',
#  'ALB_ATL_9E_12': '14',
#  'ALB_ATL_9E_13': '15',
#  'ALB_ATL_9E_14': '17',
#  'ALB_ATL_9E_15': '18',
#  'ALB_ATL_9E_18': '20',
#  'ALB_ATL_DL_0': '8',
#  'ALB_ATL_DL_11': '14',
#  'ALB_ATL_DL_12': '14',
#  'ALB_ATL_DL_13': '15',
#  'ALB_ATL_DL_14': '17',
#  'ALB_ATL_DL_15': '18',
#  'ALB_ATL_DL_16': '18',
#  'ALB_ATL_DL_18': '20',
#  'ALB_ATL_DL_6': '8',
#  'ALB_BWI_WN_0': '6',
#  'ALB_BWI_WN_10': '12',
#  'ALB_BWI_WN_11': '12',
#  'ALB_BWI_WN_12': '14',
#  'ALB_BWI_WN_13': '14',
#  'ALB_BWI_WN_14': '15',
#  'ALB_BWI_WN_15': '16',
#  'ALB_BWI_WN_16': '17',
#  'ALB_BWI_WN_17': '18',
#  'ALB_BWI_WN_18': '19',
#  'ALB_BWI_WN_19': '20',
#  'ALB_BWI_WN_20': '21',
#  'ALB_BWI_WN_22': '0',
#  'ALB_BWI_WN_6': '7',
#  'ALB_BWI_WN_7': '8',
#  'ALB_BWI_WN_8': '9',
#  'ALB_BWI_WN_9': '10',
#  'ALB_CLT_AA_0': '7',
#  'ALB_CLT_AA_10': '12',
#  'ALB_CLT_AA_11': '14',
#  'ALB_CLT_AA_12': '15',
#  'ALB_CLT_AA_13': '15',
#  'ALB_CLT_AA_14': '16',
#  'ALB_CLT_AA_16': '18',
#  'ALB_CLT_AA_18': '21',
#  'ALB_CLT_AA_19': '21',
#  'ALB_CLT_AA_6': '8',
#  'ALB_CLT_AA_7': '10',
#  'ALB_CLT_AA_8': '10',
#  'ALB_CLT_OH_11': '14',
#  'ALB_CLT_OH_12': '14',
#  'ALB_CLT_YX_0': '7',
#  'ALB_CLT_YX_11': '13',
#  'ALB_CLT_YX_6': '8',
#  'ALB_CLT_YX_8': '10',
#  'ALB_DCA_OH_0': '6',
#  'ALB_DCA_OH_11': '13',
#  'ALB_DCA_OH_13': '14',
#  'ALB_DCA_OH_14': '15',
#  'ALB_DCA_OH_16': '18',
#  'ALB_DCA_OH_17': '18',
#  'ALB_DCA_OH_8': '10',
#  'ALB_DCA_OH_9': '10',
#  'ALB_DCA_YX_11': '13',
#  'ALB_DCA_YX_9': '10',
#  'ALB_DEN_F9_17': '20',
#  'ALB_DEN_F9_18': '21',
#  'ALB_DEN_WN_10': '12',
#  'ALB_DEN_WN_12': '14',
#  'ALB_DEN_WN_13': '15',
#  'ALB_DEN_WN_14': '16',
#  'ALB_DEN_WN_17': '19',
#  'ALB_DEN_WN_18': '21',
#  'ALB_DEN_WN_19': '21',
#  'ALB_DEN_WN_6': '9',
#  'ALB_DEN_WN_7': '9',
#  'ALB_DTW_9E_0': '7',
#  'ALB_DTW_9E_12': '14',
#  'ALB_DTW_9E_13': '14',
#  'ALB_DTW_9E_17': '19',
#  'ALB_DTW_DL_0': '7',
#  'ALB_DTW_DL_13': '14',
#  'ALB_DTW_DL_17': '19',
#  'ALB_DTW_DL_6': '7',
#  'ALB_DTW_DL_9': '11',
#  'ALB_DTW_OO_0': '7',
#  'ALB_DTW_OO_12': '14',
#  'ALB_DTW_OO_13': '14',
#  'ALB_DTW_OO_17': '19',
#  'ALB_DTW_OO_6': '8',
#  'ALB_DTW_OO_9': '11',
#  'ALB_EWR_EV_10': '11',
#  'ALB_EWR_EV_17': '18',
#  'ALB_EWR_EV_18': '19',
#  'ALB_EWR_YX_18': '19',
#  'ALB_EWR_YX_6': '7',
#  'ALB_FLL_B6_16': '19',
#  'ALB_FLL_B6_17': '20',
#  'ALB_FLL_WN_10': '13',
#  'ALB_FLL_WN_12': '15',
#  'ALB_FLL_WN_13': '16',
#  'ALB_FLL_WN_16': '19',
#  'ALB_FLL_WN_7': '10',
#  'ALB_FLL_WN_8': '12',
#  'ALB_FLL_WN_9': '12',
#  'ALB_IAD_EV_14': '16',
#  'ALB_IAD_EV_19': '21',
#  'ALB_IAD_YV_14': '16',
#  'ALB_IAD_YV_19': '21',
#  'ALB_MCO_B6_13': '16',
#  'ALB_MCO_B6_14': '17',
#  'ALB_MCO_B6_15': '18',
#  'ALB_MCO_B6_16': '19',
#  'ALB_MCO_F9_12': '15',
#  'ALB_MCO_F9_18': '22',
#  'ALB_MCO_F9_19': '22',
#  'ALB_MCO_F9_20': '23',
#  'ALB_MCO_F9_9': '13',
#  'ALB_MCO_WN_0': '8',
#  'ALB_MCO_WN_10': '13',
#  'ALB_MCO_WN_11': '14',
#  'ALB_MCO_WN_12': '15',
#  'ALB_MCO_WN_13': '16',
#  'ALB_MCO_WN_14': '16',
#  'ALB_MCO_WN_15': '19',
#  'ALB_MCO_WN_16': '19',
#  'ALB_MCO_WN_17': '20',
#  'ALB_MCO_WN_18': '21',
#  'ALB_MCO_WN_19': '22',
#  'ALB_MCO_WN_20': '23',
#  'ALB_MCO_WN_21': '0',
#  'ALB_MCO_WN_6': '9',
#  'ALB_MCO_WN_7': '10',
#  'ALB_MCO_WN_8': '11',
#  'ALB_MCO_WN_9': '12',
#  'ALB_MDW_WN_0': '7',
#  'ALB_MDW_WN_12': '14',
#  'ALB_MDW_WN_13': '15',
#  'ALB_MDW_WN_14': '16',
#  'ALB_MDW_WN_15': '16',
#  'ALB_MDW_WN_16': '17',
#  'ALB_MDW_WN_17': '18',
#  'ALB_MDW_WN_18': '20',
#  'ALB_MDW_WN_6': '7',
#  'ALB_MDW_WN_7': '8',
#  'ALB_MSP_9E_6': '8',
#  'ALB_MSP_DL_6': '7',
#  'ALB_MSP_DL_8': '9',
#  'ALB_MSP_OO_0': '8',
#  'ALB_MSP_OO_6': '8',
#  'ALB_MSP_OO_8': '10',
#  'ALB_MYR_G4_11': '13',
#  'ALB_MYR_G4_12': '14',
#  'ALB_MYR_G4_13': '15',
#  'ALB_MYR_G4_14': '16',
#  'ALB_MYR_G4_16': '18',
#  'ALB_MYR_G4_9': '11',
#  'ALB_ORD_EV_10': '11',
#  'ALB_ORD_EV_12': '14',
#  'ALB_ORD_EV_13': '14',
#  'ALB_ORD_EV_16': '17',
#  'ALB_ORD_EV_17': '18',
#  'ALB_ORD_EV_7': '9',
#  'ALB_ORD_EV_9': '11',
#  'ALB_ORD_MQ_10': '12',
#  'ALB_ORD_MQ_11': '12',
#  'ALB_ORD_MQ_12': '14',
#  'ALB_ORD_MQ_17': '19',
#  'ALB_ORD_MQ_18': '19',
#  'ALB_ORD_MQ_6': '8',
#  'ALB_ORD_MQ_7': '8',
#  'ALB_ORD_OO_10': '11',
#  'ALB_ORD_OO_11': '12',
#  'ALB_ORD_OO_12': '13',
#  'ALB_ORD_OO_13': '14',
#  'ALB_ORD_OO_16': '17',
#  'ALB_ORD_OO_18': '20',
#  'ALB_ORD_OO_19': '21',
#  'ALB_ORD_OO_7': '9',
#  'ALB_ORD_OO_9': '11',
#  'ALB_ORD_UA_10': '11',
#  'ALB_ORD_UA_12': '14',
#  'ALB_ORD_UA_13': '14',
#  'ALB_ORD_UA_14': '15',
#  'ALB_ORD_UA_17': '19',
#  'ALB_ORD_UA_18': '19',
#  'ALB_ORD_UA_19': '20',
#  'ALB_ORD_UA_22': '23',
#  'ALB_ORD_UA_7': '8',
#  'ALB_ORD_UA_9': '11',
#  'ALB_ORD_YX_10': '11',
#  'ALB_ORD_YX_12': '14',
#  'ALB_ORD_YX_13': '14',
#  'ALB_ORD_YX_18': '20',
#  'ALB_PGD_G4_10': '13',
#  'ALB_PGD_G4_11': '14',
#  'ALB_PGD_G4_12': '15',
#  'ALB_PGD_G4_13': '16',
#  'ALB_PGD_G4_15': '18',
#  'ALB_PGD_G4_16': '19',
#  'ALB_PGD_G4_17': '20',
#  'ALB_PGD_G4_18': '21',
#  'ALB_PGD_G4_9': '12',
#  'ALB_PHL_OH_12': '14',
#  'ALB_PHL_OH_6': '7',
#  'ALB_PHL_YX_14': '15',
#  'ALB_PHL_YX_18': '20',
#  'ALB_PIE_G4_10': '13',
#  'ALB_PIE_G4_11': '14',
#  'ALB_PIE_G4_12': '15',
#  'ALB_PIE_G4_15': '18',
#  'ALB_PIE_G4_16': '19',
#  'ALB_PIE_G4_17': '20',
#  'ALB_PIE_G4_18': '20',
#  'ALB_PIE_G4_19': '22',
#  'ALB_PIE_G4_20': '23',
#  'ALB_PIE_G4_9': '12',
#  'ALB_RDU_F9_15': '17',
#  'ALB_RDU_F9_16': '18',
#  'ALB_RSW_F9_15': '19',
#  'ALB_RSW_F9_18': '21',
#  'ALB_RSW_F9_19': '22',
#  'ALB_RSW_WN_12': '16',
#  'ALB_RSW_WN_13': '16',
#  'ALB_RSW_WN_15': '18',
#  'ALB_RSW_WN_7': '11',
#  'ALB_RSW_WN_8': '12',
#  'ALB_SAV_G4_15': '17',
#  'ALB_SAV_G4_16': '18',
#  'ALB_SAV_G4_17': '19',
#  'ALB_SAV_G4_20': '22',
#  'ALB_SAV_G4_21': '23',
#  'ALB_SAV_G4_9': '12',
#  'ALB_SFB_G4_10': '12',
#  'ALB_SFB_G4_11': '14',
#  'ALB_SFB_G4_12': '15',
#  'ALB_SFB_G4_13': '15',
#  'ALB_SFB_G4_14': '16',
#  'ALB_SFB_G4_16': '19',
#  'ALB_SFB_G4_17': '20',
#  'ALB_SFB_G4_18': '21',
#  'ALB_SFB_G4_19': '22',
#  'ALB_SFB_G4_20': '23',
#  'ALB_SFB_G4_9': '12',
#  'ALB_TPA_WN_10': '13',
#  'ALB_TPA_WN_11': '14',
#  'ALB_TPA_WN_12': '15',
#  'ALB_TPA_WN_13': '16',
#  'ALB_TPA_WN_14': '17',
#  'ALB_TPA_WN_16': '19',
#  'ALB_TPA_WN_17': '20',
#  'ALB_TPA_WN_18': '21',
#  'ALB_TPA_WN_21': '0',
#  'ALB_TPA_WN_6': '9',
#  'ALB_TPA_WN_7': '10',
#  'ALB_TPA_WN_8': '11',
#  'ALB_TPA_WN_9': '12',
#  'ALO_ORD_MQ_0': '7',
#  'ALO_ORD_MQ_13': '14',
#  'ALO_ORD_MQ_14': '16',
#  'ALO_ORD_MQ_6': '7',
#  'ALO_ORD_MQ_8': '10',
#  'ALO_ORD_MQ_9': '10',
#  'AMA_DAL_WN_0': '6',
#  'AMA_DAL_WN_10': '11',
#  'AMA_DAL_WN_11': '12',
#  'AMA_DAL_WN_12': '13',
#  'AMA_DAL_WN_13': '14',
#  'AMA_DAL_WN_14': '15',
#  'AMA_DAL_WN_15': '16',
#  'AMA_DAL_WN_16': '17',
#  'AMA_DAL_WN_17': '18',
#  'AMA_DAL_WN_18': '19',
#  'AMA_DAL_WN_19': '20',
#  'AMA_DAL_WN_6': '7',
#  'AMA_DAL_WN_7': '8',
#  ...}

# %%
with open("dict_mappers/arrTimeHour_dict_2.pkl", "rb") as f:
    arrTimeHour_dict_2 = pickle.load(f)
arrTimeHour_dict_2
# Out:
# {'ABE_ATL': 2,
#  'ABE_BNA': 2,
#  'ABE_CLT': 2,
#  'ABE_DTW': 2,
#  'ABE_FLL': 3,
#  'ABE_MYR': 2,
#  'ABE_ORD': 2,
#  'ABE_PGD': 3,
#  'ABE_PIE': 3,
#  'ABE_SAV': 2,
#  'ABE_SFB': 2,
#  'ABI_DFW': 1,
#  'ABQ_ATL': 3,
#  'ABQ_AUS': 2,
#  'ABQ_BWI': 4,
#  'ABQ_DAL': 2,
#  'ABQ_DEN': 1,
#  'ABQ_DFW': 2,
#  'ABQ_HOU': 2,
#  'ABQ_IAH': 2,
#  'ABQ_JFK': 4,
#  'ABQ_LAS': 2,
#  'ABQ_LAX': 2,
#  'ABQ_MCI': 2,
#  'ABQ_MCO': 4,
#  'ABQ_MDW': 3,
#  'ABQ_MSP': 3,
#  'ABQ_OAK': 2,
#  'ABQ_ORD': 3,
#  'ABQ_PDX': 3,
#  'ABQ_PHX': 1,
#  'ABQ_SAN': 2,
#  'ABQ_SAT': 2,
#  'ABQ_SEA': 3,
#  'ABQ_SFO': 3,
#  'ABQ_SJC': 2,
#  'ABQ_SLC': 2,
#  'ABR_MSP': 1,
#  'ABY_ATL': 1,
#  'ACK_BOS': 1,
#  'ACK_CLT': 3,
#  'ACK_DCA': 2,
#  'ACK_HPN': 1,
#  'ACK_JFK': 1,
#  'ACK_LGA': 1,
#  'ACT_DFW': 1,
#  'ACV_DEN': 3,
#  'ACV_LAX': 2,
#  'ACV_SFO': 1,
#  'ACY_ATL': 2,
#  'ACY_FLL': 3,
#  'ACY_MCO': 3,
#  'ACY_MYR': 2,
#  'ACY_PBI': 3,
#  'ACY_RSW': 3,
#  'ACY_TPA': 2,
#  'ADK_ANC': 3,
#  'ADQ_ANC': 1,
#  'AEX_ATL': 2,
#  'AEX_DFW': 1,
#  'AEX_IAH': 1,
#  'AGS_ATL': 1,
#  'AGS_CLT': 1,
#  'AGS_DCA': 2,
#  'AGS_DFW': 3,
#  'AGS_LGA': 2,
#  'AGS_MIA': 2,
#  'AGS_ORD': 2,
#  'AGS_PHL': 2,
#  'AKN_ANC': 1,
#  'ALB_ATL': 3,
#  'ALB_BWI': 1,
#  'ALB_CLT': 2,
#  'ALB_DCA': 2,
#  'ALB_DEN': 4,
#  'ALB_DTW': 2,
#  'ALB_EWR': 1,
#  'ALB_FLL': 3,
#  'ALB_IAD': 1,
#  'ALB_MCO': 3,
#  'ALB_MDW': 2,
#  'ALB_MSP': 3,
#  'ALB_MYR': 2,
#  'ALB_ORD': 2,
#  'ALB_PGD': 3,
#  'ALB_PHL': 1,
#  'ALB_PIE': 3,
#  'ALB_RDU': 2,
#  'ALB_RSW': 3,
#  'ALB_SAV': 2,
#  'ALB_SFB': 3,
#  'ALB_TPA': 3,
#  'ALO_ORD': 1,
#  'AMA_DAL': 1,
#  'AMA_DEN': 1,
#  'AMA_DFW': 1,
#  'AMA_HOU': 2,
#  'AMA_IAH': 2,
#  'AMA_LAS': 2,
#  'AMA_PHX': 2,
#  'ANC_ADK': 3,
#  'ANC_ADQ': 1,
#  'ANC_AKN': 1,
#  'ANC_ATL': 7,
#  'ANC_BET': 1,
#  'ANC_BLI': 3,
#  'ANC_BRW': 2,
#  'ANC_CDV': 1,
#  'ANC_DEN': 5,
#  'ANC_DFW': 6,
#  'ANC_DLG': 1,
#  'ANC_EWR': 7,
#  'ANC_FAI': 1,
#  'ANC_HNL': 6,
#  'ANC_IAH': 7,
#  'ANC_JNU': 2,
#  'ANC_KOA': 7,
#  'ANC_LAX': 5,
#  'ANC_MSP': 5,
#  'ANC_OGG': 6,
#  'ANC_OME': 2,
#  'ANC_ORD': 6,
#  'ANC_OTZ': 2,
#  'ANC_PDX': 4,
#  'ANC_PHX': 6,
#  'ANC_SCC': 2,
#  'ANC_SEA': 4,
#  'ANC_SFO': 5,
#  'ANC_SLC': 5,
#  'APN_DTW': 1,
#  'APN_PLN': 1,
#  'ART_PHL': 1,
#  'ASE_ATL': 3,
#  'ASE_DEN': 1,
#  'ASE_DFW': 2,
#  'ASE_IAH': 3,
#  'ASE_LAX': 2,
#  'ASE_MSP': 2,
#  'ASE_ORD': 3,
#  'ASE_PHX': 2,
#  'ASE_SFO': 3,
#  'ASE_SLC': 1,
#  'ATL_ABE': 2,
#  'ATL_ABQ': 3,
#  'ATL_ABY': 1,
#  'ATL_ACY': 2,
#  'ATL_AEX': 2,
#  'ATL_AGS': 1,
#  'ATL_ALB': 2,
#  'ATL_ANC': 8,
#  'ATL_ASE': 4,
#  'ATL_ATW': 2,
#  'ATL_AUS': 2,
#  'ATL_AVL': 1,
#  'ATL_AVP': 2,
#  'ATL_BDL': 2,
#  'ATL_BHM': 1,
#  'ATL_BMI': 2,
#  'ATL_BNA': 1,
#  'ATL_BOS': 3,
#  'ATL_BQK': 1,
#  'ATL_BTR': 2,
#  'ATL_BTV': 2,
#  'ATL_BUF': 2,
#  'ATL_BUR': 5,
#  'ATL_BWI': 2,
#  'ATL_BZN': 4,
#  'ATL_CAE': 1,
#  'ATL_CAK': 2,
#  'ATL_CHA': 1,
#  'ATL_CHO': 2,
#  'ATL_CHS': 1,
#  'ATL_CID': 2,
#  'ATL_CLE': 2,
#  'ATL_CLT': 1,
#  'ATL_CMH': 2,
#  'ATL_COS': 3,
#  'ATL_CRW': 1,
#  'ATL_CSG': 1,
#  'ATL_CVG': 1,
#  'ATL_DAB': 1,
#  'ATL_DAL': 2,
#  'ATL_DAY': 2,
#  'ATL_DCA': 2,
#  'ATL_DEN': 3,
#  'ATL_DFW': 3,
#  'ATL_DSM': 2,
#  'ATL_DTW': 2,
#  'ATL_ECP': 1,
#  'ATL_EGE': 4,
#  'ATL_ELM': 2,
#  'ATL_ELP': 3,
#  'ATL_EVV': 1,
#  'ATL_EWN': 2,
#  'ATL_EWR': 2,
#  'ATL_EYW': 2,
#  'ATL_FAR': 3,
#  'ATL_FAY': 1,
#  'ATL_FLL': 2,
#  'ATL_FNT': 2,
#  'ATL_FSD': 3,
#  'ATL_FSM': 2,
#  'ATL_FWA': 2,
#  'ATL_GNV': 1,
#  'ATL_GPT': 1,
#  'ATL_GRB': 2,
#  'ATL_GRR': 2,
#  'ATL_GSO': 1,
#  'ATL_GSP': 1,
#  'ATL_GTR': 1,
#  'ATL_HDN': 4,
#  'ATL_HNL': 10,
#  'ATL_HOU': 2,
#  'ATL_HPN': 2,
#  'ATL_HSV': 1,
#  'ATL_IAD': 2,
#  'ATL_IAH': 2,
#  'ATL_ICT': 2,
#  'ATL_ILM': 1,
#  'ATL_IND': 2,
#  'ATL_ISP': 2,
#  'ATL_JAC': 4,
#  'ATL_JAN': 1,
#  'ATL_JAX': 1,
#  'ATL_JFK': 2,
#  'ATL_LAS': 5,
#  'ATL_LAX': 5,
#  'ATL_LEX': 1,
#  'ATL_LFT': 2,
#  'ATL_LGA': 2,
#  'ATL_LIT': 2,
#  'ATL_LNK': 2,
#  'ATL_MCI': 2,
#  'ATL_MCO': 2,
#  'ATL_MDT': 2,
#  'ATL_MDW': 2,
#  'ATL_MEM': 1,
#  'ATL_MGM': 1,
#  'ATL_MHT': 3,
#  'ATL_MIA': 2,
#  'ATL_MKE': 2,
#  'ATL_MLB': 2,
#  'ATL_MLI': 2,
#  'ATL_MLU': 2,
#  'ATL_MOB': 1,
#  'ATL_MSN': 2,
#  'ATL_MSO': 5,
#  'ATL_MSP': 3,
#  'ATL_MSY': 2,
#  'ATL_MTJ': 4,
#  'ATL_MYR': 1,
#  'ATL_OAJ': 1,
#  'ATL_OAK': 5,
#  'ATL_OKC': 2,
#  'ATL_OMA': 2,
#  'ATL_ONT': 4,
#  'ATL_ORD': 2,
#  'ATL_ORF': 2,
#  'ATL_PBI': 2,
#  'ATL_PDX': 5,
#  'ATL_PHF': 2,
#  'ATL_PHL': 2,
#  'ATL_PHX': 4,
#  'ATL_PIA': 2,
#  'ATL_PIT': 2,
#  'ATL_PNS': 1,
#  'ATL_PSP': 5,
#  'ATL_PVD': 2,
#  'ATL_PWM': 3,
#  'ATL_RAP': 3,
#  'ATL_RDU': 1,
#  'ATL_RIC': 2,
#  'ATL_RNO': 5,
#  'ATL_ROA': 1,
#  'ATL_ROC': 2,
#  'ATL_RST': 2,
#  'ATL_RSW': 2,
#  'ATL_SAN': 4,
#  'ATL_SAT': 3,
#  'ATL_SAV': 1,
#  'ATL_SBN': 2,
#  'ATL_SDF': 1,
#  'ATL_SEA': 5,
#  'ATL_SFO': 5,
#  'ATL_SGF': 2,
#  'ATL_SHV': 2,
#  'ATL_SJC': 5,
#  'ATL_SJU': 4,
#  'ATL_SLC': 4,
#  'ATL_SMF': 5,
#  'ATL_SNA': 5,
#  'ATL_SRQ': 1,
#  'ATL_STL': 2,
#  'ATL_STT': 4,
#  'ATL_STX': 4,
#  'ATL_SYR': 2,
#  'ATL_TLH': 1,
#  'ATL_TPA': 1,
#  'ATL_TRI': 1,
#  'ATL_TTN': 2,
#  'ATL_TUL': 2,
#  'ATL_TUS': 4,
#  'ATL_TVC': 2,
#  'ATL_TYS': 1,
#  'ATL_VLD': 1,
#  'ATL_VPS': 1,
#  'ATL_XNA': 2,
#  'ATW_ATL': 2,
#  'ATW_DTW': 1,
#  'ATW_LAS': 4,
#  'ATW_MSP': 1,
#  'ATW_ORD': 1,
#  'ATW_PGD': 3,
#  'ATW_PIE': 3,
#  'ATW_SFB': 3,
#  'ATY_DEN': 2,
#  'ATY_ORD': 2,
#  'ATY_PIR': 1,
#  'AUS_ABQ': 2,
#  'AUS_ATL': 2,
#  'AUS_BNA': 2,
#  'AUS_BOS': 4,
#  'AUS_BTR': 2,
#  'AUS_BWI': 3,
#  'AUS_CLE': 3,
#  'AUS_CLT': 3,
#  'AUS_CMH': 3,
#  'AUS_CVG': 3,
#  'AUS_DAL': 1,
#  'AUS_DCA': 3,
#  'AUS_DEN': 2,
#  'AUS_DFW': 1,
#  'AUS_DTW': 3,
#  'AUS_ECP': 2,
#  'AUS_ELP': 2,
#  'AUS_EWR': 4,
#  'AUS_FLL': 3,
#  'AUS_HOU': 1,
#  'AUS_IAD': 3,
#  'AUS_IAH': 1,
#  'AUS_IND': 2,
#  'AUS_JFK': 4,
#  'AUS_LAS': 3,
#  'AUS_LAX': 3,
#  'AUS_LBB': 1,
#  'AUS_LGB': 3,
#  'AUS_MCI': 2,
#  'AUS_MCO': 2,
#  'AUS_MDW': 2,
#  'AUS_MEM': 2,
#  'AUS_MIA': 3,
#  'AUS_MSP': 3,
#  'AUS_MSY': 1,
#  'AUS_OAK': 4,
#  'AUS_ONT': 3,
#  'AUS_ORD': 3,
#  'AUS_PDX': 4,
#  'AUS_PHL': 4,
#  'AUS_PHX': 2,
#  'AUS_PIT': 3,
#  'AUS_PNS': 2,
#  'AUS_RDU': 3,
#  'AUS_SAN': 3,
#  'AUS_SEA': 5,
#  'AUS_SFB': 2,
#  'AUS_SFO': 4,
#  'AUS_SJC': 4,
#  'AUS_SLC': 3,
#  'AUS_SMF': 4,
#  'AUS_SNA': 3,
#  'AUS_STL': 2,
#  'AUS_TPA': 2,
#  'AUS_VPS': 2,
#  'AVL_ATL': 1,
#  'AVL_BWI': 1,
#  'AVL_CLT': 1,
#  'AVL_DEN': 3,
#  'AVL_DFW': 3,
#  'AVL_DTW': 2,
#  'AVL_EWR': 2,
#  'AVL_FLL': 2,
#  'AVL_IAD': 2,
#  'AVL_LGA': 2,
#  'AVL_MCO': 2,
#  'AVL_ORD': 2,
#  'AVL_PBI': 2,
#  'AVL_PGD': 2,
#  'AVL_PHL': 2,
#  'AVL_PIE': 2,
#  'AVL_SFB': 2,
#  'AVL_SRQ': 2,
#  'AVL_TPA': 2,
#  'AVP_ATL': 2,
#  'AVP_CLT': 2,
#  'AVP_DTW': 2,
#  'AVP_IAD': 1,
#  'AVP_ORD': 2,
#  'AZO_DTW': 1,
#  'AZO_MSP': 2,
#  'AZO_ORD': 1,
#  'BDL_ATL': 3,
#  'BDL_BWI': 1,
#  'BDL_CLE': 2,
#  'BDL_CLT': 2,
#  'BDL_CVG': 2,
#  'BDL_DCA': 2,
#  'BDL_DEN': 5,
#  'BDL_DFW': 4,
#  'BDL_DTW': 2,
#  'BDL_FLL': 3,
#  'BDL_IAD': 1,
#  'BDL_IAH': 4,
#  'BDL_LAX': 6,
#  'BDL_MCO': 3,
#  'BDL_MDW': 2,
#  'BDL_MIA': 3,
#  'BDL_MSP': 3,
#  'BDL_MYR': 2,
#  'BDL_ORD': 3,
#  'BDL_PBI': 3,
#  'BDL_PHL': 1,
#  'BDL_RDU': 2,
#  'BDL_RSW': 3,
#  'BDL_SJU': 4,
#  'BDL_STL': 3,
#  'BDL_TPA': 3,
#  'BET_ANC': 1,
#  'BFF_DEN': 1,
#  'BFL_DEN': 3,
#  'BFL_DFW': 3,
#  'BFL_PHX': 2,
#  'BFL_SFO': 1,
#  'BFM_DEN': 3,
#  'BFM_ORD': 3,
#  'BGM_DTW': 2,
#  'BGR_CLT': 3,
#  'BGR_DCA': 2,
#  'BGR_DTW': 2,
#  'BGR_EWR': 2,
#  'BGR_LGA': 2,
#  'BGR_ORD': 3,
#  'BGR_PHL': 2,
#  'BGR_PIE': 4,
#  'BGR_SFB': 3,
#  'BHM_ATL': 1,
#  'BHM_BWI': 2,
#  'BHM_CAE': 2,
#  'BHM_CLL': 2,
#  'BHM_CLT': 2,
#  'BHM_DAL': 2,
#  'BHM_DCA': 2,
#  'BHM_DEN': 3,
#  'BHM_DFW': 2,
#  'BHM_DTW': 2,
#  'BHM_FLL': 2,
#  'BHM_HOU': 2,
#  'BHM_IAH': 2,
#  'BHM_LAS': 4,
#  'BHM_LGA': 3,
#  'BHM_MCO': 2,
#  'BHM_MDW': 2,
#  'BHM_MIA': 2,
#  'BHM_ORD': 2,
#  'BHM_PHL': 2,
#  'BHM_SFO': 5,
#  'BHM_SJC': 5,
#  'BHM_TPA': 1,
#  'BIL_DEN': 2,
#  'BIL_DFW': 3,
#  'BIL_LAS': 2,
#  'BIL_LAX': 3,
#  'BIL_MSP': 2,
#  'BIL_ORD': 3,
#  'BIL_SLC': 1,
#  'BIS_DEN': 2,
#  'BIS_DFW': 3,
#  'BIS_LAS': 3,
#  'BIS_MSP': 2,
#  'BIS_ORD': 2,
#  'BIS_SFB': 4,
#  'BJI_MSP': 1,
#  'BLI_ANC': 3,
#  'BLI_KOA': 7,
#  'BLI_LAS': 2,
#  'BLI_LAX': 3,
#  'BLI_OAK': 2,
#  'BLI_OGG': 7,
#  'BLI_PSP': 3,
#  'BLI_SAN': 3,
#  'BLI_SEA': 1,
#  'BLI_TUS': 3,
#  'BLV_FLL': 3,
#  'BLV_JAX': 2,
#  'BLV_LAS': 3,
#  'BLV_MYR': 2,
#  'BLV_PGD': 2,
#  'BLV_PIE': 2,
#  'BLV_SFB': 2,
#  'BLV_SRQ': 2,
#  'BLV_VPS': 2,
#  'BMI_ATL': 2,
#  'BMI_DEN': 3,
#  'BMI_DFW': 2,
#  'BMI_MCO': 3,
#  'BMI_ORD': 1,
#  'BMI_PIE': 2,
#  'BMI_SFB': 2,
#  'BNA_ABE': 2,
#  'BNA_ATL': 1,
#  'BNA_AUS': 2,
#  'BNA_BOS': 2,
#  'BNA_BUF': 2,
#  'BNA_BUR': 4,
#  'BNA_BWI': 2,
#  'BNA_CHS': 1,
#  'BNA_CID': 2,
#  'BNA_CLE': 1,
#  'BNA_CLT': 2,
#  'BNA_CMH': 1,
#  'BNA_DAL': 2,
#  'BNA_DCA': 2,
#  'BNA_DEN': 3,
#  'BNA_DFW': 2,
#  'BNA_DTW': 2,
#  'BNA_ECP': 1,
#  'BNA_EWR': 2,
#  'BNA_FLL': 2,
#  'BNA_GRR': 1,
#  'BNA_HOU': 2,
#  'BNA_IAD': 2,
#  'BNA_IAH': 2,
#  'BNA_JAX': 1,
#  'BNA_JFK': 3,
#  'BNA_LAS': 4,
#  'BNA_LAX': 5,
#  'BNA_LGA': 2,
#  'BNA_MCI': 2,
#  'BNA_MCO': 2,
#  'BNA_MDT': 2,
#  'BNA_MDW': 2,
#  'BNA_MIA': 2,
#  'BNA_MKE': 2,
#  'BNA_MSN': 2,
#  'BNA_MSP': 2,
#  'BNA_MSY': 2,
#  'BNA_OAK': 5,
#  'BNA_OKC': 2,
#  'BNA_OMA': 2,
#  'BNA_ORD': 2,
#  'BNA_ORF': 2,
#  'BNA_PGD': 2,
#  'BNA_PHL': 2,
#  'BNA_PHX': 4,
#  'BNA_PIE': 2,
#  'BNA_PIT': 1,
#  'BNA_PNS': 1,
#  'BNA_RDU': 2,
#  'BNA_RIC': 2,
#  'BNA_RSW': 2,
#  'BNA_SAN': 4,
#  'BNA_SAT': 2,
#  'BNA_SAV': 1,
#  'BNA_SEA': 5,
#  'BNA_SFB': 2,
#  'BNA_SFO': 5,
#  'BNA_SJC': 5,
#  'BNA_SLC': 4,
#  'BNA_SMF': 5,
#  'BNA_SRQ': 2,
#  'BNA_STL': 1,
#  'BNA_SYR': 2,
#  'BNA_TPA': 2,
#  'BNA_TTN': 2,
#  'BNA_XNA': 1,
#  'BOI_DAL': 3,
#  'BOI_DEN': 2,
#  'BOI_DFW': 3,
#  'BOI_GEG': 1,
#  'BOI_IAH': 4,
#  'BOI_LAS': 2,
#  'BOI_LAX': 2,
#  'BOI_MDW': 3,
#  'BOI_MSP': 3,
#  'BOI_OAK': 2,
#  'BOI_ORD': 4,
#  'BOI_PDX': 1,
#  'BOI_PHX': 2,
#  'BOI_SAN': 2,
#  'BOI_SEA': 2,
#  'BOI_SFO': 2,
#  'BOI_SJC': 2,
#  'BOI_SLC': 1,
#  'BOI_SMF': 2,
#  'BOS_ACK': 1,
#  'BOS_ATL': 3,
#  'BOS_AUS': 4,
#  'BOS_BNA': 3,
#  'BOS_BUF': 2,
#  'BOS_BUR': 7,
#  'BOS_BWI': 2,
#  'BOS_CHS': 2,
#  'BOS_CLE': 2,
#  'BOS_CLT': 2,
#  'BOS_CMH': 2,
#  'BOS_CVG': 2,
#  'BOS_DAL': 4,
#  'BOS_DCA': 2,
#  'BOS_DEN': 5,
#  'BOS_DFW': 4,
#  'BOS_DTW': 2,
#  'BOS_EWR': 1,
#  'BOS_FLL': 3,
#  'BOS_GSP': 3,
#  'BOS_HDN': 5,
#  'BOS_HNL': 11,
#  'BOS_HOU': 5,
#  'BOS_IAD': 2,
#  'BOS_IAH': 4,
#  'BOS_IND': 3,
#  'BOS_JAX': 3,
#  'BOS_JFK': 1,
#  'BOS_LAS': 6,
#  'BOS_LAX': 6,
#  'BOS_LGA': 1,
#  'BOS_LGB': 6,
#  'BOS_MCI': 4,
#  'BOS_MCO': 3,
#  'BOS_MDW': 3,
#  'BOS_MIA': 4,
#  'BOS_MKE': 3,
#  'BOS_MSN': 2,
#  'BOS_MSP': 3,
#  'BOS_MSY': 4,
#  'BOS_MVY': 1,
#  'BOS_MYR': 2,
#  'BOS_OAK': 7,
#  'BOS_ORD': 3,
#  'BOS_ORF': 2,
#  'BOS_PBI': 3,
#  'BOS_PDX': 6,
#  'BOS_PHL': 2,
#  'BOS_PHX': 6,
#  'BOS_PIT': 2,
#  'BOS_PSP': 6,
#  'BOS_RDU': 2,
#  'BOS_RIC': 2,
#  'BOS_ROC': 2,
#  'BOS_RSW': 3,
#  'BOS_SAN': 6,
#  'BOS_SAV': 3,
#  'BOS_SBN': 3,
#  'BOS_SEA': 6,
#  'BOS_SFO': 7,
#  'BOS_SJC': 7,
#  'BOS_SJU': 4,
#  'BOS_SLC': 6,
#  'BOS_SMF': 7,
#  'BOS_SRQ': 4,
#  'BOS_STL': 3,
#  'BOS_STT': 4,
#  'BOS_SYR': 1,
#  'BOS_TPA': 3,
#  'BPT_DFW': 1,
#  'BQK_ATL': 1,
#  'BQN_EWR': 4,
#  'BQN_FLL': 3,
#  'BQN_JFK': 4,
#  'BQN_MCO': 3,
#  'BRD_MSP': 1,
#  'BRO_DEN': 3,
#  'BRO_DFW': 2,
#  'BRO_IAH': 1,
#  'BRO_ORD': 3,
#  'BRW_ANC': 2,
#  'BRW_FAI': 1,
#  'BTM_SLC': 1,
#  'BTR_ATL': 2,
#  'BTR_AUS': 2,
#  'BTR_CLT': 2,
#  'BTR_DCA': 3,
#  'BTR_DFW': 2,
#  'BTR_IAH': 1,
#  'BTV_ATL': 3,
#  'BTV_CLT': 2,
#  'BTV_DCA': 2,
#  'BTV_DEN': 4,
#  'BTV_DTW': 2,
#  'BTV_EWR': 2,
#  'BTV_IAD': 2,
#  'BTV_JFK': 1,
#  'BTV_LGA': 1,
#  'BTV_MCO': 3,
#  'BTV_ORD': 3,
#  'BTV_PHL': 1,
#  'BUF_ATL': 2,
#  'BUF_BNA': 2,
#  'BUF_BOS': 1,
#  'BUF_BWI': 1,
#  'BUF_CLT': 2,
#  'BUF_DCA': 1,
#  'BUF_DEN': 4,
#  'BUF_DFW': 3,
#  'BUF_DTW': 1,
#  'BUF_EWR': 1,
#  'BUF_FLL': 3,
#  'BUF_IAD': 1,
#  'BUF_JFK': 1,
#  'BUF_LAS': 5,
#  'BUF_LAX': 5,
#  'BUF_LGA': 1,
#  'BUF_MCO': 3,
#  'BUF_MDW': 2,
#  'BUF_MIA': 4,
#  'BUF_MSP': 2,
#  'BUF_ORD': 2,
#  'BUF_PHL': 2,
#  'BUF_PHX': 5,
#  'BUF_RDU': 2,
#  'BUF_RSW': 3,
#  'BUF_TPA': 3,
#  'BUR_ATL': 4,
#  'BUR_BNA': 4,
#  'BUR_BOS': 5,
#  'BUR_DAL': 3,
#  'BUR_DEN': 2,
#  'BUR_DFW': 3,
#  'BUR_HOU': 3,
#  'BUR_JFK': 6,
#  'BUR_LAS': 1,
#  'BUR_MDW': 4,
#  'BUR_OAK': 1,
#  'BUR_PDX': 2,
#  'BUR_PHX': 2,
#  'BUR_SEA': 3,
#  'BUR_SFO': 1,
#  'BUR_SJC': 1,
#  'BUR_SLC': 2,
#  'BUR_SMF': 1,
#  'BWI_ABQ': 4,
#  'BWI_ALB': 1,
#  'BWI_ATL': 2,
#  'BWI_AUS': 4,
#  'BWI_AVL': 1,
#  'BWI_BDL': 1,
#  'BWI_BHM': 2,
#  'BWI_BNA': 2,
#  'BWI_BOS': 2,
#  'BWI_BUF': 1,
#  'BWI_CHS': 2,
#  'BWI_CLE': 1,
#  'BWI_CLT': 2,
#  'BWI_CMH': 1,
#  'BWI_CVG': 2,
#  'BWI_DAL': 3,
#  'BWI_DEN': 4,
#  'BWI_DFW': 3,
#  'BWI_DTW': 2,
#  'BWI_ECP': 2,
#  'BWI_EWR': 1,
#  'BWI_FLL': 3,
#  'BWI_GRR': 2,
#  'BWI_GSP': 2,
#  'BWI_HOU': 3,
#  'BWI_IAH': 4,
#  'BWI_IND': 2,
#  'BWI_ISP': 1,
#  'BWI_JAX': 2,
#  'BWI_JFK': 1,
#  'BWI_LAS': 5,
#  'BWI_LAX': 6,
#  'BWI_MCI': 3,
#  'BWI_MCO': 2,
#  'BWI_MDW': 2,
#  'BWI_MEM': 2,
#  'BWI_MHT': 1,
#  'BWI_MIA': 3,
#  'BWI_MKE': 2,
#  'BWI_MSP': 3,
#  'BWI_MSY': 3,
#  'BWI_MYR': 1,
#  'BWI_OAK': 6,
#  'BWI_OKC': 3,
#  'BWI_ORD': 2,
#  'BWI_ORF': 1,
#  'BWI_PBI': 3,
#  'BWI_PDX': 6,
#  'BWI_PHL': 1,
#  'BWI_PHX': 5,
#  'BWI_PIT': 1,
#  'BWI_PVD': 1,
#  'BWI_PWM': 2,
#  'BWI_RDU': 1,
#  'BWI_ROC': 1,
#  'BWI_RSW': 3,
#  'BWI_SAN': 5,
#  'BWI_SAT': 4,
#  'BWI_SAV': 2,
#  'BWI_SDF': 2,
#  'BWI_SEA': 6,
#  'BWI_SFO': 6,
#  'BWI_SJC': 6,
#  'BWI_SJU': 4,
#  'BWI_SLC': 5,
#  'BWI_SMF': 6,
#  'BWI_SRQ': 2,
#  'BWI_STL': 2,
#  'BWI_TPA': 2,
#  'BWI_TYS': 1,
#  'BWI_VPS': 2,
#  'BZN_ATL': 4,
#  'BZN_DEN': 2,
#  'BZN_DFW': 3,
#  'BZN_DTW': 3,
#  'BZN_EWR': 4,
#  'BZN_IAH': 3,
#  'BZN_LAS': 2,
#  'BZN_LAX': 3,
#  'BZN_LGA': 4,
#  'BZN_LGB': 3,
#  'BZN_MSP': 2,
#  'BZN_ORD': 3,
#  'BZN_PDX': 2,
#  'BZN_SEA': 2,
#  'BZN_SFO': 3,
#  'BZN_SLC': 1,
#  'CAE_ATL': 1,
#  'CAE_BHM': 2,
#  'CAE_CLT': 1,
#  'CAE_DCA': 1,
#  'CAE_DFW': 3,
#  'CAE_IAD': 1,
#  'CAE_IAH': 3,
#  'CAE_LGA': 2,
#  'CAE_MIA': 2,
#  'CAK_ATL': 2,
#  'CAK_CLT': 2,
#  'CAK_DCA': 1,
#  'CAK_EWR': 2,
#  'CAK_IAH': 3,
#  'CAK_LGA': 2,
#  'CAK_MCO': 2,
#  'CAK_ORD': 2,
#  'CAK_PHL': 1,
#  'CAK_RSW': 3,
#  'CAK_TPA': 3,
#  'CDC_SLC': 1,
#  'CDV_ANC': 1,
#  'CDV_YAK': 1,
#  'CGI_ORD': 2,
#  'CGI_UIN': 1,
#  'CHA_ATL': 1,
#  'CHA_CLT': 1,
#  'CHA_DCA': 2,
#  'CHA_DFW': 2,
#  'CHA_DTW': 2,
#  'CHA_IAD': 2,
#  'CHA_LGA': 2,
#  'CHA_MSP': 2,
#  'CHA_ORD': 2,
#  'CHA_PHL': 2,
#  'CHA_PIE': 2,
#  'CHA_SFB': 1,
#  'CHO_ATL': 2,
#  'CHO_CLT': 1,
#  'CHO_LGA': 1,
#  'CHO_ORD': 2,
#  'CHS_ATL': 1,
#  'CHS_BNA': 1,
#  'CHS_BOS': 2,
#  'CHS_BWI': 2,
#  'CHS_CLE': 2,
#  'CHS_CLT': 1,
#  'CHS_CVG': 2,
#  'CHS_DAL': 3,
#  'CHS_DCA': 2,
#  'CHS_DEN': 4,
#  'CHS_DFW': 3,
#  'CHS_DTW': 2,
#  'CHS_EWR': 2,
#  'CHS_FLL': 2,
#  'CHS_HOU': 3,
#  'CHS_IAD': 2,
#  'CHS_IAH': 3,
#  'CHS_IND': 2,
#  'CHS_JFK': 2,
#  'CHS_LCK': 2,
#  'CHS_LGA': 2,
#  'CHS_MDW': 2,
#  'CHS_MIA': 2,
#  'CHS_MSP': 3,
#  'CHS_ORD': 2,
#  'CHS_PGD': 1,
#  'CHS_PHL': 2,
#  'CHS_PIT': 2,
#  'CHS_SEA': 6,
#  'CHS_STL': 2,
#  'CHS_TTN': 2,
#  'CID_ATL': 2,
#  'CID_BNA': 1,
#  'CID_CLT': 2,
#  'CID_DEN': 2,
#  'CID_DFW': 2,
#  'CID_DTW': 2,
#  'CID_LAS': 3,
#  'CID_LAX': 4,
#  'CID_MSP': 1,
#  'CID_ORD': 1,
#  'CID_PGD': 3,
#  'CID_PHX': 4,
#  'CID_PIE': 3,
#  'CID_SFB': 3,
#  'CIU_DTW': 1,
#  'CIU_MSP': 2,
#  'CKB_AVL': 1,
#  'CKB_IAD': 1,
#  'CKB_MYR': 1,
#  'CKB_ORD': 2,
#  'CKB_SFB': 2,
#  'CLE_ATL': 2,
#  'CLE_AUS': 3,
#  'CLE_BDL': 2,
#  'CLE_BNA': 2,
#  'CLE_BOS': 2,
#  'CLE_BWI': 1,
#  'CLE_CHS': 2,
#  'CLE_CLT': 2,
#  'CLE_DAL': 3,
#  'CLE_DCA': 1,
#  'CLE_DEN': 3,
#  'CLE_DFW': 3,
#  'CLE_DTW': 1,
#  'CLE_EWR': 2,
#  'CLE_FLL': 3,
#  'CLE_IAD': 1,
#  'CLE_IAH': 3,
#  'CLE_JAX': 2,
#  'CLE_JFK': 2,
#  'CLE_LAS': 5,
#  'CLE_LAX': 5,
#  'CLE_LGA': 2,
#  'CLE_MCO': 2,
#  'CLE_MDW': 1,
#  'CLE_MIA': 3,
#  'CLE_MKE': 1,
#  'CLE_MSP': 2,
#  'CLE_MSY': 3,
#  'CLE_MYR': 2,
#  'CLE_ORD': 2,
#  'CLE_ORF': 1,
#  'CLE_PBI': 3,
#  'CLE_PGD': 2,
#  'CLE_PHL': 2,
#  'CLE_PHX': 4,
#  'CLE_PIE': 2,
#  'CLE_RDU': 2,
#  'CLE_RSW': 3,
#  'CLE_SAN': 5,
#  'CLE_SAV': 2,
#  'CLE_SEA': 5,
#  'CLE_SFB': 2,
#  'CLE_SFO': 5,
#  'CLE_SLC': 4,
#  'CLE_SRQ': 2,
#  'CLE_STL': 2,
#  'CLE_TPA': 3,
#  'CLE_VPS': 2,
#  'CLL_BHM': 2,
#  'CLL_DFW': 1,
#  'CLL_IAH': 1,
#  'CLT_ABE': 2,
#  'CLT_ACK': 2,
#  'CLT_AGS': 1,
#  'CLT_ALB': 2,
#  'CLT_ATL': 1,
#  'CLT_AUS': 3,
#  'CLT_AVL': 1,
#  'CLT_AVP': 2,
#  'CLT_BDL': 2,
#  'CLT_BGR': 2,
#  'CLT_BHM': 1,
#  'CLT_BNA': 1,
#  'CLT_BOS': 2,
#  'CLT_BTR': 2,
#  'CLT_BTV': 2,
#  'CLT_BUF': 2,
#  'CLT_BWI': 1,
#  'CLT_CAE': 1,
#  'CLT_CAK': 1,
#  'CLT_CHA': 1,
#  'CLT_CHO': 1,
#  'CLT_CHS': 1,
#  'CLT_CID': 2,
#  'CLT_CLE': 2,
#  'CLT_CMH': 1,
#  'CLT_CMI': 2,
#  'CLT_CRW': 1,
#  'CLT_CVG': 1,
#  'CLT_DAB': 2,
#  'CLT_DAL': 3,
#  'CLT_DAY': 2,
#  ...}

# %% [markdown]
# # Generate `Streamlit` file

# %%
# %%writefile flight_delay_predictor.py

# Import libraries to be used

# Directories/Files management
import os

# Timing
import time
import datetime

# Objects storage:
import joblib
import pickle

# Online data retrieval:
import requests

# Data analysis and wrangling
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) # Show all columns in DataFrames
## pd.set_option('display.max_rows', None) # It greatly slows down the output display and may freeze the kernel
import missingno as msno
from collections import Counter

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('ggplot') # choose a style: 'plt.style.available'
sns.set_theme(context='notebook',
              style="darkgrid") # {darkgrid, whitegrid, dark, white, ticks}
palette = sns.color_palette("flare", as_cmap=True);
import altair as alt

# Machine Learning:
# - Model selection:
from sklearn.model_selection import train_test_split, StratifiedShuffleSplit, KFold, cross_val_score, StratifiedKFold, \
                                    GridSearchCV, RandomizedSearchCV
from sklearn.inspection import permutation_importance

# - Basic classes for custom-made transformers:
from sklearn.base import BaseEstimator, TransformerMixin

# - Transformers:
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from category_encoders.target_encoder import TargetEncoder
from sklearn.impute import SimpleImputer
from sklearn.decomposition import PCA

# - Pipeline:
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# - Models:
from sklearn.linear_model import LogisticRegression
from xgboost import XGBClassifier, plot_importance, plot_tree

# - Metrics:
from sklearn.metrics import fbeta_score, f1_score, recall_score, precision_score, accuracy_score, \
                            confusion_matrix, classification_report, roc_curve, precision_recall_curve, \
                            roc_auc_score, average_precision_score, plot_roc_curve, plot_precision_recall_curve

# Model interpretability:
import shap

# Frontend:
import streamlit as st
import streamlit.components.v1 as components


# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------

# Define the dataset columns:
cols = [
    'MONTH',
    'DAY_OF_WEEK',
    'OP_UNIQUE_CARRIER',
    'ORIGIN',
    'DEST',
    'DEP_TIME_hour',
    'TAXI_OUT_median',
    'TAXI_IN_median',
    'ARR_DEL15', # → Target !!
    'ARR_TIME_hour',
    'DISTANCE',
    'LATITUDE_Origin',
    'LONGITUDE_Origin',
    'HourlyAltimeterSetting_Origin',
    'HourlyDryBulbTemperature_Origin',
    'HourlyPrecipitation_Origin',
    'HourlyRelativeHumidity_Origin',
    'HourlySkyConditions_Origin',
    'HourlyVisibility_Origin',
    'HourlyWindGustSpeed_Origin',
    'HourlyWindSpeed_Origin',
    'LATITUDE_Dest',
    'LONGITUDE_Dest',
    'HourlyAltimeterSetting_Dest',
    'HourlyDryBulbTemperature_Dest',
    'HourlyPrecipitation_Dest',
    'HourlyRelativeHumidity_Dest',
    'HourlySkyConditions_Dest',
    'HourlyVisibility_Dest',
    'HourlyWindGustSpeed_Dest',
    'HourlyWindSpeed_Dest',
]

cols_dtypes = {
    'MONTH' : 'string',
    'DAY_OF_WEEK' : 'string',
    'OP_UNIQUE_CARRIER' : 'string',
    'ORIGIN' : 'string',
    'DEST' : 'string',
    'DEP_TIME_hour' : 'string',
    'TAXI_OUT_median' : 'int32',
    'TAXI_IN_median' : 'int32',
    'ARR_DEL15' : 'int32', # → Target !!
    'ARR_TIME_hour' : 'string',
    'DISTANCE' : 'int32',
    'LATITUDE_Origin' : 'float64',
    'LONGITUDE_Origin' : 'float64',
    'HourlyAltimeterSetting_Origin' : 'float64',
    'HourlyDryBulbTemperature_Origin' : 'int32',
    'HourlyPrecipitation_Origin' : 'float64',
    'HourlyRelativeHumidity_Origin' : 'int32',
    'HourlySkyConditions_Origin' : 'string',
    'HourlyVisibility_Origin' : 'int32',
    'HourlyWindGustSpeed_Origin' : 'int32',
    'HourlyWindSpeed_Origin' : 'int32',
    'LATITUDE_Dest' : 'float64',
    'LONGITUDE_Dest' : 'float64',
    'HourlyAltimeterSetting_Dest' : 'float64',
    'HourlyDryBulbTemperature_Dest' : 'int32',
    'HourlyPrecipitation_Dest' : 'float64',
    'HourlyRelativeHumidity_Dest' : 'int32',
    'HourlySkyConditions_Dest' : 'string',
    'HourlyVisibility_Dest' : 'int32',
    'HourlyWindGustSpeed_Dest' : 'int32',
    'HourlyWindSpeed_Dest' : 'int32',
}

# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------

# # Load the data:
# @st.cache
# def load_data():
#     input_folder = '../../data/output/us_dot-noaa/'
#     file_name = "3_otp_lcd_2019.csv"

#     df = pd.read_csv(input_folder + file_name,
#                      encoding='latin1',
#     #                      nrows=1e5,
#                      usecols=cols,
#                      dtype=cols_dtypes
#                     )
#     X = df.drop(['ARR_DEL15'], axis=1)
#     y = df['ARR_DEL15']
#     return df, X, y

# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------

# Load the model:
# @st.cache
def load_model(path=""):
    model = joblib.load(path)
    return model
    
# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------

def frontend_appearance():
    """
    Design frontend appearance
    """

    # frontend elements of the web page 
    html_temp = """ 
    <div style ="background-color:SteelBlue;padding:13px"> 
    <h1 style ="color:white;text-align:center;">Flight Delay Forecaster</h1> 
    </div> 
    """   

    # display the frontend aspect
    st.markdown(html_temp, unsafe_allow_html = True)

# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------  

@st.cache
def weather_forecast(lat, lon):
    
    # Get/Build the url:
    coord_API_endpoint = "http://api.openweathermap.org/data/2.5/onecall?"
    join_key = "&appid="
    API_key = "b51fbb9d87131aabef6d7c2cd42b128e"
    units = "&units=imperial"
    exclude = "&exclude=current,minutely,daily,alerts"

    lat_lon = "lat=" + str(round(lat, 2))+ "&lon=" + str(round(lon, 2))

    url = coord_API_endpoint + lat_lon + exclude + join_key + API_key + units

    forecast_json_data = requests.get(url).json()
    df_predictions = pd.DataFrame()

    # Creating empty lists
    days = []
    hours = []
    pressures = []
    temperatures = []
    precipitations = []
    relHumidities = []
    skyConditions = []
    visibilities = []
    windGusts = []
    winds = []

    # Loop Through the JSON
    for num_forecasts in forecast_json_data['hourly']: # Hourly forecast for next 48 hours
        days.append(datetime.datetime.fromtimestamp(num_forecasts['dt']).strftime('%Y-%m-%d'))
        hours.append(int(datetime.datetime.fromtimestamp(num_forecasts['dt']).strftime('%H')))
        pressures.append(round(num_forecasts['pressure'] * 0.029529983071445, 2)) # hPa to inHg
        temperatures.append(int(round(num_forecasts['temp'], 0))) # imperial: Fahrenheit
        try: # "Where available"
            precipitations.append(round(num_forecasts['rain']['1h'] * 0.03937007874015748, 2)) # mm to in
        except KeyError:
            precipitations.append(0)
        relHumidities.append(num_forecasts['humidity']) # Humidity, %
        skyConditions.append(num_forecasts['clouds']) # Cloudiness, %
        visibilities.append(int(round(num_forecasts['visibility'] * 0.0006213712, 0))) # m to mi
        try: # "Where available"
            windGusts.append(int(round(num_forecasts['wind_gust'] * 0.8689762, 0))) # mi/h to kt
        except KeyError:
            windGusts.append(0)
        winds.append(int(round(num_forecasts['wind_speed'] * 0.8689762, 0))) # mi/h to kt

    # Put data into a dataframe

    def skycond(x):
        if x == 0:
            return 'CLR'
        elif x < 2/8 * 100:
            return 'FEW'
        elif x < 4/8 * 100:
            return 'SCT'
        elif x < 7/8 * 100:
            return 'BKN'
        elif x <= 8/8 * 100:
            return 'OVC'

    skyConditions = list(map(skycond, skyConditions))

    df_predictions['day'] = days
    df_predictions['hour'] = [str(hour) for hour in hours]
    df_predictions['pressure_inHg'] = pressures
    df_predictions['temperature_F'] = temperatures
    df_predictions['precipitation_in'] = precipitations
    df_predictions['relHumidity_%'] = relHumidities
    df_predictions['skyCondition'] = skyConditions
    df_predictions['visibility_mi'] = visibilities
    df_predictions['windGust_kt'] = windGusts
    df_predictions['wind_kt'] = winds
    
    return df_predictions, url    
       
# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------

# def user_inputs(df):
def user_inputs(root):
    """
    Define user input fields
    """
    
    # Create user input fields:

    
# FLIGHT DATA

    st.markdown('---')
    st.title('Flight data')
#     st.markdown('<p style="text-align: center;">Flight data</p>')
#     st.markdown(""" 
#         <div style ="background-color:#DFE9FB;padding:3px"> 
#         <h4 style ="color:black;text-align:center;">FLIGHT DATA</h4> 
#         </div> 
#         """  , unsafe_allow_html = True)
    
    
# 1) CARRIER:
    st.subheader('Carrier')
    
    # Carrier:
    with open(root + "dict_mappers/carriers_dict.pkl", "rb") as f:
        carriers_dict = pickle.load(f)
#     carrier = st.selectbox('Carrier', df['OP_UNIQUE_CARRIER'].value_counts().index, format_func = carriers_dict.get)
    with open(root + "dict_mappers/carriers_sorted_list.pkl", "rb") as f:
        carriers = pickle.load(f)
    carrier = st.selectbox('Carrier', carriers, format_func = carriers_dict.get)
    
# 2) ORIGIN:
    st.subheader('Origin')
    
    # Origin:
    originType = st.radio('Departure airport', options=['Currently operated by the A/L', 'All airports'], index=0, key=1)
    if originType == 'Currently operated by the A/L':
        with open(root + "dict_mappers/carrierOrigins_dict.pkl", "rb") as f:
            carrierOrigins_dict = pickle.load(f)
            origins = carrierOrigins_dict[carrier]
        origin = st.selectbox('Origin', origins)
    elif originType == 'All airports':
        with open(root + "dict_mappers/origins_sorted_list.pkl", "rb") as f:
            origins = pickle.load(f)
        origin = st.selectbox('Origin', origins)

    # Latitude / Longitude - ORIGIN:
    with open(root + "dict_mappers/latitude_dict.pkl", "rb") as f:
        latitude_dict = pickle.load(f)
    with open(root + "dict_mappers/longitude_dict.pkl", "rb") as f:
        longitude_dict = pickle.load(f)
    col1, col2, = st.beta_columns(2)
    with col1:
        st.text('ORIGIN - Latitude')
        latitudeOrigin = st.markdown(('{:8.5f}').format((latitude_dict[origin])))
        latitudeOrigin = latitude_dict[origin] # So that the model can use it in the proper format
    with col2:
        st.text('ORIGIN - Longitude')
        longitudeOrigin = st.markdown(('{:8.5f}').format((longitude_dict[origin])))
        longitudeOrigin = longitude_dict[origin] # So that the model can use it in the proper format
    # Taxi-out:
    with open(root + "dict_mappers/taxi_out_dict.pkl", "rb") as f:
        taxi_out_dict = pickle.load(f)          
    try:
        taxiout = st.slider('Taxi-out time [min] (*)',
                            min_value=0, max_value=40, value=taxi_out_dict[origin + '_' + carrier], step=1)
        st.markdown("(\*) *Default value is set to the median for the combination of: Origin and Carrier*")
    except KeyError:
        taxiout = st.slider('Taxi-out time [min] (*)', min_value=0, max_value=40, value=15, step=1)
        st.markdown("(\*) *The selected Carrier has not flown from Origin before. Please select a value*")
    
    
# 3) DESTINATION:
    st.subheader('Destination')
    
    # Destination:
    destType = st.radio('Departure airport', options=['Currently operated by the A/L', 'All airports'], index=0, key=2)
    if destType == 'Currently operated by the A/L':
        with open(root + "dict_mappers/carrierDests_dict.pkl", "rb") as f:
            carrierDests_dict = pickle.load(f)
            dests = carrierDests_dict[carrier]
        dest = st.selectbox('Dest', dests)
    elif destType == 'All airports':
        with open(root + "dict_mappers/dests_sorted_list.pkl", "rb") as f:
            dests = pickle.load(f)
        dest = st.selectbox('Destination', dests)

    # Latitude / Longitude - DESTINATION:
    col3, col4, = st.beta_columns(2)
    with col3:
        st.text('DESTINATION - Latitude')
        latitudeDest = st.markdown(('{:8.5f}').format((latitude_dict[dest])))
        latitudeDest = latitude_dict[dest] # So that the model can use it in the proper format
    with col4:
        st.text('DESTINATION - Longitude')
        longitudeDest = st.markdown(('{:8.5f}').format((longitude_dict[dest])))
        longitudeDest = longitude_dict[dest] # So that the model can use it in the proper format
    # Taxi-in:
    with open(root + "dict_mappers/taxi_in_dict.pkl", "rb") as f:
        taxi_in_dict = pickle.load(f)          
    try:
        taxiin = st.slider('Taxi-in time [min] (*)',
                            min_value=0, max_value=20, value=taxi_in_dict[dest + '_' + carrier], step=1)
        st.markdown("(\*) *Default value is set to the median for the combination of: Destination and Carrier*")
    except KeyError:
        taxiin = st.slider('Taxi-in time [min] (*)', min_value=0, max_value=20, value=6, step=1)
        st.markdown("(\*) *The selected Carrier has not flown to Destination before. Please select a value*")

        
# 4) TIME:
    st.subheader('Time')
    st.write("Current time:", datetime.datetime.now().strftime("%Y-%m-%d | %H:%M:%S"),
             "({})".format(datetime.datetime.now(datetime.timezone.utc).astimezone().tzinfo))
    
    col5, col6, col7 = st.beta_columns(3)    
    with col5:
        # Date:
        fdate = st.date_input("Flight date", value=datetime.date.today(),
                              min_value=datetime.date(2019, 1, 1), max_value=datetime.date(2021, 12, 31))
        fmonth = str(fdate.month)
        fweekday = str(fdate.isoweekday())    
    with col6:
        # Departure time:
#         deptime = st.selectbox('Departure time hour', list(map(str, sorted([int(hour) for hour in df['DEP_TIME_hour'].unique()]))))    
        with open(root + "dict_mappers/depTimeHours_list.pkl", "rb") as f:
            depTimeHours = pickle.load(f)
        deptime = st.selectbox('Departure time hour', list(map(str, sorted([int(hour) for hour in depTimeHours]))))    
    with col7:
        # Arrival time:
        with open(root + "dict_mappers/arrTimeHour_dict.pkl", "rb") as f:
            arrTimeHour_dict = pickle.load(f)
        with open(root + "dict_mappers/arrTimeHour_dict_2.pkl", "rb") as f:
            arrTimeHour_dict_2 = pickle.load(f)
        try:
            arrtime = st.number_input('Arrival  time hour (*)', min_value=0,
                                      value=int(arrTimeHour_dict[origin + '_' + dest + '_' + carrier + '_' + deptime]),
                                      max_value=23, step=1)
            arrtime = str(arrtime) # So that the model can use it in the proper format
            st.markdown("(\*) *Default value is set by the combination of: Origin, Destination, Carrier and Departure time hour*")
        except KeyError:
            try:
                arrtime = st.number_input('Arrival  time hour (*)', min_value=0,
                                          value=int(deptime) + int(arrTimeHour_dict_2[origin + '_' + dest]),
                                          max_value=23, step=1)
                arrtime = str(arrtime) # So that the model can use it in the proper format
                st.markdown("(\*) *The selected combination of Origin, Destination, Carrier and Departure time hour has not been flown before*")
                st.markdown("*Therefore, a default value has been set based on the combination of: Origin and Destination*")
            except KeyError:
                arrtime = st.number_input('Arrival  time hour (*)', min_value=0, value=0, max_value=23, step=1)
                arrtime = str(arrtime) # So that the model can use it in the proper format
                st.markdown("(\*) *The selected combination of Origin and Destination has not been flown before*")        

    # Distance:    
    with open(root + "dict_mappers/distance_dict.pkl", "rb") as f:
        distance_dict = pickle.load(f) 
    try:
        if distance_dict[origin + '_' + dest]:
            pass
    except KeyError:
        distance = st.slider('Distance covered [mi] (*)', min_value=0, max_value=6000, value=600, step=50)
        st.markdown("(\*) *The selected route (Origin-Destination) has not been flown before. Please select a value*")
    else: 
        st.markdown('Distance covered [mi]')
        distance = st.markdown(distance_dict[origin + '_' + dest])
        distance = distance_dict[origin + '_' + dest] # So that the model can use it in the proper format

# METEOROLOGICAL DATA

    st.markdown('---')
    st.title('Meteorological data')

    col8, col9, col10 = st.beta_columns([3, 1, 3])
    
    with col8:
    # 1) ORIGIN:
        st.subheader('Origin')     
        
       
        df_predictions, url = weather_forecast(latitudeOrigin, longitudeOrigin)
        flight_forecast = df_predictions[(df_predictions['day'] == str(fdate)) & (df_predictions['hour'] == deptime)]

        if len(flight_forecast) > 0:
            st.success("""*Weather forecast is available for the
                           departure. Therefore, meteorological
                           inputs have been defaulted accordingly.  
                           Powered by [OpenWeather]({})*""".format(url))
            altset_def = flight_forecast['pressure_inHg'].iloc[0]
            temp_def = int(flight_forecast['temperature_F'].iloc[0])
            precip_def = float(flight_forecast['precipitation_in'].iloc[0])
            relHumid_def = flight_forecast['relHumidity_%'].iloc[0]
            skyCond_def_dict = {'CLR': 0, 'FEW': 1, 'SCT': 2, 'BKN': 3, 'OVC': 4}
            skyCond_def = skyCond_def_dict[flight_forecast['skyCondition'].iloc[0]]
            visibility_def = int(flight_forecast['visibility_mi'].iloc[0])
            gust_def = int(flight_forecast['windGust_kt'].iloc[0])
            wind_def = int(flight_forecast['wind_kt'].iloc[0])
                
        else:
            st.warning("""*Unfortunately, no weather prediction is
                           available for the selected flight. Predictions
                           are only available for the next 48h.*""")
            altset_def = 29.92
            temp_def = 59
            precip_def = 0.
            relHumid_def = 60
            skyCond_def = 0
            visibility_def = 10
            gust_def = 0
            wind_def = 8
            
        # Altimeter setting - ORIGIN: 
        altsetOrigin = st.number_input('Altimeter setting [inHg]', min_value=27., value=altset_def,
                                       max_value=32., step=0.01, key=1)

        # Temperature - ORIGIN:
        tempTypeOrigin = st.radio('Temperature unit', options=['ºF', 'ºC'], index=0, key=1)
        if tempTypeOrigin == 'ºF':
            tempOrigin = st.slider('Temperature [ºF]', min_value=-50, max_value=130, value=temp_def, step=1, key=1)
        elif tempTypeOrigin == 'ºC':
            tempOrigin = st.slider('Temperature [ºC]', min_value=-50, max_value=50,
                                   value=int((temp_def - 32) / 1.8), step=1, key=1)
            tempOrigin = int(1.8 * tempOrigin + 32) # Convert Celsius to Fahrenheit to properly feed the model
            
        # Hourly precipitation - ORIGIN:
        precipOrigin = st.number_input('Hourly precipitation [in]', min_value=0.,
                                       value=precip_def, max_value=30., step=0.01, key=1)

        # Relative humidity - ORIGIN:    
        relhumOrigin = st.number_input('Relative humidity [%]', min_value=0,
                                       value=relHumid_def, max_value=100, step=1, key=1)

        # Sky condtions - ORIGIN: 
        with open(root + "dict_mappers/sky_dict.pkl", "rb") as f:
            sky_dict = pickle.load(f)
        skyOrigin = st.selectbox('Sky conditions', options=list(sky_dict.keys()),
                                 index=skyCond_def, format_func = sky_dict.get, key=1)

        # Visibility - ORIGIN:
        visibOrigin = st.number_input('Visibility [mi]', min_value=0,
                                       value=visibility_def, max_value=100, step=1, key=1)

        # Wind gust speed - ORIGIN:
        gustOrigin = st.slider('Wind gust speed [mph]', min_value=0, max_value=40, value=gust_def, step=1, key=1)

        # Wind speed - ORIGIN:
        windOrigin = st.slider('Wind speed [mph]', min_value=0, max_value=40, value=wind_def, step=1, key=1)

    with col10:
    # 2) DESTINATION:
        st.subheader('Destination')     

        df_predictions, url = weather_forecast(latitudeDest, longitudeDest)
        if int(arrtime) < int(deptime): # Late night flight arriving on the following day
            flight_forecast = df_predictions[(df_predictions['day'] == str(fdate + datetime.timedelta(days=1))) \
                                           & (df_predictions['hour'] == arrtime)]
        else:
            flight_forecast = df_predictions[(df_predictions['day'] == str(fdate)) & (df_predictions['hour'] == arrtime)]

        if len(flight_forecast) > 0:
            st.success("""*Weather forecast is available for the
                           arrival. Therefore, meteorological
                           inputs have been defaulted accordingly.  
                           Powered by [OpenWeather]({})*""".format(url))
            altset_def = flight_forecast['pressure_inHg'].iloc[0]
            temp_def = int(flight_forecast['temperature_F'].iloc[0])
            precip_def = float(flight_forecast['precipitation_in'].iloc[0])
            relHumid_def = flight_forecast['relHumidity_%'].iloc[0]
            skyCond_def_dict = {'CLR': 0, 'FEW': 1, 'SCT': 2, 'BKN': 3, 'OVC': 4}
            skyCond_def = skyCond_def_dict[flight_forecast['skyCondition'].iloc[0]]
            visibility_def = int(flight_forecast['visibility_mi'].iloc[0])
            gust_def = int(flight_forecast['windGust_kt'].iloc[0])
            wind_def = int(flight_forecast['wind_kt'].iloc[0])
                
        else:
            st.warning("""*Unfortunately, no weather prediction is
                           available for the selected flight. Predictions
                           are only available for the next 48h.*""")
            altset_def = 29.92
            temp_def = 59
            precip_def = 0.
            relHumid_def = 60
            skyCond_def = 0
            visibility_def = 10
            gust_def = 0
            wind_def = 8
            
        # Altimeter setting - DEST: 
        altsetDest = st.number_input('Altimeter setting [inHg]', min_value=27., value=altset_def,
                                       max_value=32., step=0.01, key=2)

        # Temperature - DEST:
        tempTypeDest = st.radio('Temperature unit', options=['ºF', 'ºC'], index=0, key=2)
        if tempTypeDest == 'ºF':
            tempDest = st.slider('Temperature [ºF]', min_value=-50, max_value=130, value=temp_def, step=1, key=2)
        elif tempTypeDest == 'ºC':
            tempDest = st.slider('Temperature [ºC]', min_value=-50, max_value=50,
                                   value=int((temp_def - 32) / 1.8), step=1, key=2)
            tempDest = int(1.8 * tempDest + 32) # Convert Celsius to Fahrenheit to properly feed the model
            
        # Hourly precipitation - DEST:
        precipDest = st.number_input('Hourly precipitation [in]', min_value=0.,
                                       value=precip_def, max_value=30., step=0.01, key=2)

        # Relative humidity - DEST:    
        relhumDest = st.number_input('Relative humidity [%]', min_value=0,
                                       value=relHumid_def, max_value=100, step=1, key=2)

        # Sky condtions - DEST: 
        with open(root + "dict_mappers/sky_dict.pkl", "rb") as f:
            sky_dict = pickle.load(f)
        skyDest = st.selectbox('Sky conditions', options=list(sky_dict.keys()),
                                 index=skyCond_def, format_func = sky_dict.get, key=2)

        # Visibility - DEST:
        visibDest = st.number_input('Visibility [mi]', min_value=0,
                                       value=visibility_def, max_value=100, step=1, key=2)

        # Wind gust speed - DEST:
        gustDest = st.slider('Wind gust speed [mph]', min_value=0, max_value=40, value=gust_def, step=1, key=2)

        # Wind speed - DEST:
        windDest = st.slider('Wind speed [mph]', min_value=0, max_value=40, value=wind_def, step=1, key=2)
    

    user_inputs = [
        fmonth, fweekday, carrier, origin, dest, deptime, taxiout, taxiin, arrtime, distance,                
        altsetOrigin, tempOrigin, precipOrigin,
        relhumOrigin, skyOrigin, visibOrigin, gustOrigin, windOrigin,
        altsetDest, tempDest, precipDest,
        relhumDest, skyDest, visibDest, gustDest, windDest
    ]

    
    return user_inputs

# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------

def prediction(model, X_test):  
    # Making predictions: 
    prediction = model.predict(X_test)
    score = model.predict_proba(X_test)[0, 0]
    if prediction == 0:
        result = 'ON-TIME'
    else:
        result = 'DELAYED'
    return result, score

# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------

@st.cache(hash_funcs={shap.explainers._tree.Tree: hash})
def load_shap_explainer(filename='', X_test_transformed=pd.DataFrame()):   
    # Load the explainer file (instead of generating it so as to save time):
    explainer = joblib.load(filename)
    shap_values = explainer.shap_values(X_test_transformed)
    return explainer, shap_values

def st_shap(plot, height=None):
    shap_html = f"<head>{shap.getjs()}</head><body>{plot.html()}</body>"
    components.html(shap_html, height=height) 

# ------------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------------


if __name__=='__main__': 
    
#     root = "/app/tfm_kschool/frontend/" # Used for deployment on Streamlit Sharing platform
    root = "" # Used for running local tests
    
    # Let the user know the data is loading and load the data:
#     df, X, y = load_data()

    # Load the model:
#     pipe = load_model(path="XGBoost_pipeline_model.joblib.dat")
    pipe = load_model(path=root + "XGBoost_pipeline_model.joblib.dat")
    transformer = pipe[:-1]
    model = pipe.named_steps['clf']
    
    # Load the general HMI framework:
    col1, col2, col3 = st.beta_columns([0.1,1.25,0.1])
    with col1:
        st.write("")
    with col2:
        st.image(root + 'logo3.jpeg')
    with col3:
        st.write("")
        
#     frontend_appearance()
    
    # Load the input fields:
#     inputs = user_inputs(df)
    inputs = user_inputs(root)
    
    # Generate an array based on user input values thal will be fed into the model:
    dismissed_cols = [
                      'ARR_DEL15',
                      'LATITUDE_Origin',
                      'LONGITUDE_Origin',
                      'LATITUDE_Dest',
                      'LONGITUDE_Dest'
                    ]
    X_test = pd.DataFrame(
            data=np.array(inputs)[np.newaxis], # Kind of transpose the resulting array from the 'inputs' list
            columns=[col for col in cols if col not in dismissed_cols]
        )
    cols_dtypes_frontend = cols_dtypes.copy()
    for col in dismissed_cols:
        del cols_dtypes_frontend[col]
    X_test = X_test.astype(cols_dtypes_frontend)

    # Indicate numerical and categorical features:
    num_attribs = X_test.select_dtypes('number').columns
    cat_attribs = X_test.select_dtypes(['string', 'category', 'object']).columns
    # Transform categorical variables:
    X_test_categTransformed_df = pd.DataFrame(transformer.transform(X_test)[:, 0:9], columns=cat_attribs)
    # Concatenate categorical transformed features with 'as-is' numerical features:
    X_test_transformed = pd.concat([X_test_categTransformed_df, X_test[num_attribs]], axis=1)
    X_test_transformed = X_test_transformed[X_test.columns]
       
    # When 'Predict' button is clicked, make the prediction and store it: 
    st.markdown('---')
    col11, col12, col13 = st.beta_columns([3, 1, 3])
    if col12.button("Predict"):
        # Calculate prediction:
        result = prediction(pipe, X_test)[0]
        score = prediction(pipe, X_test)[1]
        if result == 'ON-TIME':
            st.success('The flight is predicted to be **{}** ({:5.2f}%)'.format(result, 100*score))
        elif result == 'DELAYED':
            st.error('The flight is predicted to be **{}** ({:5.2f}%)'.format(result, 100*(1-score)))
        
        # SHAP values and force plot:
        with st.beta_expander("See explanatory details for this flight prediction"):
            st.write("""
                Below a *SHAP force plot* explains the contribution of each variable to the model's prediction.  
                - Red features are *forcing* the prediction to **DELAY**.
                - On the contrary, blue variables drive the prediction to **ON-TIME**.
            """)
            explainer, shap_values = load_shap_explainer(root + 'shap_treeExplainer.bz2', X_test_transformed)
            st_shap(shap.force_plot(explainer.expected_value, shap_values[0,:], X_test.iloc[0,:], link='logit'))
            
            # -----------

            shap.decision_plot(base_value=explainer.expected_value, shap_values=shap_values[0],
                              features=X_test.iloc[0,:], link='logit', feature_display_range=slice(None, -X_test.shape[1]-1, -1),
                              return_objects=True, show=False, y_demarc_color='#00172b')
            fig = plt.gcf()
            ax = plt.gca()
            fig.patch.set_facecolor('#00172b')
            ax.set_facecolor('#00172b')
            ax.set_xlabel('Probability', fontsize=16, color='white')
            ax.tick_params(axis='both', colors='white')
            ax.grid(axis='both', color='white', linestyle='-', linewidth=0.25)
            for ln in ax.lines:
                ln.set_linewidth(3)
            for text in ax.texts:
                text.set_color('white')
                text.set_alpha(0.75)
            st.pyplot(fig)
            
            # -----------
    
#     # SHAP values general overview:
#     shapSummary = st.checkbox(label="SHAP Summary Plot")
#     if shapSummary:
#         st.image(root + 'shap_summaryPlot.png')
# Out:
# Overwriting flight_delay_predictor.py

# %% [markdown]
# # Altair plots [OPTIONAL]

# %%
import altair as alt
from vega_datasets import data

# Since these data are each more than 5,000 rows we'll import from the URLs
airports = data.airports.url
flights_airport = data.flights_airport.url

states = alt.topo_feature(data.us_10m.url, feature="states")

# Create mouseover selection
select_city = alt.selection_single(
    on="mouseover", nearest=True, fields=["origin"], empty="none"
)

# Define which attributes to lookup from airports.csv
lookup_data = alt.LookupData(
    airports, key="iata", fields=["state", "latitude", "longitude"]
)

background = alt.Chart(states).mark_geoshape(
    fill="lightgray",
    stroke="white"
).properties(
    width=750,
    height=500
).project("albersUsa")

connections = alt.Chart(flights_airport).mark_rule(opacity=0.35).encode(
    latitude="latitude:Q",
    longitude="longitude:Q",
    latitude2="lat2:Q",
    longitude2="lon2:Q"
).transform_lookup(
    lookup="origin",
    from_=lookup_data
).transform_lookup(
    lookup="destination",
    from_=lookup_data,
    as_=["state", "lat2", "lon2"]
).transform_filter(
    select_city
)

points = alt.Chart(flights_airport).mark_circle().encode(
    latitude="latitude:Q",
    longitude="longitude:Q",
    size=alt.Size("routes:Q", scale=alt.Scale(range=[0, 1000]), legend=None),
    order=alt.Order("routes:Q", sort="descending"),
    tooltip=["origin:N", "routes:Q"]
).transform_aggregate(
    routes="count()",
    groupby=["origin"]
).transform_lookup(
    lookup="origin",
    from_=lookup_data
).transform_filter(
    (alt.datum.state != "PR") & (alt.datum.state != "VI")
).add_selection(
    select_city
)

(background + connections + points).configure_view(stroke=None)
# Out:
# alt.LayerChart(...)

# %% [markdown]
# ___
