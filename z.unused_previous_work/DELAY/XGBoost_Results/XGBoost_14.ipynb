# %% [markdown]
# ___

# %%
# Import libraries to be used

# Warning messages display
# import warnings
# warnings.filterwarnings(action='once') # https://docs.python.org/3/library/warnings.html#the-warnings-filter

# Directories/Files management
import os.path
## from zipfile import ZipFile # De momento no ha hecho falta 

# Timing
import time

# Data analysis and wrangling
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) # Show all columns in DataFrames
pd.set_option('display.max_rows', 100) # If too high, it greatly slows down the output display and freezes the kernel


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot') # choose a style: 'plt.style.available'
sns.set_theme(context='notebook',
              style="darkgrid") # {darkgrid, whitegrid, dark, white, ticks}
palette = sns.color_palette("flare", as_cmap=True);
import altair as alt

# Machine Learning
## from sklearn.[...] import ...

# %%
# %load_ext memory_profiler

# %%
t0 = time.perf_counter()

# %%
# Detect Operating System running and manage paths accordingly

if os.name == 'nt': # Windows
    root = r"C:\Users\turge\CompartidoVM\0.TFM"
    print("Running on Windows.")
elif os.name == 'posix': # Ubuntu
    root = "/home/dsc/shared/0.TFM"
    print("Running on Ubuntu.")
print("root path\t", root)
# Out:
# Running on Windows.
# root path	 C:\Users\turge\CompartidoVM\0.TFM

# %% [markdown]
# ___

# %% [markdown]
# ## 1. Load the dataset

# %%
cols = [
     'MONTH',
     'DAY_OF_MONTH',
     'DAY_OF_WEEK',
     'OP_UNIQUE_CARRIER',
# For the time being, 'TAIL_NUM' will be disregarded due to its high cardinality  (~ 4500) and low expected added value    
#      'TAIL_NUM',
     'ORIGIN', # Let's skip this feature to prevent high cardinality and check if it's relevant or not
     'DEST', # Let's skip this feature to prevent high cardinality and check if it's relevant or not
#      'CRS_DEP_TIME', # Redundant having the 'DEP_ARR_hour' feature
     'DEP_TIME_hour',
#      'DEP_TIME',
#      'DEP_DELAY',
#      'DEP_DEL15',
#      'TAXI_OUT',
     'TAXI_OUT_median',
#      'TAXI_IN',
     'TAXI_IN_median',
#      'CRS_ARR_TIME', # Redundant having the 'ARR_ARR_hour' feature
     'ARR_TIME_hour', 
#      'ARR_TIME',   
#      'ARR_DELAY',
     'ARR_DEL15', # → Target !!
#      'CANCELLED',
     'CRS_ELAPSED_TIME',
     'DISTANCE',
     'DISTANCE_GROUP',
#      'CARRIER_DELAY',
#      'WEATHER_DELAY',
#      'NAS_DELAY',
#      'SECURITY_DELAY',
#      'LATE_AIRCRAFT_DELAY',
]

# %%
preprocessed_input_csv_path = os.path.join(root,
                                           "Output_Data",
                                           "US_DoT",
                                           "AL_OTP_MVP_Preprocessed_19_v2_clean.csv")
preprocessed_input_csv_path
# Out:
# 'C:\\Users\\turge\\CompartidoVM\\0.TFM\\Output_Data\\US_DoT\\AL_OTP_MVP_Preprocessed_19_v2_clean.csv'

# %%
cols_dtypes = {
               'MONTH' : 'category',
               'DAY_OF_MONTH' : 'category',
               'DAY_OF_WEEK' : 'category',
               'OP_UNIQUE_CARRIER' : 'category',
               'ORIGIN' : 'category',
               'DEST' : 'category',
               'DEP_TIME_hour' : 'category',
               'TAXI_OUT_median' : 'int64',
               'TAXI_IN_median' : 'int64',
               'ARR_TIME_hour' : 'category', 
               'ARR_DEL15' : 'int32', # → Target !!
               'CRS_ELAPSED_TIME' : 'int64',
               'DISTANCE' : 'int64',
               'DISTANCE_GROUP' : 'category'
               }

# %%
# %%time

df_all = pd.read_csv(preprocessed_input_csv_path,
                     encoding='latin1',
                     usecols=cols,
                     low_memory = False)
# Out:
# Wall time: 26 s

# %%
# Cast types in accordance to previously defined dictionary:
df_all = df_all.astype(cols_dtypes)
# Display DF columns according to 'cols' order:
df_all = df_all[cols]
df_all
# Out:
#         MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST  \
# 0           1            3           4                9E    TYS  ATL
# 1           1            4           5                9E    TYS  ATL
# 2           1            5           6                9E    ATL  SGF
# 3           1            6           7                9E    ATL  SGF
# 4           1            7           1                9E    ATL  SGF
# ...       ...          ...         ...               ...    ...  ...
# 7268227    12           31           2                B6    MCO  SWF
# 7268228    12           31           2                B6    DCA  BOS
# 7268229    12           31           2                B6    PHL  BOS
# 7268230    12           31           2                B6    BOS  SJU
# 7268231    12           31           2                B6    SJU  BOS
#
#         DEP_TIME_hour  TAXI_OUT_median  TAXI_IN_median ARR_TIME_hour  \
# 0                  11               15               8            12
# 1                  11               15               8            12
# 2                   9               17               5            10
# 3                   9               17               5            10
# 4                   9               17               5            10
# ...               ...              ...             ...           ...
# 7268227            13               15               6            16
# 7268228            14               15               6            15
# 7268229             7               17               6             8
# 7268230             8               16               5            13
# 7268231             0               11               6             7
#
#          ARR_DEL15  CRS_ELAPSED_TIME  DISTANCE DISTANCE_GROUP
# 0                1                70       152              1
# 1                1                70       152              1
# 2                0               121       563              3
# 3                0               123       563              3
# 4                0               123       563              3
# ...            ...               ...       ...            ...
# 7268227          1               163       989              4
# 7268228          0                90       399              2
# 7268229          0                85       280              2
# 7268230          0               242      1674              7
# 7268231          0               249      1674              7
#
# [7268232 rows x 14 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7268232 entries, 0 to 7268231
# Data columns (total 14 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   MONTH              category
#  1   DAY_OF_MONTH       category
#  2   DAY_OF_WEEK        category
#  3   OP_UNIQUE_CARRIER  category
#  4   ORIGIN             category
#  5   DEST               category
#  6   DEP_TIME_hour      category
#  7   TAXI_OUT_median    int64
#  8   TAXI_IN_median     int64
#  9   ARR_TIME_hour      category
#  10  ARR_DEL15          int32
#  11  CRS_ELAPSED_TIME   int64
#  12  DISTANCE           int64
#  13  DISTANCE_GROUP     category
# dtypes: category(9), int32(1), int64(4)
# memory usage: 325.8 MB

# %%
# from pandas_profiling import ProfileReport

# # # Complete report:
# # prof = ProfileReport(df_all)
# # prof.to_file('informe.html')

# # Sample report (more computationally efficient)
# prof = ProfileReport(df_all.sample(10000)) 
# prof.to_file('sample_report.html')

# %%
# from pandas_profiling import ProfileReport

# # Complete report:
# prof = ProfileReport(df_all, minimal=True)
# prof.to_file('complete_report.html')

# # # Sample report (more computationally efficient)
# # prof = ProfileReport(df_all.sample(10000)) 
# # prof.to_file('sample_report.html')

# %% [markdown]
# ## 2. Dataset overview

# %%
# For the initial runs, define a reasonably-sized sample:
sample_length = int(1e6)

# The dataset is somehow imbalanced (80% on-time / 20% delayed), so let's perform some quick undersampling:
delayed = df_all[df_all['ARR_DEL15'] == 1].sample(sample_length // 2)
ontime = df_all[df_all['ARR_DEL15'] == 0].sample(sample_length // 2)
df = delayed.append(ontime)

# Get dummies for the categorical features:
df = pd.get_dummies(df)

print("On-time flights: {:7d} ({:5.2f}%)".format(len(ontime), 100*len(ontime)/len(df)))
print("Delayed flights: {:7d} ({:5.2f}%)".format(len(delayed), 100*len(delayed)/len(df)))
# Out:
# On-time flights:  500000 (50.00%)
# Delayed flights:  500000 (50.00%)

# %% [markdown]
# ### Train / Test / Validation split
# Break the dataset into three blocks:
# 1. Training (70%)
# 2. Test (15%)
# 3. Validation (15%)

# %%
# Divide the data:
train = df.sample(frac=0.7)
test_valid = df.drop(train.index)
test = test_valid.sample(frac=0.5)
valid = test_valid.drop(test.index)

print("Total dataset:      {:7d} ({:6.2f}%)".format(len(df), 100*len(df)/len(df)))
print("Training dataset:   {:7d} ( {:5.2f}%)".format(len(train), 100*len(train)/len(df)))
print("Test dataset:       {:7d} ( {:5.2f}%)".format(len(test), 100*len(test)/len(df)))
print("Validation dataset: {:7d} ( {:5.2f}%)".format(len(valid), 100*len(valid)/len(df)))
# Out:
# Total dataset:      1000000 (100.00%)
# Training dataset:    700000 ( 70.00%)
# Test dataset:        150000 ( 15.00%)
# Validation dataset:  150000 ( 15.00%)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
# Train / Test partition:
X_train, y_train = train.drop("ARR_DEL15", axis=1), train["ARR_DEL15"]
X_test, y_test = test.drop("ARR_DEL15", axis=1), test["ARR_DEL15"]

# Validation:
X_valid, y_valid = valid.drop("ARR_DEL15", axis=1), valid["ARR_DEL15"]

# %%
# Basic model definition:
xgb_model = XGBClassifier(use_label_encoder=False, verbosity=1, random_state=0,
                          n_estimators=300,
                          max_depth= 4,
                          learning_rate=0.0001,
                          objective= 'binary:logistic',
                          booster='gbtree',
                          tree_method='auto')

# %% [markdown]
# ## Training

# %%
xgb_model.fit(X_train, y_train,
              eval_set=[(X_train, y_train), (X_test, y_test), (X_valid, y_valid)],
              eval_metric='auc',
              verbose=True)
# Out:
# [0]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [1]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [2]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [3]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [4]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [5]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [6]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [7]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [8]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [9]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [10]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [11]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [12]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [13]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [14]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [15]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [16]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [17]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [18]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [19]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [20]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [21]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [22]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [23]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [24]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [25]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [26]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [27]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [28]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [29]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [30]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [31]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [32]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [33]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [34]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [35]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [36]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [37]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [38]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [39]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [40]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [41]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [42]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [43]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [44]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [45]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [46]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [47]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [48]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [49]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [50]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [51]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [52]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [53]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [54]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [55]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [56]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [57]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [58]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [59]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [60]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [61]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [62]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [63]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [64]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [65]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [66]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [67]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [68]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [69]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [70]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [71]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [72]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [73]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [74]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [75]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [76]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [77]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [78]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [79]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [80]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [81]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [82]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [83]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [84]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [85]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [86]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [87]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [88]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [89]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [90]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [91]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [92]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [93]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [94]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [95]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [96]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [97]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [98]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [99]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [100]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [101]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [102]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [103]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [104]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [105]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [106]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [107]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [108]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [109]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [110]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [111]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [112]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [113]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [114]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [115]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [116]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [117]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [118]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [119]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [120]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [121]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [122]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [123]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [124]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [125]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [126]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [127]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [128]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [129]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [130]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [131]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [132]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [133]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [134]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [135]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [136]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [137]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [138]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [139]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [140]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [141]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [142]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [143]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [144]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [145]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [146]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [147]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [148]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [149]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [150]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [151]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [152]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [153]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [154]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [155]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [156]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [157]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [158]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [159]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [160]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [161]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [162]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [163]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [164]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [165]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [166]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [167]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [168]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [169]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [170]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [171]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [172]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [173]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [174]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [175]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [176]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [177]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [178]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [179]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [180]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [181]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [182]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [183]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [184]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [185]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [186]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [187]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [188]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [189]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [190]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [191]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [192]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [193]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [194]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [195]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [196]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [197]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [198]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [199]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [200]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [201]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [202]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [203]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [204]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [205]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [206]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [207]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [208]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [209]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [210]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [211]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [212]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [213]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [214]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [215]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [216]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [217]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [218]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [219]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [220]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [221]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [222]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [223]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [224]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [225]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [226]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [227]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [228]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [229]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [230]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [231]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [232]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [233]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [234]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [235]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [236]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [237]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [238]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [239]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [240]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [241]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [242]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [243]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [244]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [245]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [246]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [247]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [248]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [249]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [250]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [251]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [252]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [253]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [254]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [255]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [256]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [257]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [258]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [259]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [260]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [261]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [262]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [263]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [264]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [265]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [266]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [267]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [268]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [269]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [270]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [271]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [272]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [273]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [274]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [275]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [276]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [277]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [278]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [279]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [280]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [281]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [282]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [283]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [284]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [285]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [286]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [287]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [288]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [289]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [290]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [291]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [292]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [293]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [294]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [295]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [296]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [297]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [298]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# [299]	validation_0-auc:0.56032	validation_1-auc:0.56024	validation_2-auc:0.56151
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.0001, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='auto', use_label_encoder=False,
#               validate_parameters=1, verbosity=1)

# %% [markdown]
# <em>
# Probar con:
#
# - `logloss`: negative log-likelihood
# - `auc`: Area under the curve. Available for binary classification and learning-to-rank tasks.
# - `aucpr`: Area under the PR curve. Available for binary classification and learning-to-rank tasks.
#
# Source: https://xgboost.readthedocs.io/en/latest/parameter.html
# </em>

# %%
# Get parameters:
xgb_model.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': False,
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'gpu_id': -1,
#  'importance_type': 'gain',
#  'interaction_constraints': '',
#  'learning_rate': 0.0001,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 1,
#  'missing': nan,
#  'monotone_constraints': '()',
#  'n_estimators': 300,
#  'n_jobs': 4,
#  'num_parallel_tree': 1,
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': 'auto',
#  'validate_parameters': 1,
#  'verbosity': 1}

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Evaluation metric results (here, `auc`)

# %%
# Evaluation results for all passed eval_sets.
# Validation metrics will help us track the performance of the model:
evals_result = xgb_model.evals_result()
evals_result
# Out:
# {'validation_0': OrderedDict([('auc',
#                [0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560322,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560323,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324,
#                 0.560324])]),
#  'validation_1': OrderedDict([('auc',
#                [0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560241,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242,
#                 0.560242])]),
#  'validation_2': OrderedDict([('auc',
#                [0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561511,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561512,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515,
#                 0.561515])])}

# %% [markdown]
# ### Additional metrics results

# %%
# Evaluate the model's metrics:

from sklearn.metrics import fbeta_score, f1_score, recall_score, precision_score, accuracy_score, \
                            confusion_matrix, roc_curve, roc_auc_score, plot_roc_curve

def clf_metrics(classifier, y_test, y_pred):
    print(confusion_matrix(y_test, y_pred))
    print("F-beta (ß=2) = {:6.3f}".format(fbeta_score(y_test, y_pred, beta=2)))   
    print("F1 =           {:6.3f}".format(f1_score(y_test, y_pred)))   
    print("Recall =       {:6.3f}".format(recall_score(y_test, y_pred)))   
    print("Precision =    {:6.3f}".format(precision_score(y_test, y_pred)))   
    print("Accuracy =     {:6.3f}".format(accuracy_score(y_test, y_pred)))

# %% [markdown]
# ### Test

# %%
y_train_pred = xgb_model.predict(X_train)
y_test_pred = xgb_model.predict(X_test)
y_valid_pred = xgb_model.predict(X_valid)
y_test_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
print("   TRAINING dataset:")
clf_metrics(xgb_model, y_train, y_train_pred)
print("--------------------------------------------------")
print("   TEST dataset:")
clf_metrics(xgb_model, y_test, y_test_pred)
print("--------------------------------------------------")
print("   VALIDATION dataset:")
clf_metrics(xgb_model, y_valid, y_valid_pred)
# Out:
#    TRAINING dataset:
# [[ 89793 260148]
#  [ 49455 300604]]
# F-beta (ß=2) =  0.766
# F1 =            0.660
# Recall =        0.859
# Precision =     0.536
# Accuracy =      0.558
# --------------------------------------------------
#    TEST dataset:
# [[19313 55713]
#  [10662 64312]]
# F-beta (ß=2) =  0.766
# F1 =            0.660
# Recall =        0.858
# Precision =     0.536
# Accuracy =      0.557
# --------------------------------------------------
#    VALIDATION dataset:
# [[19380 55653]
#  [10563 64404]]
# F-beta (ß=2) =  0.767
# F1 =            0.660
# Recall =        0.859
# Precision =     0.536
# Accuracy =      0.559

# %% [markdown]
# ### ROC curve

# %%
y_train_probabilities = xgb_model.predict_proba(X_train)[:,1]
y_test_probabilities = xgb_model.predict_proba(X_test)[:,1]
y_valid_probabilities = xgb_model.predict_proba(X_valid)[:,1]
y_test_probabilities[:10]
# Out:
# array([0.49547687, 0.50106615, 0.50106615, 0.50106615, 0.50106615,
#        0.50106615, 0.50106615, 0.50106615, 0.50106615, 0.50106615],
#       dtype=float32)

# %%
fpr_train, tpr_train, _ = roc_curve(y_train,  y_train_probabilities)
fpr_test, tpr_test, _ = roc_curve(y_test,  y_test_probabilities)
fpr_valid, tpr_valid, _ = roc_curve(y_valid,  y_valid_probabilities)

auc_train = roc_auc_score(y_train, y_train_probabilities)
auc_test = roc_auc_score(y_test, y_test_probabilities)
auc_valid = roc_auc_score(y_valid, y_valid_probabilities)

# %%
# Plot the figure:
fig, ax = plt.subplots(figsize=(6,6))

plot_roc_curve(xgb_model, X_train, y_train, color='red', ax=ax, name='XGBoost_train')
plot_roc_curve(xgb_model, X_test, y_test, color='blue', ax=ax, name='XGBoost_test')
plot_roc_curve(xgb_model, X_valid, y_valid, color='green', ax=ax, name='XGBoost_valid')
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("fpr", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("tpr", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### Feature importance (data)

# %%
# Let's build a dictionary to better see each feature with its corresponding importance:
feature_importance_dict = dict(zip(X_train.columns, xgb_model.feature_importances_))
feature_importance_dict
# Out:
# {'TAXI_OUT_median': 0.0,
#  'TAXI_IN_median': 0.0,
#  'CRS_ELAPSED_TIME': 0.0022734709,
#  'DISTANCE': 0.0018435773,
#  'MONTH_1': 0.0,
#  'MONTH_2': 0.0017334,
#  'MONTH_3': 0.0,
#  'MONTH_4': 0.0,
#  'MONTH_5': 0.0,
#  'MONTH_6': 0.0,
#  'MONTH_7': 0.0,
#  'MONTH_8': 0.0,
#  'MONTH_9': 0.0,
#  'MONTH_10': 0.0,
#  'MONTH_11': 0.0,
#  'MONTH_12': 0.0,
#  'DAY_OF_MONTH_1': 0.0,
#  'DAY_OF_MONTH_2': 0.0,
#  'DAY_OF_MONTH_3': 0.0,
#  'DAY_OF_MONTH_4': 0.0,
#  'DAY_OF_MONTH_5': 0.0,
#  'DAY_OF_MONTH_6': 0.0,
#  'DAY_OF_MONTH_7': 0.0,
#  'DAY_OF_MONTH_8': 0.0,
#  'DAY_OF_MONTH_9': 0.0,
#  'DAY_OF_MONTH_10': 0.0,
#  'DAY_OF_MONTH_11': 0.0,
#  'DAY_OF_MONTH_12': 0.0,
#  'DAY_OF_MONTH_13': 0.0,
#  'DAY_OF_MONTH_14': 0.0,
#  'DAY_OF_MONTH_15': 0.0,
#  'DAY_OF_MONTH_16': 0.0,
#  'DAY_OF_MONTH_17': 0.0,
#  'DAY_OF_MONTH_18': 0.0,
#  'DAY_OF_MONTH_19': 0.0,
#  'DAY_OF_MONTH_20': 0.0,
#  'DAY_OF_MONTH_21': 0.0,
#  'DAY_OF_MONTH_22': 0.0,
#  'DAY_OF_MONTH_23': 0.0,
#  'DAY_OF_MONTH_24': 0.0,
#  'DAY_OF_MONTH_25': 0.0,
#  'DAY_OF_MONTH_26': 0.0,
#  'DAY_OF_MONTH_27': 0.0,
#  'DAY_OF_MONTH_28': 0.0,
#  'DAY_OF_MONTH_29': 0.0,
#  'DAY_OF_MONTH_30': 0.0,
#  'DAY_OF_MONTH_31': 0.0,
#  'DAY_OF_WEEK_1': 0.0,
#  'DAY_OF_WEEK_2': 0.0,
#  'DAY_OF_WEEK_3': 0.0,
#  'DAY_OF_WEEK_4': 0.0,
#  'DAY_OF_WEEK_5': 0.0,
#  'DAY_OF_WEEK_6': 0.0,
#  'DAY_OF_WEEK_7': 0.0,
#  'OP_UNIQUE_CARRIER_9E': 0.0,
#  'OP_UNIQUE_CARRIER_AA': 0.0,
#  'OP_UNIQUE_CARRIER_AS': 0.0,
#  'OP_UNIQUE_CARRIER_B6': 0.0,
#  'OP_UNIQUE_CARRIER_DL': 0.009973649,
#  'OP_UNIQUE_CARRIER_EV': 0.0,
#  'OP_UNIQUE_CARRIER_F9': 0.0045827734,
#  'OP_UNIQUE_CARRIER_G4': 0.0,
#  'OP_UNIQUE_CARRIER_HA': 0.0,
#  'OP_UNIQUE_CARRIER_MQ': 0.0,
#  'OP_UNIQUE_CARRIER_NK': 0.0,
#  'OP_UNIQUE_CARRIER_OH': 0.0,
#  'OP_UNIQUE_CARRIER_OO': 0.0,
#  'OP_UNIQUE_CARRIER_UA': 0.0,
#  'OP_UNIQUE_CARRIER_WN': 0.022101322,
#  'OP_UNIQUE_CARRIER_YV': 0.0,
#  'OP_UNIQUE_CARRIER_YX': 0.0,
#  'ORIGIN_ABE': 0.0,
#  'ORIGIN_ABI': 0.0,
#  'ORIGIN_ABQ': 0.0,
#  'ORIGIN_ABR': 0.0,
#  'ORIGIN_ABY': 0.0,
#  'ORIGIN_ACK': 0.0,
#  'ORIGIN_ACT': 0.0,
#  'ORIGIN_ACV': 0.0,
#  'ORIGIN_ACY': 0.0,
#  'ORIGIN_ADK': 0.0,
#  'ORIGIN_ADQ': 0.0,
#  'ORIGIN_AEX': 0.0,
#  'ORIGIN_AGS': 0.0,
#  'ORIGIN_AKN': 0.0,
#  'ORIGIN_ALB': 0.0,
#  'ORIGIN_ALO': 0.0,
#  'ORIGIN_AMA': 0.0,
#  'ORIGIN_ANC': 0.0,
#  'ORIGIN_APN': 0.0,
#  'ORIGIN_ART': 0.0,
#  'ORIGIN_ASE': 0.0,
#  'ORIGIN_ATL': 0.0,
#  'ORIGIN_ATW': 0.0,
#  'ORIGIN_ATY': 0.0,
#  'ORIGIN_AUS': 0.0,
#  'ORIGIN_AVL': 0.0,
#  'ORIGIN_AVP': 0.0,
#  'ORIGIN_AZA': 0.0,
#  'ORIGIN_AZO': 0.0,
#  'ORIGIN_BDL': 0.0,
#  'ORIGIN_BET': 0.0,
#  'ORIGIN_BFF': 0.0,
#  'ORIGIN_BFL': 0.0,
#  'ORIGIN_BFM': 0.0,
#  'ORIGIN_BGM': 0.0,
#  'ORIGIN_BGR': 0.0,
#  'ORIGIN_BHM': 0.0,
#  'ORIGIN_BIL': 0.0,
#  'ORIGIN_BIS': 0.0,
#  'ORIGIN_BJI': 0.0,
#  'ORIGIN_BKG': 0.0,
#  'ORIGIN_BLI': 0.0,
#  'ORIGIN_BLV': 0.0,
#  'ORIGIN_BMI': 0.0,
#  'ORIGIN_BNA': 0.0,
#  'ORIGIN_BOI': 0.0,
#  'ORIGIN_BOS': 0.0,
#  'ORIGIN_BPT': 0.0,
#  'ORIGIN_BQK': 0.0,
#  'ORIGIN_BQN': 0.0,
#  'ORIGIN_BRD': 0.0,
#  'ORIGIN_BRO': 0.0,
#  'ORIGIN_BRW': 0.0,
#  'ORIGIN_BTM': 0.0,
#  'ORIGIN_BTR': 0.0,
#  'ORIGIN_BTV': 0.0,
#  'ORIGIN_BUF': 0.0,
#  'ORIGIN_BUR': 0.0,
#  'ORIGIN_BWI': 0.0,
#  'ORIGIN_BZN': 0.0,
#  'ORIGIN_CAE': 0.0,
#  'ORIGIN_CAK': 0.0,
#  'ORIGIN_CDC': 0.0,
#  'ORIGIN_CDV': 0.0,
#  'ORIGIN_CGI': 0.0,
#  'ORIGIN_CHA': 0.0,
#  'ORIGIN_CHO': 0.0,
#  'ORIGIN_CHS': 0.0,
#  'ORIGIN_CID': 0.0,
#  'ORIGIN_CIU': 0.0,
#  'ORIGIN_CKB': 0.0,
#  'ORIGIN_CLE': 0.0,
#  'ORIGIN_CLL': 0.0,
#  'ORIGIN_CLT': 0.0,
#  'ORIGIN_CMH': 0.0,
#  'ORIGIN_CMI': 0.0,
#  'ORIGIN_CMX': 0.0,
#  'ORIGIN_CNY': 0.0,
#  'ORIGIN_COD': 0.0,
#  'ORIGIN_COS': 0.0,
#  'ORIGIN_COU': 0.0,
#  'ORIGIN_CPR': 0.0,
#  'ORIGIN_CRP': 0.0,
#  'ORIGIN_CRW': 0.0,
#  'ORIGIN_CSG': 0.0,
#  'ORIGIN_CVG': 0.0,
#  'ORIGIN_CWA': 0.0,
#  'ORIGIN_CYS': 0.0,
#  'ORIGIN_DAB': 0.0,
#  'ORIGIN_DAL': 0.0,
#  'ORIGIN_DAY': 0.0,
#  'ORIGIN_DBQ': 0.0,
#  'ORIGIN_DCA': 0.0,
#  'ORIGIN_DEN': 0.0,
#  'ORIGIN_DFW': 0.0,
#  'ORIGIN_DHN': 0.0,
#  'ORIGIN_DLG': 0.0,
#  'ORIGIN_DLH': 0.0,
#  'ORIGIN_DRO': 0.0,
#  'ORIGIN_DRT': 0.0,
#  'ORIGIN_DSM': 0.0,
#  'ORIGIN_DTW': 0.0,
#  'ORIGIN_DVL': 0.0,
#  'ORIGIN_EAR': 0.0,
#  'ORIGIN_EAU': 0.0,
#  'ORIGIN_ECP': 0.0,
#  'ORIGIN_EGE': 0.0,
#  'ORIGIN_EKO': 0.0,
#  'ORIGIN_ELM': 0.0,
#  'ORIGIN_ELP': 0.0,
#  'ORIGIN_ERI': 0.0,
#  'ORIGIN_ESC': 0.0,
#  'ORIGIN_EUG': 0.0,
#  'ORIGIN_EVV': 0.0,
#  'ORIGIN_EWN': 0.0,
#  'ORIGIN_EWR': 0.0,
#  'ORIGIN_EYW': 0.0,
#  'ORIGIN_FAI': 0.0,
#  'ORIGIN_FAR': 0.0,
#  'ORIGIN_FAT': 0.0,
#  'ORIGIN_FAY': 0.0,
#  'ORIGIN_FCA': 0.0,
#  'ORIGIN_FLG': 0.0,
#  'ORIGIN_FLL': 0.0,
#  'ORIGIN_FNT': 0.0,
#  'ORIGIN_FSD': 0.0,
#  'ORIGIN_FSM': 0.0,
#  'ORIGIN_FWA': 0.0,
#  'ORIGIN_GCC': 0.0,
#  'ORIGIN_GCK': 0.0,
#  'ORIGIN_GEG': 0.0,
#  'ORIGIN_GFK': 0.0,
#  'ORIGIN_GGG': 0.0,
#  'ORIGIN_GJT': 0.0,
#  'ORIGIN_GNV': 0.0,
#  'ORIGIN_GPT': 0.0,
#  'ORIGIN_GRB': 0.0,
#  'ORIGIN_GRI': 0.0,
#  'ORIGIN_GRK': 0.0,
#  'ORIGIN_GRR': 0.0,
#  'ORIGIN_GSO': 0.0,
#  'ORIGIN_GSP': 0.0,
#  'ORIGIN_GST': 0.0,
#  'ORIGIN_GTF': 0.0,
#  'ORIGIN_GTR': 0.0,
#  'ORIGIN_GUC': 0.0,
#  'ORIGIN_GUM': 0.0,
#  'ORIGIN_HDN': 0.0,
#  'ORIGIN_HGR': 0.0,
#  'ORIGIN_HHH': 0.0,
#  'ORIGIN_HIB': 0.0,
#  'ORIGIN_HLN': 0.0,
#  'ORIGIN_HNL': 0.0,
#  'ORIGIN_HOB': 0.0,
#  'ORIGIN_HOU': 0.0,
#  'ORIGIN_HPN': 0.0,
#  'ORIGIN_HRL': 0.0,
#  'ORIGIN_HSV': 0.0,
#  'ORIGIN_HTS': 0.0,
#  'ORIGIN_HVN': 0.0,
#  'ORIGIN_HYA': 0.0,
#  'ORIGIN_HYS': 0.0,
#  'ORIGIN_IAD': 0.0,
#  'ORIGIN_IAG': 0.0,
#  'ORIGIN_IAH': 0.0,
#  'ORIGIN_ICT': 0.0,
#  'ORIGIN_IDA': 0.0,
#  'ORIGIN_ILM': 0.0,
#  'ORIGIN_IMT': 0.0,
#  'ORIGIN_IND': 0.0,
#  'ORIGIN_INL': 0.0,
#  'ORIGIN_ISN': 0.0,
#  'ORIGIN_ISP': 0.0,
#  'ORIGIN_ITH': 0.0,
#  'ORIGIN_ITO': 0.0,
#  'ORIGIN_JAC': 0.0,
#  'ORIGIN_JAN': 0.0,
#  'ORIGIN_JAX': 0.0,
#  'ORIGIN_JFK': 0.0,
#  'ORIGIN_JLN': 0.0,
#  'ORIGIN_JMS': 0.0,
#  'ORIGIN_JNU': 0.0,
#  'ORIGIN_KOA': 0.0,
#  'ORIGIN_KTN': 0.0,
#  'ORIGIN_LAN': 0.0,
#  'ORIGIN_LAR': 0.0,
#  'ORIGIN_LAS': 0.0,
#  'ORIGIN_LAW': 0.0,
#  'ORIGIN_LAX': 0.0,
#  'ORIGIN_LBB': 0.0,
#  'ORIGIN_LBE': 0.0,
#  'ORIGIN_LBF': 0.0,
#  'ORIGIN_LBL': 0.0,
#  'ORIGIN_LCH': 0.0,
#  'ORIGIN_LCK': 0.0,
#  'ORIGIN_LEX': 0.0,
#  'ORIGIN_LFT': 0.0,
#  'ORIGIN_LGA': 0.0,
#  'ORIGIN_LGB': 0.0,
#  'ORIGIN_LIH': 0.0,
#  'ORIGIN_LIT': 0.0,
#  'ORIGIN_LNK': 0.0,
#  'ORIGIN_LRD': 0.0,
#  'ORIGIN_LSE': 0.0,
#  'ORIGIN_LWB': 0.0,
#  'ORIGIN_LWS': 0.0,
#  'ORIGIN_LYH': 0.0,
#  'ORIGIN_MAF': 0.0,
#  'ORIGIN_MBS': 0.0,
#  'ORIGIN_MCI': 0.0,
#  'ORIGIN_MCO': 0.0,
#  'ORIGIN_MDT': 0.0,
#  'ORIGIN_MDW': 0.0,
#  'ORIGIN_MEI': 0.0,
#  'ORIGIN_MEM': 0.0,
#  'ORIGIN_MFE': 0.0,
#  'ORIGIN_MFR': 0.0,
#  'ORIGIN_MGM': 0.0,
#  'ORIGIN_MHK': 0.0,
#  'ORIGIN_MHT': 0.0,
#  'ORIGIN_MIA': 0.0,
#  'ORIGIN_MKE': 0.0,
#  'ORIGIN_MKG': 0.0,
#  'ORIGIN_MLB': 0.0,
#  'ORIGIN_MLI': 0.0,
#  'ORIGIN_MLU': 0.0,
#  'ORIGIN_MMH': 0.0,
#  'ORIGIN_MOB': 0.0,
#  'ORIGIN_MOT': 0.0,
#  'ORIGIN_MQT': 0.0,
#  'ORIGIN_MRY': 0.0,
#  'ORIGIN_MSN': 0.0,
#  'ORIGIN_MSO': 0.0,
#  'ORIGIN_MSP': 0.0,
#  'ORIGIN_MSY': 0.0,
#  'ORIGIN_MTJ': 0.0,
#  'ORIGIN_MVY': 0.0,
#  'ORIGIN_MYR': 0.0,
#  'ORIGIN_OAJ': 0.0,
#  'ORIGIN_OAK': 0.0,
#  'ORIGIN_OGD': 0.0,
#  'ORIGIN_OGG': 0.0,
#  'ORIGIN_OGS': 0.0,
#  'ORIGIN_OKC': 0.0,
#  'ORIGIN_OMA': 0.0,
#  'ORIGIN_OME': 0.0,
#  'ORIGIN_ONT': 0.0,
#  'ORIGIN_ORD': 0.0,
#  'ORIGIN_ORF': 0.0,
#  'ORIGIN_ORH': 0.0,
#  'ORIGIN_OTH': 0.0,
#  'ORIGIN_OTZ': 0.0,
#  'ORIGIN_OWB': 0.0,
#  'ORIGIN_PAE': 0.0,
#  'ORIGIN_PAH': 0.0,
#  'ORIGIN_PBG': 0.0,
#  'ORIGIN_PBI': 0.0,
#  'ORIGIN_PDX': 0.0,
#  'ORIGIN_PGD': 0.0,
#  'ORIGIN_PGV': 0.0,
#  'ORIGIN_PHF': 0.0,
#  'ORIGIN_PHL': 0.0,
#  'ORIGIN_PHX': 0.0,
#  'ORIGIN_PIA': 0.0,
#  'ORIGIN_PIB': 0.0,
#  'ORIGIN_PIE': 0.0,
#  'ORIGIN_PIH': 0.0,
#  'ORIGIN_PIR': 0.0,
#  'ORIGIN_PIT': 0.0,
#  'ORIGIN_PLN': 0.0,
#  'ORIGIN_PNS': 0.0,
#  'ORIGIN_PPG': 0.0,
#  'ORIGIN_PRC': 0.0,
#  'ORIGIN_PSC': 0.0,
#  'ORIGIN_PSE': 0.0,
#  'ORIGIN_PSG': 0.0,
#  'ORIGIN_PSM': 0.0,
#  'ORIGIN_PSP': 0.0,
#  'ORIGIN_PUB': 0.0,
#  'ORIGIN_PVD': 0.0,
#  'ORIGIN_PVU': 0.0,
#  'ORIGIN_PWM': 0.0,
#  'ORIGIN_RAP': 0.0,
#  'ORIGIN_RDD': 0.0,
#  'ORIGIN_RDM': 0.0,
#  'ORIGIN_RDU': 0.0,
#  'ORIGIN_RFD': 0.0,
#  'ORIGIN_RHI': 0.0,
#  'ORIGIN_RIC': 0.0,
#  'ORIGIN_RKS': 0.0,
#  'ORIGIN_RNO': 0.0,
#  'ORIGIN_ROA': 0.0,
#  'ORIGIN_ROC': 0.0,
#  'ORIGIN_ROW': 0.0,
#  'ORIGIN_RST': 0.0,
#  'ORIGIN_RSW': 0.0,
#  'ORIGIN_SAF': 0.0,
#  'ORIGIN_SAN': 0.0,
#  'ORIGIN_SAT': 0.0,
#  'ORIGIN_SAV': 0.0,
#  'ORIGIN_SBA': 0.0,
#  'ORIGIN_SBN': 0.0,
#  'ORIGIN_SBP': 0.0,
#  'ORIGIN_SCC': 0.0,
#  'ORIGIN_SCE': 0.0,
#  'ORIGIN_SCK': 0.0,
#  'ORIGIN_SDF': 0.0,
#  'ORIGIN_SEA': 0.0,
#  'ORIGIN_SFB': 0.0,
#  'ORIGIN_SFO': 0.0,
#  'ORIGIN_SGF': 0.0,
#  'ORIGIN_SGU': 0.0,
#  'ORIGIN_SHD': 0.0,
#  'ORIGIN_SHV': 0.0,
#  'ORIGIN_SIT': 0.0,
#  'ORIGIN_SJC': 0.0,
#  'ORIGIN_SJT': 0.0,
#  'ORIGIN_SJU': 0.0,
#  'ORIGIN_SLC': 0.0,
#  'ORIGIN_SLN': 0.0,
#  'ORIGIN_SMF': 0.0,
#  'ORIGIN_SMX': 0.0,
#  'ORIGIN_SNA': 0.0,
#  'ORIGIN_SPI': 0.0,
#  'ORIGIN_SPN': 0.0,
#  'ORIGIN_SPS': 0.0,
#  'ORIGIN_SRQ': 0.0,
#  'ORIGIN_STC': 0.0,
#  'ORIGIN_STL': 0.0,
#  'ORIGIN_STS': 0.0,
#  'ORIGIN_STT': 0.0,
#  'ORIGIN_STX': 0.0,
#  'ORIGIN_SUN': 0.0,
#  'ORIGIN_SUX': 0.0,
#  'ORIGIN_SWF': 0.0,
#  'ORIGIN_SWO': 0.0,
#  'ORIGIN_SYR': 0.0,
#  'ORIGIN_TLH': 0.0,
#  'ORIGIN_TOL': 0.0,
#  'ORIGIN_TPA': 0.0,
#  'ORIGIN_TRI': 0.0,
#  'ORIGIN_TTN': 0.0,
#  'ORIGIN_TUL': 0.0,
#  'ORIGIN_TUS': 0.0,
#  'ORIGIN_TVC': 0.0,
#  'ORIGIN_TWF': 0.0,
#  'ORIGIN_TXK': 0.0,
#  'ORIGIN_TYR': 0.0,
#  'ORIGIN_TYS': 0.0,
#  'ORIGIN_UIN': 0.0,
#  'ORIGIN_USA': 0.0,
#  'ORIGIN_VEL': 0.0,
#  'ORIGIN_VLD': 0.0,
#  'ORIGIN_VPS': 0.0,
#  'ORIGIN_WRG': 0.0,
#  'ORIGIN_WYS': 0.0,
#  'ORIGIN_XNA': 0.0,
#  'ORIGIN_XWA': 0.0,
#  'ORIGIN_YAK': 0.0,
#  'ORIGIN_YUM': 0.0,
#  'DEST_ABE': 0.0,
#  'DEST_ABI': 0.0,
#  'DEST_ABQ': 0.0,
#  'DEST_ABR': 0.0,
#  'DEST_ABY': 0.0,
#  'DEST_ACK': 0.0,
#  'DEST_ACT': 0.0,
#  'DEST_ACV': 0.0,
#  'DEST_ACY': 0.0,
#  'DEST_ADK': 0.0,
#  'DEST_ADQ': 0.0,
#  'DEST_AEX': 0.0,
#  'DEST_AGS': 0.0,
#  'DEST_AKN': 0.0,
#  'DEST_ALB': 0.0,
#  'DEST_ALO': 0.0,
#  'DEST_AMA': 0.0,
#  'DEST_ANC': 0.0,
#  'DEST_APN': 0.0,
#  'DEST_ART': 0.0,
#  'DEST_ASE': 0.0,
#  'DEST_ATL': 0.0,
#  'DEST_ATW': 0.0,
#  'DEST_ATY': 0.0,
#  'DEST_AUS': 0.0,
#  'DEST_AVL': 0.0,
#  'DEST_AVP': 0.0,
#  'DEST_AZA': 0.0,
#  'DEST_AZO': 0.0,
#  'DEST_BDL': 0.0,
#  'DEST_BET': 0.0,
#  'DEST_BFF': 0.0,
#  'DEST_BFL': 0.0,
#  'DEST_BFM': 0.0,
#  'DEST_BGM': 0.0,
#  'DEST_BGR': 0.0,
#  'DEST_BHM': 0.0,
#  'DEST_BIL': 0.0,
#  'DEST_BIS': 0.0,
#  'DEST_BJI': 0.0,
#  'DEST_BKG': 0.0,
#  'DEST_BLI': 0.0,
#  'DEST_BLV': 0.0,
#  'DEST_BMI': 0.0,
#  'DEST_BNA': 0.0,
#  'DEST_BOI': 0.0,
#  'DEST_BOS': 0.0,
#  'DEST_BPT': 0.0,
#  'DEST_BQK': 0.0,
#  'DEST_BQN': 0.0,
#  'DEST_BRD': 0.0,
#  'DEST_BRO': 0.0,
#  'DEST_BRW': 0.0,
#  'DEST_BTM': 0.0,
#  'DEST_BTR': 0.0,
#  'DEST_BTV': 0.0,
#  'DEST_BUF': 0.0,
#  'DEST_BUR': 0.0,
#  'DEST_BWI': 0.0,
#  'DEST_BZN': 0.0,
#  'DEST_CAE': 0.0,
#  'DEST_CAK': 0.0,
#  'DEST_CDC': 0.0,
#  'DEST_CDV': 0.0,
#  'DEST_CGI': 0.0,
#  'DEST_CHA': 0.0,
#  'DEST_CHO': 0.0,
#  'DEST_CHS': 0.0,
#  'DEST_CID': 0.0,
#  'DEST_CIU': 0.0,
#  'DEST_CKB': 0.0,
#  'DEST_CLE': 0.0,
#  'DEST_CLL': 0.0,
#  'DEST_CLT': 0.0,
#  'DEST_CMH': 0.0,
#  'DEST_CMI': 0.0,
#  'DEST_CMX': 0.0,
#  'DEST_CNY': 0.0,
#  'DEST_COD': 0.0,
#  'DEST_COS': 0.0,
#  'DEST_COU': 0.0,
#  'DEST_CPR': 0.0,
#  'DEST_CRP': 0.0,
#  'DEST_CRW': 0.0,
#  'DEST_CSG': 0.0,
#  'DEST_CVG': 0.0,
#  'DEST_CWA': 0.0,
#  'DEST_CYS': 0.0,
#  'DEST_DAB': 0.0,
#  'DEST_DAL': 0.0,
#  'DEST_DAY': 0.0,
#  'DEST_DBQ': 0.0,
#  'DEST_DCA': 0.0,
#  'DEST_DEN': 0.0,
#  'DEST_DFW': 0.0,
#  'DEST_DHN': 0.0,
#  'DEST_DLG': 0.0,
#  'DEST_DLH': 0.0,
#  'DEST_DRO': 0.0,
#  'DEST_DRT': 0.0,
#  'DEST_DSM': 0.0,
#  'DEST_DTW': 0.0,
#  'DEST_DVL': 0.0,
#  'DEST_EAR': 0.0,
#  'DEST_EAU': 0.0,
#  'DEST_ECP': 0.0,
#  'DEST_EGE': 0.0,
#  'DEST_EKO': 0.0,
#  'DEST_ELM': 0.0,
#  'DEST_ELP': 0.0,
#  'DEST_ERI': 0.0,
#  'DEST_ESC': 0.0,
#  'DEST_EUG': 0.0,
#  'DEST_EVV': 0.0,
#  'DEST_EWN': 0.0,
#  'DEST_EWR': 0.0,
#  'DEST_EYW': 0.0,
#  'DEST_FAI': 0.0,
#  'DEST_FAR': 0.0,
#  'DEST_FAT': 0.0,
#  'DEST_FAY': 0.0,
#  'DEST_FCA': 0.0,
#  'DEST_FLG': 0.0,
#  'DEST_FLL': 0.0,
#  'DEST_FNT': 0.0,
#  'DEST_FSD': 0.0,
#  'DEST_FSM': 0.0,
#  'DEST_FWA': 0.0,
#  'DEST_GCC': 0.0,
#  'DEST_GCK': 0.0,
#  'DEST_GEG': 0.0,
#  'DEST_GFK': 0.0,
#  'DEST_GGG': 0.0,
#  'DEST_GJT': 0.0,
#  'DEST_GNV': 0.0,
#  'DEST_GPT': 0.0,
#  'DEST_GRB': 0.0,
#  'DEST_GRI': 0.0,
#  'DEST_GRK': 0.0,
#  'DEST_GRR': 0.0,
#  'DEST_GSO': 0.0,
#  'DEST_GSP': 0.0,
#  'DEST_GST': 0.0,
#  'DEST_GTF': 0.0,
#  'DEST_GTR': 0.0,
#  'DEST_GUC': 0.0,
#  'DEST_GUM': 0.0,
#  'DEST_HDN': 0.0,
#  'DEST_HGR': 0.0,
#  'DEST_HHH': 0.0,
#  'DEST_HIB': 0.0,
#  'DEST_HLN': 0.0,
#  'DEST_HNL': 0.0,
#  'DEST_HOB': 0.0,
#  'DEST_HOU': 0.0,
#  'DEST_HPN': 0.0,
#  'DEST_HRL': 0.0,
#  'DEST_HSV': 0.0,
#  'DEST_HTS': 0.0,
#  'DEST_HVN': 0.0,
#  'DEST_HYA': 0.0,
#  'DEST_HYS': 0.0,
#  'DEST_IAD': 0.0,
#  'DEST_IAG': 0.0,
#  'DEST_IAH': 0.0,
#  'DEST_ICT': 0.0,
#  'DEST_IDA': 0.0,
#  'DEST_ILM': 0.0,
#  'DEST_IMT': 0.0,
#  'DEST_IND': 0.0,
#  'DEST_INL': 0.0,
#  'DEST_ISN': 0.0,
#  'DEST_ISP': 0.0,
#  'DEST_ITH': 0.0,
#  'DEST_ITO': 0.0,
#  'DEST_JAC': 0.0,
#  'DEST_JAN': 0.0,
#  'DEST_JAX': 0.0,
#  'DEST_JFK': 0.0,
#  'DEST_JLN': 0.0,
#  'DEST_JMS': 0.0,
#  'DEST_JNU': 0.0,
#  'DEST_KOA': 0.0,
#  'DEST_KTN': 0.0,
#  'DEST_LAN': 0.0,
#  'DEST_LAR': 0.0,
#  'DEST_LAS': 0.0,
#  'DEST_LAW': 0.0,
#  'DEST_LAX': 0.0,
#  'DEST_LBB': 0.0,
#  'DEST_LBE': 0.0,
#  'DEST_LBF': 0.0,
#  'DEST_LBL': 0.0,
#  'DEST_LCH': 0.0,
#  'DEST_LCK': 0.0,
#  'DEST_LEX': 0.0,
#  'DEST_LFT': 0.0,
#  'DEST_LGA': 0.0,
#  'DEST_LGB': 0.0,
#  'DEST_LIH': 0.0,
#  'DEST_LIT': 0.0,
#  'DEST_LNK': 0.0,
#  'DEST_LRD': 0.0,
#  'DEST_LSE': 0.0,
#  'DEST_LWB': 0.0,
#  'DEST_LWS': 0.0,
#  'DEST_LYH': 0.0,
#  'DEST_MAF': 0.0,
#  'DEST_MBS': 0.0,
#  'DEST_MCI': 0.0,
#  'DEST_MCO': 0.0,
#  'DEST_MDT': 0.0,
#  'DEST_MDW': 0.0,
#  'DEST_MEI': 0.0,
#  'DEST_MEM': 0.0,
#  'DEST_MFE': 0.0,
#  'DEST_MFR': 0.0,
#  'DEST_MGM': 0.0,
#  'DEST_MHK': 0.0,
#  'DEST_MHT': 0.0,
#  'DEST_MIA': 0.0,
#  'DEST_MKE': 0.0,
#  'DEST_MKG': 0.0,
#  'DEST_MLB': 0.0,
#  'DEST_MLI': 0.0,
#  'DEST_MLU': 0.0,
#  'DEST_MMH': 0.0,
#  'DEST_MOB': 0.0,
#  'DEST_MOT': 0.0,
#  'DEST_MQT': 0.0,
#  'DEST_MRY': 0.0,
#  'DEST_MSN': 0.0,
#  'DEST_MSO': 0.0,
#  'DEST_MSP': 0.0,
#  'DEST_MSY': 0.0,
#  'DEST_MTJ': 0.0,
#  'DEST_MVY': 0.0,
#  'DEST_MYR': 0.0,
#  'DEST_OAJ': 0.0,
#  'DEST_OAK': 0.0,
#  'DEST_OGD': 0.0,
#  'DEST_OGG': 0.0,
#  'DEST_OGS': 0.0,
#  'DEST_OKC': 0.0,
#  'DEST_OMA': 0.0,
#  'DEST_OME': 0.0,
#  'DEST_ONT': 0.0,
#  'DEST_ORD': 0.0,
#  'DEST_ORF': 0.0,
#  'DEST_ORH': 0.0,
#  'DEST_OTH': 0.0,
#  'DEST_OTZ': 0.0,
#  'DEST_OWB': 0.0,
#  'DEST_PAE': 0.0,
#  'DEST_PAH': 0.0,
#  'DEST_PBG': 0.0,
#  'DEST_PBI': 0.0,
#  'DEST_PDX': 0.0,
#  'DEST_PGD': 0.0,
#  'DEST_PGV': 0.0,
#  'DEST_PHF': 0.0,
#  'DEST_PHL': 0.0,
#  'DEST_PHX': 0.0,
#  'DEST_PIA': 0.0,
#  'DEST_PIB': 0.0,
#  'DEST_PIE': 0.0,
#  'DEST_PIH': 0.0,
#  'DEST_PIR': 0.0,
#  'DEST_PIT': 0.0,
#  'DEST_PLN': 0.0,
#  'DEST_PNS': 0.0,
#  'DEST_PPG': 0.0,
#  'DEST_PRC': 0.0,
#  'DEST_PSC': 0.0,
#  'DEST_PSE': 0.0,
#  'DEST_PSG': 0.0,
#  'DEST_PSM': 0.0,
#  'DEST_PSP': 0.0,
#  'DEST_PUB': 0.0,
#  'DEST_PVD': 0.0,
#  'DEST_PVU': 0.0,
#  'DEST_PWM': 0.0,
#  'DEST_RAP': 0.0,
#  'DEST_RDD': 0.0,
#  'DEST_RDM': 0.0,
#  'DEST_RDU': 0.0,
#  'DEST_RFD': 0.0,
#  'DEST_RHI': 0.0,
#  'DEST_RIC': 0.0,
#  'DEST_RKS': 0.0,
#  'DEST_RNO': 0.0,
#  'DEST_ROA': 0.0,
#  'DEST_ROC': 0.0,
#  'DEST_ROW': 0.0,
#  'DEST_RST': 0.0,
#  'DEST_RSW': 0.0,
#  'DEST_SAF': 0.0,
#  'DEST_SAN': 0.0,
#  'DEST_SAT': 0.0,
#  'DEST_SAV': 0.0,
#  'DEST_SBA': 0.0,
#  'DEST_SBN': 0.0,
#  'DEST_SBP': 0.0,
#  'DEST_SCC': 0.0,
#  'DEST_SCE': 0.0,
#  'DEST_SCK': 0.0,
#  'DEST_SDF': 0.0,
#  'DEST_SEA': 0.0,
#  'DEST_SFB': 0.0,
#  'DEST_SFO': 0.0008248116,
#  'DEST_SGF': 0.0,
#  'DEST_SGU': 0.0,
#  'DEST_SHD': 0.0,
#  'DEST_SHV': 0.0,
#  'DEST_SIT': 0.0,
#  'DEST_SJC': 0.0,
#  'DEST_SJT': 0.0,
#  'DEST_SJU': 0.0,
#  'DEST_SLC': 0.0,
#  'DEST_SLN': 0.0,
#  'DEST_SMF': 0.0,
#  'DEST_SMX': 0.0,
#  'DEST_SNA': 0.0,
#  'DEST_SPI': 0.0,
#  'DEST_SPN': 0.0,
#  'DEST_SPS': 0.0,
#  'DEST_SRQ': 0.0,
#  'DEST_STC': 0.0,
#  'DEST_STL': 0.0,
#  'DEST_STS': 0.0,
#  'DEST_STT': 0.0,
#  'DEST_STX': 0.0,
#  'DEST_SUN': 0.0,
#  'DEST_SUX': 0.0,
#  'DEST_SWF': 0.0,
#  'DEST_SWO': 0.0,
#  'DEST_SYR': 0.0,
#  'DEST_TLH': 0.0,
#  'DEST_TOL': 0.0,
#  'DEST_TPA': 0.0,
#  'DEST_TRI': 0.0,
#  'DEST_TTN': 0.0,
#  'DEST_TUL': 0.0,
#  'DEST_TUS': 0.0,
#  'DEST_TVC': 0.0,
#  'DEST_TWF': 0.0,
#  'DEST_TXK': 0.0,
#  'DEST_TYR': 0.0,
#  'DEST_TYS': 0.0,
#  'DEST_UIN': 0.0,
#  'DEST_USA': 0.0,
#  'DEST_VEL': 0.0,
#  'DEST_VLD': 0.0,
#  'DEST_VPS': 0.0,
#  'DEST_WRG': 0.0,
#  'DEST_WYS': 0.0,
#  'DEST_XNA': 0.0,
#  'DEST_XWA': 0.0,
#  'DEST_YAK': 0.0,
#  'DEST_YUM': 0.0,
#  'DEP_TIME_hour_0': 0.16587059,
#  'DEP_TIME_hour_6': 0.38690782,
#  'DEP_TIME_hour_7': 0.22624892,
#  'DEP_TIME_hour_8': 0.1776397,
#  'DEP_TIME_hour_9': 0.0,
#  'DEP_TIME_hour_10': 0.0,
#  'DEP_TIME_hour_11': 0.0,
#  'DEP_TIME_hour_12': 0.0,
#  'DEP_TIME_hour_13': 0.0,
#  'DEP_TIME_hour_14': 0.0,
#  'DEP_TIME_hour_15': 0.0,
#  'DEP_TIME_hour_16': 0.0,
#  'DEP_TIME_hour_17': 0.0,
#  'DEP_TIME_hour_18': 0.0,
#  'DEP_TIME_hour_19': 0.0,
#  'DEP_TIME_hour_20': 0.0,
#  'DEP_TIME_hour_21': 0.0,
#  'DEP_TIME_hour_22': 0.0,
#  'DEP_TIME_hour_23': 0.0,
#  'ARR_TIME_hour_0': 0.0,
#  'ARR_TIME_hour_6': 0.0,
#  'ARR_TIME_hour_7': 0.0,
#  'ARR_TIME_hour_8': 0.0,
#  'ARR_TIME_hour_9': 0.0,
#  'ARR_TIME_hour_10': 0.0,
#  'ARR_TIME_hour_11': 0.0,
#  'ARR_TIME_hour_12': 0.0,
#  'ARR_TIME_hour_13': 0.0,
#  'ARR_TIME_hour_14': 0.0,
#  'ARR_TIME_hour_15': 0.0,
#  'ARR_TIME_hour_16': 0.0,
#  'ARR_TIME_hour_17': 0.0,
#  'ARR_TIME_hour_18': 0.0,
#  'ARR_TIME_hour_19': 0.0,
#  'ARR_TIME_hour_20': 0.0,
#  'ARR_TIME_hour_21': 0.0,
#  'ARR_TIME_hour_22': 0.0,
#  'ARR_TIME_hour_23': 0.0,
#  'DISTANCE_GROUP_1': 0.0,
#  'DISTANCE_GROUP_2': 0.0,
#  'DISTANCE_GROUP_3': 0.0,
#  'DISTANCE_GROUP_4': 0.0,
#  'DISTANCE_GROUP_5': 0.0,
#  'DISTANCE_GROUP_6': 0.0,
#  'DISTANCE_GROUP_7': 0.0,
#  'DISTANCE_GROUP_8': 0.0,
#  'DISTANCE_GROUP_9': 0.0,
#  'DISTANCE_GROUP_10': 0.0,
#  'DISTANCE_GROUP_11': 0.0}

# %% [markdown]
# ### Feature importance (plot)

# %% [markdown]
# #### Weight-based

# %%
from xgboost import plot_importance

fig,ax = plt.subplots(figsize=(5,5))

plot_importance(booster=xgb_model,
                ax=ax,
                grid=True,
                importance_type='weight', # ”weight” is the number of times a feature appears in a tree
                max_num_features=None, 
                height=0.5,
                xlim=None,
                ylim=None, 
                title='Feature importance (WEIGHT-based)',
                xlabel='F score',
                ylabel='Features',
                show_values=True);

# %% [markdown]
# #### Gain-based

# %%
from xgboost import plot_importance

fig,ax = plt.subplots(figsize=(5,5))

plot_importance(booster=xgb_model,
                ax=ax,
                grid=True,
                importance_type='gain', # ”weight” is the number of times a feature appears in a tree
                max_num_features=None, 
                height=0.5,
                xlim=None,
                ylim=None, 
                title='Feature importance (GAIN-based)',
                xlabel='F score',
                ylabel='Features',
                show_values=True);

# %% [markdown]
# ### Tree

# %%
from xgboost import plot_tree

fig,ax = plt.subplots(figsize=(80,50))

plot_tree(booster=xgb_model,
          num_trees=0,
          ax=ax)

plt.savefig('plot_tree_14.png')

# %% [markdown]
# ### Graphviz (tree)

# %% [markdown]
# *Convert specified tree to graphviz instance. IPython can automatically plot the returned graphiz instance. Otherwise, you should call `.render()` method of the returned graphiz instance.*

# %%
from xgboost import to_graphviz

tree_graphviz = to_graphviz(booster=xgb_model,
                            yes_color='#0000FF',
                            no_color='#FF0000',
                            condition_node_params={'shape': 'box',
                                                   'style': 'filled,rounded',
                                                   'fillcolor': '#78bceb'},
                            leaf_node_params={'shape': 'box',
                                              'style': 'filled',
                                              'fillcolor': '#e48038'})

format = 'png'
tree_graphviz = to_graphviz(xgb_model)
tree_graphviz.graph_attr = {'dpi':'400'}
tree_graphviz.render('tree_graphviz_14', format = format)
# Out:
# 'tree_graphviz_14.png'

# %% [markdown]
# ___

# %%
t1 = time.perf_counter() - t0
print("Time elapsed: {:2.0f}h {:2.0f}min {:2.0f}s".format(t1//3600, (t1%3600)//60, (t1%3600)%60))
# Out:
# Time elapsed:  1h  6min  7s

# %% [raw]
# Time elapsed:  1h  6min  7s

# %% [markdown]
# ## Save the model

# %%
from joblib import dump, load

# Save model to file:
dump(xgb_model, "XGBoost_14.joblib.dat")
print("Saved model to: XGBoost_14.joblib.dat")
# Out:
# Saved model to: XGBoost_14.joblib.dat

# %%
# Load model from file:
loaded_model = load("XGBoost_14.joblib.dat")
print("Loaded model from: XGBoost_14.joblib.dat")
# Out:
# Loaded model from: XGBoost_14.joblib.dat

# %%
# Make predictions for test data
predictions = loaded_model.predict(X_test)

# Evaluate predictions:
recall = recall_score(y_test, predictions)
print("Loaded model recall: {:6.3f}".format(recall))
# Out:
# Loaded model recall:  0.858

# %% [markdown]
# ___

# %% [markdown]
# ___
