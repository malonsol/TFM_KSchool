# %% [markdown]
# ___

# %%
# Import libraries to be used

# Warning messages display
# import warnings
# warnings.filterwarnings(action='once') # https://docs.python.org/3/library/warnings.html#the-warnings-filter

# Directories/Files management
import os.path
## from zipfile import ZipFile # De momento no ha hecho falta 

# Timing
import time

# Data analysis and wrangling
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', None) # Show all columns in DataFrames
pd.set_option('display.max_rows', 100) # If too high, it greatly slows down the output display and freezes the kernel


# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('ggplot') # choose a style: 'plt.style.available'
sns.set_theme(context='notebook',
              style="darkgrid") # {darkgrid, whitegrid, dark, white, ticks}
palette = sns.color_palette("flare", as_cmap=True);
import altair as alt

# Machine Learning
## from sklearn.[...] import ...

# %%
# %load_ext memory_profiler

# %%
t0 = time.perf_counter()

# %%
# Detect Operating System running and manage paths accordingly

if os.name == 'nt': # Windows
    root = r"C:\Users\turge\CompartidoVM\0.TFM"
    print("Running on Windows.")
elif os.name == 'posix': # Ubuntu
    root = "/home/dsc/shared/0.TFM"
    print("Running on Ubuntu.")
print("root path\t", root)
# Out:
# Running on Windows.
# root path	 C:\Users\turge\CompartidoVM\0.TFM

# %% [markdown]
# ___

# %% [markdown]
# ## 1. Load the dataset

# %%
cols = [
     'MONTH',
     'DAY_OF_MONTH',
     'DAY_OF_WEEK',
     'OP_UNIQUE_CARRIER',
# For the time being, 'TAIL_NUM' will be disregarded due to its high cardinality  (~ 4500) and low expected added value    
#      'TAIL_NUM',
#      'ORIGIN', # Let's skip this feature to prevent high cardinality and check if it's relevant or not
#      'DEST', # Let's skip this feature to prevent high cardinality and check if it's relevant or not
#      'CRS_DEP_TIME', # Redundant having the 'DEP_ARR_hour' feature
     'DEP_TIME_hour',
#      'DEP_TIME',
#      'DEP_DELAY',
#      'DEP_DEL15',
#      'TAXI_OUT',
     'TAXI_OUT_median',
#      'TAXI_IN',
     'TAXI_IN_median',
#      'CRS_ARR_TIME', # Redundant having the 'ARR_ARR_hour' feature
     'ARR_TIME_hour', 
#      'ARR_TIME',   
#      'ARR_DELAY',
     'ARR_DEL15', # → Target !!
#      'CANCELLED',
     'CRS_ELAPSED_TIME',
     'DISTANCE',
     'DISTANCE_GROUP',
#      'CARRIER_DELAY',
#      'WEATHER_DELAY',
#      'NAS_DELAY',
#      'SECURITY_DELAY',
#      'LATE_AIRCRAFT_DELAY',
]

# %%
preprocessed_input_csv_path = os.path.join(root,
                                           "Output_Data",
                                           "US_DoT",
                                           "AL_OTP_MVP_Preprocessed_19_v2_clean.csv")
preprocessed_input_csv_path
# Out:
# 'C:\\Users\\turge\\CompartidoVM\\0.TFM\\Output_Data\\US_DoT\\AL_OTP_MVP_Preprocessed_19_v2_clean.csv'

# %%
cols_dtypes = {
               'MONTH' : 'category',
               'DAY_OF_MONTH' : 'category',
               'DAY_OF_WEEK' : 'category',
               'OP_UNIQUE_CARRIER' : 'category',
#                'ORIGIN' : 'category',
#                'DEST' : 'category',
               'DEP_TIME_hour' : 'category',
               'TAXI_OUT_median' : 'int64',
               'TAXI_IN_median' : 'int64',
               'ARR_TIME_hour' : 'category', 
               'ARR_DEL15' : 'int32', # → Target !!
               'CRS_ELAPSED_TIME' : 'int64',
               'DISTANCE' : 'int64',
               'DISTANCE_GROUP' : 'category'
               }

# %%
# %%time

df_all = pd.read_csv(preprocessed_input_csv_path,
                     encoding='latin1',
                     usecols=cols,
                     low_memory = False)
# Out:
# Wall time: 18.5 s

# %%
# Cast types in accordance to previously defined dictionary:
df_all = df_all.astype(cols_dtypes)
# Display DF columns according to 'cols' order:
df_all = df_all[cols]
df_all
# Out:
#         MONTH DAY_OF_MONTH DAY_OF_WEEK OP_UNIQUE_CARRIER DEP_TIME_hour  \
# 0           1            3           4                9E            11
# 1           1            4           5                9E            11
# 2           1            5           6                9E             9
# 3           1            6           7                9E             9
# 4           1            7           1                9E             9
# ...       ...          ...         ...               ...           ...
# 7268227    12           31           2                B6            13
# 7268228    12           31           2                B6            14
# 7268229    12           31           2                B6             7
# 7268230    12           31           2                B6             8
# 7268231    12           31           2                B6             0
#
#          TAXI_OUT_median  TAXI_IN_median ARR_TIME_hour  ARR_DEL15  \
# 0                     15               8            12          1
# 1                     15               8            12          1
# 2                     17               5            10          0
# 3                     17               5            10          0
# 4                     17               5            10          0
# ...                  ...             ...           ...        ...
# 7268227               15               6            16          1
# 7268228               15               6            15          0
# 7268229               17               6             8          0
# 7268230               16               5            13          0
# 7268231               11               6             7          0
#
#          CRS_ELAPSED_TIME  DISTANCE DISTANCE_GROUP
# 0                      70       152              1
# 1                      70       152              1
# 2                     121       563              3
# 3                     123       563              3
# 4                     123       563              3
# ...                   ...       ...            ...
# 7268227               163       989              4
# 7268228                90       399              2
# 7268229                85       280              2
# 7268230               242      1674              7
# 7268231               249      1674              7
#
# [7268232 rows x 12 columns]

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7268232 entries, 0 to 7268231
# Data columns (total 12 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   MONTH              category
#  1   DAY_OF_MONTH       category
#  2   DAY_OF_WEEK        category
#  3   OP_UNIQUE_CARRIER  category
#  4   DEP_TIME_hour      category
#  5   TAXI_OUT_median    int64
#  6   TAXI_IN_median     int64
#  7   ARR_TIME_hour      category
#  8   ARR_DEL15          int32
#  9   CRS_ELAPSED_TIME   int64
#  10  DISTANCE           int64
#  11  DISTANCE_GROUP     category
# dtypes: category(7), int32(1), int64(4)
# memory usage: 298.1 MB

# %%
# from pandas_profiling import ProfileReport

# # # Complete report:
# # prof = ProfileReport(df_all)
# # prof.to_file('informe.html')

# # Sample report (more computationally efficient)
# prof = ProfileReport(df_all.sample(10000)) 
# prof.to_file('sample_report.html')

# %%
# from pandas_profiling import ProfileReport

# # Complete report:
# prof = ProfileReport(df_all, minimal=True)
# prof.to_file('complete_report.html')

# # # Sample report (more computationally efficient)
# # prof = ProfileReport(df_all.sample(10000)) 
# # prof.to_file('sample_report.html')

# %% [markdown]
# ## 2. Dataset overview

# %%
# For the initial runs, define a reasonably-sized sample:
sample_length = int(len(df_all))

# The dataset is somehow imbalanced (80% on-time / 20% delayed), so let's perform some quick undersampling:
delayed = df_all[df_all['ARR_DEL15'] == 1]
ontime = df_all[df_all['ARR_DEL15'] == 0].sample(len(delayed))
df = delayed.append(ontime)

# Get dummies for the categorical features:
df = pd.get_dummies(df)

print("On-time flights: {:7d} ({:5.2f}%)".format(len(ontime), 100*len(ontime)/len(df)))
print("Delayed flights: {:7d} ({:5.2f}%)".format(len(delayed), 100*len(delayed)/len(df)))
# Out:
# On-time flights: 1389253 (50.00%)
# Delayed flights: 1389253 (50.00%)

# %% [markdown]
# ### Train / Test / Validation split
# Break the dataset into three blocks:
# 1. Training (70%)
# 2. Test (15%)
# 3. Validation (15%)

# %%
# Divide the data:
train = df.sample(frac=0.7)
test_valid = df.drop(train.index)
test = test_valid.sample(frac=0.5)
valid = test_valid.drop(test.index)

print("Total dataset:      {:7d} ({:6.2f}%)".format(len(df), 100*len(df)/len(df)))
print("Training dataset:   {:7d} ( {:5.2f}%)".format(len(train), 100*len(train)/len(df)))
print("Test dataset:       {:7d} ( {:5.2f}%)".format(len(test), 100*len(test)/len(df)))
print("Validation dataset: {:7d} ( {:5.2f}%)".format(len(valid), 100*len(valid)/len(df)))
# Out:
# Total dataset:      2778506 (100.00%)
# Training dataset:   1944954 ( 70.00%)
# Test dataset:        416776 ( 15.00%)
# Validation dataset:  416776 ( 15.00%)

# %% [markdown]
# # XGBoost

# %%
from xgboost import XGBClassifier

# %%
# Train / Test partition:
X_train, y_train = train.drop("ARR_DEL15", axis=1), train["ARR_DEL15"]
X_test, y_test = test.drop("ARR_DEL15", axis=1), test["ARR_DEL15"]

# Validation:
X_valid, y_valid = valid.drop("ARR_DEL15", axis=1), valid["ARR_DEL15"]

# %%
# Basic model definition:
xgb_model = XGBClassifier(use_label_encoder=False, verbosity=1, random_state=0,
                          n_estimators=300,
                          max_depth= 4,
                          learning_rate=0.0001,
                          objective= 'binary:logistic',
                          booster='gbtree',
                          tree_method='auto')

# %% [markdown]
# ## Training

# %%
xgb_model.fit(X_train, y_train,
              eval_set=[(X_train, y_train), (X_test, y_test), (X_valid, y_valid)],
              eval_metric='auc',
              verbose=True)
# Out:
# [0]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [1]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [2]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [3]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [4]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [5]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [6]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [7]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [8]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [9]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [10]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [11]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [12]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [13]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [14]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [15]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [16]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [17]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [18]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [19]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [20]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [21]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [22]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [23]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [24]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [25]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [26]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [27]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [28]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [29]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [30]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [31]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [32]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [33]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [34]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [35]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [36]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [37]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [38]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [39]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [40]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [41]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [42]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [43]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [44]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [45]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [46]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [47]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [48]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [49]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [50]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [51]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [52]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [53]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [54]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [55]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [56]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [57]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [58]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [59]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [60]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [61]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [62]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [63]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [64]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [65]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [66]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [67]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [68]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [69]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [70]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [71]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [72]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [73]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [74]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [75]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [76]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [77]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [78]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [79]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [80]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [81]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [82]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [83]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [84]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [85]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [86]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [87]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [88]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [89]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [90]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [91]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [92]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [93]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [94]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [95]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [96]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [97]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [98]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [99]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [100]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [101]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [102]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [103]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [104]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [105]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [106]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [107]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [108]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [109]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [110]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [111]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [112]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [113]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [114]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [115]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [116]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [117]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [118]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [119]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [120]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [121]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [122]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [123]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [124]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [125]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [126]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [127]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [128]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [129]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [130]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [131]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [132]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [133]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [134]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [135]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [136]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [137]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [138]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [139]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [140]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [141]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [142]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [143]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [144]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [145]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [146]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [147]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [148]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [149]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [150]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [151]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [152]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [153]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [154]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [155]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [156]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [157]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [158]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [159]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [160]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [161]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [162]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [163]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [164]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [165]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [166]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [167]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [168]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [169]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [170]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [171]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [172]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [173]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [174]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [175]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [176]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [177]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [178]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [179]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [180]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [181]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [182]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [183]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [184]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [185]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [186]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [187]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [188]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [189]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [190]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [191]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [192]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [193]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [194]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [195]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [196]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [197]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [198]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [199]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [200]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [201]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [202]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [203]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [204]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [205]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [206]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [207]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [208]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [209]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [210]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [211]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [212]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [213]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [214]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [215]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [216]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [217]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [218]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [219]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [220]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [221]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [222]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [223]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [224]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [225]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [226]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [227]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [228]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [229]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [230]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [231]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [232]	validation_0-auc:0.56159	validation_1-auc:0.56143	validation_2-auc:0.56096
# [233]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [234]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [235]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [236]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [237]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [238]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [239]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [240]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [241]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [242]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [243]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [244]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [245]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [246]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [247]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [248]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [249]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [250]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [251]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [252]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [253]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [254]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [255]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [256]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [257]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [258]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [259]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [260]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [261]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [262]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [263]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [264]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [265]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [266]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [267]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [268]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [269]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [270]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [271]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [272]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [273]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [274]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [275]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [276]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [277]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [278]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [279]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [280]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [281]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [282]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [283]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [284]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [285]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [286]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [287]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [288]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [289]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [290]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [291]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [292]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [293]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [294]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [295]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [296]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [297]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [298]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# [299]	validation_0-auc:0.56159	validation_1-auc:0.56144	validation_2-auc:0.56096
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.0001, max_delta_step=0, max_depth=4,
#               min_child_weight=1, missing=nan, monotone_constraints='()',
#               n_estimators=300, n_jobs=4, num_parallel_tree=1, random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#               tree_method='auto', use_label_encoder=False,
#               validate_parameters=1, verbosity=1)

# %% [markdown]
# <em>
# Probar con:
#
# - `logloss`: negative log-likelihood
# - `auc`: Area under the curve. Available for binary classification and learning-to-rank tasks.
# - `aucpr`: Area under the PR curve. Available for binary classification and learning-to-rank tasks.
#
# Source: https://xgboost.readthedocs.io/en/latest/parameter.html
# </em>

# %%
# Get parameters:
xgb_model.get_params()
# Out:
# {'objective': 'binary:logistic',
#  'use_label_encoder': False,
#  'base_score': 0.5,
#  'booster': 'gbtree',
#  'colsample_bylevel': 1,
#  'colsample_bynode': 1,
#  'colsample_bytree': 1,
#  'gamma': 0,
#  'gpu_id': -1,
#  'importance_type': 'gain',
#  'interaction_constraints': '',
#  'learning_rate': 0.0001,
#  'max_delta_step': 0,
#  'max_depth': 4,
#  'min_child_weight': 1,
#  'missing': nan,
#  'monotone_constraints': '()',
#  'n_estimators': 300,
#  'n_jobs': 4,
#  'num_parallel_tree': 1,
#  'random_state': 0,
#  'reg_alpha': 0,
#  'reg_lambda': 1,
#  'scale_pos_weight': 1,
#  'subsample': 1,
#  'tree_method': 'auto',
#  'validate_parameters': 1,
#  'verbosity': 1}

# %% [markdown]
# ## Evaluation

# %% [markdown]
# ### Evaluation metric results (here, `auc`)

# %%
# Evaluation results for all passed eval_sets.
# Validation metrics will help us track the performance of the model:
evals_result = xgb_model.evals_result()
evals_result
# Out:
# {'validation_0': OrderedDict([('auc',
#                [0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561592,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561593,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594,
#                 0.561594])]),
#  'validation_1': OrderedDict([('auc',
#                [0.561434,
#                 0.561434,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561434,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561434,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561435,
#                 0.561435,
#                 0.561435,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561436,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437,
#                 0.561437])]),
#  'validation_2': OrderedDict([('auc',
#                [0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560956,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560956,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957,
#                 0.560957])])}

# %% [markdown]
# ### Additional metrics results

# %%
# Evaluate the model's metrics:

from sklearn.metrics import fbeta_score, f1_score, recall_score, precision_score, accuracy_score, \
                            confusion_matrix, roc_curve, roc_auc_score, plot_roc_curve

def clf_metrics(classifier, y_test, y_pred):
    print(confusion_matrix(y_test, y_pred))
    print("F-beta (ß=2) = {:6.3f}".format(fbeta_score(y_test, y_pred, beta=2)))   
    print("F1 =           {:6.3f}".format(f1_score(y_test, y_pred)))   
    print("Recall =       {:6.3f}".format(recall_score(y_test, y_pred)))   
    print("Precision =    {:6.3f}".format(precision_score(y_test, y_pred)))   
    print("Accuracy =     {:6.3f}".format(accuracy_score(y_test, y_pred)))

# %% [markdown]
# ### Test

# %%
y_train_pred = xgb_model.predict(X_train)
y_test_pred = xgb_model.predict(X_test)
y_valid_pred = xgb_model.predict(X_valid)
y_test_pred
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
print("   TRAINING dataset:")
clf_metrics(xgb_model, y_train, y_train_pred)
print("--------------------------------------------------")
print("   TEST dataset:")
clf_metrics(xgb_model, y_test, y_test_pred)
print("--------------------------------------------------")
print("   VALIDATION dataset:")
clf_metrics(xgb_model, y_valid, y_valid_pred)
# Out:
#    TRAINING dataset:
# [[251472 721156]
#  [136912 835414]]
# F-beta (ß=2) =  0.767
# F1 =            0.661
# Recall =        0.859
# Precision =     0.537
# Accuracy =      0.559
# --------------------------------------------------
#    TEST dataset:
# [[ 53866 154076]
#  [ 29594 179240]]
# F-beta (ß=2) =  0.767
# F1 =            0.661
# Recall =        0.858
# Precision =     0.538
# Accuracy =      0.559
# --------------------------------------------------
#    VALIDATION dataset:
# [[ 53866 154817]
#  [ 29447 178646]]
# F-beta (ß=2) =  0.766
# F1 =            0.660
# Recall =        0.858
# Precision =     0.536
# Accuracy =      0.558

# %% [markdown]
# ### ROC curve

# %%
y_train_probabilities = xgb_model.predict_proba(X_train)[:,1]
y_test_probabilities = xgb_model.predict_proba(X_test)[:,1]
y_valid_probabilities = xgb_model.predict_proba(X_valid)[:,1]
y_test_probabilities[:10]
# Out:
# array([0.50108474, 0.50108474, 0.50108474, 0.50108474, 0.49531645,
#        0.50108474, 0.50108474, 0.50108474, 0.50108474, 0.50108474],
#       dtype=float32)

# %%
fpr_train, tpr_train, _ = roc_curve(y_train,  y_train_probabilities)
fpr_test, tpr_test, _ = roc_curve(y_test,  y_test_probabilities)
fpr_valid, tpr_valid, _ = roc_curve(y_valid,  y_valid_probabilities)

auc_train = roc_auc_score(y_train, y_train_probabilities)
auc_test = roc_auc_score(y_test, y_test_probabilities)
auc_valid = roc_auc_score(y_valid, y_valid_probabilities)

# %%
# Plot the figure:
fig, ax = plt.subplots(figsize=(6,6))

plot_roc_curve(xgb_model, X_train, y_train, color='red', ax=ax, name='XGBoost_train')
plot_roc_curve(xgb_model, X_test, y_test, color='blue', ax=ax, name='XGBoost_test')
plot_roc_curve(xgb_model, X_valid, y_valid, color='green', ax=ax, name='XGBoost_valid')
plt.plot([0,1], [0,1], color='orange', linestyle='--')

plt.xticks(np.arange(0.0, 1.1, step=0.1))
plt.xlabel("fpr", fontsize=15)

plt.yticks(np.arange(0.0, 1.1, step=0.1))
plt.ylabel("tpr", fontsize=15)

plt.title('ROC Curve Analysis', fontweight='bold', fontsize=15)
plt.legend(prop={'size':13}, loc='lower right')

# %% [markdown]
# ## Plotting

# %% [markdown]
# ### Feature importance (data)

# %%
# Let's build a dictionary to better see each feature with its corresponding importance:
feature_importance_dict = dict(zip(X_train.columns, xgb_model.feature_importances_))
feature_importance_dict
# Out:
# {'TAXI_OUT_median': 0.0,
#  'TAXI_IN_median': 0.00089107134,
#  'CRS_ELAPSED_TIME': 0.0,
#  'DISTANCE': 0.0019627041,
#  'MONTH_1': 0.0,
#  'MONTH_2': 0.0024001996,
#  'MONTH_3': 0.0,
#  'MONTH_4': 0.0,
#  'MONTH_5': 0.0,
#  'MONTH_6': 0.0,
#  'MONTH_7': 0.0,
#  'MONTH_8': 0.0,
#  'MONTH_9': 0.0,
#  'MONTH_10': 0.0,
#  'MONTH_11': 0.0,
#  'MONTH_12': 0.0,
#  'DAY_OF_MONTH_1': 0.0003926203,
#  'DAY_OF_MONTH_2': 0.0,
#  'DAY_OF_MONTH_3': 0.0,
#  'DAY_OF_MONTH_4': 0.0,
#  'DAY_OF_MONTH_5': 0.0,
#  'DAY_OF_MONTH_6': 0.0,
#  'DAY_OF_MONTH_7': 0.0,
#  'DAY_OF_MONTH_8': 0.0,
#  'DAY_OF_MONTH_9': 0.0,
#  'DAY_OF_MONTH_10': 0.0,
#  'DAY_OF_MONTH_11': 0.0,
#  'DAY_OF_MONTH_12': 0.0,
#  'DAY_OF_MONTH_13': 0.0,
#  'DAY_OF_MONTH_14': 0.0,
#  'DAY_OF_MONTH_15': 0.0,
#  'DAY_OF_MONTH_16': 0.0,
#  'DAY_OF_MONTH_17': 0.0,
#  'DAY_OF_MONTH_18': 0.0,
#  'DAY_OF_MONTH_19': 0.0,
#  'DAY_OF_MONTH_20': 0.0,
#  'DAY_OF_MONTH_21': 0.0,
#  'DAY_OF_MONTH_22': 0.0,
#  'DAY_OF_MONTH_23': 0.0,
#  'DAY_OF_MONTH_24': 0.0,
#  'DAY_OF_MONTH_25': 0.0,
#  'DAY_OF_MONTH_26': 0.0,
#  'DAY_OF_MONTH_27': 0.0,
#  'DAY_OF_MONTH_28': 0.0,
#  'DAY_OF_MONTH_29': 0.0,
#  'DAY_OF_MONTH_30': 0.0,
#  'DAY_OF_MONTH_31': 0.0,
#  'DAY_OF_WEEK_1': 0.0,
#  'DAY_OF_WEEK_2': 0.0,
#  'DAY_OF_WEEK_3': 0.0,
#  'DAY_OF_WEEK_4': 0.0,
#  'DAY_OF_WEEK_5': 0.0,
#  'DAY_OF_WEEK_6': 0.0,
#  'DAY_OF_WEEK_7': 0.0,
#  'OP_UNIQUE_CARRIER_9E': 0.0,
#  'OP_UNIQUE_CARRIER_AA': 0.0,
#  'OP_UNIQUE_CARRIER_AS': 0.0,
#  'OP_UNIQUE_CARRIER_B6': 0.0,
#  'OP_UNIQUE_CARRIER_DL': 0.009034523,
#  'OP_UNIQUE_CARRIER_EV': 0.0,
#  'OP_UNIQUE_CARRIER_F9': 0.0,
#  'OP_UNIQUE_CARRIER_G4': 0.0,
#  'OP_UNIQUE_CARRIER_HA': 0.0,
#  'OP_UNIQUE_CARRIER_MQ': 0.0,
#  'OP_UNIQUE_CARRIER_NK': 0.0,
#  'OP_UNIQUE_CARRIER_OH': 0.0,
#  'OP_UNIQUE_CARRIER_OO': 0.0,
#  'OP_UNIQUE_CARRIER_UA': 0.0,
#  'OP_UNIQUE_CARRIER_WN': 0.022307005,
#  'OP_UNIQUE_CARRIER_YV': 0.0,
#  'OP_UNIQUE_CARRIER_YX': 0.0,
#  'DEP_TIME_hour_0': 0.17949238,
#  'DEP_TIME_hour_6': 0.3837043,
#  'DEP_TIME_hour_7': 0.22443183,
#  'DEP_TIME_hour_8': 0.17538324,
#  'DEP_TIME_hour_9': 0.0,
#  'DEP_TIME_hour_10': 0.0,
#  'DEP_TIME_hour_11': 0.0,
#  'DEP_TIME_hour_12': 0.0,
#  'DEP_TIME_hour_13': 0.0,
#  'DEP_TIME_hour_14': 0.0,
#  'DEP_TIME_hour_15': 0.0,
#  'DEP_TIME_hour_16': 0.0,
#  'DEP_TIME_hour_17': 0.0,
#  'DEP_TIME_hour_18': 0.0,
#  'DEP_TIME_hour_19': 0.0,
#  'DEP_TIME_hour_20': 0.0,
#  'DEP_TIME_hour_21': 0.0,
#  'DEP_TIME_hour_22': 0.0,
#  'DEP_TIME_hour_23': 0.0,
#  'ARR_TIME_hour_0': 0.0,
#  'ARR_TIME_hour_6': 0.0,
#  'ARR_TIME_hour_7': 0.0,
#  'ARR_TIME_hour_8': 0.0,
#  'ARR_TIME_hour_9': 0.0,
#  'ARR_TIME_hour_10': 0.0,
#  'ARR_TIME_hour_11': 0.0,
#  'ARR_TIME_hour_12': 0.0,
#  'ARR_TIME_hour_13': 0.0,
#  'ARR_TIME_hour_14': 0.0,
#  'ARR_TIME_hour_15': 0.0,
#  'ARR_TIME_hour_16': 0.0,
#  'ARR_TIME_hour_17': 0.0,
#  'ARR_TIME_hour_18': 0.0,
#  'ARR_TIME_hour_19': 0.0,
#  'ARR_TIME_hour_20': 0.0,
#  'ARR_TIME_hour_21': 0.0,
#  'ARR_TIME_hour_22': 0.0,
#  'ARR_TIME_hour_23': 0.0,
#  'DISTANCE_GROUP_1': 0.0,
#  'DISTANCE_GROUP_2': 0.0,
#  'DISTANCE_GROUP_3': 0.0,
#  'DISTANCE_GROUP_4': 0.0,
#  'DISTANCE_GROUP_5': 0.0,
#  'DISTANCE_GROUP_6': 0.0,
#  'DISTANCE_GROUP_7': 0.0,
#  'DISTANCE_GROUP_8': 0.0,
#  'DISTANCE_GROUP_9': 0.0,
#  'DISTANCE_GROUP_10': 0.0,
#  'DISTANCE_GROUP_11': 0.0}

# %% [markdown]
# ### Feature importance (plot)

# %% [markdown]
# #### Weight-based

# %%
from xgboost import plot_importance

fig,ax = plt.subplots(figsize=(5,5))

plot_importance(booster=xgb_model,
                ax=ax,
                grid=True,
                importance_type='weight', # ”weight” is the number of times a feature appears in a tree
                max_num_features=None, 
                height=0.5,
                xlim=None,
                ylim=None, 
                title='Feature importance (WEIGHT-based)',
                xlabel='F score',
                ylabel='Features',
                show_values=True);

# %% [markdown]
# #### Gain-based

# %%
from xgboost import plot_importance

fig,ax = plt.subplots(figsize=(5,5))

plot_importance(booster=xgb_model,
                ax=ax,
                grid=True,
                importance_type='gain', # ”weight” is the number of times a feature appears in a tree
                max_num_features=None, 
                height=0.5,
                xlim=None,
                ylim=None, 
                title='Feature importance (GAIN-based)',
                xlabel='F score',
                ylabel='Features',
                show_values=True);

# %% [markdown]
# ### Tree

# %%
from xgboost import plot_tree

fig,ax = plt.subplots(figsize=(80,50))

plot_tree(booster=xgb_model,
          num_trees=0,
          ax=ax)

plt.savefig('plot_tree_12.png')

# %% [markdown]
# ### Graphviz (tree)

# %% [markdown]
# *Convert specified tree to graphviz instance. IPython can automatically plot the returned graphiz instance. Otherwise, you should call `.render()` method of the returned graphiz instance.*

# %%
from xgboost import to_graphviz

tree_graphviz = to_graphviz(booster=xgb_model,
                            yes_color='#0000FF',
                            no_color='#FF0000',
                            condition_node_params={'shape': 'box',
                                                   'style': 'filled,rounded',
                                                   'fillcolor': '#78bceb'},
                            leaf_node_params={'shape': 'box',
                                              'style': 'filled',
                                              'fillcolor': '#e48038'})

format = 'png'
tree_graphviz = to_graphviz(xgb_model)
tree_graphviz.graph_attr = {'dpi':'400'}
tree_graphviz.render('tree_graphviz_12', format = format)
# Out:
# 'tree_graphviz_12.png'

# %% [markdown]
# ___

# %%
t1 = time.perf_counter() - t0
print("Time elapsed: {:2.0f}h {:2.0f}min {:2.0f}s".format(t1//3600, (t1%3600)//60, (t1%3600)%60))
# Out:
# Time elapsed:  0h 30min 12s

# %% [raw]
# Time elapsed:  0h 30min 12s

# %% [markdown]
# ## Save the model

# %%
from joblib import dump, load

# Save model to file:
dump(xgb_model, "XGBoost_12.joblib.dat")
print("Saved model to: XGBoost_12.joblib.dat")
# Out:
# Saved model to: XGBoost_12.joblib.dat

# %%
# Load model from file:
loaded_model = load("XGBoost_12.joblib.dat")
print("Loaded model from: XGBoost_12.joblib.dat")
# Out:
# Loaded model from: XGBoost_12.joblib.dat

# %%
# Make predictions for test data
predictions = loaded_model.predict(X_test)

# Evaluate predictions:
recall = recall_score(y_test, predictions)
print("Loaded model recall: {:6.3f}".format(recall))
# Out:
# Loaded model recall:  0.858

# %% [markdown]
# ___

# %% [markdown]
# ___
